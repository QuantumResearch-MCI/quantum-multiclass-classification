# %%
# !python -m pip install numpy pandas \
    qiskit-aer qiskit-algorithms qiskit-machine-learning qiskit-ibm-runtime \
    pylatexenc ucimlrepo \
    xgboost catboost seaborn libsvm-official \
    jinja2 \
    scikit-optimize
# Out:
# Requirement already satisfied: numpy in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (2.4.4)
# Requirement already satisfied: pandas in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.0.2)
# Requirement already satisfied: qiskit-aer in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.17.2)
# Requirement already satisfied: qiskit-algorithms in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.4.0)
# Requirement already satisfied: qiskit-machine-learning in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.9.0)
# Requirement already satisfied: qiskit-ibm-runtime in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.46.1)
# Requirement already satisfied: pylatexenc in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (2.10)
# Requirement already satisfied: ucimlrepo in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.0.7)
# Requirement already satisfied: xgboost in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.2.0)
# Requirement already satisfied: catboost in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (1.2.10)
# Requirement already satisfied: seaborn in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.13.2)
# Requirement already satisfied: libsvm-official in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.37.0)
# Requirement already satisfied: jinja2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.1.6)
# Requirement already satisfied: scikit-optimize in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.10.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: qiskit>=1.1.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-aer) (2.3.1)
# Requirement already satisfied: scipy>=1.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-aer) (1.17.1)
# Requirement already satisfied: psutil>=5 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: scikit-learn>=1.2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-machine-learning) (1.8.0)
# Requirement already satisfied: setuptools>=40.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-machine-learning) (82.0.1)
# Requirement already satisfied: dill>=0.3.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-machine-learning) (0.4.1)
# Requirement already satisfied: requests>=2.32.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (2.33.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: urllib3>=2.4.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: ibm-platform-services>=0.55.3 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (0.75.0)
# Requirement already satisfied: ibm-quantum-schemas>=0.5.20260320 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (0.6.20260414)
# Requirement already satisfied: pydantic>=2.7.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (2.13.0)
# Requirement already satisfied: packaging in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (26.1)
# Requirement already satisfied: pybase64>=1.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (1.4.3)
# Requirement already satisfied: samplomatic>=0.13.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (0.18.0)
# Requirement already satisfied: certifi>=2020.12.5 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from ucimlrepo) (2026.2.25)
# Requirement already satisfied: graphviz in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (3.10.8)
# Requirement already satisfied: plotly in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (6.7.0)
# Requirement already satisfied: six in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from jinja2) (3.0.3)
# Requirement already satisfied: joblib>=0.11 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from scikit-optimize) (1.5.3)
# Requirement already satisfied: pyaml>=16.9 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from scikit-optimize) (26.2.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (2.12.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (2.46.0)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: PyYAML in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0.3)
# Requirement already satisfied: cryptography>=1.3 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.7)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Requirement already satisfied: sspilib>=0.3.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.5.0)
# Requirement already satisfied: orjson>=3.9.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from samplomatic>=0.13.0->qiskit-ibm-runtime) (3.11.8)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from plotly->catboost) (2.19.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
project_root = Path(os.environ["PROJECT_ROOT"])
print(f"Project root: {project_root}")

sys.path.append(os.path.abspath(project_root))

from utils.prepare_data import prepare_data
# Out:
# Project root: c:\`Bioinformatics\quantum-gesang\codes

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import warnings
from qiskit.transpiler import generate_preset_pass_manager
warnings.filterwarnings('ignore')

# %%
import sys
import importlib

def reload_package(package_name):
    modules_to_reload = [
        name for name in sys.modules
        if name.startswith(package_name)
    ]

    for name in sorted(modules_to_reload, reverse=True):
        importlib.reload(sys.modules[name])

# Usage
reload_package("model")
reload_package("utils")

# %%
dataset_path = os.path.join(project_root, "dataset", "Dataset_TehHijau.csv")
feature_cols = [
        "MQ3", 
        "TGS822", 
        "TGS2602", 
        "MQ5", 
        "MQ138", 
        "TGS2620", 
        "TGS813", 
        "TGS2600", 
        "TGS2611", 
        "TGS2603",
        "Humidity",
        "Celsius",
    ]
target_cols = "Kategori"

quantum_kernel_types = [
    # 'full', 
    'linear', 
    # 'circular', 
    # 'pauli_x', 
    # 'pauli_y', 
    # 'pauli_z'
]
kernel_types = [
    'linear', 
    # 'poly', 
    # 'rbf', 
    # 'sigmoid'
]

# %%
import pandas as pd
data = pd.read_csv(dataset_path)
data.head(10)
# Out:
#     MQ3  TGS822  TGS2602    MQ5  MQ138  TGS2620  TGS813  TGS2600  TGS2611  \
# 0  90.0    43.0     46.0  133.0   97.0     46.0   552.0    289.0    546.0
# 1  90.0    42.0     47.0  133.0   96.0     47.0   551.0    290.0    547.0
# 2  89.0    42.0     47.0  133.0   97.0     45.0   553.0    291.0    547.0
# 3  89.0    41.0     47.0  133.0   96.0     45.0   552.0    290.0    546.0
# 4  90.0    42.0     48.0  132.0   95.0     46.0   552.0    289.0    546.0
# 5  90.0    42.0     46.0  132.0   96.0     45.0   552.0    289.0    545.0
# 6  89.0    43.0     46.0  133.0   96.0     45.0   552.0    291.0    546.0
# 7  90.0    42.0     46.0  132.0   96.0     46.0   551.0    290.0    547.0
# 8  90.0    41.0     47.0  132.0   97.0     46.0   550.0    290.0    548.0
# 9  90.0    41.0     48.0  132.0   95.0     46.0   551.0    289.0    547.0
#
#    TGS2603  Humidity  Celsius Chop_ID Sampling_ID  Aroma  Taste  Color  \
# 0    371.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 1    371.0      46.5     38.9   TR612     TR612_1    2.9     36    3.2
# 2    369.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 3    370.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 4    371.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 5    370.0      46.5     38.8   TR612     TR612_1    2.9     36    3.2
# 6    369.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 7    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 8    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 9    371.0      46.3     38.7   TR612     TR612_1    2.9     36    3.2
#
#    Appearance  Dreg Kategori Standar Kualitas  MQ3_mean  MQ3_min  MQ3_max  \
# 0         2.8   3.2        D             Baik      89.7     89.0       90
# 1         2.8   3.2        D             Baik      89.7     89.0       90
# 2         2.8   3.2        D             Baik      89.7     89.0       90
# 3         2.8   3.2        D             Baik      89.7     89.0       90
# 4         2.8   3.2        D             Baik      89.7     89.0       90
# 5         2.8   3.2        D             Baik      89.7     89.0       90
# 6         2.8   3.2        D             Baik      89.7     89.0       90
# 7         2.8   3.2        D             Baik      89.7     89.0       90
# 8         2.8   3.2        D             Baik      89.7     89.0       90
# 9         2.8   3.2        D             Baik      89.7     89.0       90
#
#     MQ3_std  MQ3_skew  MQ3_kurtosis  MQ3_auc  TGS822_mean  TGS822_min  \
# 0  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 1  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 2  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 3  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 4  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 5  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 6  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 7  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 8  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 9  0.483046 -0.872872     -1.238095    807.0         41.9          41
#
#    TGS822_max  TGS822_std  TGS822_skew  TGS822_kurtosis  TGS822_auc  \
# 0          43    0.737865     0.139942        -0.960433       377.0
# 1          43    0.737865     0.139942        -0.960433       377.0
# 2          43    0.737865     0.139942        -0.960433       377.0
# 3          43    0.737865     0.139942        -0.960433       377.0
# 4          43    0.737865     0.139942        -0.960433       377.0
# 5          43    0.737865     0.139942        -0.960433       377.0
# 6          43    0.737865     0.139942        -0.960433       377.0
# 7          43    0.737865     0.139942        -0.960433       377.0
# 8          43    0.737865     0.139942        -0.960433       377.0
# 9          43    0.737865     0.139942        -0.960433       377.0
#
#    TGS2602_mean  TGS2602_min  TGS2602_max  TGS2602_std  TGS2602_skew  \
# 0          46.8           46           48     0.788811      0.343622
# 1          46.8           46           48     0.788811      0.343622
# 2          46.8           46           48     0.788811      0.343622
# 3          46.8           46           48     0.788811      0.343622
# 4          46.8           46           48     0.788811      0.343622
# 5          46.8           46           48     0.788811      0.343622
# 6          46.8           46           48     0.788811      0.343622
# 7          46.8           46           48     0.788811      0.343622
# 8          46.8           46           48     0.788811      0.343622
# 9          46.8           46           48     0.788811      0.343622
#
#    TGS2602_kurtosis  TGS2602_auc  MQ5_mean  MQ5_min  MQ5_max   MQ5_std  \
# 0         -1.153061        421.0     132.5      132    133.0  0.527046
# 1         -1.153061        421.0     132.5      132    133.0  0.527046
# 2         -1.153061        421.0     132.5      132    133.0  0.527046
# 3         -1.153061        421.0     132.5      132    133.0  0.527046
# 4         -1.153061        421.0     132.5      132    133.0  0.527046
# 5         -1.153061        421.0     132.5      132    133.0  0.527046
# 6         -1.153061        421.0     132.5      132    133.0  0.527046
# 7         -1.153061        421.0     132.5      132    133.0  0.527046
# 8         -1.153061        421.0     132.5      132    133.0  0.527046
# 9         -1.153061        421.0     132.5      132    133.0  0.527046
#
#    MQ5_skew  MQ5_kurtosis  MQ5_auc  MQ138_mean  MQ138_min  MQ138_max  \
# 0       0.0          -2.0   1192.5        96.1         95         97
# 1       0.0          -2.0   1192.5        96.1         95         97
# 2       0.0          -2.0   1192.5        96.1         95         97
# 3       0.0          -2.0   1192.5        96.1         95         97
# 4       0.0          -2.0   1192.5        96.1         95         97
# 5       0.0          -2.0   1192.5        96.1         95         97
# 6       0.0          -2.0   1192.5        96.1         95         97
# 7       0.0          -2.0   1192.5        96.1         95         97
# 8       0.0          -2.0   1192.5        96.1         95         97
# 9       0.0          -2.0   1192.5        96.1         95         97
#
#    MQ138_std  MQ138_skew  MQ138_kurtosis  MQ138_auc  TGS2620_mean  \
# 0   0.737865   -0.139942       -0.960433      865.0          45.7
# 1   0.737865   -0.139942       -0.960433      865.0          45.7
# 2   0.737865   -0.139942       -0.960433      865.0          45.7
# 3   0.737865   -0.139942       -0.960433      865.0          45.7
# 4   0.737865   -0.139942       -0.960433      865.0          45.7
# 5   0.737865   -0.139942       -0.960433      865.0          45.7
# 6   0.737865   -0.139942       -0.960433      865.0          45.7
# 7   0.737865   -0.139942       -0.960433      865.0          45.7
# 8   0.737865   -0.139942       -0.960433      865.0          45.7
# 9   0.737865   -0.139942       -0.960433      865.0          45.7
#
#    TGS2620_min  TGS2620_max  TGS2620_std  TGS2620_skew  TGS2620_kurtosis  \
# 0           45           47     0.674949      0.365675         -0.705532
# 1           45           47     0.674949      0.365675         -0.705532
# 2           45           47     0.674949      0.365675         -0.705532
# 3           45           47     0.674949      0.365675         -0.705532
# 4           45           47     0.674949      0.365675         -0.705532
# 5           45           47     0.674949      0.365675         -0.705532
# 6           45           47     0.674949      0.365675         -0.705532
# 7           45           47     0.674949      0.365675         -0.705532
# 8           45           47     0.674949      0.365675         -0.705532
# 9           45           47     0.674949      0.365675         -0.705532
#
#    TGS2620_auc  TGS813_mean  TGS813_min  TGS813_max  TGS813_std  TGS813_skew  \
# 0        411.0        551.6         550         553    0.843274    -0.328125
# 1        411.0        551.6         550         553    0.843274    -0.328125
# 2        411.0        551.6         550         553    0.843274    -0.328125
# 3        411.0        551.6         550         553    0.843274    -0.328125
# 4        411.0        551.6         550         553    0.843274    -0.328125
# 5        411.0        551.6         550         553    0.843274    -0.328125
# 6        411.0        551.6         550         553    0.843274    -0.328125
# 7        411.0        551.6         550         553    0.843274    -0.328125
# 8        411.0        551.6         550         553    0.843274    -0.328125
# 9        411.0        551.6         550         553    0.843274    -0.328125
#
#    TGS813_kurtosis  TGS813_auc  TGS2600_mean  TGS2600_min  TGS2600_max  \
# 0        -0.335937      4964.5         289.8        289.0          291
# 1        -0.335937      4964.5         289.8        289.0          291
# 2        -0.335937      4964.5         289.8        289.0          291
# 3        -0.335937      4964.5         289.8        289.0          291
# 4        -0.335937      4964.5         289.8        289.0          291
# 5        -0.335937      4964.5         289.8        289.0          291
# 6        -0.335937      4964.5         289.8        289.0          291
# 7        -0.335937      4964.5         289.8        289.0          291
# 8        -0.335937      4964.5         289.8        289.0          291
# 9        -0.335937      4964.5         289.8        289.0          291
#
#    TGS2600_std  TGS2600_skew  TGS2600_kurtosis  TGS2600_auc  TGS2611_mean  \
# 0     0.788811      0.343622         -1.153061       2609.0         546.5
# 1     0.788811      0.343622         -1.153061       2609.0         546.5
# 2     0.788811      0.343622         -1.153061       2609.0         546.5
# 3     0.788811      0.343622         -1.153061       2609.0         546.5
# 4     0.788811      0.343622         -1.153061       2609.0         546.5
# 5     0.788811      0.343622         -1.153061       2609.0         546.5
# 6     0.788811      0.343622         -1.153061       2609.0         546.5
# 7     0.788811      0.343622         -1.153061       2609.0         546.5
# 8     0.788811      0.343622         -1.153061       2609.0         546.5
# 9     0.788811      0.343622         -1.153061       2609.0         546.5
#
#    TGS2611_min  TGS2611_max  TGS2611_std  TGS2611_skew  TGS2611_kurtosis  \
# 0          545          548     0.849837           0.0         -0.485207
# 1          545          548     0.849837           0.0         -0.485207
# 2          545          548     0.849837           0.0         -0.485207
# 3          545          548     0.849837           0.0         -0.485207
# 4          545          548     0.849837           0.0         -0.485207
# 5          545          548     0.849837           0.0         -0.485207
# 6          545          548     0.849837           0.0         -0.485207
# 7          545          548     0.849837           0.0         -0.485207
# 8          545          548     0.849837           0.0         -0.485207
# 9          545          548     0.849837           0.0         -0.485207
#
#    TGS2611_auc  TGS2603_mean  TGS2603_min  TGS2603_max  TGS2603_std  \
# 0       4918.5         370.2          369          371     0.788811
# 1       4918.5         370.2          369          371     0.788811
# 2       4918.5         370.2          369          371     0.788811
# 3       4918.5         370.2          369          371     0.788811
# 4       4918.5         370.2          369          371     0.788811
# 5       4918.5         370.2          369          371     0.788811
# 6       4918.5         370.2          369          371     0.788811
# 7       4918.5         370.2          369          371     0.788811
# 8       4918.5         370.2          369          371     0.788811
# 9       4918.5         370.2          369          371     0.788811
#
#    TGS2603_skew  TGS2603_kurtosis  TGS2603_auc  Humidity_mean  Humidity_min  \
# 0     -0.343622         -1.153061       3331.0          46.43          46.3
# 1     -0.343622         -1.153061       3331.0          46.43          46.3
# 2     -0.343622         -1.153061       3331.0          46.43          46.3
# 3     -0.343622         -1.153061       3331.0          46.43          46.3
# 4     -0.343622         -1.153061       3331.0          46.43          46.3
# 5     -0.343622         -1.153061       3331.0          46.43          46.3
# 6     -0.343622         -1.153061       3331.0          46.43          46.3
# 7     -0.343622         -1.153061       3331.0          46.43          46.3
# 8     -0.343622         -1.153061       3331.0          46.43          46.3
# 9     -0.343622         -1.153061       3331.0          46.43          46.3
#
#    Humidity_max  Humidity_std  Humidity_skew  Humidity_kurtosis  Humidity_auc  \
# 0          46.5      0.067495      -0.365675          -0.705532        417.95
# 1          46.5      0.067495      -0.365675          -0.705532        417.95
# 2          46.5      0.067495      -0.365675          -0.705532        417.95
# 3          46.5      0.067495      -0.365675          -0.705532        417.95
# 4          46.5      0.067495      -0.365675          -0.705532        417.95
# 5          46.5      0.067495      -0.365675          -0.705532        417.95
# 6          46.5      0.067495      -0.365675          -0.705532        417.95
# 7          46.5      0.067495      -0.365675          -0.705532        417.95
# 8          46.5      0.067495      -0.365675          -0.705532        417.95
# 9          46.5      0.067495      -0.365675          -0.705532        417.95
#
#    Celsius_mean  Celsius_min  Celsius_max  Celsius_std  Celsius_skew  \
# 0         38.81         38.7         38.9      0.08756      -0.18843
# 1         38.81         38.7         38.9      0.08756      -0.18843
# 2         38.81         38.7         38.9      0.08756      -0.18843
# 3         38.81         38.7         38.9      0.08756      -0.18843
# 4         38.81         38.7         38.9      0.08756      -0.18843
# 5         38.81         38.7         38.9      0.08756      -0.18843
# 6         38.81         38.7         38.9      0.08756      -0.18843
# 7         38.81         38.7         38.9      0.08756      -0.18843
# 8         38.81         38.7         38.9      0.08756      -0.18843
# 9         38.81         38.7         38.9      0.08756      -0.18843
#
#    Celsius_kurtosis  Celsius_auc  Aroma_mean  Aroma_min  Aroma_max  \
# 0          -1.52615        349.3         2.9        2.9        2.9
# 1          -1.52615        349.3         2.9        2.9        2.9
# 2          -1.52615        349.3         2.9        2.9        2.9
# 3          -1.52615        349.3         2.9        2.9        2.9
# 4          -1.52615        349.3         2.9        2.9        2.9
# 5          -1.52615        349.3         2.9        2.9        2.9
# 6          -1.52615        349.3         2.9        2.9        2.9
# 7          -1.52615        349.3         2.9        2.9        2.9
# 8          -1.52615        349.3         2.9        2.9        2.9
# 9          -1.52615        349.3         2.9        2.9        2.9
#
#       Aroma_std  Aroma_auc  Taste_mean  Taste_min  Taste_max  Taste_std  \
# 0  4.681111e-16       26.1          36         36         36          0
# 1  4.681111e-16       26.1          36         36         36          0
# 2  4.681111e-16       26.1          36         36         36          0
# 3  4.681111e-16       26.1          36         36         36          0
# 4  4.681111e-16       26.1          36         36         36          0
# 5  4.681111e-16       26.1          36         36         36          0
# 6  4.681111e-16       26.1          36         36         36          0
# 7  4.681111e-16       26.1          36         36         36          0
# 8  4.681111e-16       26.1          36         36         36          0
# 9  4.681111e-16       26.1          36         36         36          0
#
#    Taste_auc  Color_mean  Color_min  Color_max     Color_std  Color_auc  \
# 0        324         3.2        3.2        3.2  4.681111e-16       28.8
# 1        324         3.2        3.2        3.2  4.681111e-16       28.8
# 2        324         3.2        3.2        3.2  4.681111e-16       28.8
# 3        324         3.2        3.2        3.2  4.681111e-16       28.8
# 4        324         3.2        3.2        3.2  4.681111e-16       28.8
# 5        324         3.2        3.2        3.2  4.681111e-16       28.8
# 6        324         3.2        3.2        3.2  4.681111e-16       28.8
# 7        324         3.2        3.2        3.2  4.681111e-16       28.8
# 8        324         3.2        3.2        3.2  4.681111e-16       28.8
# 9        324         3.2        3.2        3.2  4.681111e-16       28.8
#
#    Appearance_mean  Appearance_min  Appearance_max  Appearance_std  \
# 0              2.8             2.8             2.8    4.681111e-16
# 1              2.8             2.8             2.8    4.681111e-16
# 2              2.8             2.8             2.8    4.681111e-16
# 3              2.8             2.8             2.8    4.681111e-16
# 4              2.8             2.8             2.8    4.681111e-16
# 5              2.8             2.8             2.8    4.681111e-16
# 6              2.8             2.8             2.8    4.681111e-16
# 7              2.8             2.8             2.8    4.681111e-16
# 8              2.8             2.8             2.8    4.681111e-16
# 9              2.8             2.8             2.8    4.681111e-16
#
#    Appearance_auc  Dreg_mean  Dreg_min  Dreg_max      Dreg_std  Dreg_auc
# 0            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 1            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 2            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 3            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 4            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 5            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 6            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 7            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 8            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 9            25.2        3.2       3.2       3.2  4.681111e-16      28.8

# %%
data.describe()
# Out:
#                 MQ3        TGS822       TGS2602           MQ5         MQ138  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      89.414833     47.600730     47.936209     98.291575     89.182246
# std        3.669168      4.678116      4.616558     15.849443      4.209028
# min       80.000000     37.000000     36.000000     64.000000     78.000000
# 25%       87.000000     45.000000     45.000000     88.000000     86.000000
# 50%       89.000000     47.000000     47.000000     96.000000     89.000000
# 75%       91.000000     50.000000     50.000000    109.000000     92.000000
# max      101.000000     64.000000     64.000000    188.000000    103.000000
#
#             TGS2620        TGS813       TGS2600       TGS2611       TGS2603  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      51.548756    533.670093    213.738592    531.124604    330.500336
# std        4.967588      7.007443     24.613671      5.552207     12.907070
# min       39.000000    514.000000    186.000000    518.000000    303.000000
# 25%       49.000000    529.000000    198.000000    527.000000    322.000000
# 50%       51.000000    532.000000    206.000000    530.000000    329.000000
# 75%       54.000000    536.000000    215.000000    533.000000    335.000000
# max       80.000000    554.000000    304.000000    548.000000    371.000000
#
#            Humidity       Celsius         Aroma         Taste         Color  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      48.387732     39.656701      2.935143     34.888942      3.035383
# std        3.126527      1.312791      0.257778      1.732650      0.255256
# min       39.200000     36.000000      2.400000     31.000000      2.400000
# 25%       46.300000     38.900000      2.800000     33.000000      2.800000
# 50%       48.500000     39.600000      2.900000     35.000000      3.000000
# 75%       50.400000     40.600000      3.100000     36.000000      3.200000
# max       60.200000     43.600000      3.800000     38.000000      3.700000
#
#          Appearance          Dreg      MQ3_mean       MQ3_min       MQ3_max  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean       3.135306      3.071880     89.401187     88.072610     90.838121
# std        0.270518      0.307778      4.282145      7.651619     21.264395
# min        2.800000      2.400000     72.380000      0.000000     82.000000
# 25%        2.900000      2.800000     87.100000     86.000000     88.000000
# 50%        3.100000      3.000000     89.200000     88.000000     90.000000
# 75%        3.300000      3.200000     91.100000     90.000000     92.000000
# max        3.800000      3.900000    160.200000    100.000000    803.000000
#
#             MQ3_std      MQ3_skew  MQ3_kurtosis       MQ3_auc   TGS822_mean  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean       0.983066      0.031130     -0.497871    797.282995     51.381383
# std        7.032746      0.840692      1.501362     52.931071    134.638191
# min        0.316228     -2.666667     -2.000000    511.500000     35.100000
# 25%        0.516398     -0.365675     -1.333333    781.500000     44.900000
# 50%        0.567646      0.000000     -0.705532    800.000000     46.900000
# 75%        0.674949      0.408248      0.154260    819.000000     50.300000
# max      225.857280      2.666667      5.111111   1513.000000   4902.100000
#
#          TGS822_min    TGS822_max    TGS822_std   TGS822_skew  \
# count  10409.000000  10409.000000  10409.000000  10409.000000
# mean      46.428283     86.377366     12.767992      0.047886
# std        5.136031   1345.593517    425.520299      0.552556
# min        0.000000     39.000000      0.316228     -2.666667
# 25%       44.000000     46.000000      0.674949     -0.223607
# 50%       46.000000     48.000000      0.788811      0.000000
# 75%       49.000000     51.000000      0.918937      0.365675
# max       61.000000  48600.000000  15353.877024      2.666667
#
#        TGS822_kurtosis    TGS822_auc  TGS2602_mean   TGS2602_min  \
# count     10409.000000  10409.000000  10409.000000  10409.000000
# mean         -0.767730    461.091603     48.923492     46.665674
# std           0.759330   1346.620866     27.219648      5.088537
# min          -2.000000    244.500000     35.900000      0.000000
# 25%          -1.213319    397.500000     45.600000     44.000000
# 50%          -0.897959    421.500000     47.200000     46.000000
# 75%          -0.444444    451.000000     50.300000     49.000000
# max           5.111111  48975.000000    959.200000     61.000000
#
#         TGS2602_max   TGS2602_std  TGS2602_skew  TGS2602_kurtosis  \
# count  10409.000000  10409.000000  10409.000000      10409.000000
# mean      56.401095      3.417439      0.042129         -0.742829
# std      180.916345     64.156847      0.547445          0.739631
# min       38.000000      0.316228     -2.661423         -2.000000
# 25%       47.000000      0.707107     -0.271545         -1.153061
# 50%       48.000000      0.823273      0.000000         -0.837370
# 75%       52.000000      0.948683      0.343622         -0.444444
# max     4995.000000   1925.490114      2.666667          5.111111
#
#         TGS2602_auc      MQ5_mean       MQ5_min       MQ5_max       MQ5_std  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean     435.501633     98.319587     97.190220     99.975002      0.977440
# std      272.739018     15.985696     16.412742     29.400385      8.140189
# min      245.000000     64.900000      0.000000     66.000000      0.316228
# 25%      405.000000     87.800000     87.000000     89.000000      0.487950
# 50%      423.000000     96.400000     96.000000     97.000000      0.567646
# 75%      451.500000    108.900000    108.000000    110.000000      0.699206
# max     9541.500000    182.000000    176.000000    939.200000    268.049170
#
#            MQ5_skew  MQ5_kurtosis       MQ5_auc    MQ138_mean     MQ138_min  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean       0.153864     -0.336209    872.003728     89.167083     87.839082
# std        0.873800      1.542203    150.300578      4.220817      5.963905
# min       -2.666667     -2.000000    459.500000     74.100000      0.000000
# 25%       -0.209922     -1.238095    778.500000     86.428571     85.000000
# 50%        0.000000     -0.628099    854.500000     88.600000     87.000000
# 75%        0.625514      0.250000    974.000000     92.100000     91.000000
# max        2.666667      5.111111   1671.700000    114.222222    100.000000
#
#           MQ138_max     MQ138_std    MQ138_skew  MQ138_kurtosis     MQ138_auc  \
# count  10409.000000  10409.000000  10409.000000    10409.000000  10409.000000
# mean      90.566625      0.975194      0.054069       -0.778237    790.103132
# std        7.759153      2.798350      0.558517        0.739505     58.771488
# min       80.000000      0.316228     -2.666667       -2.000000    509.500000
# 25%       88.000000      0.699206     -0.271545       -1.238095    767.500000
# 50%       90.000000      0.823273      0.000000       -0.897959    794.000000
# 75%       93.000000      0.966092      0.382818       -0.485207    826.000000
# max      327.000000     79.796268      2.474323        5.111111    940.000000
#
#        TGS2620_mean   TGS2620_min   TGS2620_max   TGS2620_std  TGS2620_skew  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      52.047207     50.200692     56.931309      2.411880      0.011063
# std       17.146579      6.110356    131.709310     46.550137      0.618758
# min       37.750000      0.000000     41.000000      0.316228     -2.666667
# 25%       48.800000     48.000000     50.000000      0.632456     -0.343622
# 50%       51.100000     50.000000     52.000000      0.707107      0.000000
# 75%       54.500000     53.000000     55.000000      0.823273      0.343622
# max      681.500000     68.000000   5096.000000   1783.727478      2.666667
#
#        TGS2620_kurtosis   TGS2620_auc   TGS813_mean    TGS813_min  \
# count      10409.000000  10409.000000  10409.000000  10409.000000
# mean          -0.779548    460.377366    533.585382    530.475646
# std            0.944303    139.116630      7.076472     22.158615
# min           -2.000000    244.500000    487.200000      0.000000
# 25%           -1.329389    435.000000    528.900000    526.000000
# 50%           -0.960433    457.500000    532.100000    529.000000
# 75%           -0.444444    488.500000    536.000000    534.000000
# max            5.111111   5401.500000    552.666667    552.000000
#
#          TGS813_max    TGS813_std   TGS813_skew  TGS813_kurtosis  \
# count  10409.000000  10409.000000  10409.000000     10409.000000
# mean     535.648189      1.716062     -0.230519        -0.613955
# std        6.352277      6.679696      0.605296         0.951359
# min      525.000000      0.316228     -2.666667        -2.000000
# 25%      531.000000      0.971825     -0.580993        -1.203214
# 50%      534.000000      1.418136     -0.211547        -0.775022
# 75%      538.000000      1.870829      0.110588        -0.276929
# max      554.000000    171.255624      2.666667         5.111111
#
#          TGS813_auc  TGS2600_mean   TGS2600_min   TGS2600_max   TGS2600_std  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean    4754.938419    215.542657    212.039427    231.564223      6.549817
# std      193.833399     77.472793     27.167422    653.653277    217.414970
# min     3176.500000    182.490000      0.000000    189.000000      0.316228
# 25%     4754.000000    198.500000    198.000000    199.000000      0.527046
# 50%     4783.500000    205.400000    204.000000    206.000000      0.674949
# 75%     4817.500000    215.400000    214.000000    216.000000      0.788811
# max     4974.000000   3048.444444    302.000000  25410.000000   8385.583374
#
#        TGS2600_skew  TGS2600_kurtosis   TGS2600_auc  TGS2611_mean  \
# count  10409.000000      10409.000000  10409.000000  10409.000000
# mean      -0.059306         -0.657508   1919.990364    531.039823
# std        0.666301          1.127310    693.665474      5.820037
# min       -2.666667         -2.000000   1157.500000    482.500000
# 25%       -0.365675         -1.238095   1772.000000    527.400000
# 50%        0.000000         -0.705532   1840.500000    530.000000
# 75%        0.328125         -0.444444   1934.500000    533.000000
# max        2.666667          5.111111  27183.500000    547.300000
#
#         TGS2611_min   TGS2611_max   TGS2611_std  TGS2611_skew  \
# count  10409.000000  10409.000000  10409.000000  10409.000000
# mean     529.310693    532.089442      1.000540     -0.031123
# std       21.482818      5.537689      6.616937      0.568960
# min        0.000000    521.000000      0.316228     -2.666667
# 25%      526.000000    528.000000      0.632456     -0.343622
# 50%      529.000000    531.000000      0.737865      0.000000
# 75%      532.000000    534.000000      0.843274      0.343622
# max      546.000000    548.000000    169.640666      2.666667
#
#        TGS2611_kurtosis   TGS2611_auc  TGS2603_mean   TGS2603_min  \
# count      10409.000000  10409.000000  10409.000000  10409.000000
# mean          -0.890127   4742.842444    330.447166    328.831396
# std            0.811196    167.298428     12.855213     18.210511
# min           -2.000000   3167.500000    303.700000      0.000000
# 25%           -1.452909   4739.000000    321.900000    321.000000
# 50%           -0.960433   4769.000000    328.700000    328.000000
# 75%           -0.500000   4795.500000    335.600000    334.000000
# max            5.111111   4926.000000    370.200000    369.000000
#
#         TGS2603_max   TGS2603_std  TGS2603_skew  TGS2603_kurtosis  \
# count  10409.000000  10409.000000  10409.000000      10409.000000
# mean     331.640503      0.980595      0.022313         -0.777011
# std       12.875590      4.372807      0.541380          0.741411
# min      304.000000      0.316228     -2.666667         -2.000000
# 25%      323.000000      0.699206     -0.343622         -1.153061
# 50%      330.000000      0.816497      0.000000         -0.895833
# 75%      337.000000      0.918937      0.343622         -0.485207
# max      371.000000    113.142977      2.666667          5.111111
#
#         TGS2603_auc  Humidity_mean  Humidity_min  Humidity_max  Humidity_std  \
# count  10409.000000   1.040900e+04  10409.000000  1.040900e+04  1.040900e+04
# mean    2953.280046   4.077809e+03     48.175252  4.034278e+04  1.274229e+04
# std      142.283603   1.369807e+05      3.645837  1.369807e+06  4.331711e+05
# min     1955.500000   3.932000e+01      0.000000  3.950000e+01  3.162278e-02
# 25%     2885.500000   4.635000e+01     46.200000  4.650000e+01  5.163978e-02
# 50%     2951.000000   4.850000e+01     48.300000  4.870000e+01  6.992059e-02
# 75%     3008.500000   5.037000e+01     50.200000  5.050000e+01  1.135292e-01
# max     3331.000000   4.660302e+06     60.100000  4.660260e+07  1.473702e+07
#
#        Humidity_skew  Humidity_kurtosis  Humidity_auc  Celsius_mean  \
# count   1.040900e+04       10409.000000  1.040900e+04  10409.000000
# mean   -2.069636e-02          -0.448380  4.072700e+04     39.656171
# std     9.620238e-01           1.755567  1.369807e+06      1.311917
# min    -2.666667e+00          -2.000000  2.858000e+02     36.075000
# 25%    -4.082483e-01          -1.425074  4.148000e+02     38.910000
# 50%    -3.835271e-14          -1.004730  4.338000e+02     39.580000
# 75%     3.934379e-01          -0.222222  4.524000e+02     40.610000
# max     2.666667e+00           5.111111  4.660298e+07     43.520000
#
#         Celsius_min   Celsius_max   Celsius_std  Celsius_skew  \
# count  10409.000000  10409.000000  10409.000000  1.040900e+04
# mean      39.596032     39.718417      0.050683 -3.135385e-03
# std        1.313344      1.307077      0.014026  1.324687e+00
# min       36.000000     36.100000      0.031623 -2.666667e+00
# 25%       38.900000     39.000000      0.042164 -8.728716e-01
# 50%       39.500000     39.600000      0.048305  2.131541e-13
# 75%       40.600000     40.700000      0.052705  8.728716e-01
# max       43.500000     43.600000      0.105409  2.666667e+00
#
#        Celsius_kurtosis   Celsius_auc    Aroma_mean     Aroma_min  \
# count      10409.000000  10409.000000  10409.000000  10409.000000
# mean           0.023642    355.665448      2.935143      2.935143
# std            2.446926     14.858732      0.257778      0.257778
# min           -2.000000    246.950000      2.400000      2.400000
# 25%           -1.833333    349.450000      2.800000      2.800000
# 50%           -1.166667    355.950000      2.900000      2.900000
# 75%            0.250000    364.750000      3.100000      3.100000
# max            5.111111    391.650000      3.800000      3.800000
#
#           Aroma_max     Aroma_std     Aroma_auc    Taste_mean     Taste_min  \
# count  10409.000000  1.040900e+04  10409.000000  10409.000000  10409.000000
# mean       2.935143  3.738503e-16     26.416284     34.888942     34.888942
# std        0.257778  1.877307e-16      2.319999      1.732650      1.732650
# min        2.400000  0.000000e+00     21.600000     31.000000     31.000000
# 25%        2.800000  4.681111e-16     25.200000     33.000000     33.000000
# 50%        2.900000  4.681111e-16     26.100000     35.000000     35.000000
# 75%        3.100000  4.681111e-16     27.900000     36.000000     36.000000
# max        3.800000  4.681111e-16     34.200000     38.000000     38.000000
#
#           Taste_max  Taste_std     Taste_auc    Color_mean     Color_min  \
# count  10409.000000    10409.0  10409.000000  10409.000000  10409.000000
# mean      34.888942        0.0    314.000480      3.035383      3.035383
# std        1.732650        0.0     15.593852      0.255256      0.255256
# min       31.000000        0.0    279.000000      2.400000      2.400000
# 25%       33.000000        0.0    297.000000      2.800000      2.800000
# 50%       35.000000        0.0    315.000000      3.000000      3.000000
# 75%       36.000000        0.0    324.000000      3.200000      3.200000
# max       38.000000        0.0    342.000000      3.700000      3.700000
#
#           Color_max     Color_std     Color_auc  Appearance_mean  \
# count  10409.000000  1.040900e+04  10409.000000     10409.000000
# mean       3.035383  3.169160e-16     27.318446         3.135306
# std        0.255256  2.189081e-16      2.297302         0.270518
# min        2.400000  0.000000e+00     21.600000         2.800000
# 25%        2.800000  0.000000e+00     25.200000         2.900000
# 50%        3.000000  4.681111e-16     27.000000         3.100000
# 75%        3.200000  4.681111e-16     28.800000         3.300000
# max        3.700000  4.681111e-16     33.300000         3.800000
#
#        Appearance_min  Appearance_max  Appearance_std  Appearance_auc  \
# count    10409.000000    10409.000000    1.040900e+04    10409.000000
# mean         3.135306        3.135306    2.763515e-16       28.217754
# std          0.270518        0.270518    2.302133e-16        2.434658
# min          2.800000        2.800000    0.000000e+00       25.200000
# 25%          2.900000        2.900000    0.000000e+00       26.100000
# 50%          3.100000        3.100000    4.681111e-16       27.900000
# 75%          3.300000        3.300000    4.681111e-16       29.700000
# max          3.800000        3.800000    4.681111e-16       34.200000
#
#           Dreg_mean      Dreg_min      Dreg_max      Dreg_std      Dreg_auc
# count  10409.000000  10409.000000  10409.000000  1.040900e+04  10409.000000
# mean       3.071880      3.071880      3.071880  3.367936e-16     27.646921
# std        0.307778      0.307778      0.307778  2.103121e-16      2.769999
# min        2.400000      2.400000      2.400000  0.000000e+00     21.600000
# 25%        2.800000      2.800000      2.800000  0.000000e+00     25.200000
# 50%        3.000000      3.000000      3.000000  4.681111e-16     27.000000
# 75%        3.200000      3.200000      3.200000  4.681111e-16     28.800000
# max        3.900000      3.900000      3.900000  4.681111e-16     35.100000

# %%
import matplotlib.pyplot as plt
data['Kategori'].hist()
plt.xlabel('Kategori')
plt.ylabel('Count')
plt.title('Histogram for the Kategori')
# Out:
# Text(0.5, 1.0, 'Histogram for the Kategori')

# %%
X = data[feature_cols]
y = data[target_cols]

print(X.shape, y.shape)
# Out:
# (10409, 12) (10409,)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
def plot_pca_variance(X, n_components, threshold=0.95):
  pca = PCA(n_components=n_components)
  pca.fit(X)

  cumvar = np.cumsum(pca.explained_variance_ratio_)
  n_optimal = np.argmax(cumvar >= threshold) + 1

  plt.figure(figsize=(8, 5))
  plt.plot(range(1, n_components + 1), cumvar, marker='o', color='blue')
  plt.axhline(y=threshold, color='gray', linestyle='--', linewidth=1)
  plt.xlabel('Number of Principal Components')
  plt.ylabel('Cumulative Explained Variance')
  plt.xticks(range(1, n_components + 1))
  plt.grid(True)
  plt.tight_layout()
  plt.show()

  print(f'Optimal number of components to retain {threshold*100:.0f}% variance: {n_optimal}')

  return n_optimal

# %%
n_optimal = plot_pca_variance(X, n_components=X.shape[1], threshold=0.95)
# Out:
# Optimal number of components to retain 95% variance: 4

# %%
import time
from pathlib import Path
from datetime import datetime

all_best = []  # collects best_result from every model
_iter_t0 = None

# Logger setup
log_dir = Path("./results/logs/fqk")
log_dir.mkdir(parents=True, exist_ok=True)

_current_log_path = None

def setup_logger(name):
  """Panggil di awal tiap section. name contoh: 'svc_linear', 'xgb_gbtree'."""
  global _current_log_path
  _current_log_path = log_dir / f"quantum_{name}_hpo.log"
  # truncate file kalau sudah ada, biar tiap run fresh
  _current_log_path.write_text("")
  log(f"📝 Log: {_current_log_path}")
  log(f"🕒 Started: {datetime.now().isoformat(timespec='seconds')}")

def log(msg=""):
  """Print ke console dan append ke file log section aktif."""
  print(msg)
  if _current_log_path is not None:
    with open(_current_log_path, "a", encoding="utf-8") as f:
      f.write(str(msg) + "\n")

# %%
import pickle
from pathlib import Path

# Checkpoint dir — sama strukturnya kayak log_dir tapi pakai .pkl
ckpt_dir = Path("./results/checkpoints/pqk")  # ganti path sesuai notebook
ckpt_dir.mkdir(parents=True, exist_ok=True)

def load_checkpoint(name):
    """Load checkpoint kalau ada, return dict kosong kalau belum ada."""
    ckpt_path = ckpt_dir / f"quantum_{name}_hpo.pkl"
    if ckpt_path.exists():
        with open(ckpt_path, "rb") as f:
            data = pickle.load(f)
        log(f"♻️  Resumed checkpoint: {ckpt_path} ({len(data['done_configs'])} configs done)")
        return data, ckpt_path
    return {"done_configs": {}, "results": [], "best_result": None, "best_score": -np.inf}, ckpt_path

def save_checkpoint(ckpt_path, data):
    """Save progress atomically (tulis ke .tmp dulu, lalu rename)."""
    tmp = ckpt_path.with_suffix(".pkl.tmp")
    with open(tmp, "wb") as f:
        pickle.dump(data, f)
    tmp.replace(ckpt_path)  # atomic on most filesystems

# %% [markdown]
# # Quantum Global Configuration

# %%
mode = 'pqk'

# %% [markdown]
# # Full

# %%
QKERNEL='full'

# %% [markdown]
# ## 1. QSVC

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [0.1, 1, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qsvc_full")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qsvc import QSVCWrapper
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', QSVCWrapper(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        # random_state=42, 
        # decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\gs\quantum\fqk\qsvc_full.log
# 🕒 Started: 2026-05-29T19:42:17
# 🔬 Search space: 3 C × 2 lambda_ × 2 n_measurements =  12 configs × 5 folds = 60 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/12] C=0.1 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9414 | Prec=0.9447 | Rec=0.9414 | F1=0.9402 | AUROC=0.9959 | PRAUC=0.9868
#     F2 → Acc=0.9467 | Prec=0.9496 | Rec=0.9467 | F1=0.9452 | AUROC=0.9941 | PRAUC=0.9814
#     F3 → Acc=0.9448 | Prec=0.9473 | Rec=0.9448 | F1=0.9431 | AUROC=0.9940 | PRAUC=0.9786
#     F4 → Acc=0.9467 | Prec=0.9483 | Rec=0.9467 | F1=0.9464 | AUROC=0.9966 | PRAUC=0.9866
#     F5 → Acc=0.9385 | Prec=0.9414 | Rec=0.9385 | F1=0.9379 | AUROC=0.9945 | PRAUC=0.9805
#   ✅  Acc:0.9436±0.0032 | Precision:0.9463±0.0029  |Recall:0.9436±0.0032 |F1:0.9425±0.0031 | AUROC:0.9950±0.0010 | PRAUC:0.9828±0.0033 | MCC:0.9195 | Composite:0.9738
#
#   ▶ [2/12] C=0.1 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.9414 | Prec=0.9447 | Rec=0.9414 | F1=0.9402 | AUROC=0.9959 | PRAUC=0.9869
#     F2 → Acc=0.9467 | Prec=0.9496 | Rec=0.9467 | F1=0.9452 | AUROC=0.9941 | PRAUC=0.9815
#     F3 → Acc=0.9448 | Prec=0.9473 | Rec=0.9448 | F1=0.9431 | AUROC=0.9940 | PRAUC=0.9784
#     F4 → Acc=0.9467 | Prec=0.9483 | Rec=0.9467 | F1=0.9464 | AUROC=0.9966 | PRAUC=0.9864
#     F5 → Acc=0.9385 | Prec=0.9414 | Rec=0.9385 | F1=0.9379 | AUROC=0.9945 | PRAUC=0.9806
#   ✅  Acc:0.9436±0.0032 | Precision:0.9463±0.0029  |Recall:0.9436±0.0032 |F1:0.9425±0.0031 | AUROC:0.9950±0.0010 | PRAUC:0.9828±0.0033 | MCC:0.9195 | Composite:0.9738
#
#   ▶ [3/12] C=0.1 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.4995 | Prec=0.5442 | Rec=0.4995 | F1=0.4015 | AUROC=0.7372 | PRAUC=0.5351
#     F2 → Acc=0.4966 | Prec=0.5603 | Rec=0.4966 | F1=0.3967 | AUROC=0.7332 | PRAUC=0.5241
#     F3 → Acc=0.5058 | Prec=0.5569 | Rec=0.5058 | F1=0.4108 | AUROC=0.7517 | PRAUC=0.5502
#     F4 → Acc=0.5034 | Prec=0.5772 | Rec=0.5034 | F1=0.4041 | AUROC=0.7361 | PRAUC=0.5458
#     F5 → Acc=0.4954 | Prec=0.5375 | Rec=0.4954 | F1=0.3964 | AUROC=0.7342 | PRAUC=0.5366
#   ✅  Acc:0.5001±0.0039 | Precision:0.5552±0.0138  |Recall:0.5001±0.0039 |F1:0.4019±0.0053 | AUROC:0.7385±0.0068 | PRAUC:0.5384±0.0091 | MCC:0.2085 | Composite:0.5923
#
#   ▶ [4/12] C=0.1 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.4995 | Prec=0.5442 | Rec=0.4995 | F1=0.4015 | AUROC=0.7376 | PRAUC=0.5358
#     F2 → Acc=0.4966 | Prec=0.5603 | Rec=0.4966 | F1=0.3967 | AUROC=0.7333 | PRAUC=0.5241
#     F3 → Acc=0.5058 | Prec=0.5569 | Rec=0.5058 | F1=0.4108 | AUROC=0.7517 | PRAUC=0.5504
#     F4 → Acc=0.5034 | Prec=0.5772 | Rec=0.5034 | F1=0.4041 | AUROC=0.7364 | PRAUC=0.5459
#     F5 → Acc=0.4954 | Prec=0.5375 | Rec=0.4954 | F1=0.3964 | AUROC=0.7343 | PRAUC=0.5366
#   ✅  Acc:0.5001±0.0039 | Precision:0.5552±0.0138  |Recall:0.5001±0.0039 |F1:0.4019±0.0053 | AUROC:0.7387±0.0067 | PRAUC:0.5386±0.0091 | MCC:0.2085 | Composite:0.5925
#
#   ▶ [5/12] C=1 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9741 | Prec=0.9744 | Rec=0.9741 | F1=0.9742 | AUROC=0.9988 | PRAUC=0.9955
#     F2 → Acc=0.9741 | Prec=0.9744 | Rec=0.9741 | F1=0.9741 | AUROC=0.9975 | PRAUC=0.9916
#     F3 → Acc=0.9664 | Prec=0.9669 | Rec=0.9664 | F1=0.9664 | AUROC=0.9969 | PRAUC=0.9885
#     F4 → Acc=0.9760 | Prec=0.9762 | Rec=0.9760 | F1=0.9760 | AUROC=0.9986 | PRAUC=0.9930
#     F5 → Acc=0.9625 | Prec=0.9634 | Rec=0.9625 | F1=0.9626 | AUROC=0.9976 | PRAUC=0.9902
#   ✅  Acc:0.9706±0.0052 | Precision:0.9711±0.0050  |Recall:0.9706±0.0052 |F1:0.9707±0.0052 | AUROC:0.9979±0.0007 | PRAUC:0.9918±0.0024 | MCC:0.9578 | Composite:0.9867
#
#   ▶ [6/12] C=1 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.9741 | Prec=0.9744 | Rec=0.9741 | F1=0.9742 | AUROC=0.9988 | PRAUC=0.9956
#     F2 → Acc=0.9741 | Prec=0.9744 | Rec=0.9741 | F1=0.9741 | AUROC=0.9975 | PRAUC=0.9917
#     F3 → Acc=0.9664 | Prec=0.9669 | Rec=0.9664 | F1=0.9664 | AUROC=0.9969 | PRAUC=0.9884
#     F4 → Acc=0.9760 | Prec=0.9762 | Rec=0.9760 | F1=0.9760 | AUROC=0.9986 | PRAUC=0.9930
#     F5 → Acc=0.9625 | Prec=0.9634 | Rec=0.9625 | F1=0.9626 | AUROC=0.9976 | PRAUC=0.9902
#   ✅  Acc:0.9706±0.0052 | Precision:0.9711±0.0050  |Recall:0.9706±0.0052 |F1:0.9707±0.0052 | AUROC:0.9979±0.0007 | PRAUC:0.9918±0.0024 | MCC:0.9578 | Composite:0.9867
#
#   ▶ [7/12] C=1 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.5533 | Prec=0.5976 | Rec=0.5533 | F1=0.5009 | AUROC=0.7767 | PRAUC=0.5942
#     F2 → Acc=0.5500 | Prec=0.6032 | Rec=0.5500 | F1=0.4913 | AUROC=0.7721 | PRAUC=0.5882
#     F3 → Acc=0.5711 | Prec=0.6039 | Rec=0.5711 | F1=0.5220 | AUROC=0.7852 | PRAUC=0.6119
#     F4 → Acc=0.5456 | Prec=0.5645 | Rec=0.5456 | F1=0.4891 | AUROC=0.7675 | PRAUC=0.5839
#     F5 → Acc=0.5632 | Prec=0.5915 | Rec=0.5632 | F1=0.5084 | AUROC=0.7753 | PRAUC=0.6052
#   ✅  Acc:0.5566±0.0093 | Precision:0.5921±0.0145  |Recall:0.5566±0.0093 |F1:0.5023±0.0120 | AUROC:0.7754±0.0058 | PRAUC:0.5967±0.0104 | MCC:0.3176 | Composite:0.6429
#
#   ▶ [8/12] C=1 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.5533 | Prec=0.5976 | Rec=0.5533 | F1=0.5009 | AUROC=0.7766 | PRAUC=0.5941
#     F2 → Acc=0.5500 | Prec=0.6032 | Rec=0.5500 | F1=0.4913 | AUROC=0.7721 | PRAUC=0.5881
#     F3 → Acc=0.5711 | Prec=0.6039 | Rec=0.5711 | F1=0.5220 | AUROC=0.7852 | PRAUC=0.6120
#     F4 → Acc=0.5456 | Prec=0.5645 | Rec=0.5456 | F1=0.4891 | AUROC=0.7676 | PRAUC=0.5836
#     F5 → Acc=0.5632 | Prec=0.5915 | Rec=0.5632 | F1=0.5084 | AUROC=0.7752 | PRAUC=0.6049
#   ✅  Acc:0.5566±0.0093 | Precision:0.5921±0.0145  |Recall:0.5566±0.0093 |F1:0.5023±0.0120 | AUROC:0.7753±0.0058 | PRAUC:0.5965±0.0105 | MCC:0.3176 | Composite:0.6428
#
#   ▶ [9/12] C=10 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9827 | Prec=0.9830 | Rec=0.9827 | F1=0.9828 | AUROC=0.9981 | PRAUC=0.9952
#     F2 → Acc=0.9789 | Prec=0.9790 | Rec=0.9789 | F1=0.9789 | AUROC=0.9988 | PRAUC=0.9959
#     F3 → Acc=0.9745 | Prec=0.9746 | Rec=0.9745 | F1=0.9745 | AUROC=0.9977 | PRAUC=0.9927
#     F4 → Acc=0.9808 | Prec=0.9810 | Rec=0.9808 | F1=0.9808 | AUROC=0.9989 | PRAUC=0.9961
#     F5 → Acc=0.9721 | Prec=0.9724 | Rec=0.9721 | F1=0.9722 | AUROC=0.9983 | PRAUC=0.9940
#   ✅  Acc:0.9778±0.0039 | Precision:0.9780±0.0039  |Recall:0.9778±0.0039 |F1:0.9779±0.0039 | AUROC:0.9984±0.0005 | PRAUC:0.9948±0.0013 | MCC:0.9681 | Composite:0.9903
#
#   ▶ [10/12] C=10 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.9827 | Prec=0.9830 | Rec=0.9827 | F1=0.9828 | AUROC=0.9981 | PRAUC=0.9951
#     F2 → Acc=0.9789 | Prec=0.9790 | Rec=0.9789 | F1=0.9789 | AUROC=0.9988 | PRAUC=0.9959
#     F3 → Acc=0.9745 | Prec=0.9746 | Rec=0.9745 | F1=0.9745 | AUROC=0.9976 | PRAUC=0.9926
#     F4 → Acc=0.9808 | Prec=0.9810 | Rec=0.9808 | F1=0.9808 | AUROC=0.9990 | PRAUC=0.9962
#     F5 → Acc=0.9721 | Prec=0.9724 | Rec=0.9721 | F1=0.9722 | AUROC=0.9983 | PRAUC=0.9940
#   ✅  Acc:0.9778±0.0039 | Precision:0.9780±0.0039  |Recall:0.9778±0.0039 |F1:0.9779±0.0039 | AUROC:0.9984±0.0005 | PRAUC:0.9948±0.0013 | MCC:0.9681 | Composite:0.9903
#
#   ▶ [11/12] C=10 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.5965 | Prec=0.6167 | Rec=0.5965 | F1=0.5617 | AUROC=0.8041 | PRAUC=0.6462
#     F2 → Acc=0.5946 | Prec=0.6113 | Rec=0.5946 | F1=0.5628 | AUROC=0.8061 | PRAUC=0.6496
#     F3 → Acc=0.6033 | Prec=0.6204 | Rec=0.6033 | F1=0.5714 | AUROC=0.8150 | PRAUC=0.6611
#     F4 → Acc=0.5860 | Prec=0.5918 | Rec=0.5860 | F1=0.5520 | AUROC=0.8010 | PRAUC=0.6414
#     F5 → Acc=0.6016 | Prec=0.6261 | Rec=0.6016 | F1=0.5662 | AUROC=0.8158 | PRAUC=0.6669
#   ✅  Acc:0.5964±0.0061 | Precision:0.6133±0.0118  |Recall:0.5964±0.0061 |F1:0.5628±0.0064 | AUROC:0.8084±0.0059 | PRAUC:0.6530±0.0095 | MCC:0.3883 | Composite:0.6860
#
#   ▶ [12/12] C=10 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.5965 | Prec=0.6167 | Rec=0.5965 | F1=0.5617 | AUROC=0.8041 | PRAUC=0.6461
#     F2 → Acc=0.5946 | Prec=0.6113 | Rec=0.5946 | F1=0.5628 | AUROC=0.8061 | PRAUC=0.6496
#     F3 → Acc=0.6033 | Prec=0.6204 | Rec=0.6033 | F1=0.5714 | AUROC=0.8151 | PRAUC=0.6611
#     F4 → Acc=0.5860 | Prec=0.5918 | Rec=0.5860 | F1=0.5520 | AUROC=0.8011 | PRAUC=0.6413
#     F5 → Acc=0.6016 | Prec=0.6261 | Rec=0.6016 | F1=0.5662 | AUROC=0.8157 | PRAUC=0.6668
#   ✅  Acc:0.5964±0.0061 | Precision:0.6133±0.0118  |Recall:0.5964±0.0061 |F1:0.5628±0.0064 | AUROC:0.8084±0.0059 | PRAUC:0.6530±0.0095 | MCC:0.3883 | Composite:0.6859
#
# 🏆 Best config : C=10 | lambda_=0.1 | n_measurements=256
#    Composite   : 0.9903119867815876 (AUROC=0.9984±0.0005 | PRAUC=0.9948±0.0013 | Acc=0.9778±0.0039 |Prec=0.9780±0.0039 |Rec=0.9778±0.0039) |

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qsvc_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/qsvc_full.csv

# %%
# ── Collect best result ──
best_result['model'] = f"QSVC ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QSVC ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [QSVC (full)] recorded | Exec. time: 126.6s

# %% [markdown]
# ## 2. QXGB (Hybrid Quantum XGBoost)

# %% [markdown]
# ### 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_gbtree_full")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='gbtree',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\gs\quantum\fqk\qxgb_gbtree_full.log
# 🕒 Started: 2026-05-29T20:10:11
# 🔬 Search space: 2 n_estimators × 2 learning_rate × 2 max_depth × 2 lambda_ × 2 n_measurements =  32 configs × 5 folds = 160 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.8953 | Prec=0.9017 | Rec=0.8953 | F1=0.8930 | AUROC=0.9920 | PRAUC=0.9811
#     F2 → Acc=0.8809 | Prec=0.8914 | Rec=0.8809 | F1=0.8795 | AUROC=0.9909 | PRAUC=0.9795
#     F3 → Acc=0.8886 | Prec=0.8950 | Rec=0.8886 | F1=0.8869 | AUROC=0.9924 | PRAUC=0.9797
#     F4 → Acc=0.8842 | Prec=0.8976 | Rec=0.8842 | F1=0.8830 | AUROC=0.9928 | PRAUC=0.9839
#     F5 → Acc=0.8981 | Prec=0.9036 | Rec=0.8981 | F1=0.8971 | AUROC=0.9900 | PRAUC=0.9745
#   ✅  Acc:0.8894±0.0065 | Precision:0.8978±0.0044  |Recall:0.8894±0.0065 |F1:0.8879±0.0064 | AUROC:0.9916±0.0010 | PRAUC:0.9797±0.0031 | MCC:0.8414 | Composite:0.9536
#
#   ▶ [2/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.8953 | Prec=0.9017 | Rec=0.8953 | F1=0.8930 | AUROC=0.9920 | PRAUC=0.9811
#     F2 → Acc=0.8809 | Prec=0.8914 | Rec=0.8809 | F1=0.8795 | AUROC=0.9909 | PRAUC=0.9795
#     F3 → Acc=0.8886 | Prec=0.8950 | Rec=0.8886 | F1=0.8869 | AUROC=0.9924 | PRAUC=0.9797
#     F4 → Acc=0.8842 | Prec=0.8976 | Rec=0.8842 | F1=0.8830 | AUROC=0.9928 | PRAUC=0.9839
#     F5 → Acc=0.8981 | Prec=0.9036 | Rec=0.8981 | F1=0.8971 | AUROC=0.9900 | PRAUC=0.9745
#   ✅  Acc:0.8894±0.0065 | Precision:0.8978±0.0044  |Recall:0.8894±0.0065 |F1:0.8879±0.0064 | AUROC:0.9916±0.0010 | PRAUC:0.9797±0.0031 | MCC:0.8414 | Composite:0.9536
#
#   ▶ [3/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.4909 | Prec=0.5827 | Rec=0.4909 | F1=0.3790 | AUROC=0.7322 | PRAUC=0.5355
#     F2 → Acc=0.4957 | Prec=0.6077 | Rec=0.4957 | F1=0.3869 | AUROC=0.7361 | PRAUC=0.5475
#     F3 → Acc=0.5091 | Prec=0.6597 | Rec=0.5091 | F1=0.4038 | AUROC=0.7661 | PRAUC=0.5911
#     F4 → Acc=0.5000 | Prec=0.6143 | Rec=0.5000 | F1=0.3946 | AUROC=0.7515 | PRAUC=0.5758
#     F5 → Acc=0.4921 | Prec=0.6170 | Rec=0.4921 | F1=0.3787 | AUROC=0.7404 | PRAUC=0.5614
#   ✅  Acc:0.4975±0.0066 | Precision:0.6163±0.0249  |Recall:0.4975±0.0066 |F1:0.3886±0.0096 | AUROC:0.7453±0.0123 | PRAUC:0.5622±0.0197 | MCC:0.2147 | Composite:0.6017
#
#   ▶ [4/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.4909 | Prec=0.5827 | Rec=0.4909 | F1=0.3790 | AUROC=0.7322 | PRAUC=0.5355
#     F2 → Acc=0.4957 | Prec=0.6077 | Rec=0.4957 | F1=0.3869 | AUROC=0.7361 | PRAUC=0.5475
#     F3 → Acc=0.5091 | Prec=0.6597 | Rec=0.5091 | F1=0.4038 | AUROC=0.7661 | PRAUC=0.5911
#     F4 → Acc=0.5000 | Prec=0.6143 | Rec=0.5000 | F1=0.3946 | AUROC=0.7515 | PRAUC=0.5758
#     F5 → Acc=0.4921 | Prec=0.6170 | Rec=0.4921 | F1=0.3787 | AUROC=0.7404 | PRAUC=0.5614
#   ✅  Acc:0.4975±0.0066 | Precision:0.6163±0.0249  |Recall:0.4975±0.0066 |F1:0.3886±0.0096 | AUROC:0.7453±0.0123 | PRAUC:0.5622±0.0197 | MCC:0.2147 | Composite:0.6017
#
#   ▶ [5/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9693 | Prec=0.9693 | Rec=0.9693 | F1=0.9691 | AUROC=0.9989 | PRAUC=0.9964
#     F2 → Acc=0.9659 | Prec=0.9662 | Rec=0.9659 | F1=0.9657 | AUROC=0.9984 | PRAUC=0.9955
#     F3 → Acc=0.9597 | Prec=0.9600 | Rec=0.9597 | F1=0.9591 | AUROC=0.9978 | PRAUC=0.9937
#     F4 → Acc=0.9673 | Prec=0.9681 | Rec=0.9673 | F1=0.9670 | AUROC=0.9989 | PRAUC=0.9961
#     F5 → Acc=0.9587 | Prec=0.9588 | Rec=0.9587 | F1=0.9583 | AUROC=0.9979 | PRAUC=0.9932
#   ✅  Acc:0.9642±0.0042 | Precision:0.9645±0.0043  |Recall:0.9642±0.0042 |F1:0.9638±0.0043 | AUROC:0.9984±0.0005 | PRAUC:0.9950±0.0013 | MCC:0.9482 | Composite:0.9858
#
#   ▶ [6/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.9693 | Prec=0.9693 | Rec=0.9693 | F1=0.9691 | AUROC=0.9989 | PRAUC=0.9964
#     F2 → Acc=0.9659 | Prec=0.9662 | Rec=0.9659 | F1=0.9657 | AUROC=0.9984 | PRAUC=0.9955
#     F3 → Acc=0.9597 | Prec=0.9600 | Rec=0.9597 | F1=0.9591 | AUROC=0.9978 | PRAUC=0.9937
#     F4 → Acc=0.9673 | Prec=0.9681 | Rec=0.9673 | F1=0.9670 | AUROC=0.9989 | PRAUC=0.9961
#     F5 → Acc=0.9587 | Prec=0.9588 | Rec=0.9587 | F1=0.9583 | AUROC=0.9979 | PRAUC=0.9932
#   ✅  Acc:0.9642±0.0042 | Precision:0.9645±0.0043  |Recall:0.9642±0.0042 |F1:0.9638±0.0043 | AUROC:0.9984±0.0005 | PRAUC:0.9950±0.0013 | MCC:0.9482 | Composite:0.9858
#
#   ▶ [7/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.5451 | Prec=0.6112 | Rec=0.5451 | F1=0.4730 | AUROC=0.7973 | PRAUC=0.6288
#     F2 → Acc=0.5500 | Prec=0.6374 | Rec=0.5500 | F1=0.4788 | AUROC=0.8028 | PRAUC=0.6394
#     F3 → Acc=0.5600 | Prec=0.6433 | Rec=0.5600 | F1=0.4916 | AUROC=0.8212 | PRAUC=0.6694
#     F4 → Acc=0.5562 | Prec=0.6278 | Rec=0.5562 | F1=0.4903 | AUROC=0.8039 | PRAUC=0.6470
#     F5 → Acc=0.5502 | Prec=0.6267 | Rec=0.5502 | F1=0.4804 | AUROC=0.8067 | PRAUC=0.6522
#   ✅  Acc:0.5523±0.0052 | Precision:0.6293±0.0109  |Recall:0.5523±0.0052 |F1:0.4828±0.0071 | AUROC:0.8064±0.0080 | PRAUC:0.6474±0.0135 | MCC:0.3201 | Composite:0.6687
#
#   ▶ [8/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.5451 | Prec=0.6112 | Rec=0.5451 | F1=0.4730 | AUROC=0.7973 | PRAUC=0.6288
#     F2 → Acc=0.5500 | Prec=0.6374 | Rec=0.5500 | F1=0.4788 | AUROC=0.8028 | PRAUC=0.6394
#     F3 → Acc=0.5600 | Prec=0.6433 | Rec=0.5600 | F1=0.4916 | AUROC=0.8212 | PRAUC=0.6694
#     F4 → Acc=0.5562 | Prec=0.6278 | Rec=0.5562 | F1=0.4903 | AUROC=0.8039 | PRAUC=0.6470
#     F5 → Acc=0.5502 | Prec=0.6267 | Rec=0.5502 | F1=0.4804 | AUROC=0.8067 | PRAUC=0.6522
#   ✅  Acc:0.5523±0.0052 | Precision:0.6293±0.0109  |Recall:0.5523±0.0052 |F1:0.4828±0.0071 | AUROC:0.8064±0.0080 | PRAUC:0.6474±0.0135 | MCC:0.3201 | Composite:0.6687
#
#   ▶ [9/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9765 | Prec=0.9766 | Rec=0.9765 | F1=0.9765 | AUROC=0.9992 | PRAUC=0.9973
#     F2 → Acc=0.9793 | Prec=0.9794 | Rec=0.9793 | F1=0.9794 | AUROC=0.9991 | PRAUC=0.9974
#     F3 → Acc=0.9707 | Prec=0.9708 | Rec=0.9707 | F1=0.9707 | AUROC=0.9985 | PRAUC=0.9955
#     F4 → Acc=0.9793 | Prec=0.9795 | Rec=0.9793 | F1=0.9794 | AUROC=0.9993 | PRAUC=0.9975
#     F5 → Acc=0.9654 | Prec=0.9654 | Rec=0.9654 | F1=0.9653 | AUROC=0.9984 | PRAUC=0.9942
#   ✅  Acc:0.9743±0.0054 | Precision:0.9744±0.0055  |Recall:0.9743±0.0054 |F1:0.9743±0.0055 | AUROC:0.9989±0.0004 | PRAUC:0.9964±0.0013 | MCC:0.9629 | Composite:0.9898
#
#   ▶ [10/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.9765 | Prec=0.9766 | Rec=0.9765 | F1=0.9765 | AUROC=0.9992 | PRAUC=0.9973
#     F2 → Acc=0.9793 | Prec=0.9794 | Rec=0.9793 | F1=0.9794 | AUROC=0.9991 | PRAUC=0.9974
#     F3 → Acc=0.9707 | Prec=0.9708 | Rec=0.9707 | F1=0.9707 | AUROC=0.9985 | PRAUC=0.9955
#     F4 → Acc=0.9793 | Prec=0.9795 | Rec=0.9793 | F1=0.9794 | AUROC=0.9993 | PRAUC=0.9975
#     F5 → Acc=0.9654 | Prec=0.9654 | Rec=0.9654 | F1=0.9653 | AUROC=0.9984 | PRAUC=0.9942
#   ✅  Acc:0.9743±0.0054 | Precision:0.9744±0.0055  |Recall:0.9743±0.0054 |F1:0.9743±0.0055 | AUROC:0.9989±0.0004 | PRAUC:0.9964±0.0013 | MCC:0.9629 | Composite:0.9898
#
#   ▶ [11/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.5701 | Prec=0.5645 | Rec=0.5701 | F1=0.5339 | AUROC=0.7942 | PRAUC=0.6183
#     F2 → Acc=0.5869 | Prec=0.5886 | Rec=0.5869 | F1=0.5540 | AUROC=0.7972 | PRAUC=0.6271
#     F3 → Acc=0.6057 | Prec=0.6073 | Rec=0.6057 | F1=0.5742 | AUROC=0.8194 | PRAUC=0.6644
#     F4 → Acc=0.5937 | Prec=0.5889 | Rec=0.5937 | F1=0.5651 | AUROC=0.8045 | PRAUC=0.6469
#     F5 → Acc=0.5906 | Prec=0.5982 | Rec=0.5906 | F1=0.5571 | AUROC=0.8014 | PRAUC=0.6435
#   ✅  Acc:0.5894±0.0115 | Precision:0.5895±0.0143  |Recall:0.5894±0.0115 |F1:0.5569±0.0134 | AUROC:0.8033±0.0088 | PRAUC:0.6401±0.0161 | MCC:0.3740 | Composite:0.6776
#
#   ▶ [12/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.5701 | Prec=0.5645 | Rec=0.5701 | F1=0.5339 | AUROC=0.7942 | PRAUC=0.6183
#     F2 → Acc=0.5869 | Prec=0.5886 | Rec=0.5869 | F1=0.5540 | AUROC=0.7972 | PRAUC=0.6271
#     F3 → Acc=0.6057 | Prec=0.6073 | Rec=0.6057 | F1=0.5742 | AUROC=0.8194 | PRAUC=0.6644
#     F4 → Acc=0.5937 | Prec=0.5889 | Rec=0.5937 | F1=0.5651 | AUROC=0.8045 | PRAUC=0.6469
#     F5 → Acc=0.5906 | Prec=0.5982 | Rec=0.5906 | F1=0.5571 | AUROC=0.8014 | PRAUC=0.6435
#   ✅  Acc:0.5894±0.0115 | Precision:0.5895±0.0143  |Recall:0.5894±0.0115 |F1:0.5569±0.0134 | AUROC:0.8033±0.0088 | PRAUC:0.6401±0.0161 | MCC:0.3740 | Composite:0.6776
#
#   ▶ [13/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9808 | Prec=0.9810 | Rec=0.9808 | F1=0.9808 | AUROC=0.9994 | PRAUC=0.9977
#     F2 → Acc=0.9813 | Prec=0.9814 | Rec=0.9813 | F1=0.9813 | AUROC=0.9994 | PRAUC=0.9981
#     F3 → Acc=0.9712 | Prec=0.9713 | Rec=0.9712 | F1=0.9711 | AUROC=0.9988 | PRAUC=0.9962
#     F4 → Acc=0.9808 | Prec=0.9808 | Rec=0.9808 | F1=0.9807 | AUROC=0.9995 | PRAUC=0.9979
#     F5 → Acc=0.9702 | Prec=0.9704 | Rec=0.9702 | F1=0.9702 | AUROC=0.9987 | PRAUC=0.9955
#   ✅  Acc:0.9768±0.0050 | Precision:0.9770±0.0050  |Recall:0.9768±0.0050 |F1:0.9768±0.0051 | AUROC:0.9991±0.0003 | PRAUC:0.9971±0.0010 | MCC:0.9667 | Composite:0.9910
#
#   ▶ [14/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | lambda_=0.1 | n_measurements=1024
#     F1 → Acc=0.9808 | Prec=0.9810 | Rec=0.9808 | F1=0.9808 | AUROC=0.9994 | PRAUC=0.9977
#     F2 → Acc=0.9813 | Prec=0.9814 | Rec=0.9813 | F1=0.9813 | AUROC=0.9994 | PRAUC=0.9981
#     F3 → Acc=0.9712 | Prec=0.9713 | Rec=0.9712 | F1=0.9711 | AUROC=0.9988 | PRAUC=0.9962
#     F4 → Acc=0.9808 | Prec=0.9808 | Rec=0.9808 | F1=0.9807 | AUROC=0.9995 | PRAUC=0.9979
#     F5 → Acc=0.9702 | Prec=0.9704 | Rec=0.9702 | F1=0.9702 | AUROC=0.9987 | PRAUC=0.9955
#   ✅  Acc:0.9768±0.0050 | Precision:0.9770±0.0050  |Recall:0.9768±0.0050 |F1:0.9768±0.0051 | AUROC:0.9991±0.0003 | PRAUC:0.9971±0.0010 | MCC:0.9667 | Composite:0.9910
#
#   ▶ [15/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | lambda_=5 | n_measurements=256
#     F1 → Acc=0.6220 | Prec=0.6135 | Rec=0.6220 | F1=0.6033 | AUROC=0.8284 | PRAUC=0.6767
#     F2 → Acc=0.6287 | Prec=0.6375 | Rec=0.6287 | F1=0.6091 | AUROC=0.8387 | PRAUC=0.6925
#     F3 → Acc=0.6412 | Prec=0.6511 | Rec=0.6412 | F1=0.6213 | AUROC=0.8458 | PRAUC=0.7119
#     F4 → Acc=0.6330 | Prec=0.6238 | Rec=0.6330 | F1=0.6163 | AUROC=0.8337 | PRAUC=0.6841
#     F5 → Acc=0.6233 | Prec=0.6102 | Rec=0.6233 | F1=0.6022 | AUROC=0.8354 | PRAUC=0.6897
#   ✅  Acc:0.6296±0.0070 | Precision:0.6272±0.0152  |Recall:0.6296±0.0070 |F1:0.6105±0.0074 | AUROC:0.8364±0.0058 | PRAUC:0.6910±0.0118 | MCC:0.4432 | Composite:0.7190
#
#   ▶ [16/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | lambda_=5 | n_measurements=1024
#     F1 → Acc=0.6220 | Prec=0.6135 | Rec=0.6220 | F1=0.6033 | AUROC=0.8284 | PRAUC=0.6767
#     F2 → Acc=0.6287 | Prec=0.6375 | Rec=0.6287 | F1=0.6091 | AUROC=0.8387 | PRAUC=0.6925
#     F3 → Acc=0.6412 | Prec=0.6511 | Rec=0.6412 | F1=0.6213 | AUROC=0.8458 | PRAUC=0.7119
#     F4 → Acc=0.6330 | Prec=0.6238 | Rec=0.6330 | F1=0.6163 | AUROC=0.8337 | PRAUC=0.6841
#     F5 → Acc=0.6233 | Prec=0.6102 | Rec=0.6233 | F1=0.6022 | AUROC=0.8354 | PRAUC=0.6897
#   ✅  Acc:0.6296±0.0070 | Precision:0.6272±0.0152  |Recall:0.6296±0.0070 |F1:0.6105±0.0074 | AUROC:0.8364±0.0058 | PRAUC:0.6910±0.0118 | MCC:0.4432 | Composite:0.7190
#
#   ▶ [17/32] n_estimators=500 | learning_rate=0.01 | max_depth=4 | lambda_=0.1 | n_measurements=256
#     F1 → Acc=0.9678 | Prec=0.9681 | Rec=0.9678 | F1=0.9679 | AUROC=0.9981 | PRAUC=0.9943
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 65
#      61
#      62     model.fit(X_train, y_train)
#      63
#      64     y_pred = model.predict(X_val)
# ---> 65     y_prob = model.predict_proba(X_val)
#      66
#      67     y_val_all.extend(y_val)
#      68     y_pred_all.extend(y_pred)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\sklearn\pipeline.py:859, in Pipeline.predict_proba(self, X, **params)
#     857     for _, name, transform in self._iter(with_final=False):
#     858         Xt = transform.transform(Xt)
# --> 859     return self.steps[-1][1].predict_proba(Xt, **params)
#     861 # metadata routing enabled
#     862 routed_params = process_routing(self, "predict_proba", **params)
#
# File c:\`Bioinformatics\quantum-gesang\codes\model\quantum\qxgb.py:86, in predict_proba(self, X)
#      84 def predict_proba(self, X):
#      85   K_test = self.qkernel_.evaluate(X, self.X_train)
# ---> 86   return self.model_.predict_proba(K_test)
#
# File c:\`Bioinformatics\quantum-gesang\codes\model\quantum\ProjectedQuantumKernel.py:131, in ProjectedQuantumKernel.evaluate(self, x_vec, y_vec)
#     117 def evaluate(self, x_vec, y_vec=None):
#     118     """
#     119     Compute PQK Gram matrix K[i, j] = k_PQ(x_i, y_j).
#     120
#    (...)    129     K : ndarray of shape (N_x, N_y) (or (N_x, N_x) if y_vec is None)
#     130     """
# --> 131     Phi_x = self._project(x_vec)
#     132     Phi_y = Phi_x if y_vec is None else self._project(y_vec)
#     133     # RBF kernel: exp(-gamma * ||phi_x - phi_y||^2)
#
# File c:\`Bioinformatics\quantum-gesang\codes\model\quantum\ProjectedQuantumKernel.py:105, in ProjectedQuantumKernel._project(self, X)
#     102 for i, x in enumerate(X):
#     103     # Bind parameters and compute the full statevector |phi(x)>
#     104     bound = self.feature_map.assign_parameters(x)
# --> 105     sv = Statevector(bound)
#     107     # Compute <P_k>_x for each (k, P) — this is equivalent to
#     108     # tracing out other qubits then measuring P on qubit k.
#     109     for j, obs in enumerate(self._observables):
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:101, in Statevector.__init__(self, data, dims)
#      99     self._data = np.ravel(data.data)
#     100 elif isinstance(data, (QuantumCircuit, Instruction)):
# --> 101     self._data = Statevector.from_instruction(data).data
#     102 else:
#     103     raise QiskitError("Invalid input data format for Statevector")
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:846, in Statevector.from_instruction(cls, instruction)
#     844 init[0] = 1.0
#     845 vec = Statevector(init, dims=instruction.num_qubits * (2,))
# --> 846 return Statevector._evolve_instruction(vec, instruction)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:1042, in Statevector._evolve_instruction(statevec, obj, qargs)
#    1040     else:
#    1041         new_qargs = [qargs[qubits[tup]] for tup in instruction.qubits]
# -> 1042     Statevector._evolve_instruction(statevec, instruction.operation, qargs=new_qargs)
#    1043 return statevec
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:984, in Statevector._evolve_instruction(statevec, obj, qargs)
#     980 mat = Operator._instruction_to_matrix(obj)
#     981 if mat is not None:
#     982     # Perform the composition and inplace update the current state
#     983     # of the operator
# --> 984     return Statevector._evolve_operator(statevec, Operator(mat), qargs=qargs)
#     986 # Special instruction types
#     987 if isinstance(obj, Reset):
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:957, in Statevector._evolve_operator(statevec, oper, qargs)
#     953 tensor_shape = tensor.shape
#     955 # Perform contraction
#     956 tensor = np.reshape(
# --> 957     np.dot(oper.data, np.reshape(tensor, contract_shape)),
#     958     tensor_shape,
#     959 )
#     961 # Transpose back to  original subsystem spec and flatten
#     962 statevec._data = np.reshape(np.transpose(tensor, axes_inv), new_shape.shape[0])
#
# KeyboardInterrupt:

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_gbtree_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/qxgb_gbtree_full.csv

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB GBTree ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB GBTree ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [QXGB GBTree (full)] recorded | Exec. time: 42.4s

# %% [markdown]
# ### 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  'rate_drop': [0.1, 0.5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_dart_full")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='dart',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\gs\quantum\all\qxgb_dart_full.log
# 🕒 Started: 2026-05-22T15:18:20
# 🔬 Search space: 2 n_estimators × 2 learning_rate × 2 max_depth × 2 rate_drop × 2 lambda_ × 1 n_measurements =  32 configs × 5 folds = 160 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9270 | PRAUC=0.8511
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9145 | PRAUC=0.8396
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9759 | PRAUC=0.9538
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9476 | PRAUC=0.8991
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9375 | PRAUC=0.8828
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9405±0.0208 | PRAUC:0.8853±0.0404 | MCC:0.0000 | Composite:0.7577
#
#   ▶ [2/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6627 | PRAUC=0.5176
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6688 | PRAUC=0.5432
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6288 | PRAUC=0.4412
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6899 | PRAUC=0.4932
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6325 | PRAUC=0.4731
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6565±0.0230 | PRAUC:0.4937±0.0352 | MCC:0.0000 | Composite:0.5325
#
#   ▶ [3/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9163 | PRAUC=0.8268
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.8971 | PRAUC=0.8219
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9693 | PRAUC=0.9329
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9422 | PRAUC=0.8824
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9360 | PRAUC=0.8828
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9322±0.0244 | PRAUC:0.8694±0.0411 | MCC:0.0000 | Composite:0.7496
#
#   ▶ [4/32] n_estimators=100 | learning_rate=0.01 | max_depth=4 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6820 | PRAUC=0.5254
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6539 | PRAUC=0.5124
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.5995 | PRAUC=0.4132
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6661 | PRAUC=0.4784
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6255 | PRAUC=0.4599
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6454±0.0295 | PRAUC:0.4779±0.0399 | MCC:0.0000 | Composite:0.5235
#
#   ▶ [5/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9341 | PRAUC=0.8615
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9534 | PRAUC=0.8979
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9857 | PRAUC=0.9679
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9637 | PRAUC=0.9181
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9570 | PRAUC=0.9104
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9588±0.0167 | PRAUC:0.9112±0.0344 | MCC:0.0000 | Composite:0.7724
#
#   ▶ [6/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6684 | PRAUC=0.5163
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.7056 | PRAUC=0.5900
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6391 | PRAUC=0.4618
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6894 | PRAUC=0.5012
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6285 | PRAUC=0.4682
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6662±0.0292 | PRAUC:0.5075±0.0460 | MCC:0.0000 | Composite:0.5403
#
#   ▶ [7/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9289 | PRAUC=0.8481
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9377 | PRAUC=0.8794
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9736 | PRAUC=0.9386
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9593 | PRAUC=0.9063
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9555 | PRAUC=0.9117
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9510±0.0159 | PRAUC:0.8968±0.0308 | MCC:0.0000 | Composite:0.7650
#
#   ▶ [8/32] n_estimators=100 | learning_rate=0.01 | max_depth=10 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6659 | PRAUC=0.4996
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6763 | PRAUC=0.5127
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6130 | PRAUC=0.4339
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6490 | PRAUC=0.4702
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.5922 | PRAUC=0.4321
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6393±0.0319 | PRAUC:0.4697±0.0330 | MCC:0.0000 | Composite:0.5187
#
#   ▶ [9/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.6857 | Prec=0.7053 | Rec=0.6857 | F1=0.6640 | AUROC=0.9203 | PRAUC=0.8444
#     F2 → Acc=0.7596 | Prec=0.7725 | Rec=0.7596 | F1=0.7413 | AUROC=0.9479 | PRAUC=0.8850
#     F3 → Acc=0.8750 | Prec=0.8735 | Rec=0.8750 | F1=0.8639 | AUROC=0.9813 | PRAUC=0.9544
#     F4 → Acc=0.8173 | Prec=0.8153 | Rec=0.8173 | F1=0.8070 | AUROC=0.9572 | PRAUC=0.9147
#     F5 → Acc=0.7692 | Prec=0.7951 | Rec=0.7692 | F1=0.7534 | AUROC=0.9600 | PRAUC=0.9297
#   ✅  Acc:0.7814±0.0630 | Precision:0.7923±0.0549  |Recall:0.7814±0.0630 |F1:0.7659±0.0670 | AUROC:0.9534±0.0198 | PRAUC:0.9057±0.0380 | MCC:0.6819 | Composite:0.8801
#
#   ▶ [10/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4952 | Prec=0.6937 | Rec=0.4952 | F1=0.3786 | AUROC=0.6764 | PRAUC=0.5360
#     F2 → Acc=0.4904 | Prec=0.5201 | Rec=0.4904 | F1=0.3573 | AUROC=0.6457 | PRAUC=0.4947
#     F3 → Acc=0.4519 | Prec=0.4250 | Rec=0.4519 | F1=0.2975 | AUROC=0.6332 | PRAUC=0.4523
#     F4 → Acc=0.4615 | Prec=0.3681 | Rec=0.4615 | F1=0.3172 | AUROC=0.6895 | PRAUC=0.4925
#     F5 → Acc=0.4615 | Prec=0.4959 | Rec=0.4615 | F1=0.3269 | AUROC=0.6486 | PRAUC=0.4905
#   ✅  Acc:0.4721±0.0173 | Precision:0.5006±0.1104  |Recall:0.4721±0.0173 |F1:0.3355±0.0290 | AUROC:0.6587±0.0209 | PRAUC:0.4932±0.0265 | MCC:0.1490 | Composite:0.5413
#
#   ▶ [11/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.5238 | Prec=0.6354 | Rec=0.5238 | F1=0.4137 | AUROC=0.9168 | PRAUC=0.8360
#     F2 → Acc=0.5288 | Prec=0.6636 | Rec=0.5288 | F1=0.4240 | AUROC=0.9078 | PRAUC=0.8301
#     F3 → Acc=0.5000 | Prec=0.6569 | Rec=0.5000 | F1=0.3749 | AUROC=0.9726 | PRAUC=0.9437
#     F4 → Acc=0.5000 | Prec=0.6569 | Rec=0.5000 | F1=0.3749 | AUROC=0.9468 | PRAUC=0.8886
#     F5 → Acc=0.4615 | Prec=0.4206 | Rec=0.4615 | F1=0.3103 | AUROC=0.9447 | PRAUC=0.8917
#   ✅  Acc:0.5028±0.0238 | Precision:0.6067±0.0935  |Recall:0.5028±0.0238 |F1:0.3796±0.0399 | AUROC:0.9378±0.0232 | PRAUC:0.8780±0.0417 | MCC:0.2493 | Composite:0.7729
#
#   ▶ [12/32] n_estimators=100 | learning_rate=0.1 | max_depth=4 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6863 | PRAUC=0.5255
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6523 | PRAUC=0.5160
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.5933 | PRAUC=0.4053
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6623 | PRAUC=0.4742
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6329 | PRAUC=0.4541
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6454±0.0312 | PRAUC:0.4750±0.0437 | MCC:0.0000 | Composite:0.5226
#
#   ▶ [13/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.7238 | Prec=0.7398 | Rec=0.7238 | F1=0.7036 | AUROC=0.9277 | PRAUC=0.8613
#     F2 → Acc=0.7788 | Prec=0.7868 | Rec=0.7788 | F1=0.7649 | AUROC=0.9602 | PRAUC=0.9041
#     F3 → Acc=0.8558 | Prec=0.8540 | Rec=0.8558 | F1=0.8449 | AUROC=0.9878 | PRAUC=0.9710
#     F4 → Acc=0.7981 | Prec=0.8021 | Rec=0.7981 | F1=0.7871 | AUROC=0.9627 | PRAUC=0.9224
#     F5 → Acc=0.7692 | Prec=0.7850 | Rec=0.7692 | F1=0.7525 | AUROC=0.9699 | PRAUC=0.9402
#   ✅  Acc:0.7851±0.0429 | Precision:0.7935±0.0367  |Recall:0.7851±0.0429 |F1:0.7706±0.0462 | AUROC:0.9617±0.0195 | PRAUC:0.9198±0.0366 | MCC:0.6868 | Composite:0.8889
#
#   ▶ [14/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.5048 | Prec=0.5947 | Rec=0.5048 | F1=0.3957 | AUROC=0.6805 | PRAUC=0.5270
#     F2 → Acc=0.5000 | Prec=0.4691 | Rec=0.5000 | F1=0.3736 | AUROC=0.6487 | PRAUC=0.5134
#     F3 → Acc=0.4712 | Prec=0.4092 | Rec=0.4712 | F1=0.3368 | AUROC=0.6395 | PRAUC=0.4583
#     F4 → Acc=0.4712 | Prec=0.5417 | Rec=0.4712 | F1=0.3360 | AUROC=0.6746 | PRAUC=0.4970
#     F5 → Acc=0.4615 | Prec=0.4591 | Rec=0.4615 | F1=0.3263 | AUROC=0.6343 | PRAUC=0.4719
#   ✅  Acc:0.4817±0.0173 | Precision:0.4948±0.0655  |Recall:0.4817±0.0173 |F1:0.3537±0.0265 | AUROC:0.6555±0.0186 | PRAUC:0.4935±0.0255 | MCC:0.1754 | Composite:0.5436
#
#   ▶ [15/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.5238 | Prec=0.6354 | Rec=0.5238 | F1=0.4137 | AUROC=0.9293 | PRAUC=0.8578
#     F2 → Acc=0.5288 | Prec=0.6636 | Rec=0.5288 | F1=0.4240 | AUROC=0.9395 | PRAUC=0.8810
#     F3 → Acc=0.5192 | Prec=0.6613 | Rec=0.5192 | F1=0.4094 | AUROC=0.9741 | PRAUC=0.9447
#     F4 → Acc=0.5096 | Prec=0.6590 | Rec=0.5096 | F1=0.3904 | AUROC=0.9580 | PRAUC=0.9055
#     F5 → Acc=0.4808 | Prec=0.4246 | Rec=0.4808 | F1=0.3442 | AUROC=0.9629 | PRAUC=0.9196
#   ✅  Acc:0.5125±0.0171 | Precision:0.6088±0.0926  |Recall:0.5125±0.0171 |F1:0.3963±0.0282 | AUROC:0.9528±0.0162 | PRAUC:0.9017±0.0301 | MCC:0.2715 | Composite:0.7890
#
#   ▶ [16/32] n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6671 | PRAUC=0.5031
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6607 | PRAUC=0.5001
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6005 | PRAUC=0.4240
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6313 | PRAUC=0.4660
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.5945 | PRAUC=0.4340
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6308±0.0298 | PRAUC:0.4654±0.0326 | MCC:0.0000 | Composite:0.5145
#
#   ▶ [17/32] n_estimators=500 | learning_rate=0.01 | max_depth=4 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9305 | PRAUC=0.8497
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9168 | PRAUC=0.8398
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9785 | PRAUC=0.9567
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9501 | PRAUC=0.9029
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9389 | PRAUC=0.8859
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9430±0.0208 | PRAUC:0.8870±0.0418 | MCC:0.0000 | Composite:0.7591
#
#   ▶ [18/32] n_estimators=500 | learning_rate=0.01 | max_depth=4 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6610 | PRAUC=0.5233
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6724 | PRAUC=0.5486
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6305 | PRAUC=0.4448
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6932 | PRAUC=0.4985
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6382 | PRAUC=0.4891
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6591±0.0228 | PRAUC:0.5009±0.0349 | MCC:0.0000 | Composite:0.5357
#
#   ▶ [19/32] n_estimators=500 | learning_rate=0.01 | max_depth=4 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9230 | PRAUC=0.8377
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9021 | PRAUC=0.8286
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9729 | PRAUC=0.9403
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9457 | PRAUC=0.8881
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9377 | PRAUC=0.8809
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9363±0.0236 | PRAUC:0.8751±0.0400 | MCC:0.0000 | Composite:0.7529
#
#   ▶ [20/32] n_estimators=500 | learning_rate=0.01 | max_depth=4 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6807 | PRAUC=0.5266
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6560 | PRAUC=0.5261
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6079 | PRAUC=0.4210
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6725 | PRAUC=0.4847
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6320 | PRAUC=0.4707
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6498±0.0268 | PRAUC:0.4858±0.0393 | MCC:0.0000 | Composite:0.5276
#
#   ▶ [21/32] n_estimators=500 | learning_rate=0.01 | max_depth=10 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9373 | PRAUC=0.8661
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9556 | PRAUC=0.9019
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9872 | PRAUC=0.9693
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9643 | PRAUC=0.9190
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9607 | PRAUC=0.9175
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9610±0.0160 | PRAUC:0.9148±0.0333 | MCC:0.0000 | Composite:0.7743
#
#   ▶ [22/32] n_estimators=500 | learning_rate=0.01 | max_depth=10 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6669 | PRAUC=0.5180
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.7055 | PRAUC=0.5912
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6452 | PRAUC=0.4669
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6956 | PRAUC=0.5104
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.6334 | PRAUC=0.4788
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6693±0.0279 | PRAUC:0.5131±0.0435 | MCC:0.0000 | Composite:0.5432
#
#   ▶ [23/32] n_estimators=500 | learning_rate=0.01 | max_depth=10 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.9317 | PRAUC=0.8531
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9431 | PRAUC=0.8876
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9789 | PRAUC=0.9471
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.9612 | PRAUC=0.9088
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.9581 | PRAUC=0.9150
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.9546±0.0161 | PRAUC:0.9023±0.0311 | MCC:0.0000 | Composite:0.7681
#
#   ▶ [24/32] n_estimators=500 | learning_rate=0.01 | max_depth=10 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6698 | PRAUC=0.5043
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6792 | PRAUC=0.5268
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6224 | PRAUC=0.4495
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6632 | PRAUC=0.4818
#     F5 → Acc=0.4423 | Prec=0.1956 | Rec=0.4423 | F1=0.2713 | AUROC=0.5984 | PRAUC=0.4491
#   ✅  Acc:0.4472±0.0059 | Precision:0.2001±0.0053  |Recall:0.4472±0.0059 |F1:0.2764±0.0061 | AUROC:0.6466±0.0309 | PRAUC:0.4823±0.0305 | MCC:0.0000 | Composite:0.5254
#
#   ▶ [25/32] n_estimators=500 | learning_rate=0.1 | max_depth=4 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.6762 | Prec=0.6908 | Rec=0.6762 | F1=0.6581 | AUROC=0.9242 | PRAUC=0.8524
#     F2 → Acc=0.7692 | Prec=0.7746 | Rec=0.7692 | F1=0.7536 | AUROC=0.9535 | PRAUC=0.8928
#     F3 → Acc=0.8846 | Prec=0.8916 | Rec=0.8846 | F1=0.8825 | AUROC=0.9853 | PRAUC=0.9592
#     F4 → Acc=0.8173 | Prec=0.8074 | Rec=0.8173 | F1=0.8073 | AUROC=0.9589 | PRAUC=0.9204
#     F5 → Acc=0.7788 | Prec=0.7998 | Rec=0.7788 | F1=0.7634 | AUROC=0.9630 | PRAUC=0.9350
#   ✅  Acc:0.7852±0.0680 | Precision:0.7928±0.0644  |Recall:0.7852±0.0680 |F1:0.7730±0.0733 | AUROC:0.9570±0.0196 | PRAUC:0.9120±0.0368 | MCC:0.6849 | Composite:0.8847
#
#   ▶ [26/32] n_estimators=500 | learning_rate=0.1 | max_depth=4 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4952 | Prec=0.6752 | Rec=0.4952 | F1=0.3881 | AUROC=0.6707 | PRAUC=0.5299
#     F2 → Acc=0.4904 | Prec=0.4670 | Rec=0.4904 | F1=0.3574 | AUROC=0.6552 | PRAUC=0.5195
#     F3 → Acc=0.4519 | Prec=0.3734 | Rec=0.4519 | F1=0.3146 | AUROC=0.6472 | PRAUC=0.4650
#     F4 → Acc=0.4712 | Prec=0.5173 | Rec=0.4712 | F1=0.3502 | AUROC=0.6951 | PRAUC=0.4963
#     F5 → Acc=0.4808 | Prec=0.4724 | Rec=0.4808 | F1=0.3728 | AUROC=0.6543 | PRAUC=0.5005
#   ✅  Acc:0.4779±0.0154 | Precision:0.5011±0.0989  |Recall:0.4779±0.0154 |F1:0.3566±0.0248 | AUROC:0.6645±0.0171 | PRAUC:0.5023±0.0223 | MCC:0.1564 | Composite:0.5482
#
#   ▶ [27/32] n_estimators=500 | learning_rate=0.1 | max_depth=4 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.5524 | Prec=0.6448 | Rec=0.5524 | F1=0.4623 | AUROC=0.9238 | PRAUC=0.8474
#     F2 → Acc=0.5385 | Prec=0.6659 | Rec=0.5385 | F1=0.4378 | AUROC=0.9153 | PRAUC=0.8411
#     F3 → Acc=0.5481 | Prec=0.6683 | Rec=0.5481 | F1=0.4592 | AUROC=0.9752 | PRAUC=0.9506
#     F4 → Acc=0.5192 | Prec=0.6613 | Rec=0.5192 | F1=0.4094 | AUROC=0.9484 | PRAUC=0.8918
#     F5 → Acc=0.5288 | Prec=0.6565 | Rec=0.5288 | F1=0.4272 | AUROC=0.9463 | PRAUC=0.8982
#   ✅  Acc:0.5374±0.0122 | Precision:0.6593±0.0083  |Recall:0.5374±0.0122 |F1:0.4392±0.0199 | AUROC:0.9418±0.0210 | PRAUC:0.8858±0.0397 | MCC:0.3226 | Composite:0.7883
#
#   ▶ [28/32] n_estimators=500 | learning_rate=0.1 | max_depth=4 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6863 | PRAUC=0.5333
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6560 | PRAUC=0.5217
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6043 | PRAUC=0.4177
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6712 | PRAUC=0.4803
#     F5 → Acc=0.4519 | Prec=0.4187 | Rec=0.4519 | F1=0.2915 | AUROC=0.6405 | PRAUC=0.4656
#   ✅  Acc:0.4492±0.0055 | Precision:0.2447±0.0871  |Recall:0.4492±0.0055 |F1:0.2805±0.0079 | AUROC:0.6517±0.0281 | PRAUC:0.4837±0.0415 | MCC:0.0456 | Composite:0.5282
#
#   ▶ [29/32] n_estimators=500 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.7048 | Prec=0.7176 | Rec=0.7048 | F1=0.6871 | AUROC=0.9298 | PRAUC=0.8632
#     F2 → Acc=0.7981 | Prec=0.8005 | Rec=0.7981 | F1=0.7857 | AUROC=0.9641 | PRAUC=0.9090
#     F3 → Acc=0.8942 | Prec=0.8995 | Rec=0.8942 | F1=0.8917 | AUROC=0.9901 | PRAUC=0.9752
#     F4 → Acc=0.8365 | Prec=0.8249 | Rec=0.8365 | F1=0.8276 | AUROC=0.9642 | PRAUC=0.9262
#     F5 → Acc=0.7692 | Prec=0.7850 | Rec=0.7692 | F1=0.7525 | AUROC=0.9725 | PRAUC=0.9490
#   ✅  Acc:0.8006±0.0636 | Precision:0.8055±0.0590  |Recall:0.8006±0.0636 |F1:0.7889±0.0689 | AUROC:0.9641±0.0196 | PRAUC:0.9245±0.0379 | MCC:0.7078 | Composite:0.8964
#
#   ▶ [30/32] n_estimators=500 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.5143 | Prec=0.6042 | Rec=0.5143 | F1=0.4107 | AUROC=0.6770 | PRAUC=0.5252
#     F2 → Acc=0.5000 | Prec=0.4691 | Rec=0.5000 | F1=0.3736 | AUROC=0.6612 | PRAUC=0.5308
#     F3 → Acc=0.4808 | Prec=0.4464 | Rec=0.4808 | F1=0.3583 | AUROC=0.6490 | PRAUC=0.4657
#     F4 → Acc=0.5000 | Prec=0.6569 | Rec=0.5000 | F1=0.3908 | AUROC=0.6881 | PRAUC=0.5146
#     F5 → Acc=0.4615 | Prec=0.4736 | Rec=0.4615 | F1=0.3412 | AUROC=0.6447 | PRAUC=0.4845
#   ✅  Acc:0.4913±0.0183 | Precision:0.5300±0.0843  |Recall:0.4913±0.0183 |F1:0.3749±0.0243 | AUROC:0.6640±0.0164 | PRAUC:0.5042±0.0250 | MCC:0.1992 | Composite:0.5532
#
#   ▶ [31/32] n_estimators=500 | learning_rate=0.1 | max_depth=10 | rate_drop=0.5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.5524 | Prec=0.6292 | Rec=0.5524 | F1=0.4610 | AUROC=0.9327 | PRAUC=0.8653
#     F2 → Acc=0.5673 | Prec=0.6481 | Rec=0.5673 | F1=0.4867 | AUROC=0.9443 | PRAUC=0.8883
#     F3 → Acc=0.6058 | Prec=0.6588 | Rec=0.6058 | F1=0.5413 | AUROC=0.9788 | PRAUC=0.9525
#     F4 → Acc=0.5769 | Prec=0.6415 | Rec=0.5769 | F1=0.5005 | AUROC=0.9612 | PRAUC=0.9131
#     F5 → Acc=0.6154 | Prec=0.6789 | Rec=0.6154 | F1=0.5470 | AUROC=0.9633 | PRAUC=0.9221
#   ✅  Acc:0.5836±0.0236 | Precision:0.6513±0.0168  |Recall:0.5836±0.0236 |F1:0.5073±0.0327 | AUROC:0.9561±0.0160 | PRAUC:0.9082±0.0297 | MCC:0.3992 | Composite:0.8160
#
#   ▶ [32/32] n_estimators=500 | learning_rate=0.1 | max_depth=10 | rate_drop=0.5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4381 | Prec=0.1919 | Rec=0.4381 | F1=0.2669 | AUROC=0.6731 | PRAUC=0.5107
#     F2 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6688 | PRAUC=0.5105
#     F3 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6149 | PRAUC=0.4396
#     F4 → Acc=0.4519 | Prec=0.2042 | Rec=0.4519 | F1=0.2813 | AUROC=0.6448 | PRAUC=0.4781
#     F5 → Acc=0.4519 | Prec=0.4187 | Rec=0.4519 | F1=0.2915 | AUROC=0.6029 | PRAUC=0.4427
#   ✅  Acc:0.4492±0.0055 | Precision:0.2447±0.0871  |Recall:0.4492±0.0055 |F1:0.2805±0.0079 | AUROC:0.6409±0.0281 | PRAUC:0.4763±0.0311 | MCC:0.0456 | Composite:0.5221
#
# 🏆 Best config : n_estimators=500 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | lambda_=0.1 | n_measurements=None
#    Composite   : 0.8964097222376002 (AUROC=0.9641±0.0196 | PRAUC=0.9245154985744486 | Acc=0.8005677655677657 |Prec=0.8055150987694889 |Rec=0.8005677655677657) |

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_dart_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/qxgb_dart_full.csv

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB Dart ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB Dart ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [QXGB Dart (full)] recorded | Exec. time: 367.3s

# %% [markdown]
# ## 3. QCat (Hybrid Quantum Catboost)

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [100, 500],
  'depth': [4, 10],
  'learning_rate': [0.01, 0.1],
  'l2_leaf_reg': [1, 5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qcat_full")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qcat import QCAT
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qcat', QCAT(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_seed=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\gs\quantum\all\qcat_full.log
# 🕒 Started: 2026-05-22T16:50:04
# 🔬 Search space: 2 iterations × 2 depth × 2 learning_rate × 2 l2_leaf_reg × 2 lambda_ × 1 n_measurements =  32 configs × 5 folds = 160 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/32] iterations=100 | depth=4 | learning_rate=0.01 | l2_leaf_reg=1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.6857 | Prec=0.7027 | Rec=0.6857 | F1=0.6587 | AUROC=0.8903 | PRAUC=0.7862
#     F2 → Acc=0.7308 | Prec=0.7394 | Rec=0.7308 | F1=0.7016 | AUROC=0.9118 | PRAUC=0.8031
#     F3 → Acc=0.7692 | Prec=0.7723 | Rec=0.7692 | F1=0.7469 | AUROC=0.9582 | PRAUC=0.8948
#     F4 → Acc=0.7692 | Prec=0.7600 | Rec=0.7692 | F1=0.7557 | AUROC=0.9251 | PRAUC=0.8575
#     F5 → Acc=0.7404 | Prec=0.7532 | Rec=0.7404 | F1=0.7155 | AUROC=0.9399 | PRAUC=0.8630
#   ✅  Acc:0.7391±0.0308 | Precision:0.7455±0.0239  |Recall:0.7391±0.0308 |F1:0.7157±0.0347 | AUROC:0.9251±0.0232 | PRAUC:0.8409±0.0402 | MCC:0.6165 | Composite:0.8350
#
#   ▶ [2/32] iterations=100 | depth=4 | learning_rate=0.01 | l2_leaf_reg=1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4571 | Prec=0.4063 | Rec=0.4571 | F1=0.3335 | AUROC=0.5874 | PRAUC=0.4345
#     F2 → Acc=0.4712 | Prec=0.6505 | Rec=0.4712 | F1=0.3220 | AUROC=0.6444 | PRAUC=0.4990
#     F3 → Acc=0.4519 | Prec=0.3730 | Rec=0.4519 | F1=0.3273 | AUROC=0.6025 | PRAUC=0.4286
#     F4 → Acc=0.4712 | Prec=0.5417 | Rec=0.4712 | F1=0.3360 | AUROC=0.6721 | PRAUC=0.4872
#     F5 → Acc=0.4423 | Prec=0.3546 | Rec=0.4423 | F1=0.3288 | AUROC=0.6275 | PRAUC=0.4543
#   ✅  Acc:0.4587±0.0112 | Precision:0.4652±0.1135  |Recall:0.4587±0.0112 |F1:0.3295±0.0049 | AUROC:0.6268±0.0300 | PRAUC:0.4607±0.0280 | MCC:0.0895 | Composite:0.5154
#
#   ▶ [3/32] iterations=100 | depth=4 | learning_rate=0.01 | l2_leaf_reg=5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.6762 | Prec=0.7016 | Rec=0.6762 | F1=0.6513 | AUROC=0.8713 | PRAUC=0.7615
#     F2 → Acc=0.6442 | Prec=0.6901 | Rec=0.6442 | F1=0.6002 | AUROC=0.8844 | PRAUC=0.7564
#     F3 → Acc=0.7596 | Prec=0.7715 | Rec=0.7596 | F1=0.7374 | AUROC=0.9492 | PRAUC=0.8740
#     F4 → Acc=0.7212 | Prec=0.7197 | Rec=0.7212 | F1=0.7025 | AUROC=0.9184 | PRAUC=0.8489
#     F5 → Acc=0.6731 | Prec=0.7149 | Rec=0.6731 | F1=0.6371 | AUROC=0.9291 | PRAUC=0.8390
#   ✅  Acc:0.6949±0.0407 | Precision:0.7195±0.0280  |Recall:0.6949±0.0407 |F1:0.6657±0.0486 | AUROC:0.9105±0.0287 | PRAUC:0.8159±0.0480 | MCC:0.5498 | Composite:0.8071
#
#   ▶ [4/32] iterations=100 | depth=4 | learning_rate=0.01 | l2_leaf_reg=5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4571 | Prec=0.4424 | Rec=0.4571 | F1=0.3322 | AUROC=0.5958 | PRAUC=0.4381
#     F2 → Acc=0.4615 | Prec=0.4274 | Rec=0.4615 | F1=0.3016 | AUROC=0.6284 | PRAUC=0.4903
#     F3 → Acc=0.4615 | Prec=0.4311 | Rec=0.4615 | F1=0.3202 | AUROC=0.5982 | PRAUC=0.4142
#     F4 → Acc=0.4615 | Prec=0.5376 | Rec=0.4615 | F1=0.3170 | AUROC=0.6750 | PRAUC=0.5001
#     F5 → Acc=0.4231 | Prec=0.2951 | Rec=0.4231 | F1=0.2957 | AUROC=0.6134 | PRAUC=0.4342
#   ✅  Acc:0.4530±0.0150 | Precision:0.4267±0.0773  |Recall:0.4530±0.0150 |F1:0.3134±0.0132 | AUROC:0.6222±0.0289 | PRAUC:0.4554±0.0337 | MCC:0.0655 | Composite:0.5102
#
#   ▶ [5/32] iterations=100 | depth=4 | learning_rate=0.1 | l2_leaf_reg=1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.7143 | Prec=0.7178 | Rec=0.7143 | F1=0.7054 | AUROC=0.9295 | PRAUC=0.8472
#     F2 → Acc=0.8462 | Prec=0.8586 | Rec=0.8462 | F1=0.8391 | AUROC=0.9768 | PRAUC=0.9277
#     F3 → Acc=0.9327 | Prec=0.9364 | Rec=0.9327 | F1=0.9304 | AUROC=0.9913 | PRAUC=0.9821
#     F4 → Acc=0.8654 | Prec=0.8682 | Rec=0.8654 | F1=0.8636 | AUROC=0.9501 | PRAUC=0.9099
#     F5 → Acc=0.8462 | Prec=0.8590 | Rec=0.8462 | F1=0.8445 | AUROC=0.9720 | PRAUC=0.9487
#   ✅  Acc:0.8409±0.0709 | Precision:0.8480±0.0713  |Recall:0.8409±0.0709 |F1:0.8366±0.0732 | AUROC:0.9640±0.0217 | PRAUC:0.9231±0.0449 | MCC:0.7684 | Composite:0.9093
#
#   ▶ [6/32] iterations=100 | depth=4 | learning_rate=0.1 | l2_leaf_reg=1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4286 | Prec=0.4220 | Rec=0.4286 | F1=0.3545 | AUROC=0.6039 | PRAUC=0.4845
#     F2 → Acc=0.5096 | Prec=0.5073 | Rec=0.5096 | F1=0.4177 | AUROC=0.6676 | PRAUC=0.5217
#     F3 → Acc=0.4615 | Prec=0.3972 | Rec=0.4615 | F1=0.3962 | AUROC=0.6405 | PRAUC=0.4725
#     F4 → Acc=0.4808 | Prec=0.4571 | Rec=0.4808 | F1=0.4198 | AUROC=0.6881 | PRAUC=0.4718
#     F5 → Acc=0.4808 | Prec=0.4787 | Rec=0.4808 | F1=0.4360 | AUROC=0.6498 | PRAUC=0.4899
#   ✅  Acc:0.4723±0.0267 | Precision:0.4525±0.0393  |Recall:0.4723±0.0267 |F1:0.4048±0.0282 | AUROC:0.6500±0.0282 | PRAUC:0.4881±0.0182 | MCC:0.1514 | Composite:0.5368
#
#   ▶ [7/32] iterations=100 | depth=4 | learning_rate=0.1 | l2_leaf_reg=5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.6952 | Prec=0.6897 | Rec=0.6952 | F1=0.6793 | AUROC=0.9170 | PRAUC=0.8274
#     F2 → Acc=0.7885 | Prec=0.7814 | Rec=0.7885 | F1=0.7708 | AUROC=0.9560 | PRAUC=0.8866
#     F3 → Acc=0.8750 | Prec=0.8839 | Rec=0.8750 | F1=0.8717 | AUROC=0.9851 | PRAUC=0.9581
#     F4 → Acc=0.8365 | Prec=0.8225 | Rec=0.8365 | F1=0.8263 | AUROC=0.9464 | PRAUC=0.8943
#     F5 → Acc=0.7885 | Prec=0.7947 | Rec=0.7885 | F1=0.7709 | AUROC=0.9682 | PRAUC=0.9438
#   ✅  Acc:0.7967±0.0602 | Precision:0.7944±0.0631  |Recall:0.7967±0.0602 |F1:0.7838±0.0645 | AUROC:0.9545±0.0228 | PRAUC:0.9020±0.0464 | MCC:0.7016 | Composite:0.8844
#
#   ▶ [8/32] iterations=100 | depth=4 | learning_rate=0.1 | l2_leaf_reg=5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4857 | Prec=0.5382 | Rec=0.4857 | F1=0.3934 | AUROC=0.6037 | PRAUC=0.4773
#     F2 → Acc=0.5192 | Prec=0.5786 | Rec=0.5192 | F1=0.4199 | AUROC=0.6518 | PRAUC=0.5172
#     F3 → Acc=0.4808 | Prec=0.4007 | Rec=0.4808 | F1=0.3978 | AUROC=0.6976 | PRAUC=0.5461
#     F4 → Acc=0.5385 | Prec=0.5808 | Rec=0.5385 | F1=0.4540 | AUROC=0.6870 | PRAUC=0.4910
#     F5 → Acc=0.4712 | Prec=0.3915 | Rec=0.4712 | F1=0.3916 | AUROC=0.6491 | PRAUC=0.4741
#   ✅  Acc:0.4991±0.0255 | Precision:0.4980±0.0846  |Recall:0.4991±0.0255 |F1:0.4113±0.0236 | AUROC:0.6578±0.0331 | PRAUC:0.5011±0.0271 | MCC:0.2011 | Composite:0.5527
#
#   ▶ [9/32] iterations=100 | depth=10 | learning_rate=0.01 | l2_leaf_reg=1 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.8381 | Prec=0.8422 | Rec=0.8381 | F1=0.8373 | AUROC=0.9424 | PRAUC=0.8923
#     F2 → Acc=0.8365 | Prec=0.8201 | Rec=0.8365 | F1=0.8242 | AUROC=0.9652 | PRAUC=0.9210
#     F3 → Acc=0.8654 | Prec=0.8639 | Rec=0.8654 | F1=0.8628 | AUROC=0.9829 | PRAUC=0.9538
#     F4 → Acc=0.8846 | Prec=0.8900 | Rec=0.8846 | F1=0.8849 | AUROC=0.9529 | PRAUC=0.9220
#     F5 → Acc=0.8558 | Prec=0.8604 | Rec=0.8558 | F1=0.8527 | AUROC=0.9688 | PRAUC=0.9373
#   ✅  Acc:0.8561±0.0179 | Precision:0.8553±0.0233  |Recall:0.8561±0.0179 |F1:0.8524±0.0209 | AUROC:0.9624±0.0138 | PRAUC:0.9253±0.0204 | MCC:0.7907 | Composite:0.9146
#
#   ▶ [10/32] iterations=100 | depth=10 | learning_rate=0.01 | l2_leaf_reg=1 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4571 | Prec=0.4991 | Rec=0.4571 | F1=0.3465 | AUROC=0.6495 | PRAUC=0.4964
#     F2 → Acc=0.4904 | Prec=0.6406 | Rec=0.4904 | F1=0.3700 | AUROC=0.6669 | PRAUC=0.5179
#     F3 → Acc=0.4615 | Prec=0.3788 | Rec=0.4615 | F1=0.3498 | AUROC=0.6167 | PRAUC=0.4254
#     F4 → Acc=0.4904 | Prec=0.6857 | Rec=0.4904 | F1=0.3716 | AUROC=0.6645 | PRAUC=0.4956
#     F5 → Acc=0.4519 | Prec=0.3741 | Rec=0.4519 | F1=0.3363 | AUROC=0.6319 | PRAUC=0.4608
#   ✅  Acc:0.4703±0.0167 | Precision:0.5157±0.1293  |Recall:0.4703±0.0167 |F1:0.3549±0.0138 | AUROC:0.6459±0.0192 | PRAUC:0.4792±0.0325 | MCC:0.1306 | Composite:0.5318
#
#   ▶ [11/32] iterations=100 | depth=10 | learning_rate=0.01 | l2_leaf_reg=5 | lambda_=0.1 | n_measurements=None
#     F1 → Acc=0.8190 | Prec=0.8244 | Rec=0.8190 | F1=0.8147 | AUROC=0.9369 | PRAUC=0.8822
#     F2 → Acc=0.7981 | Prec=0.7841 | Rec=0.7981 | F1=0.7835 | AUROC=0.9563 | PRAUC=0.8995
#     F3 → Acc=0.8750 | Prec=0.8731 | Rec=0.8750 | F1=0.8702 | AUROC=0.9792 | PRAUC=0.9480
#     F4 → Acc=0.8750 | Prec=0.8813 | Rec=0.8750 | F1=0.8758 | AUROC=0.9559 | PRAUC=0.9281
#     F5 → Acc=0.8558 | Prec=0.8318 | Rec=0.8558 | F1=0.8431 | AUROC=0.9704 | PRAUC=0.9341
#   ✅  Acc:0.8446±0.0310 | Precision:0.8390±0.0353  |Recall:0.8446±0.0310 |F1:0.8375±0.0346 | AUROC:0.9597±0.0144 | PRAUC:0.9184±0.0240 | MCC:0.7735 | Composite:0.9076
#
#   ▶ [12/32] iterations=100 | depth=10 | learning_rate=0.01 | l2_leaf_reg=5 | lambda_=5 | n_measurements=None
#     F1 → Acc=0.4667 | Prec=0.5186 | Rec=0.4667 | F1=0.3418 | AUROC=0.6585 | PRAUC=0.4834
#     F2 → Acc=0.4808 | Prec=0.5669 | Rec=0.4808 | F1=0.3530 | AUROC=0.6651 | PRAUC=0.4925
#     F3 → Acc=0.4615 | Prec=0.4074 | Rec=0.4615 | F1=0.3690 | AUROC=0.5845 | PRAUC=0.3981
#     F4 → Acc=0.4712 | Prec=0.5889 | Rec=0.4712 | F1=0.3502 | AUROC=0.6614 | PRAUC=0.4787
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 61
#      57         **params
#      58       ))
#      59     ])
#      60
# ---> 61     model.fit(X_train, y_train)
#      62
#      63     y_pred = model.predict(X_val)
#      64     y_prob = model.predict_proba(X_val)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\sklearn\pipeline.py:621, in Pipeline.fit(self, X, y, **params)
#     615     if self._final_estimator != "passthrough":
#     616         last_step_params = self._get_metadata_for_step(
#     617             step_idx=len(self) - 1,
#     618             step_params=routed_params[self.steps[-1][0]],
#     619             all_params=params,
#     620         )
# --> 621         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     623 return self
#
# File c:\`Bioinformatics\quantum-gesang\codes\model\quantum\qcat.py:73, in QCAT.fit(self, X, y)
#      70 self.classes_ = np.unique(y)
#      71 self.model_ = self._build_model()
# ---> 73 K_train = self.qkernel_.evaluate(X, X)
#      74 self.model_.fit(K_train, y)
#      75 return self
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit_machine_learning\kernels\fidelity_statevector_kernel.py:121, in FidelityStatevectorKernel.evaluate(self, x_vec, y_vec)
#     118 elif not np.array_equal(x_vec, y_vec):
#     119     is_symmetric = False
# --> 121 return self._evaluate(x_vec, y_vec, is_symmetric)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit_machine_learning\kernels\fidelity_statevector_kernel.py:126, in FidelityStatevectorKernel._evaluate(self, x_vec, y_vec, is_symmetric)
#     123 def _evaluate(self, x_vec: np.ndarray, y_vec: np.ndarray, is_symmetric: bool):
#     124     kernel_shape = (x_vec.shape[0], y_vec.shape[0])
# --> 126     x_svs = [self._get_statevector(tuple(x)) for x in x_vec]
#     127     y_svs = [self._get_statevector(tuple(y)) for y in y_vec]
#     129     kernel_matrix = np.ones(kernel_shape)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit_machine_learning\kernels\fidelity_statevector_kernel.py:144, in FidelityStatevectorKernel._get_statevector_(self, param_values)
#     141 def _get_statevector_(self, param_values: tuple[float]) -> np.ndarray:
#     142     # lru_cache requires hashable function arguments.
#     143     qc = self._feature_map.assign_parameters(param_values)
# --> 144     return self._statevector_type(qc).data
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:101, in Statevector.__init__(self, data, dims)
#      99     self._data = np.ravel(data.data)
#     100 elif isinstance(data, (QuantumCircuit, Instruction)):
# --> 101     self._data = Statevector.from_instruction(data).data
#     102 else:
#     103     raise QiskitError("Invalid input data format for Statevector")
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:846, in Statevector.from_instruction(cls, instruction)
#     844 init[0] = 1.0
#     845 vec = Statevector(init, dims=instruction.num_qubits * (2,))
# --> 846 return Statevector._evolve_instruction(vec, instruction)
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:1042, in Statevector._evolve_instruction(statevec, obj, qargs)
#    1040     else:
#    1041         new_qargs = [qargs[qubits[tup]] for tup in instruction.qubits]
# -> 1042     Statevector._evolve_instruction(statevec, instruction.operation, qargs=new_qargs)
#    1043 return statevec
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:984, in Statevector._evolve_instruction(statevec, obj, qargs)
#     980 mat = Operator._instruction_to_matrix(obj)
#     981 if mat is not None:
#     982     # Perform the composition and inplace update the current state
#     983     # of the operator
# --> 984     return Statevector._evolve_operator(statevec, Operator(mat), qargs=qargs)
#     986 # Special instruction types
#     987 if isinstance(obj, Reset):
#
# File c:\`Bioinformatics\quantum-gesang\codes\.quantum\Lib\site-packages\qiskit\quantum_info\states\statevector.py:957, in Statevector._evolve_operator(statevec, oper, qargs)
#     953 tensor_shape = tensor.shape
#     955 # Perform contraction
#     956 tensor = np.reshape(
# --> 957     np.dot(oper.data, np.reshape(tensor, contract_shape)),
#     958     tensor_shape,
#     959 )
#     961 # Transpose back to  original subsystem spec and flatten
#     962 statevec._data = np.reshape(np.transpose(tensor, axes_inv), new_shape.shape[0])
#
# KeyboardInterrupt:

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qcat_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QCat ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QCat ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# # Linear

# %%
QKERNEL='linear'

# %% [markdown]
# ## 1. QSVC

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [0.1, 1, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qsvc_linear")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qsvc import QSVCWrapper
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', QSVCWrapper(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_state=42, 
        decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qsvc_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QSVC ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QSVC ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 2. QXGB (Hybrid Quantum XGBoost)

# %% [markdown]
# ### 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_gbtree_linear")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='gbtree',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_gbtree_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB GBTree ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB GBTree ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ### 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  'rate_drop': [0.1, 0.5],
  'skip_drop': [0.1, 0.5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_dart_linear")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='dart',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_dart_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB Dart ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB Dart ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 3. QCat (Hybrid Quantum Catboost)

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [100, 500],
  'depth': [4, 10],
  'learning_rate': [0.01, 0.1],
  'l2_leaf_reg': [1, 5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qcat_linear")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qcat import QCAT
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qcat', QCAT(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_seed=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qcat_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QCat ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QCat ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# # Circular

# %%
QKERNEL='circular'

# %% [markdown]
# ## 1. QSVC

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [0.1, 1, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qsvc_circular")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qsvc import QSVCWrapper
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', QSVCWrapper(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_state=42, 
        decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qsvc_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QSVC ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QSVC ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 2. QXGB (Hybrid Quantum XGBoost)

# %% [markdown]
# ### 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_gbtree_circular")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='gbtree',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_gbtree_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB GBTree ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB GBTree ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ### 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  'rate_drop': [0.1, 0.5],
  'skip_drop': [0.1, 0.5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_dart_circular")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='dart',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_dart_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB Dart ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB Dart ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 3. QCat (Hybrid Quantum Catboost)

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [100, 500],
  'depth': [4, 10],
  'learning_rate': [0.01, 0.1],
  'l2_leaf_reg': [1, 5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qcat_circular")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qcat import QCAT
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qcat', QCAT(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_seed=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qcat_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QCat ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QCat ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# # Pauli X

# %%
QKERNEL='pauli_x'

# %% [markdown]
# ## 1. QSVC

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [0.1, 1, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qsvc_paulix")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qsvc import QSVCWrapper
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', QSVCWrapper(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_state=42, 
        decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qsvc_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QSVC ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QSVC ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 2. QXGB (Hybrid Quantum XGBoost)

# %% [markdown]
# ### 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_gbtree_paulix")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='gbtree',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_gbtree_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB GBTree ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB GBTree ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ### 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  'rate_drop': [0.1, 0.5],
  'skip_drop': [0.1, 0.5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_dart_paulix")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='dart',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_dart_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB Dart ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB Dart ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 3. QCat (Hybrid Quantum Catboost)

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [100, 500],
  'depth': [4, 10],
  'learning_rate': [0.01, 0.1],
  'l2_leaf_reg': [1, 5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qcat_paulix")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qcat import QCAT
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qcat', QCAT(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_seed=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qcat_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QCat ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QCat ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# # Pauli Y

# %%
QKERNEL='pauli_y'

# %% [markdown]
# ## 1. QSVC

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [0.1, 1, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qsvc_pauliy")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qsvc import QSVCWrapper
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', QSVCWrapper(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_state=42, 
        decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qsvc_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QSVC ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QSVC ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 2. QXGB (Hybrid Quantum XGBoost)

# %% [markdown]
# ### 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_gbtree_pauliy")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='gbtree',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_gbtree_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB GBTree ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB GBTree ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ### 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  'rate_drop': [0.1, 0.5],
  'skip_drop': [0.1, 0.5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_dart_pauliy")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='dart',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_dart_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB Dart ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB Dart ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 3. QCat (Hybrid Quantum Catboost)

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [100, 500],
  'depth': [4, 10],
  'learning_rate': [0.01, 0.1],
  'l2_leaf_reg': [1, 5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qcat_pauliy")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qcat import QCAT
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qcat', QCAT(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_seed=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qcat_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QCat ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QCat ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# # Pauli Z

# %%
QKERNEL='pauli_z'

# %% [markdown]
# ## 1. QSVC

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [0.1, 1, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qsvc_pauliz")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qsvc import QSVCWrapper
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', QSVCWrapper(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_state=42, 
        decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qsvc_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QSVC ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QSVC ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 2. QXGB (Hybrid Quantum XGBoost)

# %% [markdown]
# ### 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_gbtree_pauliz")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='gbtree',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_gbtree_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB GBTree ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB GBTree ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ### 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'n_estimators': [100, 500],
  'learning_rate': [0.01, 0.1],
  'max_depth': [4, 10],

  'rate_drop': [0.1, 0.5],
  'skip_drop': [0.1, 0.5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qxgb_dart_pauliz")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qxgb import QXGB
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qxgb', QXGB(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        booster='dart',
        random_state=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qxgb_dart_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QXGB Dart ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QXGB Dart ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ## 3. QCat (Hybrid Quantum Catboost)

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [100, 500],
  'depth': [4, 10],
  'learning_rate': [0.01, 0.1],
  'l2_leaf_reg': [1, 5],

  # quantum params
  'lambda_': [0.1, 5],
  'n_measurements': [256, 1024],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("qcat_pauliz")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from model.quantum.qcat import QCAT
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # n_measurement dipakai kalau mode != 'fsk'
    
    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('qcat', QCAT(
        # quantum
        kernel=QKERNEL, 
        mode=mode, 
        n_qubits=n_optimal,
        n_features=n_optimal,

        # classical
        random_seed=42,
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    #  
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
print(
    f"   Composite   : {best_result['composite']} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)

# %%
import pandas as pd
import os

dirpath = "./results/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + f"qcat_{QKERNEL}_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")

# %%
# ── Collect best result ──
best_result['model'] = f"QCat ({QKERNEL})"
all_best.append(dict(best_result))
log(f"✅ [QCat ({QKERNEL})] recorded | Exec. time: {best_result['execution_time']:.1f}s")

# %% [markdown]
# ---
# # 📊 Tabel Evaluasi Akhir

# %%
# ════════════════════════════════════════════════════════════
# 📊 TABEL EVALUASI AKHIR – Quantum Models
# ════════════════════════════════════════════════════════════
import pandas as pd

KERNEL_ORDER = {'full': 0, 'linear': 1, 'circular': 2,
                'pauli_x': 3, 'pauli_y': 4, 'pauli_z': 5}

def build_eval_table(all_best):
    rows = []
    for r in all_best:
        params_str = ' | '.join(f'{k}={v}' for k, v in r.get('params', {}).items())
        rows.append({
            'Model'          : r['model'],
            'Accuracy'       : r['acc'],
            'Precision'      : r['prec'],
            'Recall'         : r['rec'],
            'F1-Score'       : r['f1'],
            'ROC-AUC'        : r['roc'],
            'PR-AUC'         : r['pra'],
            'Exec. Time (s)' : round(r['execution_time'], 2) if 'execution_time' in r else 'N/A',
            'Best Params'    : params_str,
        })
    df = pd.DataFrame(rows)
    def _kord(m):
        for k, v in KERNEL_ORDER.items():
            if k in m.lower(): return v
        return 99
    df['_kord'] = df['Model'].apply(_kord)
    df = df.sort_values(['_kord', 'ROC-AUC'], ascending=[True, False])
    df = df.drop(columns=['_kord']).reset_index(drop=True)
    df.index += 1
    return df

pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.4f}'.format)

eval_df = build_eval_table(all_best)
display(eval_df)

# %%
import os
os.makedirs('./results', exist_ok=True)
eval_df.to_csv('./results/eval_quantum_final_hpo.csv', index=True)
print('✅ Saved: ./results/eval_quantum_final_hpo.csv')
