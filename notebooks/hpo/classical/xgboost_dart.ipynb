# %% [markdown]
# # XGBoost Dart — Hyperparameter Optimization

# %%
# !python -m pip install numpy pandas \
#     qiskit-aer qiskit-algorithms qiskit-machine-learning qiskit-ibm-runtime \
#     pylatexenc ucimlrepo \
#     xgboost catboost seaborn libsvm-official \
#     jinja2 scikit-optimize tensorflow imbalanced-learn

# %%
import sys
import os

cwd = os.path.abspath(os.getcwd())
project_root = cwd.split("quantum-multiclass-classification")[0] + "quantum-multiclass-classification"
print(f"Project root: {project_root}")

sys.path.append(os.path.abspath(project_root))

from utils.prepare_data import prepare_data
# Out:
# Project root: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

import sys
import importlib

def reload_package(package_name):
    modules_to_reload = [name for name in sys.modules if name.startswith(package_name)]
    for name in sorted(modules_to_reload, reverse=True):
        importlib.reload(sys.modules[name])

reload_package("model")
reload_package("utils")

# %%
dataset_path = os.path.join(project_root, "dataset", "Dataset_TehHijau.csv")
feature_cols = [
        "MQ3", "TGS822", "TGS2602", "MQ5", "MQ138", "TGS2620",
        "TGS813", "TGS2600", "TGS2611", "TGS2603", "Humidity", "Celsius",
    ]
target_cols = "Kategori"

import pandas as pd
data = pd.read_csv(dataset_path)
data.head(10)
# Out:
#     MQ3  TGS822  TGS2602    MQ5  MQ138  TGS2620  TGS813  TGS2600  TGS2611  \
# 0  90.0    43.0     46.0  133.0   97.0     46.0   552.0    289.0    546.0
# 1  90.0    42.0     47.0  133.0   96.0     47.0   551.0    290.0    547.0
# 2  89.0    42.0     47.0  133.0   97.0     45.0   553.0    291.0    547.0
# 3  89.0    41.0     47.0  133.0   96.0     45.0   552.0    290.0    546.0
# 4  90.0    42.0     48.0  132.0   95.0     46.0   552.0    289.0    546.0
# 5  90.0    42.0     46.0  132.0   96.0     45.0   552.0    289.0    545.0
# 6  89.0    43.0     46.0  133.0   96.0     45.0   552.0    291.0    546.0
# 7  90.0    42.0     46.0  132.0   96.0     46.0   551.0    290.0    547.0
# 8  90.0    41.0     47.0  132.0   97.0     46.0   550.0    290.0    548.0
# 9  90.0    41.0     48.0  132.0   95.0     46.0   551.0    289.0    547.0
#
#    TGS2603  Humidity  Celsius Chop_ID Sampling_ID  Aroma  Taste  Color  \
# 0    371.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 1    371.0      46.5     38.9   TR612     TR612_1    2.9     36    3.2
# 2    369.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 3    370.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 4    371.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 5    370.0      46.5     38.8   TR612     TR612_1    2.9     36    3.2
# 6    369.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 7    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 8    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 9    371.0      46.3     38.7   TR612     TR612_1    2.9     36    3.2
#
#    Appearance  Dreg Kategori Standar Kualitas  MQ3_mean  MQ3_min  MQ3_max  \
# 0         2.8   3.2        D             Baik      89.7     89.0       90
# 1         2.8   3.2        D             Baik      89.7     89.0       90
# 2         2.8   3.2        D             Baik      89.7     89.0       90
# 3         2.8   3.2        D             Baik      89.7     89.0       90
# 4         2.8   3.2        D             Baik      89.7     89.0       90
# 5         2.8   3.2        D             Baik      89.7     89.0       90
# 6         2.8   3.2        D             Baik      89.7     89.0       90
# 7         2.8   3.2        D             Baik      89.7     89.0       90
# 8         2.8   3.2        D             Baik      89.7     89.0       90
# 9         2.8   3.2        D             Baik      89.7     89.0       90
#
#     MQ3_std  MQ3_skew  MQ3_kurtosis  MQ3_auc  TGS822_mean  TGS822_min  \
# 0  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 1  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 2  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 3  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 4  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 5  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 6  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 7  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 8  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 9  0.483046 -0.872872     -1.238095    807.0         41.9          41
#
#    TGS822_max  TGS822_std  TGS822_skew  TGS822_kurtosis  TGS822_auc  \
# 0          43    0.737865     0.139942        -0.960433       377.0
# 1          43    0.737865     0.139942        -0.960433       377.0
# 2          43    0.737865     0.139942        -0.960433       377.0
# 3          43    0.737865     0.139942        -0.960433       377.0
# 4          43    0.737865     0.139942        -0.960433       377.0
# 5          43    0.737865     0.139942        -0.960433       377.0
# 6          43    0.737865     0.139942        -0.960433       377.0
# 7          43    0.737865     0.139942        -0.960433       377.0
# 8          43    0.737865     0.139942        -0.960433       377.0
# 9          43    0.737865     0.139942        -0.960433       377.0
#
#    TGS2602_mean  TGS2602_min  TGS2602_max  TGS2602_std  TGS2602_skew  \
# 0          46.8           46           48     0.788811      0.343622
# 1          46.8           46           48     0.788811      0.343622
# 2          46.8           46           48     0.788811      0.343622
# 3          46.8           46           48     0.788811      0.343622
# 4          46.8           46           48     0.788811      0.343622
# 5          46.8           46           48     0.788811      0.343622
# 6          46.8           46           48     0.788811      0.343622
# 7          46.8           46           48     0.788811      0.343622
# 8          46.8           46           48     0.788811      0.343622
# 9          46.8           46           48     0.788811      0.343622
#
#    TGS2602_kurtosis  TGS2602_auc  MQ5_mean  MQ5_min  MQ5_max   MQ5_std  \
# 0         -1.153061        421.0     132.5      132    133.0  0.527046
# 1         -1.153061        421.0     132.5      132    133.0  0.527046
# 2         -1.153061        421.0     132.5      132    133.0  0.527046
# 3         -1.153061        421.0     132.5      132    133.0  0.527046
# 4         -1.153061        421.0     132.5      132    133.0  0.527046
# 5         -1.153061        421.0     132.5      132    133.0  0.527046
# 6         -1.153061        421.0     132.5      132    133.0  0.527046
# 7         -1.153061        421.0     132.5      132    133.0  0.527046
# 8         -1.153061        421.0     132.5      132    133.0  0.527046
# 9         -1.153061        421.0     132.5      132    133.0  0.527046
#
#    MQ5_skew  MQ5_kurtosis  MQ5_auc  MQ138_mean  MQ138_min  MQ138_max  \
# 0       0.0          -2.0   1192.5        96.1         95         97
# 1       0.0          -2.0   1192.5        96.1         95         97
# 2       0.0          -2.0   1192.5        96.1         95         97
# 3       0.0          -2.0   1192.5        96.1         95         97
# 4       0.0          -2.0   1192.5        96.1         95         97
# 5       0.0          -2.0   1192.5        96.1         95         97
# 6       0.0          -2.0   1192.5        96.1         95         97
# 7       0.0          -2.0   1192.5        96.1         95         97
# 8       0.0          -2.0   1192.5        96.1         95         97
# 9       0.0          -2.0   1192.5        96.1         95         97
#
#    MQ138_std  MQ138_skew  MQ138_kurtosis  MQ138_auc  TGS2620_mean  \
# 0   0.737865   -0.139942       -0.960433      865.0          45.7
# 1   0.737865   -0.139942       -0.960433      865.0          45.7
# 2   0.737865   -0.139942       -0.960433      865.0          45.7
# 3   0.737865   -0.139942       -0.960433      865.0          45.7
# 4   0.737865   -0.139942       -0.960433      865.0          45.7
# 5   0.737865   -0.139942       -0.960433      865.0          45.7
# 6   0.737865   -0.139942       -0.960433      865.0          45.7
# 7   0.737865   -0.139942       -0.960433      865.0          45.7
# 8   0.737865   -0.139942       -0.960433      865.0          45.7
# 9   0.737865   -0.139942       -0.960433      865.0          45.7
#
#    TGS2620_min  TGS2620_max  TGS2620_std  TGS2620_skew  TGS2620_kurtosis  \
# 0           45           47     0.674949      0.365675         -0.705532
# 1           45           47     0.674949      0.365675         -0.705532
# 2           45           47     0.674949      0.365675         -0.705532
# 3           45           47     0.674949      0.365675         -0.705532
# 4           45           47     0.674949      0.365675         -0.705532
# 5           45           47     0.674949      0.365675         -0.705532
# 6           45           47     0.674949      0.365675         -0.705532
# 7           45           47     0.674949      0.365675         -0.705532
# 8           45           47     0.674949      0.365675         -0.705532
# 9           45           47     0.674949      0.365675         -0.705532
#
#    TGS2620_auc  TGS813_mean  TGS813_min  TGS813_max  TGS813_std  TGS813_skew  \
# 0        411.0        551.6         550         553    0.843274    -0.328125
# 1        411.0        551.6         550         553    0.843274    -0.328125
# 2        411.0        551.6         550         553    0.843274    -0.328125
# 3        411.0        551.6         550         553    0.843274    -0.328125
# 4        411.0        551.6         550         553    0.843274    -0.328125
# 5        411.0        551.6         550         553    0.843274    -0.328125
# 6        411.0        551.6         550         553    0.843274    -0.328125
# 7        411.0        551.6         550         553    0.843274    -0.328125
# 8        411.0        551.6         550         553    0.843274    -0.328125
# 9        411.0        551.6         550         553    0.843274    -0.328125
#
#    TGS813_kurtosis  TGS813_auc  TGS2600_mean  TGS2600_min  TGS2600_max  \
# 0        -0.335937      4964.5         289.8        289.0          291
# 1        -0.335937      4964.5         289.8        289.0          291
# 2        -0.335937      4964.5         289.8        289.0          291
# 3        -0.335937      4964.5         289.8        289.0          291
# 4        -0.335937      4964.5         289.8        289.0          291
# 5        -0.335937      4964.5         289.8        289.0          291
# 6        -0.335937      4964.5         289.8        289.0          291
# 7        -0.335937      4964.5         289.8        289.0          291
# 8        -0.335937      4964.5         289.8        289.0          291
# 9        -0.335937      4964.5         289.8        289.0          291
#
#    TGS2600_std  TGS2600_skew  TGS2600_kurtosis  TGS2600_auc  TGS2611_mean  \
# 0     0.788811      0.343622         -1.153061       2609.0         546.5
# 1     0.788811      0.343622         -1.153061       2609.0         546.5
# 2     0.788811      0.343622         -1.153061       2609.0         546.5
# 3     0.788811      0.343622         -1.153061       2609.0         546.5
# 4     0.788811      0.343622         -1.153061       2609.0         546.5
# 5     0.788811      0.343622         -1.153061       2609.0         546.5
# 6     0.788811      0.343622         -1.153061       2609.0         546.5
# 7     0.788811      0.343622         -1.153061       2609.0         546.5
# 8     0.788811      0.343622         -1.153061       2609.0         546.5
# 9     0.788811      0.343622         -1.153061       2609.0         546.5
#
#    TGS2611_min  TGS2611_max  TGS2611_std  TGS2611_skew  TGS2611_kurtosis  \
# 0          545          548     0.849837           0.0         -0.485207
# 1          545          548     0.849837           0.0         -0.485207
# 2          545          548     0.849837           0.0         -0.485207
# 3          545          548     0.849837           0.0         -0.485207
# 4          545          548     0.849837           0.0         -0.485207
# 5          545          548     0.849837           0.0         -0.485207
# 6          545          548     0.849837           0.0         -0.485207
# 7          545          548     0.849837           0.0         -0.485207
# 8          545          548     0.849837           0.0         -0.485207
# 9          545          548     0.849837           0.0         -0.485207
#
#    TGS2611_auc  TGS2603_mean  TGS2603_min  TGS2603_max  TGS2603_std  \
# 0       4918.5         370.2          369          371     0.788811
# 1       4918.5         370.2          369          371     0.788811
# 2       4918.5         370.2          369          371     0.788811
# 3       4918.5         370.2          369          371     0.788811
# 4       4918.5         370.2          369          371     0.788811
# 5       4918.5         370.2          369          371     0.788811
# 6       4918.5         370.2          369          371     0.788811
# 7       4918.5         370.2          369          371     0.788811
# 8       4918.5         370.2          369          371     0.788811
# 9       4918.5         370.2          369          371     0.788811
#
#    TGS2603_skew  TGS2603_kurtosis  TGS2603_auc  Humidity_mean  Humidity_min  \
# 0     -0.343622         -1.153061       3331.0          46.43          46.3
# 1     -0.343622         -1.153061       3331.0          46.43          46.3
# 2     -0.343622         -1.153061       3331.0          46.43          46.3
# 3     -0.343622         -1.153061       3331.0          46.43          46.3
# 4     -0.343622         -1.153061       3331.0          46.43          46.3
# 5     -0.343622         -1.153061       3331.0          46.43          46.3
# 6     -0.343622         -1.153061       3331.0          46.43          46.3
# 7     -0.343622         -1.153061       3331.0          46.43          46.3
# 8     -0.343622         -1.153061       3331.0          46.43          46.3
# 9     -0.343622         -1.153061       3331.0          46.43          46.3
#
#    Humidity_max  Humidity_std  Humidity_skew  Humidity_kurtosis  Humidity_auc  \
# 0          46.5      0.067495      -0.365675          -0.705532        417.95
# 1          46.5      0.067495      -0.365675          -0.705532        417.95
# 2          46.5      0.067495      -0.365675          -0.705532        417.95
# 3          46.5      0.067495      -0.365675          -0.705532        417.95
# 4          46.5      0.067495      -0.365675          -0.705532        417.95
# 5          46.5      0.067495      -0.365675          -0.705532        417.95
# 6          46.5      0.067495      -0.365675          -0.705532        417.95
# 7          46.5      0.067495      -0.365675          -0.705532        417.95
# 8          46.5      0.067495      -0.365675          -0.705532        417.95
# 9          46.5      0.067495      -0.365675          -0.705532        417.95
#
#    Celsius_mean  Celsius_min  Celsius_max  Celsius_std  Celsius_skew  \
# 0         38.81         38.7         38.9      0.08756      -0.18843
# 1         38.81         38.7         38.9      0.08756      -0.18843
# 2         38.81         38.7         38.9      0.08756      -0.18843
# 3         38.81         38.7         38.9      0.08756      -0.18843
# 4         38.81         38.7         38.9      0.08756      -0.18843
# 5         38.81         38.7         38.9      0.08756      -0.18843
# 6         38.81         38.7         38.9      0.08756      -0.18843
# 7         38.81         38.7         38.9      0.08756      -0.18843
# 8         38.81         38.7         38.9      0.08756      -0.18843
# 9         38.81         38.7         38.9      0.08756      -0.18843
#
#    Celsius_kurtosis  Celsius_auc  Aroma_mean  Aroma_min  Aroma_max  \
# 0          -1.52615        349.3         2.9        2.9        2.9
# 1          -1.52615        349.3         2.9        2.9        2.9
# 2          -1.52615        349.3         2.9        2.9        2.9
# 3          -1.52615        349.3         2.9        2.9        2.9
# 4          -1.52615        349.3         2.9        2.9        2.9
# 5          -1.52615        349.3         2.9        2.9        2.9
# 6          -1.52615        349.3         2.9        2.9        2.9
# 7          -1.52615        349.3         2.9        2.9        2.9
# 8          -1.52615        349.3         2.9        2.9        2.9
# 9          -1.52615        349.3         2.9        2.9        2.9
#
#       Aroma_std  Aroma_auc  Taste_mean  Taste_min  Taste_max  Taste_std  \
# 0  4.681111e-16       26.1          36         36         36          0
# 1  4.681111e-16       26.1          36         36         36          0
# 2  4.681111e-16       26.1          36         36         36          0
# 3  4.681111e-16       26.1          36         36         36          0
# 4  4.681111e-16       26.1          36         36         36          0
# 5  4.681111e-16       26.1          36         36         36          0
# 6  4.681111e-16       26.1          36         36         36          0
# 7  4.681111e-16       26.1          36         36         36          0
# 8  4.681111e-16       26.1          36         36         36          0
# 9  4.681111e-16       26.1          36         36         36          0
#
#    Taste_auc  Color_mean  Color_min  Color_max     Color_std  Color_auc  \
# 0        324         3.2        3.2        3.2  4.681111e-16       28.8
# 1        324         3.2        3.2        3.2  4.681111e-16       28.8
# 2        324         3.2        3.2        3.2  4.681111e-16       28.8
# 3        324         3.2        3.2        3.2  4.681111e-16       28.8
# 4        324         3.2        3.2        3.2  4.681111e-16       28.8
# 5        324         3.2        3.2        3.2  4.681111e-16       28.8
# 6        324         3.2        3.2        3.2  4.681111e-16       28.8
# 7        324         3.2        3.2        3.2  4.681111e-16       28.8
# 8        324         3.2        3.2        3.2  4.681111e-16       28.8
# 9        324         3.2        3.2        3.2  4.681111e-16       28.8
#
#    Appearance_mean  Appearance_min  Appearance_max  Appearance_std  \
# 0              2.8             2.8             2.8    4.681111e-16
# 1              2.8             2.8             2.8    4.681111e-16
# 2              2.8             2.8             2.8    4.681111e-16
# 3              2.8             2.8             2.8    4.681111e-16
# 4              2.8             2.8             2.8    4.681111e-16
# 5              2.8             2.8             2.8    4.681111e-16
# 6              2.8             2.8             2.8    4.681111e-16
# 7              2.8             2.8             2.8    4.681111e-16
# 8              2.8             2.8             2.8    4.681111e-16
# 9              2.8             2.8             2.8    4.681111e-16
#
#    Appearance_auc  Dreg_mean  Dreg_min  Dreg_max      Dreg_std  Dreg_auc
# 0            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 1            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 2            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 3            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 4            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 5            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 6            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 7            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 8            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 9            25.2        3.2       3.2       3.2  4.681111e-16      28.8

# %%
X = data[feature_cols]
y = data[target_cols]
print(X.shape, y.shape)

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Groups for StratifiedKFold — prevents leakage across folds.
# Many rows share the same Sampling_ID; they must stay within the same fold.
# (Sampling_ID, not Chop_ID: class B has only 2 Chop_ID -> can't make 5 folds.)
groups = data["Sampling_ID"].values
print("n groups:", len(set(groups)))
# Out:
# (10409, 12) (10409,)
# n groups: 274

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

def plot_pca_variance(X, n_components, threshold=0.95):
    pca = PCA(n_components=n_components)
    pca.fit(X)
    cumvar = np.cumsum(pca.explained_variance_ratio_)
    n_optimal = np.argmax(cumvar >= threshold) + 1

    plt.figure(figsize=(8, 5))
    plt.plot(range(1, n_components + 1), cumvar, marker='o', color='blue')
    plt.axhline(y=threshold, color='gray', linestyle='--', linewidth=1)
    plt.xlabel('Number of Principal Components')
    plt.ylabel('Cumulative Explained Variance')
    plt.xticks(range(1, n_components + 1))
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print(f'Optimal number of components to retain {threshold*100:.0f}% variance: {n_optimal}')
    return n_optimal

n_optimal = plot_pca_variance(X, n_components=X.shape[1], threshold=0.92)
# Out:
# Optimal number of components to retain 92% variance: 3

# %%
import time, json, pickle
import numpy as np
from pathlib import Path
from datetime import datetime

CATEGORY = "classical"
# Bump when the HPO logic changes in a way that invalidates old checkpoints.
# v2: dropped class_weight/sample_weight balancing + overfit-aware selection.
# v3: added SMOTEENN resampling inside the CV pipeline (train-fold only).
# v4: scoring switched to penalized validation log-loss (minimize), not composite.
# v5: overfit penalty now uses TWO signals — loss_gap + macro-F1 gap.
CKPT_VERSION = 5
HPO_RESULTS = Path(project_root) / "notebooks" / "hpo" / "results"
CSV_DIR  = HPO_RESULTS / "csv" / CATEGORY
LOG_DIR  = HPO_RESULTS / "logs" / CATEGORY
CKPT_DIR = HPO_RESULTS / "checkpoints" / CATEGORY
BEST_DIR = HPO_RESULTS / "best"
FIG_DIR  = HPO_RESULTS / "figures" / CATEGORY
for _d in (CSV_DIR, LOG_DIR, CKPT_DIR, BEST_DIR, FIG_DIR):
    _d.mkdir(parents=True, exist_ok=True)

_current_log_path = None

def setup_logger(name):
    """Call at the start of each section; name is the section slug."""
    global _current_log_path
    _current_log_path = LOG_DIR / f"{name}.log"
    _current_log_path.write_text("")          # fresh log every run
    log(f"📝 Log: {_current_log_path}")
    log(f"🕒 Started: {datetime.now().isoformat(timespec='seconds')}")

def log(msg=""):
    print(msg)
    if _current_log_path is not None:
        with open(_current_log_path, "a", encoding="utf-8") as f:
            f.write(str(msg) + "\n")

def _fresh_ckpt():
    # best_score = +inf because selection minimizes penalized log-loss.
    return {"version": CKPT_VERSION, "done_configs": {}, "results": [],
            "best_result": None, "best_score": np.inf}

def load_checkpoint(name):
    """Resume a section; returns an empty skeleton if no (compatible) checkpoint."""
    ckpt_path = CKPT_DIR / f"{name}.pkl"
    if ckpt_path.exists():
        with open(ckpt_path, "rb") as f:
            data = pickle.load(f)
        if data.get("version") != CKPT_VERSION:
            log(f"♻️  Ignoring stale checkpoint (v{data.get('version')} != v{CKPT_VERSION}); starting fresh: {ckpt_path}")
            return _fresh_ckpt(), ckpt_path
        log(f"♻️  Resumed checkpoint: {ckpt_path} ({len(data['done_configs'])} configs done)")
        return data, ckpt_path
    return _fresh_ckpt(), ckpt_path

def save_checkpoint(ckpt_path, data):
    """Atomic save (write .tmp then replace)."""
    data.setdefault("version", CKPT_VERSION)
    tmp = ckpt_path.with_suffix(".pkl.tmp")
    with open(tmp, "wb") as f:
        pickle.dump(data, f)
    tmp.replace(ckpt_path)

def save_best(name, model_label, best_result, extra=None):
    """Persist the section's best result so results.ipynb can aggregate it."""
    payload = {
        "name": name,
        "model": model_label,
        "category": CATEGORY,
        "tag": best_result.get("tag"),
        "loss": best_result.get("loss"),
        "selection_score": best_result.get("selection_score"),
        "train_loss_cv": best_result.get("train_loss_cv"),
        "train_f1macro_cv": best_result.get("train_f1macro_cv"),
        "loss_gap": best_result.get("loss_gap"),
        "f1_gap": best_result.get("f1_gap"),
        "acc": best_result.get("acc"),
        "prec": best_result.get("prec"),
        "rec": best_result.get("rec"),
        "f1": best_result.get("f1"),
        "f1_macro": best_result.get("f1_macro"),
        "roc": best_result.get("roc"),
        "pra": best_result.get("pra"),
        "execution_time": best_result.get("execution_time"),
        "params": best_result.get("params", {}),
    }
    if extra:
        payload.update(extra)
    with open(BEST_DIR / f"{name}.json", "w", encoding="utf-8") as f:
        json.dump(payload, f, ensure_ascii=False, indent=2, default=str)
    log(f"💾 Best saved: {BEST_DIR / (name + '.json')}")

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, log_loss

def plot_fit_diagnostic(build_estimator, params, name, title,
                        normalize_proba=False, fit_kwargs_fn=None,
                        overfit_gap=0.05, low_thresh=0.80):
    """Refit best params per fold, compare TRAIN vs VAL to flag over/underfit."""
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    _fkw = fit_kwargs_fn or (lambda y_tr: {})

    def _scores(model, Xs, ys):
        yp = model.predict(Xs)
        pr = model.predict_proba(Xs)
        if normalize_proba:
            pr = pr / pr.sum(axis=1, keepdims=True)
        a = accuracy_score(ys, yp)
        ll = log_loss(ys, pr, labels=np.unique(y))
        return a, ll

    tr_acc, va_acc, tr_loss, va_loss = [], [], [], []
    for tr, va in skf.split(X, y, groups):
        m = build_estimator(params)
        m.fit(X.iloc[tr], y[tr], **_fkw(y[tr]))
        a1, c1 = _scores(m, X.iloc[tr], y[tr])
        a2, c2 = _scores(m, X.iloc[va], y[va])
        tr_acc.append(a1); va_acc.append(a2); tr_loss.append(c1); va_loss.append(c2)

    tr_acc_m, va_acc_m = float(np.mean(tr_acc)), float(np.mean(va_acc))
    gap = tr_acc_m - va_acc_m
    # Overfit (train >> val) is checked first so a big gap is never masked as
    # "Underfit" just because both means sit below low_thresh.
    if gap > overfit_gap:
        verdict = "Overfit"
    elif va_acc_m < low_thresh:
        verdict = "Underfit"
    else:
        verdict = "Generalized"

    folds = np.arange(1, 6)
    w = 0.35
    fig, ax = plt.subplots(1, 2, figsize=(12, 4.5))
    ax[0].bar(folds - w/2, tr_acc, w, label='Train', color='#4C72B0')
    ax[0].bar(folds + w/2, va_acc, w, label='Validation', color='#DD8452')
    ax[0].axhline(tr_acc_m, color='#4C72B0', ls='--', lw=1)
    ax[0].axhline(va_acc_m, color='#DD8452', ls='--', lw=1)
    ax[0].set_title('Accuracy'); ax[0].set_xlabel('Fold'); ax[0].set_ylim(0, 1.05)
    ax[0].set_xticks(folds); ax[0].legend(); ax[0].grid(axis='y', alpha=0.3)

    ax[1].bar(folds - w/2, tr_loss, w, label='Train', color='#4C72B0')
    ax[1].bar(folds + w/2, va_loss, w, label='Validation', color='#DD8452')
    ax[1].set_title('Log-loss (lower = better)')
    ax[1].set_xlabel('Fold')
    ax[1].set_xticks(folds); ax[1].legend(); ax[1].grid(axis='y', alpha=0.3)

    fig.suptitle(f"{title} — best-param fit: {verdict}  "
                 f"(train acc={tr_acc_m:.3f}, val acc={va_acc_m:.3f}, gap={gap:+.3f})",
                 fontsize=12)
    fig.tight_layout()
    fig_path = FIG_DIR / f"{name}_fit.png"
    fig.savefig(fig_path, dpi=120, bbox_inches='tight')
    plt.show()

    log(f"📈 Fit diagnostic [{title}] → {verdict} "
        f"(train acc={tr_acc_m:.4f} | val acc={va_acc_m:.4f} | gap={gap:+.4f})")
    log(f"🖼️  Figure: {fig_path}")
    return {"fit_verdict": verdict, "train_acc": tr_acc_m,
            "val_acc": va_acc_m, "fit_gap": float(gap)}

# %% [markdown]
# ## Dart

# %%
# Search Space + estimator builder
import numpy as np

NORMALIZE_PROBA = False

search_space = {
  'n_estimators': [80, 150],
  'learning_rate': [0.05, 0.1],
  'max_depth': [3, 4],
  'min_child_weight': [1, 5],
  'reg_lambda': [1, 5],
  
  'rate_drop': [0.1, 0.2],
}

from imblearn.pipeline import Pipeline
from imblearn.combine import SMOTEENN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from xgboost import XGBClassifier

def build_estimator(params):
    return Pipeline([
        ('scaler', StandardScaler()),
        ('pca', PCA(n_components=n_optimal)),
        ('smoteenn', SMOTEENN(random_state=42)),  # train-fold only (no leak)
        ('xgb', XGBClassifier(booster='dart', objective='multi:softprob',
                              subsample=0.8, colsample_bytree=0.8,
                              random_state=42, device='cuda', **params)),
    ])

fit_kwargs_fn = lambda y_tr: {}

# %%
setup_logger("xgb_dart")
from sklearn.model_selection import StratifiedKFold
from itertools import product
import time
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score,
    average_precision_score, matthews_corrcoef,
    precision_score, recall_score, log_loss,
)

state = 42
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

classes = np.unique(y)

# Primary scoring = mean validation LOG-LOSS (lower is better). Overfit is checked
# with TWO signals, each penalized only beyond its own tolerance:
#   loss_gap = val_loss - train_loss        -> probability calibration
#   f1_gap   = train_macroF1 - val_macroF1  -> per-class balance (catches minority overfit)
#   penalty  = W_LOSS*max(0, loss_gap - TOL_LOSS) + W_F1*max(0, f1_gap - TOL_F1)
#   selection_score = val_loss + penalty    -> best config = the MINIMUM
# Train metrics are measured on the ORIGINAL (non-resampled) train fold.
TOL_LOSS = 0.05   # "free" train-val log-loss gap (no penalty below this)
TOL_F1   = 0.05   # "free" train-val macro-F1 gap
W_LOSS   = 1.0    # weight for the log-loss overfit signal
W_F1     = 1.0    # weight for the macro-F1 overfit signal

param_keys = list(search_space.keys())
param_vals = list(search_space.values())
search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = int(np.prod([len(v) for v in param_vals]))
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: mean validation log-loss (lower better); overfit penalty on loss_gap + macroF1_gap")
log(f"   Overfit guard: +{W_LOSS}×max(0, loss_gap - {TOL_LOSS}) +{W_F1}×max(0, f1_gap - {TOL_F1})")

ckpt, ckpt_path = load_checkpoint("xgb_dart")
done_configs = ckpt["done_configs"]
results      = ckpt["results"]
best_result  = ckpt["best_result"]
best_score   = ckpt["best_score"]

for i, comb in enumerate(product(*param_vals)):
    params = dict(zip(param_keys, comb))
    tag = " | ".join(f"{k}={v}" for k, v in params.items())

    if tag in done_configs:
        log(f"\n  ⏭️  [{i+1}/{total_configs}] {tag}  (skipped, already done)")
        continue

    log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
    _iter_t0 = time.perf_counter()

    accs, f1s, f1ms, rocs, pras, precs, recs, lls = [], [], [], [], [], [], [], []
    tr_lls, tr_f1ms = [], []
    y_val_all, y_pred_all = [], []
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y, groups), 1):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        model = build_estimator(params)
        model.fit(X_train, y_train, **fit_kwargs_fn(y_train))

        y_pred = model.predict(X_val)
        y_prob = model.predict_proba(X_val)
        if NORMALIZE_PROBA:
            y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)

        # Train log-loss + macro-F1 (original train fold) for the overfit checks
        tr_prob = model.predict_proba(X_train)
        if NORMALIZE_PROBA:
            tr_prob = tr_prob / tr_prob.sum(axis=1, keepdims=True)
        tr_lls.append(log_loss(y_train, tr_prob, labels=classes))
        # use model.predict (not argmax of proba) so train f1 matches how val f1 is computed
        tr_f1ms.append(f1_score(y_train, model.predict(X_train), average='macro'))

        y_val_all.extend(y_val)
        y_pred_all.extend(y_pred)

        acc  = accuracy_score(y_val, y_pred)
        f1   = f1_score(y_val, y_pred, average='weighted')
        f1m  = f1_score(y_val, y_pred, average='macro')
        roc  = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
        pra  = average_precision_score(y_val, y_prob, average='weighted')
        prec = precision_score(y_val, y_pred, average='weighted')
        rec  = recall_score(y_val, y_pred, average='weighted')
        ll   = log_loss(y_val, y_prob, labels=classes)

        accs.append(acc); f1s.append(f1); f1ms.append(f1m); rocs.append(roc)
        pras.append(pra); precs.append(prec); recs.append(rec); lls.append(ll)

        log(f"    F{fold} → Loss={ll:.4f} | Acc={acc:.4f} | F1w={f1:.4f} | F1m={f1m:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

        results.append({
            "tag": tag, **params, "fold": fold,
            "accuracy": acc, "precision": prec, "recall": rec,
            "F1": f1, "f1_macro": f1m, "auroc": roc, "prauc": pra,
            "loss": ll, "train_loss": tr_lls[-1],
        })

    acc_mean,  acc_std  = np.mean(accs),  np.std(accs)
    prec_mean, prec_std = np.mean(precs), np.std(precs)
    rec_mean,  rec_std  = np.mean(recs),  np.std(recs)
    f1_mean,   f1_std   = np.mean(f1s),   np.std(f1s)
    f1m_mean,  f1m_std  = np.mean(f1ms),  np.std(f1ms)
    roc_mean,  roc_std  = np.mean(rocs),  np.std(rocs)
    pra_mean,  pra_std  = np.mean(pras),  np.std(pras)
    loss_mean, loss_std = np.mean(lls),   np.std(lls)
    mcc = matthews_corrcoef(y_val_all, y_pred_all)

    # Overfit-aware selection: MINIMIZE val log-loss, penalize TWO overfit signals:
    #   loss_gap = val_loss - train_loss ; f1_gap = train_macroF1 - val_macroF1
    tr_loss_mean = float(np.mean(tr_lls))
    tr_f1m_mean  = float(np.mean(tr_f1ms))
    loss_gap = loss_mean - tr_loss_mean
    f1_gap   = tr_f1m_mean - f1m_mean
    penalty  = W_LOSS * max(0.0, loss_gap - TOL_LOSS) + W_F1 * max(0.0, f1_gap - TOL_F1)
    selection_score = loss_mean + penalty
    overfit_flag = " ⚠️ OVERFIT" if (loss_gap > TOL_LOSS or f1_gap > TOL_F1) else ""

    log(
        f"  ✅  Loss:{loss_mean:.4f}±{loss_std:.4f} | "
        f"Acc:{acc_mean:.4f}±{acc_std:.4f} | "
        f"F1w:{f1_mean:.4f}±{f1_std:.4f} | "
        f"F1macro:{f1m_mean:.4f}±{f1m_std:.4f} | "
        f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
        f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
        f"MCC:{mcc:.4f}"
    )
    log(
        f"      ↳ LossGap:{loss_gap:+.4f} (tr {tr_loss_mean:.4f}) | "
        f"F1macroGap:{f1_gap:+.4f} (tr {tr_f1m_mean:.4f}) | "
        f"Penalty:{penalty:.4f} | Selection(loss):{selection_score:.4f}{overfit_flag}"
    )

    iter_time = time.perf_counter() - _iter_t0
    if best_score is None or selection_score < best_score:
        best_score = selection_score
        best_result = {
            'tag': tag,
            'loss': f"{loss_mean:.4f}±{loss_std:.4f}",
            'selection_score': selection_score,
            'train_loss_cv': f"{tr_loss_mean:.4f}",
            'train_f1macro_cv': f"{tr_f1m_mean:.4f}",
            'loss_gap': f"{loss_gap:+.4f}",
            'f1_gap': f"{f1_gap:+.4f}",
            'acc':  f"{acc_mean:.4f}±{acc_std:.4f}",
            'f1':   f"{f1_mean:.4f}±{f1_std:.4f}",
            'f1_macro': f"{f1m_mean:.4f}±{f1m_std:.4f}",
            'roc':  f"{roc_mean:.4f}±{roc_std:.4f}",
            'pra':  f"{pra_mean:.4f}±{pra_std:.4f}",
            'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
            'rec':  f"{rec_mean:.4f}±{rec_std:.4f}",
            'params': params, 'execution_time': iter_time,
        }

    done_configs[tag] = {"loss": loss_mean, "selection_score": selection_score,
                         "loss_gap": loss_gap, "f1_gap": f1_gap, "params": params}
    save_checkpoint(ckpt_path, {
        "version": CKPT_VERSION,
        "done_configs": done_configs, "results": results,
        "best_result": best_result, "best_score": best_score,
    })

log(f"\n🏆 Best config : {best_result['tag']}  (min penalized log-loss)")
log(
    f"   Log-loss    : {best_result['loss']} "
    f"(Acc={best_result['acc']} | F1w={best_result['f1']} | F1macro={best_result['f1_macro']} | "
    f"AUROC={best_result['roc']} | PRAUC={best_result['pra']})"
)
log(
    f"   Selection   : {best_result['selection_score']:.4f} "
    f"(LossGap={best_result['loss_gap']} | F1macroGap={best_result['f1_gap']})"
)
# Out:
# 📝 Log: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\logs\classical\xgb_dart.log
# 🕒 Started: 2026-06-08T11:27:19
# 🔬 Search space: 2 n_estimators × 2 learning_rate × 2 max_depth × 2 min_child_weight × 2 reg_lambda × 2 rate_drop =  64 configs × 5 folds = 320 fits
#    Scoring criterion: mean validation log-loss (lower better); overfit penalty on loss_gap + macroF1_gap
#    Overfit guard: +1.0×max(0, loss_gap - 0.05) +1.0×max(0, f1_gap - 0.05)
#
#   ▶ [1/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.3756 | Acc=0.6297 | F1w=0.6398 | F1m=0.5773 | AUROC=0.8961 | PRAUC=0.7759
#     F2 → Loss=1.3785 | Acc=0.6402 | F1w=0.6520 | F1m=0.5921 | AUROC=0.8942 | PRAUC=0.7782
#     F3 → Loss=1.3800 | Acc=0.6446 | F1w=0.6578 | F1m=0.5812 | AUROC=0.8954 | PRAUC=0.7833
#     F4 → Loss=1.3761 | Acc=0.6503 | F1w=0.6585 | F1m=0.5949 | AUROC=0.8894 | PRAUC=0.7721
#     F5 → Loss=1.3796 | Acc=0.6343 | F1w=0.6454 | F1m=0.5828 | AUROC=0.9029 | PRAUC=0.7926
#   ✅  Loss:1.3780±0.0018 | Acc:0.6398±0.0073 | F1w:0.6507±0.0072 | F1macro:0.5857±0.0067 | AUROC:0.8956±0.0043 | PRAUC:0.7804±0.0071 | MCC:0.5241
#       ↳ LossGap:+0.0034 (tr 1.3746) | F1macroGap:+0.0062 (tr 0.5919) | Penalty:0.0000 | Selection(loss):1.3780
#
#   ▶ [2/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.4536 | Acc=0.6354 | F1w=0.6476 | F1m=0.5791 | AUROC=0.8874 | PRAUC=0.7702
#     F2 → Loss=1.4564 | Acc=0.6081 | F1w=0.6217 | F1m=0.5630 | AUROC=0.8843 | PRAUC=0.7669
#     F3 → Loss=1.4586 | Acc=0.6239 | F1w=0.6396 | F1m=0.5640 | AUROC=0.8861 | PRAUC=0.7743
#     F4 → Loss=1.4523 | Acc=0.6273 | F1w=0.6365 | F1m=0.5764 | AUROC=0.8771 | PRAUC=0.7661
#     F5 → Loss=1.4589 | Acc=0.5930 | F1w=0.6099 | F1m=0.5288 | AUROC=0.8914 | PRAUC=0.7764
#   ✅  Loss:1.4560±0.0026 | Acc:0.6175±0.0152 | F1w:0.6311±0.0135 | F1macro:0.5623±0.0179 | AUROC:0.8852±0.0047 | PRAUC:0.7708±0.0040 | MCC:0.5019
#       ↳ LossGap:+0.0020 (tr 1.4540) | F1macroGap:+0.0073 (tr 0.5696) | Penalty:0.0000 | Selection(loss):1.4560
#
#   ▶ [3/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.3782 | Acc=0.6158 | F1w=0.6255 | F1m=0.5621 | AUROC=0.8965 | PRAUC=0.7783
#     F2 → Loss=1.3815 | Acc=0.6292 | F1w=0.6412 | F1m=0.5815 | AUROC=0.8956 | PRAUC=0.7789
#     F3 → Loss=1.3832 | Acc=0.6330 | F1w=0.6463 | F1m=0.5685 | AUROC=0.8951 | PRAUC=0.7818
#     F4 → Loss=1.3795 | Acc=0.6499 | F1w=0.6580 | F1m=0.5946 | AUROC=0.8889 | PRAUC=0.7701
#     F5 → Loss=1.3832 | Acc=0.6026 | F1w=0.6146 | F1m=0.5328 | AUROC=0.9017 | PRAUC=0.7917
#   ✅  Loss:1.3811±0.0020 | Acc:0.6261±0.0160 | F1w:0.6371±0.0153 | F1macro:0.5679±0.0208 | AUROC:0.8955±0.0041 | PRAUC:0.7802±0.0070 | MCC:0.5087
#       ↳ LossGap:+0.0034 (tr 1.3777) | F1macroGap:+0.0083 (tr 0.5762) | Penalty:0.0000 | Selection(loss):1.3811
#
#   ▶ [4/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.4560 | Acc=0.6302 | F1w=0.6411 | F1m=0.5711 | AUROC=0.8869 | PRAUC=0.7680
#     F2 → Loss=1.4585 | Acc=0.6052 | F1w=0.6201 | F1m=0.5565 | AUROC=0.8864 | PRAUC=0.7697
#     F3 → Loss=1.4609 | Acc=0.6225 | F1w=0.6383 | F1m=0.5630 | AUROC=0.8860 | PRAUC=0.7739
#     F4 → Loss=1.4555 | Acc=0.5946 | F1w=0.6050 | F1m=0.5287 | AUROC=0.8759 | PRAUC=0.7629
#     F5 → Loss=1.4616 | Acc=0.5935 | F1w=0.6104 | F1m=0.5291 | AUROC=0.8904 | PRAUC=0.7753
#   ✅  Loss:1.4585±0.0025 | Acc:0.6092±0.0148 | F1w:0.6229±0.0145 | F1macro:0.5497±0.0176 | AUROC:0.8851±0.0049 | PRAUC:0.7700±0.0044 | MCC:0.4925
#       ↳ LossGap:+0.0020 (tr 1.4565) | F1macroGap:+0.0079 (tr 0.5576) | Penalty:0.0000 | Selection(loss):1.4585
#
#   ▶ [5/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.3756 | Acc=0.6287 | F1w=0.6388 | F1m=0.5765 | AUROC=0.8963 | PRAUC=0.7764
#     F2 → Loss=1.3783 | Acc=0.6551 | F1w=0.6681 | F1m=0.6000 | AUROC=0.8946 | PRAUC=0.7789
#     F3 → Loss=1.3800 | Acc=0.6446 | F1w=0.6578 | F1m=0.5812 | AUROC=0.8956 | PRAUC=0.7839
#     F4 → Loss=1.3766 | Acc=0.6503 | F1w=0.6585 | F1m=0.5949 | AUROC=0.8892 | PRAUC=0.7719
#     F5 → Loss=1.3797 | Acc=0.6329 | F1w=0.6440 | F1m=0.5818 | AUROC=0.9027 | PRAUC=0.7923
#   ✅  Loss:1.3780±0.0017 | Acc:0.6423±0.0101 | F1w:0.6534±0.0106 | F1macro:0.5869±0.0090 | AUROC:0.8957±0.0043 | PRAUC:0.7807±0.0070 | MCC:0.5271
#       ↳ LossGap:+0.0034 (tr 1.3747) | F1macroGap:+0.0051 (tr 0.5920) | Penalty:0.0000 | Selection(loss):1.3780
#
#   ▶ [6/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.4537 | Acc=0.6378 | F1w=0.6501 | F1m=0.5817 | AUROC=0.8875 | PRAUC=0.7709
#     F2 → Loss=1.4562 | Acc=0.6090 | F1w=0.6232 | F1m=0.5626 | AUROC=0.8848 | PRAUC=0.7687
#     F3 → Loss=1.4586 | Acc=0.6239 | F1w=0.6396 | F1m=0.5640 | AUROC=0.8861 | PRAUC=0.7746
#     F4 → Loss=1.4528 | Acc=0.6273 | F1w=0.6365 | F1m=0.5764 | AUROC=0.8768 | PRAUC=0.7659
#     F5 → Loss=1.4590 | Acc=0.5939 | F1w=0.6110 | F1m=0.5299 | AUROC=0.8913 | PRAUC=0.7763
#   ✅  Loss:1.4561±0.0025 | Acc:0.6184±0.0153 | F1w:0.6321±0.0136 | F1macro:0.5629±0.0180 | AUROC:0.8853±0.0048 | PRAUC:0.7713±0.0038 | MCC:0.5029
#       ↳ LossGap:+0.0020 (tr 1.4541) | F1macroGap:+0.0064 (tr 0.5693) | Penalty:0.0000 | Selection(loss):1.4561
#
#   ▶ [7/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.3784 | Acc=0.6158 | F1w=0.6255 | F1m=0.5621 | AUROC=0.8967 | PRAUC=0.7786
#     F2 → Loss=1.3813 | Acc=0.6326 | F1w=0.6447 | F1m=0.5841 | AUROC=0.8960 | PRAUC=0.7799
#     F3 → Loss=1.3832 | Acc=0.6330 | F1w=0.6463 | F1m=0.5685 | AUROC=0.8951 | PRAUC=0.7820
#     F4 → Loss=1.3799 | Acc=0.6499 | F1w=0.6580 | F1m=0.5946 | AUROC=0.8888 | PRAUC=0.7699
#     F5 → Loss=1.3836 | Acc=0.6036 | F1w=0.6154 | F1m=0.5336 | AUROC=0.9019 | PRAUC=0.7918
#   ✅  Loss:1.3813±0.0020 | Acc:0.6270±0.0159 | F1w:0.6380±0.0154 | F1macro:0.5686±0.0209 | AUROC:0.8957±0.0042 | PRAUC:0.7804±0.0070 | MCC:0.5096
#       ↳ LossGap:+0.0034 (tr 1.3778) | F1macroGap:+0.0086 (tr 0.5773) | Penalty:0.0000 | Selection(loss):1.3813
#
#   ▶ [8/64] n_estimators=80 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.4562 | Acc=0.6302 | F1w=0.6411 | F1m=0.5711 | AUROC=0.8871 | PRAUC=0.7683
#     F2 → Loss=1.4584 | Acc=0.6037 | F1w=0.6192 | F1m=0.5535 | AUROC=0.8867 | PRAUC=0.7704
#     F3 → Loss=1.4609 | Acc=0.6225 | F1w=0.6383 | F1m=0.5630 | AUROC=0.8860 | PRAUC=0.7738
#     F4 → Loss=1.4560 | Acc=0.5941 | F1w=0.6045 | F1m=0.5284 | AUROC=0.8758 | PRAUC=0.7623
#     F5 → Loss=1.4616 | Acc=0.5944 | F1w=0.6114 | F1m=0.5303 | AUROC=0.8906 | PRAUC=0.7756
#   ✅  Loss:1.4586±0.0023 | Acc:0.6090±0.0148 | F1w:0.6229±0.0145 | F1macro:0.5493±0.0172 | AUROC:0.8852±0.0050 | PRAUC:0.7701±0.0046 | MCC:0.4924
#       ↳ LossGap:+0.0020 (tr 1.4566) | F1macroGap:+0.0076 (tr 0.5569) | Penalty:0.0000 | Selection(loss):1.4586
#
#   ▶ [9/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.3040 | Acc=0.7426 | F1w=0.7464 | F1m=0.7311 | AUROC=0.9325 | PRAUC=0.8504
#     F2 → Loss=1.3071 | Acc=0.7392 | F1w=0.7474 | F1m=0.7214 | AUROC=0.9327 | PRAUC=0.8522
#     F3 → Loss=1.3100 | Acc=0.7320 | F1w=0.7395 | F1m=0.6954 | AUROC=0.9341 | PRAUC=0.8541
#     F4 → Loss=1.3079 | Acc=0.7166 | F1w=0.7221 | F1m=0.6812 | AUROC=0.9319 | PRAUC=0.8522
#     F5 → Loss=1.3165 | Acc=0.7299 | F1w=0.7380 | F1m=0.7140 | AUROC=0.9232 | PRAUC=0.8351
#   ✅  Loss:1.3091±0.0042 | Acc:0.7321±0.0090 | F1w:0.7387±0.0091 | F1macro:0.7086±0.0180 | AUROC:0.9309±0.0039 | PRAUC:0.8488±0.0069 | MCC:0.6467
#       ↳ LossGap:+0.0058 (tr 1.3033) | F1macroGap:+0.0130 (tr 0.7216) | Penalty:0.0000 | Selection(loss):1.3091
#
#   ▶ [10/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.4037 | Acc=0.7008 | F1w=0.7102 | F1m=0.6563 | AUROC=0.9232 | PRAUC=0.8327
#     F2 → Loss=1.4055 | Acc=0.7080 | F1w=0.7199 | F1m=0.6625 | AUROC=0.9273 | PRAUC=0.8430
#     F3 → Loss=1.4101 | Acc=0.6681 | F1w=0.6832 | F1m=0.6160 | AUROC=0.9218 | PRAUC=0.8378
#     F4 → Loss=1.4029 | Acc=0.7109 | F1w=0.7183 | F1m=0.6738 | AUROC=0.9217 | PRAUC=0.8377
#     F5 → Loss=1.4127 | Acc=0.7054 | F1w=0.7180 | F1m=0.6679 | AUROC=0.9193 | PRAUC=0.8310
#   ✅  Loss:1.4070±0.0038 | Acc:0.6986±0.0156 | F1w:0.7099±0.0138 | F1macro:0.6553±0.0205 | AUROC:0.9227±0.0026 | PRAUC:0.8364±0.0043 | MCC:0.6105
#       ↳ LossGap:+0.0040 (tr 1.4030) | F1macroGap:+0.0087 (tr 0.6640) | Penalty:0.0000 | Selection(loss):1.4070
#
#   ▶ [11/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.3099 | Acc=0.7459 | F1w=0.7499 | F1m=0.7308 | AUROC=0.9307 | PRAUC=0.8458
#     F2 → Loss=1.3119 | Acc=0.7349 | F1w=0.7419 | F1m=0.7148 | AUROC=0.9309 | PRAUC=0.8486
#     F3 → Loss=1.3156 | Acc=0.7267 | F1w=0.7340 | F1m=0.6926 | AUROC=0.9323 | PRAUC=0.8498
#     F4 → Loss=1.3131 | Acc=0.7272 | F1w=0.7316 | F1m=0.6951 | AUROC=0.9294 | PRAUC=0.8488
#     F5 → Loss=1.3199 | Acc=0.7222 | F1w=0.7309 | F1m=0.7022 | AUROC=0.9204 | PRAUC=0.8302
#   ✅  Loss:1.3141±0.0035 | Acc:0.7314±0.0083 | F1w:0.7377±0.0073 | F1macro:0.7071±0.0141 | AUROC:0.9287±0.0043 | PRAUC:0.8447±0.0074 | MCC:0.6456
#       ↳ LossGap:+0.0059 (tr 1.3081) | F1macroGap:+0.0146 (tr 0.7217) | Penalty:0.0000 | Selection(loss):1.3141
#
#   ▶ [12/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.4076 | Acc=0.7128 | F1w=0.7202 | F1m=0.6742 | AUROC=0.9227 | PRAUC=0.8331
#     F2 → Loss=1.4086 | Acc=0.7133 | F1w=0.7238 | F1m=0.6692 | AUROC=0.9266 | PRAUC=0.8429
#     F3 → Loss=1.4152 | Acc=0.6643 | F1w=0.6798 | F1m=0.6116 | AUROC=0.9198 | PRAUC=0.8316
#     F4 → Loss=1.4076 | Acc=0.7089 | F1w=0.7164 | F1m=0.6736 | AUROC=0.9203 | PRAUC=0.8352
#     F5 → Loss=1.4169 | Acc=0.7098 | F1w=0.7224 | F1m=0.6702 | AUROC=0.9153 | PRAUC=0.8236
#   ✅  Loss:1.4112±0.0040 | Acc:0.7018±0.0188 | F1w:0.7125±0.0165 | F1macro:0.6598±0.0242 | AUROC:0.9209±0.0037 | PRAUC:0.8333±0.0062 | MCC:0.6136
#       ↳ LossGap:+0.0042 (tr 1.4070) | F1macroGap:+0.0081 (tr 0.6679) | Penalty:0.0000 | Selection(loss):1.4112
#
#   ▶ [13/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.3042 | Acc=0.7416 | F1w=0.7454 | F1m=0.7305 | AUROC=0.9324 | PRAUC=0.8504
#     F2 → Loss=1.3075 | Acc=0.7387 | F1w=0.7469 | F1m=0.7220 | AUROC=0.9327 | PRAUC=0.8523
#     F3 → Loss=1.3101 | Acc=0.7315 | F1w=0.7390 | F1m=0.6951 | AUROC=0.9341 | PRAUC=0.8541
#     F4 → Loss=1.3084 | Acc=0.7209 | F1w=0.7259 | F1m=0.6869 | AUROC=0.9315 | PRAUC=0.8516
#     F5 → Loss=1.3168 | Acc=0.7295 | F1w=0.7376 | F1m=0.7135 | AUROC=0.9232 | PRAUC=0.8353
#   ✅  Loss:1.3094±0.0042 | Acc:0.7324±0.0073 | F1w:0.7390±0.0075 | F1macro:0.7096±0.0163 | AUROC:0.9308±0.0039 | PRAUC:0.8487±0.0068 | MCC:0.6470
#       ↳ LossGap:+0.0057 (tr 1.3038) | F1macroGap:+0.0132 (tr 0.7228) | Penalty:0.0000 | Selection(loss):1.3094
#
#   ▶ [14/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.4040 | Acc=0.7003 | F1w=0.7099 | F1m=0.6553 | AUROC=0.9230 | PRAUC=0.8345
#     F2 → Loss=1.4058 | Acc=0.7070 | F1w=0.7188 | F1m=0.6619 | AUROC=0.9274 | PRAUC=0.8430
#     F3 → Loss=1.4103 | Acc=0.6676 | F1w=0.6827 | F1m=0.6157 | AUROC=0.9218 | PRAUC=0.8378
#     F4 → Loss=1.4035 | Acc=0.7099 | F1w=0.7176 | F1m=0.6729 | AUROC=0.9217 | PRAUC=0.8379
#     F5 → Loss=1.4129 | Acc=0.7049 | F1w=0.7174 | F1m=0.6675 | AUROC=0.9194 | PRAUC=0.8314
#   ✅  Loss:1.4073±0.0037 | Acc:0.6980±0.0155 | F1w:0.7093±0.0136 | F1macro:0.6547±0.0203 | AUROC:0.9227±0.0026 | PRAUC:0.8369±0.0039 | MCC:0.6097
#       ↳ LossGap:+0.0038 (tr 1.4034) | F1macroGap:+0.0080 (tr 0.6627) | Penalty:0.0000 | Selection(loss):1.4073
#
#   ▶ [15/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.3101 | Acc=0.7440 | F1w=0.7480 | F1m=0.7268 | AUROC=0.9307 | PRAUC=0.8458
#     F2 → Loss=1.3120 | Acc=0.7339 | F1w=0.7412 | F1m=0.7144 | AUROC=0.9309 | PRAUC=0.8485
#     F3 → Loss=1.3157 | Acc=0.7286 | F1w=0.7362 | F1m=0.6938 | AUROC=0.9325 | PRAUC=0.8493
#     F4 → Loss=1.3139 | Acc=0.7253 | F1w=0.7299 | F1m=0.6928 | AUROC=0.9292 | PRAUC=0.8487
#     F5 → Loss=1.3201 | Acc=0.7222 | F1w=0.7308 | F1m=0.7035 | AUROC=0.9203 | PRAUC=0.8300
#   ✅  Loss:1.3144±0.0034 | Acc:0.7308±0.0076 | F1w:0.7372±0.0068 | F1macro:0.7063±0.0129 | AUROC:0.9287±0.0043 | PRAUC:0.8445±0.0073 | MCC:0.6452
#       ↳ LossGap:+0.0058 (tr 1.3086) | F1macroGap:+0.0140 (tr 0.7203) | Penalty:0.0000 | Selection(loss):1.3144
#
#   ▶ [16/64] n_estimators=80 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.4079 | Acc=0.7128 | F1w=0.7203 | F1m=0.6741 | AUROC=0.9228 | PRAUC=0.8332
#     F2 → Loss=1.4088 | Acc=0.7128 | F1w=0.7231 | F1m=0.6692 | AUROC=0.9266 | PRAUC=0.8425
#     F3 → Loss=1.4154 | Acc=0.6633 | F1w=0.6789 | F1m=0.6101 | AUROC=0.9196 | PRAUC=0.8312
#     F4 → Loss=1.4083 | Acc=0.7085 | F1w=0.7159 | F1m=0.6731 | AUROC=0.9201 | PRAUC=0.8347
#     F5 → Loss=1.4171 | Acc=0.7083 | F1w=0.7205 | F1m=0.6721 | AUROC=0.9146 | PRAUC=0.8225
#   ✅  Loss:1.4115±0.0039 | Acc:0.7011±0.0190 | F1w:0.7117±0.0166 | F1macro:0.6598±0.0249 | AUROC:0.9207±0.0040 | PRAUC:0.8328±0.0064 | MCC:0.6127
#       ↳ LossGap:+0.0040 (tr 1.4075) | F1macroGap:+0.0073 (tr 0.6670) | Penalty:0.0000 | Selection(loss):1.4115
#
#   ▶ [17/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.2008 | Acc=0.6671 | F1w=0.6741 | F1m=0.6319 | AUROC=0.9084 | PRAUC=0.8001
#     F2 → Loss=1.2057 | Acc=0.6633 | F1w=0.6733 | F1m=0.6160 | AUROC=0.9070 | PRAUC=0.8011
#     F3 → Loss=1.2063 | Acc=0.6844 | F1w=0.6927 | F1m=0.6183 | AUROC=0.9123 | PRAUC=0.8022
#     F4 → Loss=1.2040 | Acc=0.6681 | F1w=0.6751 | F1m=0.6210 | AUROC=0.9046 | PRAUC=0.7948
#     F5 → Loss=1.2102 | Acc=0.6857 | F1w=0.6969 | F1m=0.6393 | AUROC=0.9104 | PRAUC=0.8077
#   ✅  Loss:1.2054±0.0031 | Acc:0.6737±0.0094 | F1w:0.6824±0.0102 | F1macro:0.6253±0.0089 | AUROC:0.9085±0.0027 | PRAUC:0.8012±0.0041 | MCC:0.5644
#       ↳ LossGap:+0.0063 (tr 1.1991) | F1macroGap:+0.0053 (tr 0.6305) | Penalty:0.0000 | Selection(loss):1.2054
#
#   ▶ [18/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.3168 | Acc=0.6441 | F1w=0.6550 | F1m=0.5902 | AUROC=0.8977 | PRAUC=0.7783
#     F2 → Loss=1.3200 | Acc=0.6330 | F1w=0.6440 | F1m=0.5888 | AUROC=0.8962 | PRAUC=0.7816
#     F3 → Loss=1.3208 | Acc=0.6599 | F1w=0.6704 | F1m=0.5926 | AUROC=0.8991 | PRAUC=0.7853
#     F4 → Loss=1.3160 | Acc=0.6571 | F1w=0.6645 | F1m=0.6077 | AUROC=0.8880 | PRAUC=0.7728
#     F5 → Loss=1.3218 | Acc=0.6550 | F1w=0.6679 | F1m=0.6036 | AUROC=0.9008 | PRAUC=0.7916
#   ✅  Loss:1.3191±0.0023 | Acc:0.6498±0.0100 | F1w:0.6604±0.0097 | F1macro:0.5966±0.0076 | AUROC:0.8964±0.0045 | PRAUC:0.7819±0.0063 | MCC:0.5350
#       ↳ LossGap:+0.0043 (tr 1.3148) | F1macroGap:+0.0056 (tr 0.6022) | Penalty:0.0000 | Selection(loss):1.3191
#
#   ▶ [19/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.2061 | Acc=0.6599 | F1w=0.6671 | F1m=0.6229 | AUROC=0.9073 | PRAUC=0.7970
#     F2 → Loss=1.2107 | Acc=0.6619 | F1w=0.6719 | F1m=0.6151 | AUROC=0.9062 | PRAUC=0.7989
#     F3 → Loss=1.2093 | Acc=0.6796 | F1w=0.6883 | F1m=0.6108 | AUROC=0.9143 | PRAUC=0.8025
#     F4 → Loss=1.2081 | Acc=0.6609 | F1w=0.6690 | F1m=0.6165 | AUROC=0.9043 | PRAUC=0.7939
#     F5 → Loss=1.2136 | Acc=0.6833 | F1w=0.6945 | F1m=0.6385 | AUROC=0.9082 | PRAUC=0.8040
#   ✅  Loss:1.2096±0.0025 | Acc:0.6691±0.0102 | F1w:0.6782±0.0111 | F1macro:0.6208±0.0097 | AUROC:0.9081±0.0034 | PRAUC:0.7993±0.0037 | MCC:0.5595
#       ↳ LossGap:+0.0062 (tr 1.2034) | F1macroGap:+0.0061 (tr 0.6268) | Penalty:0.0000 | Selection(loss):1.2096
#
#   ▶ [20/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.3210 | Acc=0.6359 | F1w=0.6466 | F1m=0.5807 | AUROC=0.8961 | PRAUC=0.7765
#     F2 → Loss=1.3244 | Acc=0.6321 | F1w=0.6431 | F1m=0.5869 | AUROC=0.8966 | PRAUC=0.7811
#     F3 → Loss=1.3240 | Acc=0.6484 | F1w=0.6577 | F1m=0.5774 | AUROC=0.8992 | PRAUC=0.7853
#     F4 → Loss=1.3200 | Acc=0.6542 | F1w=0.6614 | F1m=0.6052 | AUROC=0.8878 | PRAUC=0.7749
#     F5 → Loss=1.3253 | Acc=0.6502 | F1w=0.6631 | F1m=0.5981 | AUROC=0.8998 | PRAUC=0.7892
#   ✅  Loss:1.3230±0.0020 | Acc:0.6442±0.0086 | F1w:0.6544±0.0081 | F1macro:0.5897±0.0105 | AUROC:0.8959±0.0043 | PRAUC:0.7814±0.0054 | MCC:0.5283
#       ↳ LossGap:+0.0042 (tr 1.3187) | F1macroGap:+0.0070 (tr 0.5967) | Penalty:0.0000 | Selection(loss):1.3230
#
#   ▶ [21/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.2004 | Acc=0.6667 | F1w=0.6735 | F1m=0.6317 | AUROC=0.9086 | PRAUC=0.7997
#     F2 → Loss=1.2059 | Acc=0.6638 | F1w=0.6736 | F1m=0.6168 | AUROC=0.9071 | PRAUC=0.8011
#     F3 → Loss=1.2063 | Acc=0.6844 | F1w=0.6927 | F1m=0.6182 | AUROC=0.9126 | PRAUC=0.8027
#     F4 → Loss=1.2047 | Acc=0.6686 | F1w=0.6753 | F1m=0.6246 | AUROC=0.9045 | PRAUC=0.7944
#     F5 → Loss=1.2104 | Acc=0.6848 | F1w=0.6959 | F1m=0.6387 | AUROC=0.9103 | PRAUC=0.8076
#   ✅  Loss:1.2055±0.0032 | Acc:0.6736±0.0091 | F1w:0.6822±0.0100 | F1macro:0.6260±0.0082 | AUROC:0.9086±0.0028 | PRAUC:0.8011±0.0043 | MCC:0.5644
#       ↳ LossGap:+0.0062 (tr 1.1993) | F1macroGap:+0.0045 (tr 0.6305) | Penalty:0.0000 | Selection(loss):1.2055
#
#   ▶ [22/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.3169 | Acc=0.6460 | F1w=0.6570 | F1m=0.5925 | AUROC=0.8979 | PRAUC=0.7786
#     F2 → Loss=1.3200 | Acc=0.6326 | F1w=0.6434 | F1m=0.5882 | AUROC=0.8964 | PRAUC=0.7819
#     F3 → Loss=1.3207 | Acc=0.6575 | F1w=0.6680 | F1m=0.5908 | AUROC=0.8996 | PRAUC=0.7864
#     F4 → Loss=1.3166 | Acc=0.6566 | F1w=0.6640 | F1m=0.6074 | AUROC=0.8879 | PRAUC=0.7727
#     F5 → Loss=1.3220 | Acc=0.6535 | F1w=0.6664 | F1m=0.6024 | AUROC=0.9007 | PRAUC=0.7914
#   ✅  Loss:1.3192±0.0021 | Acc:0.6492±0.0093 | F1w:0.6598±0.0090 | F1macro:0.5963±0.0074 | AUROC:0.8965±0.0045 | PRAUC:0.7822±0.0064 | MCC:0.5341
#       ↳ LossGap:+0.0043 (tr 1.3149) | F1macroGap:+0.0052 (tr 0.6015) | Penalty:0.0000 | Selection(loss):1.3192
#
#   ▶ [23/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.2059 | Acc=0.6604 | F1w=0.6675 | F1m=0.6232 | AUROC=0.9077 | PRAUC=0.7980
#     F2 → Loss=1.2104 | Acc=0.6614 | F1w=0.6714 | F1m=0.6147 | AUROC=0.9065 | PRAUC=0.7997
#     F3 → Loss=1.2091 | Acc=0.6796 | F1w=0.6882 | F1m=0.6111 | AUROC=0.9145 | PRAUC=0.8041
#     F4 → Loss=1.2088 | Acc=0.6604 | F1w=0.6685 | F1m=0.6162 | AUROC=0.9041 | PRAUC=0.7932
#     F5 → Loss=1.2135 | Acc=0.6828 | F1w=0.6941 | F1m=0.6377 | AUROC=0.9082 | PRAUC=0.8040
#   ✅  Loss:1.2095±0.0025 | Acc:0.6689±0.0101 | F1w:0.6779±0.0110 | F1macro:0.6206±0.0094 | AUROC:0.9082±0.0035 | PRAUC:0.7998±0.0041 | MCC:0.5592
#       ↳ LossGap:+0.0062 (tr 1.2034) | F1macroGap:+0.0059 (tr 0.6265) | Penalty:0.0000 | Selection(loss):1.2095
#
#   ▶ [24/64] n_estimators=80 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.3211 | Acc=0.6359 | F1w=0.6466 | F1m=0.5807 | AUROC=0.8963 | PRAUC=0.7768
#     F2 → Loss=1.3242 | Acc=0.6287 | F1w=0.6397 | F1m=0.5832 | AUROC=0.8971 | PRAUC=0.7821
#     F3 → Loss=1.3240 | Acc=0.6484 | F1w=0.6577 | F1m=0.5774 | AUROC=0.8992 | PRAUC=0.7854
#     F4 → Loss=1.3204 | Acc=0.6547 | F1w=0.6619 | F1m=0.6058 | AUROC=0.8870 | PRAUC=0.7711
#     F5 → Loss=1.3253 | Acc=0.6502 | F1w=0.6631 | F1m=0.5981 | AUROC=0.8998 | PRAUC=0.7894
#   ✅  Loss:1.3230±0.0019 | Acc:0.6436±0.0097 | F1w:0.6538±0.0092 | F1macro:0.5890±0.0110 | AUROC:0.8959±0.0046 | PRAUC:0.7810±0.0064 | MCC:0.5276
#       ↳ LossGap:+0.0042 (tr 1.3188) | F1macroGap:+0.0071 (tr 0.5962) | Penalty:0.0000 | Selection(loss):1.3230
#
#   ▶ [25/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.0898 | Acc=0.7651 | F1w=0.7688 | F1m=0.7548 | AUROC=0.9397 | PRAUC=0.8618
#     F2 → Loss=1.0932 | Acc=0.7637 | F1w=0.7684 | F1m=0.7586 | AUROC=0.9358 | PRAUC=0.8574
#     F3 → Loss=1.0930 | Acc=0.7642 | F1w=0.7686 | F1m=0.7380 | AUROC=0.9407 | PRAUC=0.8629
#     F4 → Loss=1.0966 | Acc=0.7574 | F1w=0.7614 | F1m=0.7531 | AUROC=0.9357 | PRAUC=0.8571
#     F5 → Loss=1.1007 | Acc=0.7544 | F1w=0.7606 | F1m=0.7377 | AUROC=0.9315 | PRAUC=0.8485
#   ✅  Loss:1.0947±0.0037 | Acc:0.7610±0.0042 | F1w:0.7656±0.0037 | F1macro:0.7485±0.0088 | AUROC:0.9367±0.0033 | PRAUC:0.8575±0.0051 | MCC:0.6802
#       ↳ LossGap:+0.0101 (tr 1.0846) | F1macroGap:+0.0126 (tr 0.7611) | Penalty:0.0000 | Selection(loss):1.0947
#
#   ▶ [26/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.2276 | Acc=0.7507 | F1w=0.7544 | F1m=0.7475 | AUROC=0.9331 | PRAUC=0.8510
#     F2 → Loss=1.2311 | Acc=0.7541 | F1w=0.7606 | F1m=0.7416 | AUROC=0.9308 | PRAUC=0.8487
#     F3 → Loss=1.2382 | Acc=0.7320 | F1w=0.7407 | F1m=0.6979 | AUROC=0.9326 | PRAUC=0.8496
#     F4 → Loss=1.2331 | Acc=0.7402 | F1w=0.7445 | F1m=0.7275 | AUROC=0.9293 | PRAUC=0.8477
#     F5 → Loss=1.2429 | Acc=0.7347 | F1w=0.7430 | F1m=0.7188 | AUROC=0.9239 | PRAUC=0.8351
#   ✅  Loss:1.2346±0.0054 | Acc:0.7423±0.0087 | F1w:0.7486±0.0076 | F1macro:0.7267±0.0176 | AUROC:0.9300±0.0033 | PRAUC:0.8464±0.0058 | MCC:0.6587
#       ↳ LossGap:+0.0072 (tr 1.2274) | F1macroGap:+0.0140 (tr 0.7406) | Penalty:0.0000 | Selection(loss):1.2346
#
#   ▶ [27/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.0956 | Acc=0.7666 | F1w=0.7708 | F1m=0.7542 | AUROC=0.9383 | PRAUC=0.8598
#     F2 → Loss=1.1014 | Acc=0.7695 | F1w=0.7742 | F1m=0.7600 | AUROC=0.9348 | PRAUC=0.8551
#     F3 → Loss=1.0999 | Acc=0.7584 | F1w=0.7625 | F1m=0.7318 | AUROC=0.9391 | PRAUC=0.8600
#     F4 → Loss=1.1043 | Acc=0.7546 | F1w=0.7587 | F1m=0.7455 | AUROC=0.9339 | PRAUC=0.8535
#     F5 → Loss=1.1162 | Acc=0.7439 | F1w=0.7499 | F1m=0.7320 | AUROC=0.9277 | PRAUC=0.8419
#   ✅  Loss:1.1035±0.0069 | Acc:0.7586±0.0091 | F1w:0.7632±0.0087 | F1macro:0.7447±0.0114 | AUROC:0.9348±0.0040 | PRAUC:0.8541±0.0066 | MCC:0.6772
#       ↳ LossGap:+0.0100 (tr 1.0935) | F1macroGap:+0.0126 (tr 0.7573) | Penalty:0.0000 | Selection(loss):1.1035
#
#   ▶ [28/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.2355 | Acc=0.7464 | F1w=0.7502 | F1m=0.7401 | AUROC=0.9308 | PRAUC=0.8476
#     F2 → Loss=1.2387 | Acc=0.7493 | F1w=0.7557 | F1m=0.7382 | AUROC=0.9290 | PRAUC=0.8436
#     F3 → Loss=1.2456 | Acc=0.7248 | F1w=0.7337 | F1m=0.6908 | AUROC=0.9306 | PRAUC=0.8447
#     F4 → Loss=1.2404 | Acc=0.7368 | F1w=0.7411 | F1m=0.7196 | AUROC=0.9276 | PRAUC=0.8440
#     F5 → Loss=1.2491 | Acc=0.7309 | F1w=0.7384 | F1m=0.7163 | AUROC=0.9212 | PRAUC=0.8299
#   ✅  Loss:1.2418±0.0049 | Acc:0.7376±0.0092 | F1w:0.7438±0.0080 | F1macro:0.7210±0.0178 | AUROC:0.9278±0.0035 | PRAUC:0.8420±0.0062 | MCC:0.6528
#       ↳ LossGap:+0.0071 (tr 1.2347) | F1macroGap:+0.0139 (tr 0.7349) | Penalty:0.0000 | Selection(loss):1.2418
#
#   ▶ [29/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.0895 | Acc=0.7661 | F1w=0.7697 | F1m=0.7569 | AUROC=0.9397 | PRAUC=0.8629
#     F2 → Loss=1.0938 | Acc=0.7646 | F1w=0.7692 | F1m=0.7608 | AUROC=0.9359 | PRAUC=0.8573
#     F3 → Loss=1.0933 | Acc=0.7627 | F1w=0.7672 | F1m=0.7351 | AUROC=0.9407 | PRAUC=0.8634
#     F4 → Loss=1.0975 | Acc=0.7574 | F1w=0.7615 | F1m=0.7567 | AUROC=0.9356 | PRAUC=0.8567
#     F5 → Loss=1.1009 | Acc=0.7544 | F1w=0.7606 | F1m=0.7381 | AUROC=0.9316 | PRAUC=0.8491
#   ✅  Loss:1.0950±0.0039 | Acc:0.7611±0.0044 | F1w:0.7656±0.0038 | F1macro:0.7495±0.0107 | AUROC:0.9367±0.0032 | PRAUC:0.8579±0.0052 | MCC:0.6804
#       ↳ LossGap:+0.0098 (tr 1.0852) | F1macroGap:+0.0112 (tr 0.7607) | Penalty:0.0000 | Selection(loss):1.0950
#
#   ▶ [30/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.2277 | Acc=0.7493 | F1w=0.7529 | F1m=0.7465 | AUROC=0.9331 | PRAUC=0.8511
#     F2 → Loss=1.2318 | Acc=0.7550 | F1w=0.7616 | F1m=0.7473 | AUROC=0.9307 | PRAUC=0.8484
#     F3 → Loss=1.2385 | Acc=0.7305 | F1w=0.7389 | F1m=0.6966 | AUROC=0.9326 | PRAUC=0.8492
#     F4 → Loss=1.2341 | Acc=0.7344 | F1w=0.7389 | F1m=0.7180 | AUROC=0.9292 | PRAUC=0.8472
#     F5 → Loss=1.2432 | Acc=0.7357 | F1w=0.7439 | F1m=0.7196 | AUROC=0.9239 | PRAUC=0.8352
#   ✅  Loss:1.2351±0.0053 | Acc:0.7410±0.0095 | F1w:0.7472±0.0088 | F1macro:0.7256±0.0192 | AUROC:0.9299±0.0033 | PRAUC:0.8463±0.0057 | MCC:0.6570
#       ↳ LossGap:+0.0070 (tr 1.2281) | F1macroGap:+0.0129 (tr 0.7385) | Penalty:0.0000 | Selection(loss):1.2351
#
#   ▶ [31/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.0960 | Acc=0.7704 | F1w=0.7747 | F1m=0.7566 | AUROC=0.9385 | PRAUC=0.8596
#     F2 → Loss=1.1023 | Acc=0.7699 | F1w=0.7744 | F1m=0.7644 | AUROC=0.9345 | PRAUC=0.8542
#     F3 → Loss=1.1001 | Acc=0.7598 | F1w=0.7639 | F1m=0.7315 | AUROC=0.9390 | PRAUC=0.8604
#     F4 → Loss=1.1054 | Acc=0.7536 | F1w=0.7578 | F1m=0.7445 | AUROC=0.9336 | PRAUC=0.8531
#     F5 → Loss=1.1165 | Acc=0.7410 | F1w=0.7469 | F1m=0.7314 | AUROC=0.9275 | PRAUC=0.8416
#   ✅  Loss:1.1040±0.0070 | Acc:0.7590±0.0110 | F1w:0.7636±0.0105 | F1macro:0.7457±0.0132 | AUROC:0.9346±0.0041 | PRAUC:0.8538±0.0067 | MCC:0.6776
#       ↳ LossGap:+0.0098 (tr 1.0943) | F1macroGap:+0.0109 (tr 0.7566) | Penalty:0.0000 | Selection(loss):1.1040
#
#   ▶ [32/64] n_estimators=80 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.2357 | Acc=0.7464 | F1w=0.7501 | F1m=0.7403 | AUROC=0.9310 | PRAUC=0.8477
#     F2 → Loss=1.2392 | Acc=0.7478 | F1w=0.7542 | F1m=0.7358 | AUROC=0.9289 | PRAUC=0.8433
#     F3 → Loss=1.2459 | Acc=0.7281 | F1w=0.7363 | F1m=0.6949 | AUROC=0.9303 | PRAUC=0.8448
#     F4 → Loss=1.2414 | Acc=0.7354 | F1w=0.7397 | F1m=0.7182 | AUROC=0.9274 | PRAUC=0.8436
#     F5 → Loss=1.2493 | Acc=0.7309 | F1w=0.7383 | F1m=0.7166 | AUROC=0.9212 | PRAUC=0.8296
#   ✅  Loss:1.2423±0.0048 | Acc:0.7377±0.0080 | F1w:0.7437±0.0071 | F1macro:0.7212±0.0161 | AUROC:0.9278±0.0035 | PRAUC:0.8418±0.0063 | MCC:0.6527
#       ↳ LossGap:+0.0070 (tr 1.2353) | F1macroGap:+0.0136 (tr 0.7347) | Penalty:0.0000 | Selection(loss):1.2423
#
#   ▶ [33/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.3490 | Acc=0.6335 | F1w=0.6430 | F1m=0.5810 | AUROC=0.8983 | PRAUC=0.7791
#     F2 → Loss=1.3515 | Acc=0.6556 | F1w=0.6687 | F1m=0.6023 | AUROC=0.8982 | PRAUC=0.7832
#     F3 → Loss=1.3530 | Acc=0.6475 | F1w=0.6605 | F1m=0.5831 | AUROC=0.8997 | PRAUC=0.7884
#     F4 → Loss=1.3494 | Acc=0.6465 | F1w=0.6535 | F1m=0.5932 | AUROC=0.8936 | PRAUC=0.7774
#     F5 → Loss=1.3530 | Acc=0.6391 | F1w=0.6497 | F1m=0.5908 | AUROC=0.9046 | PRAUC=0.7951
#   ✅  Loss:1.3512±0.0017 | Acc:0.6444±0.0076 | F1w:0.6551±0.0089 | F1macro:0.5901±0.0076 | AUROC:0.8989±0.0035 | PRAUC:0.7846±0.0065 | MCC:0.5300
#       ↳ LossGap:+0.0038 (tr 1.3474) | F1macroGap:+0.0045 (tr 0.5946) | Penalty:0.0000 | Selection(loss):1.3512
#
#   ▶ [34/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.4375 | Acc=0.6402 | F1w=0.6516 | F1m=0.5833 | AUROC=0.8907 | PRAUC=0.7739
#     F2 → Loss=1.4402 | Acc=0.6215 | F1w=0.6348 | F1m=0.5768 | AUROC=0.8872 | PRAUC=0.7699
#     F3 → Loss=1.4424 | Acc=0.6422 | F1w=0.6563 | F1m=0.5792 | AUROC=0.8899 | PRAUC=0.7786
#     F4 → Loss=1.4366 | Acc=0.6398 | F1w=0.6491 | F1m=0.5849 | AUROC=0.8806 | PRAUC=0.7702
#     F5 → Loss=1.4431 | Acc=0.6305 | F1w=0.6441 | F1m=0.5808 | AUROC=0.8949 | PRAUC=0.7810
#   ✅  Loss:1.4400±0.0026 | Acc:0.6348±0.0078 | F1w:0.6472±0.0074 | F1macro:0.5810±0.0029 | AUROC:0.8887±0.0047 | PRAUC:0.7747±0.0045 | MCC:0.5202
#       ↳ LossGap:+0.0022 (tr 1.4378) | F1macroGap:+0.0053 (tr 0.5863) | Penalty:0.0000 | Selection(loss):1.4400
#
#   ▶ [35/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.3519 | Acc=0.6234 | F1w=0.6327 | F1m=0.5690 | AUROC=0.8984 | PRAUC=0.7810
#     F2 → Loss=1.3548 | Acc=0.6268 | F1w=0.6379 | F1m=0.5789 | AUROC=0.8986 | PRAUC=0.7828
#     F3 → Loss=1.3566 | Acc=0.6340 | F1w=0.6453 | F1m=0.5701 | AUROC=0.8991 | PRAUC=0.7859
#     F4 → Loss=1.3530 | Acc=0.6455 | F1w=0.6527 | F1m=0.5925 | AUROC=0.8928 | PRAUC=0.7756
#     F5 → Loss=1.3566 | Acc=0.6358 | F1w=0.6464 | F1m=0.5879 | AUROC=0.9034 | PRAUC=0.7947
#   ✅  Loss:1.3546±0.0019 | Acc:0.6331±0.0077 | F1w:0.6430±0.0070 | F1macro:0.5797±0.0094 | AUROC:0.8985±0.0034 | PRAUC:0.7840±0.0063 | MCC:0.5160
#       ↳ LossGap:+0.0038 (tr 1.3507) | F1macroGap:+0.0066 (tr 0.5863) | Penalty:0.0000 | Selection(loss):1.3546
#
#   ▶ [36/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.4401 | Acc=0.6398 | F1w=0.6513 | F1m=0.5816 | AUROC=0.8913 | PRAUC=0.7744
#     F2 → Loss=1.4426 | Acc=0.6215 | F1w=0.6349 | F1m=0.5750 | AUROC=0.8888 | PRAUC=0.7723
#     F3 → Loss=1.4448 | Acc=0.6383 | F1w=0.6518 | F1m=0.5739 | AUROC=0.8898 | PRAUC=0.7776
#     F4 → Loss=1.4400 | Acc=0.6061 | F1w=0.6157 | F1m=0.5384 | AUROC=0.8797 | PRAUC=0.7669
#     F5 → Loss=1.4460 | Acc=0.6031 | F1w=0.6187 | F1m=0.5359 | AUROC=0.8943 | PRAUC=0.7805
#   ✅  Loss:1.4427±0.0024 | Acc:0.6218±0.0154 | F1w:0.6345±0.0154 | F1macro:0.5609±0.0196 | AUROC:0.8888±0.0049 | PRAUC:0.7744±0.0046 | MCC:0.5054
#       ↳ LossGap:+0.0023 (tr 1.4404) | F1macroGap:+0.0072 (tr 0.5681) | Penalty:0.0000 | Selection(loss):1.4427
#
#   ▶ [37/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.3489 | Acc=0.6335 | F1w=0.6430 | F1m=0.5807 | AUROC=0.8988 | PRAUC=0.7805
#     F2 → Loss=1.3513 | Acc=0.6551 | F1w=0.6682 | F1m=0.6017 | AUROC=0.8985 | PRAUC=0.7837
#     F3 → Loss=1.3530 | Acc=0.6479 | F1w=0.6610 | F1m=0.5834 | AUROC=0.8999 | PRAUC=0.7886
#     F4 → Loss=1.3498 | Acc=0.6460 | F1w=0.6530 | F1m=0.5929 | AUROC=0.8933 | PRAUC=0.7770
#     F5 → Loss=1.3532 | Acc=0.6377 | F1w=0.6480 | F1m=0.5901 | AUROC=0.9042 | PRAUC=0.7948
#   ✅  Loss:1.3513±0.0017 | Acc:0.6441±0.0077 | F1w:0.6546±0.0090 | F1macro:0.5898±0.0074 | AUROC:0.8990±0.0035 | PRAUC:0.7849±0.0063 | MCC:0.5295
#       ↳ LossGap:+0.0037 (tr 1.3475) | F1macroGap:+0.0038 (tr 0.5936) | Penalty:0.0000 | Selection(loss):1.3513
#
#   ▶ [38/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.4377 | Acc=0.6398 | F1w=0.6511 | F1m=0.5827 | AUROC=0.8907 | PRAUC=0.7746
#     F2 → Loss=1.4400 | Acc=0.6239 | F1w=0.6373 | F1m=0.5783 | AUROC=0.8878 | PRAUC=0.7719
#     F3 → Loss=1.4424 | Acc=0.6422 | F1w=0.6563 | F1m=0.5792 | AUROC=0.8900 | PRAUC=0.7788
#     F4 → Loss=1.4371 | Acc=0.6398 | F1w=0.6491 | F1m=0.5849 | AUROC=0.8805 | PRAUC=0.7701
#     F5 → Loss=1.4432 | Acc=0.6314 | F1w=0.6450 | F1m=0.5819 | AUROC=0.8948 | PRAUC=0.7806
#   ✅  Loss:1.4401±0.0025 | Acc:0.6354±0.0068 | F1w:0.6478±0.0064 | F1macro:0.5814±0.0024 | AUROC:0.8887±0.0047 | PRAUC:0.7752±0.0040 | MCC:0.5208
#       ↳ LossGap:+0.0022 (tr 1.4379) | F1macroGap:+0.0048 (tr 0.5862) | Penalty:0.0000 | Selection(loss):1.4401
#
#   ▶ [39/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.3520 | Acc=0.6225 | F1w=0.6318 | F1m=0.5687 | AUROC=0.8986 | PRAUC=0.7813
#     F2 → Loss=1.3546 | Acc=0.6263 | F1w=0.6375 | F1m=0.5782 | AUROC=0.8991 | PRAUC=0.7837
#     F3 → Loss=1.3565 | Acc=0.6340 | F1w=0.6453 | F1m=0.5701 | AUROC=0.8992 | PRAUC=0.7859
#     F4 → Loss=1.3534 | Acc=0.6455 | F1w=0.6527 | F1m=0.5925 | AUROC=0.8927 | PRAUC=0.7751
#     F5 → Loss=1.3570 | Acc=0.6415 | F1w=0.6523 | F1m=0.5926 | AUROC=0.9036 | PRAUC=0.7947
#   ✅  Loss:1.3547±0.0019 | Acc:0.6340±0.0087 | F1w:0.6439±0.0082 | F1macro:0.5804±0.0104 | AUROC:0.8986±0.0035 | PRAUC:0.7841±0.0064 | MCC:0.5171
#       ↳ LossGap:+0.0038 (tr 1.3509) | F1macroGap:+0.0070 (tr 0.5874) | Penalty:0.0000 | Selection(loss):1.3547
#
#   ▶ [40/64] n_estimators=150 | learning_rate=0.05 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.4403 | Acc=0.6402 | F1w=0.6518 | F1m=0.5822 | AUROC=0.8915 | PRAUC=0.7749
#     F2 → Loss=1.4425 | Acc=0.6215 | F1w=0.6351 | F1m=0.5735 | AUROC=0.8892 | PRAUC=0.7731
#     F3 → Loss=1.4448 | Acc=0.6383 | F1w=0.6518 | F1m=0.5739 | AUROC=0.8897 | PRAUC=0.7774
#     F4 → Loss=1.4404 | Acc=0.6042 | F1w=0.6134 | F1m=0.5361 | AUROC=0.8796 | PRAUC=0.7664
#     F5 → Loss=1.4459 | Acc=0.6040 | F1w=0.6198 | F1m=0.5371 | AUROC=0.8944 | PRAUC=0.7814
#   ✅  Loss:1.4428±0.0023 | Acc:0.6217±0.0157 | F1w:0.6344±0.0159 | F1macro:0.5606±0.0198 | AUROC:0.8889±0.0050 | PRAUC:0.7746±0.0050 | MCC:0.5053
#       ↳ LossGap:+0.0023 (tr 1.4405) | F1macroGap:+0.0071 (tr 0.5677) | Penalty:0.0000 | Selection(loss):1.4428
#
#   ▶ [41/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.2706 | Acc=0.7541 | F1w=0.7580 | F1m=0.7415 | AUROC=0.9342 | PRAUC=0.8527
#     F2 → Loss=1.2732 | Acc=0.7493 | F1w=0.7569 | F1m=0.7325 | AUROC=0.9340 | PRAUC=0.8546
#     F3 → Loss=1.2756 | Acc=0.7387 | F1w=0.7461 | F1m=0.7006 | AUROC=0.9363 | PRAUC=0.8579
#     F4 → Loss=1.2746 | Acc=0.7454 | F1w=0.7501 | F1m=0.7252 | AUROC=0.9333 | PRAUC=0.8544
#     F5 → Loss=1.2836 | Acc=0.7347 | F1w=0.7426 | F1m=0.7177 | AUROC=0.9245 | PRAUC=0.8365
#   ✅  Loss:1.2755±0.0044 | Acc:0.7445±0.0070 | F1w:0.7507±0.0060 | F1macro:0.7235±0.0139 | AUROC:0.9325±0.0041 | PRAUC:0.8512±0.0075 | MCC:0.6607
#       ↳ LossGap:+0.0064 (tr 1.2691) | F1macroGap:+0.0120 (tr 0.7355) | Penalty:0.0000 | Selection(loss):1.2755
#
#   ▶ [42/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.3834 | Acc=0.7190 | F1w=0.7256 | F1m=0.6975 | AUROC=0.9260 | PRAUC=0.8378
#     F2 → Loss=1.3851 | Acc=0.7113 | F1w=0.7221 | F1m=0.6704 | AUROC=0.9296 | PRAUC=0.8474
#     F3 → Loss=1.3894 | Acc=0.6734 | F1w=0.6878 | F1m=0.6210 | AUROC=0.9262 | PRAUC=0.8457
#     F4 → Loss=1.3828 | Acc=0.7085 | F1w=0.7151 | F1m=0.6717 | AUROC=0.9245 | PRAUC=0.8422
#     F5 → Loss=1.3925 | Acc=0.7078 | F1w=0.7200 | F1m=0.6679 | AUROC=0.9210 | PRAUC=0.8332
#   ✅  Loss:1.3867±0.0037 | Acc:0.7040±0.0158 | F1w:0.7141±0.0136 | F1macro:0.6657±0.0248 | AUROC:0.9255±0.0028 | PRAUC:0.8413±0.0052 | MCC:0.6161
#       ↳ LossGap:+0.0044 (tr 1.3823) | F1macroGap:+0.0115 (tr 0.6772) | Penalty:0.0000 | Selection(loss):1.3867
#
#   ▶ [43/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.2771 | Acc=0.7526 | F1w=0.7567 | F1m=0.7372 | AUROC=0.9323 | PRAUC=0.8484
#     F2 → Loss=1.2785 | Acc=0.7445 | F1w=0.7508 | F1m=0.7230 | AUROC=0.9322 | PRAUC=0.8510
#     F3 → Loss=1.2816 | Acc=0.7301 | F1w=0.7374 | F1m=0.6941 | AUROC=0.9342 | PRAUC=0.8538
#     F4 → Loss=1.2803 | Acc=0.7450 | F1w=0.7488 | F1m=0.7275 | AUROC=0.9308 | PRAUC=0.8513
#     F5 → Loss=1.2875 | Acc=0.7304 | F1w=0.7386 | F1m=0.7094 | AUROC=0.9216 | PRAUC=0.8312
#   ✅  Loss:1.2810±0.0036 | Acc:0.7405±0.0089 | F1w:0.7464±0.0074 | F1macro:0.7182±0.0151 | AUROC:0.9302±0.0044 | PRAUC:0.8471±0.0081 | MCC:0.6555
#       ↳ LossGap:+0.0065 (tr 1.2745) | F1macroGap:+0.0152 (tr 0.7335) | Penalty:0.0000 | Selection(loss):1.2810
#
#   ▶ [44/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.3878 | Acc=0.7267 | F1w=0.7316 | F1m=0.7091 | AUROC=0.9248 | PRAUC=0.8362
#     F2 → Loss=1.3886 | Acc=0.7161 | F1w=0.7253 | F1m=0.6787 | AUROC=0.9282 | PRAUC=0.8451
#     F3 → Loss=1.3948 | Acc=0.6657 | F1w=0.6802 | F1m=0.6139 | AUROC=0.9236 | PRAUC=0.8387
#     F4 → Loss=1.3877 | Acc=0.7075 | F1w=0.7136 | F1m=0.6720 | AUROC=0.9229 | PRAUC=0.8390
#     F5 → Loss=1.3972 | Acc=0.7112 | F1w=0.7230 | F1m=0.6730 | AUROC=0.9169 | PRAUC=0.8257
#   ✅  Loss:1.3912±0.0040 | Acc:0.7054±0.0209 | F1w:0.7148±0.0182 | F1macro:0.6694±0.0309 | AUROC:0.9233±0.0037 | PRAUC:0.8369±0.0063 | MCC:0.6163
#       ↳ LossGap:+0.0046 (tr 1.3867) | F1macroGap:+0.0109 (tr 0.6803) | Penalty:0.0000 | Selection(loss):1.3912
#
#   ▶ [45/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.2709 | Acc=0.7526 | F1w=0.7565 | F1m=0.7407 | AUROC=0.9342 | PRAUC=0.8529
#     F2 → Loss=1.2737 | Acc=0.7478 | F1w=0.7554 | F1m=0.7321 | AUROC=0.9340 | PRAUC=0.8547
#     F3 → Loss=1.2757 | Acc=0.7387 | F1w=0.7461 | F1m=0.7006 | AUROC=0.9363 | PRAUC=0.8579
#     F4 → Loss=1.2751 | Acc=0.7454 | F1w=0.7500 | F1m=0.7261 | AUROC=0.9330 | PRAUC=0.8540
#     F5 → Loss=1.2840 | Acc=0.7338 | F1w=0.7417 | F1m=0.7165 | AUROC=0.9245 | PRAUC=0.8367
#   ✅  Loss:1.2759±0.0044 | Acc:0.7437±0.0067 | F1w:0.7499±0.0056 | F1macro:0.7232±0.0138 | AUROC:0.9324±0.0041 | PRAUC:0.8513±0.0075 | MCC:0.6598
#       ↳ LossGap:+0.0063 (tr 1.2696) | F1macroGap:+0.0125 (tr 0.7357) | Penalty:0.0000 | Selection(loss):1.2759
#
#   ▶ [46/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.3837 | Acc=0.7176 | F1w=0.7242 | F1m=0.6963 | AUROC=0.9258 | PRAUC=0.8387
#     F2 → Loss=1.3854 | Acc=0.7099 | F1w=0.7205 | F1m=0.6697 | AUROC=0.9297 | PRAUC=0.8473
#     F3 → Loss=1.3895 | Acc=0.6715 | F1w=0.6859 | F1m=0.6192 | AUROC=0.9261 | PRAUC=0.8455
#     F4 → Loss=1.3834 | Acc=0.7104 | F1w=0.7172 | F1m=0.6734 | AUROC=0.9246 | PRAUC=0.8424
#     F5 → Loss=1.3927 | Acc=0.7074 | F1w=0.7195 | F1m=0.6674 | AUROC=0.9212 | PRAUC=0.8336
#   ✅  Loss:1.3870±0.0036 | Acc:0.7033±0.0163 | F1w:0.7135±0.0140 | F1macro:0.6652±0.0252 | AUROC:0.9255±0.0027 | PRAUC:0.8415±0.0049 | MCC:0.6153
#       ↳ LossGap:+0.0042 (tr 1.3827) | F1macroGap:+0.0110 (tr 0.6762) | Penalty:0.0000 | Selection(loss):1.3870
#
#   ▶ [47/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.2773 | Acc=0.7526 | F1w=0.7568 | F1m=0.7371 | AUROC=0.9324 | PRAUC=0.8484
#     F2 → Loss=1.2787 | Acc=0.7426 | F1w=0.7489 | F1m=0.7221 | AUROC=0.9322 | PRAUC=0.8511
#     F3 → Loss=1.2817 | Acc=0.7315 | F1w=0.7388 | F1m=0.6944 | AUROC=0.9343 | PRAUC=0.8537
#     F4 → Loss=1.2811 | Acc=0.7430 | F1w=0.7469 | F1m=0.7257 | AUROC=0.9305 | PRAUC=0.8510
#     F5 → Loss=1.2877 | Acc=0.7304 | F1w=0.7385 | F1m=0.7107 | AUROC=0.9215 | PRAUC=0.8311
#   ✅  Loss:1.2813±0.0036 | Acc:0.7400±0.0082 | F1w:0.7460±0.0068 | F1macro:0.7180±0.0145 | AUROC:0.9302±0.0045 | PRAUC:0.8471±0.0081 | MCC:0.6549
#       ↳ LossGap:+0.0064 (tr 1.2749) | F1macroGap:+0.0143 (tr 0.7323) | Penalty:0.0000 | Selection(loss):1.2813
#
#   ▶ [48/64] n_estimators=150 | learning_rate=0.05 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.3881 | Acc=0.7190 | F1w=0.7237 | F1m=0.7032 | AUROC=0.9249 | PRAUC=0.8364
#     F2 → Loss=1.3888 | Acc=0.7147 | F1w=0.7239 | F1m=0.6771 | AUROC=0.9283 | PRAUC=0.8449
#     F3 → Loss=1.3950 | Acc=0.6667 | F1w=0.6813 | F1m=0.6149 | AUROC=0.9235 | PRAUC=0.8386
#     F4 → Loss=1.3885 | Acc=0.7070 | F1w=0.7135 | F1m=0.6703 | AUROC=0.9227 | PRAUC=0.8386
#     F5 → Loss=1.3974 | Acc=0.7098 | F1w=0.7215 | F1m=0.6719 | AUROC=0.9163 | PRAUC=0.8249
#   ✅  Loss:1.3915±0.0039 | Acc:0.7034±0.0188 | F1w:0.7128±0.0162 | F1macro:0.6675±0.0288 | AUROC:0.9231±0.0039 | PRAUC:0.8367±0.0065 | MCC:0.6141
#       ↳ LossGap:+0.0044 (tr 1.3871) | F1macroGap:+0.0099 (tr 0.6774) | Penalty:0.0000 | Selection(loss):1.3915
#
#   ▶ [49/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.1633 | Acc=0.6792 | F1w=0.6851 | F1m=0.6596 | AUROC=0.9115 | PRAUC=0.8060
#     F2 → Loss=1.1683 | Acc=0.6710 | F1w=0.6811 | F1m=0.6226 | AUROC=0.9100 | PRAUC=0.8068
#     F3 → Loss=1.1679 | Acc=0.6931 | F1w=0.7004 | F1m=0.6266 | AUROC=0.9162 | PRAUC=0.8091
#     F4 → Loss=1.1676 | Acc=0.6806 | F1w=0.6875 | F1m=0.6347 | AUROC=0.9076 | PRAUC=0.7997
#     F5 → Loss=1.1730 | Acc=0.7025 | F1w=0.7125 | F1m=0.6669 | AUROC=0.9136 | PRAUC=0.8154
#   ✅  Loss:1.1680±0.0031 | Acc:0.6853±0.0112 | F1w:0.6933±0.0116 | F1macro:0.6421±0.0179 | AUROC:0.9118±0.0030 | PRAUC:0.8074±0.0051 | MCC:0.5791
#       ↳ LossGap:+0.0069 (tr 1.1611) | F1macroGap:+0.0067 (tr 0.6488) | Penalty:0.0000 | Selection(loss):1.1680
#
#   ▶ [50/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.2927 | Acc=0.6451 | F1w=0.6555 | F1m=0.5936 | AUROC=0.9006 | PRAUC=0.7835
#     F2 → Loss=1.2955 | Acc=0.6427 | F1w=0.6535 | F1m=0.5965 | AUROC=0.8994 | PRAUC=0.7874
#     F3 → Loss=1.2965 | Acc=0.6551 | F1w=0.6665 | F1m=0.5886 | AUROC=0.9031 | PRAUC=0.7904
#     F4 → Loss=1.2919 | Acc=0.6590 | F1w=0.6665 | F1m=0.6080 | AUROC=0.8927 | PRAUC=0.7783
#     F5 → Loss=1.2976 | Acc=0.6559 | F1w=0.6690 | F1m=0.6043 | AUROC=0.9037 | PRAUC=0.7965
#   ✅  Loss:1.2948±0.0022 | Acc:0.6516±0.0065 | F1w:0.6622±0.0064 | F1macro:0.5982±0.0070 | AUROC:0.8999±0.0039 | PRAUC:0.7872±0.0062 | MCC:0.5371
#       ↳ LossGap:+0.0046 (tr 1.2902) | F1macroGap:+0.0060 (tr 0.6042) | Penalty:0.0000 | Selection(loss):1.2948
#
#   ▶ [51/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.1689 | Acc=0.6777 | F1w=0.6838 | F1m=0.6562 | AUROC=0.9108 | PRAUC=0.8041
#     F2 → Loss=1.1733 | Acc=0.6691 | F1w=0.6789 | F1m=0.6214 | AUROC=0.9094 | PRAUC=0.8047
#     F3 → Loss=1.1707 | Acc=0.6974 | F1w=0.7061 | F1m=0.6295 | AUROC=0.9180 | PRAUC=0.8102
#     F4 → Loss=1.1717 | Acc=0.6705 | F1w=0.6780 | F1m=0.6278 | AUROC=0.9073 | PRAUC=0.7989
#     F5 → Loss=1.1762 | Acc=0.6953 | F1w=0.7054 | F1m=0.6615 | AUROC=0.9115 | PRAUC=0.8116
#   ✅  Loss:1.1722±0.0025 | Acc:0.6820±0.0121 | F1w:0.6904±0.0127 | F1macro:0.6393±0.0163 | AUROC:0.9114±0.0036 | PRAUC:0.8059±0.0046 | MCC:0.5756
#       ↳ LossGap:+0.0069 (tr 1.1653) | F1macroGap:+0.0079 (tr 0.6472) | Penalty:0.0000 | Selection(loss):1.1722
#
#   ▶ [52/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.2971 | Acc=0.6374 | F1w=0.6481 | F1m=0.5828 | AUROC=0.8990 | PRAUC=0.7819
#     F2 → Loss=1.3001 | Acc=0.6340 | F1w=0.6449 | F1m=0.5886 | AUROC=0.8999 | PRAUC=0.7869
#     F3 → Loss=1.2998 | Acc=0.6547 | F1w=0.6658 | F1m=0.5868 | AUROC=0.9031 | PRAUC=0.7896
#     F4 → Loss=1.2961 | Acc=0.6551 | F1w=0.6630 | F1m=0.6048 | AUROC=0.8916 | PRAUC=0.7763
#     F5 → Loss=1.3015 | Acc=0.6526 | F1w=0.6659 | F1m=0.6022 | AUROC=0.9029 | PRAUC=0.7946
#   ✅  Loss:1.2989±0.0020 | Acc:0.6467±0.0091 | F1w:0.6575±0.0091 | F1macro:0.5930±0.0088 | AUROC:0.8993±0.0042 | PRAUC:0.7859±0.0063 | MCC:0.5320
#       ↳ LossGap:+0.0046 (tr 1.2943) | F1macroGap:+0.0068 (tr 0.5998) | Penalty:0.0000 | Selection(loss):1.2989
#
#   ▶ [53/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.1629 | Acc=0.6796 | F1w=0.6855 | F1m=0.6602 | AUROC=0.9117 | PRAUC=0.8057
#     F2 → Loss=1.1685 | Acc=0.6705 | F1w=0.6805 | F1m=0.6223 | AUROC=0.9100 | PRAUC=0.8062
#     F3 → Loss=1.1679 | Acc=0.6945 | F1w=0.7019 | F1m=0.6285 | AUROC=0.9164 | PRAUC=0.8093
#     F4 → Loss=1.1683 | Acc=0.6796 | F1w=0.6866 | F1m=0.6340 | AUROC=0.9074 | PRAUC=0.7993
#     F5 → Loss=1.1731 | Acc=0.7016 | F1w=0.7114 | F1m=0.6664 | AUROC=0.9136 | PRAUC=0.8153
#   ✅  Loss:1.1681±0.0033 | Acc:0.6852±0.0113 | F1w:0.6932±0.0116 | F1macro:0.6423±0.0176 | AUROC:0.9118±0.0031 | PRAUC:0.8071±0.0052 | MCC:0.5790
#       ↳ LossGap:+0.0069 (tr 1.1612) | F1macroGap:+0.0069 (tr 0.6491) | Penalty:0.0000 | Selection(loss):1.1681
#
#   ▶ [54/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.2927 | Acc=0.6479 | F1w=0.6584 | F1m=0.5957 | AUROC=0.9008 | PRAUC=0.7841
#     F2 → Loss=1.2954 | Acc=0.6436 | F1w=0.6544 | F1m=0.5979 | AUROC=0.8995 | PRAUC=0.7875
#     F3 → Loss=1.2963 | Acc=0.6609 | F1w=0.6715 | F1m=0.5931 | AUROC=0.9036 | PRAUC=0.7914
#     F4 → Loss=1.2925 | Acc=0.6585 | F1w=0.6660 | F1m=0.6077 | AUROC=0.8926 | PRAUC=0.7782
#     F5 → Loss=1.2978 | Acc=0.6545 | F1w=0.6674 | F1m=0.6034 | AUROC=0.9036 | PRAUC=0.7964
#   ✅  Loss:1.2950±0.0021 | Acc:0.6531±0.0065 | F1w:0.6635±0.0062 | F1macro:0.5996±0.0053 | AUROC:0.9001±0.0040 | PRAUC:0.7875±0.0062 | MCC:0.5387
#       ↳ LossGap:+0.0046 (tr 1.2903) | F1macroGap:+0.0048 (tr 0.6044) | Penalty:0.0000 | Selection(loss):1.2950
#
#   ▶ [55/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.1687 | Acc=0.6787 | F1w=0.6848 | F1m=0.6590 | AUROC=0.9110 | PRAUC=0.8043
#     F2 → Loss=1.1731 | Acc=0.6691 | F1w=0.6789 | F1m=0.6214 | AUROC=0.9097 | PRAUC=0.8053
#     F3 → Loss=1.1707 | Acc=0.6993 | F1w=0.7082 | F1m=0.6320 | AUROC=0.9181 | PRAUC=0.8113
#     F4 → Loss=1.1724 | Acc=0.6705 | F1w=0.6780 | F1m=0.6278 | AUROC=0.9072 | PRAUC=0.7981
#     F5 → Loss=1.1762 | Acc=0.6953 | F1w=0.7054 | F1m=0.6615 | AUROC=0.9115 | PRAUC=0.8115
#   ✅  Loss:1.1722±0.0025 | Acc:0.6826±0.0125 | F1w:0.6911±0.0131 | F1macro:0.6403±0.0166 | AUROC:0.9115±0.0036 | PRAUC:0.8061±0.0050 | MCC:0.5763
#       ↳ LossGap:+0.0069 (tr 1.1654) | F1macroGap:+0.0070 (tr 0.6474) | Penalty:0.0000 | Selection(loss):1.1722
#
#   ▶ [56/64] n_estimators=150 | learning_rate=0.1 | max_depth=3 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.2971 | Acc=0.6369 | F1w=0.6477 | F1m=0.5824 | AUROC=0.8992 | PRAUC=0.7821
#     F2 → Loss=1.2999 | Acc=0.6306 | F1w=0.6415 | F1m=0.5848 | AUROC=0.9003 | PRAUC=0.7876
#     F3 → Loss=1.2998 | Acc=0.6547 | F1w=0.6658 | F1m=0.5868 | AUROC=0.9032 | PRAUC=0.7898
#     F4 → Loss=1.2965 | Acc=0.6551 | F1w=0.6628 | F1m=0.6054 | AUROC=0.8913 | PRAUC=0.7756
#     F5 → Loss=1.3014 | Acc=0.6526 | F1w=0.6659 | F1m=0.6022 | AUROC=0.9030 | PRAUC=0.7946
#   ✅  Loss:1.2989±0.0018 | Acc:0.6460±0.0102 | F1w:0.6567±0.0102 | F1macro:0.5923±0.0095 | AUROC:0.8994±0.0043 | PRAUC:0.7859±0.0065 | MCC:0.5310
#       ↳ LossGap:+0.0045 (tr 1.2944) | F1macroGap:+0.0068 (tr 0.5992) | Penalty:0.0000 | Selection(loss):1.2989
#
#   ▶ [57/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.0447 | Acc=0.7776 | F1w=0.7812 | F1m=0.7638 | AUROC=0.9421 | PRAUC=0.8663
#     F2 → Loss=1.0486 | Acc=0.7767 | F1w=0.7806 | F1m=0.7736 | AUROC=0.9377 | PRAUC=0.8612
#     F3 → Loss=1.0477 | Acc=0.7810 | F1w=0.7842 | F1m=0.7633 | AUROC=0.9433 | PRAUC=0.8686
#     F4 → Loss=1.0532 | Acc=0.7661 | F1w=0.7701 | F1m=0.7620 | AUROC=0.9371 | PRAUC=0.8600
#     F5 → Loss=1.0580 | Acc=0.7578 | F1w=0.7634 | F1m=0.7401 | AUROC=0.9335 | PRAUC=0.8521
#   ✅  Loss:1.0504±0.0047 | Acc:0.7718±0.0086 | F1w:0.7759±0.0079 | F1macro:0.7606±0.0110 | AUROC:0.9387±0.0036 | PRAUC:0.8616±0.0057 | MCC:0.6927
#       ↳ LossGap:+0.0109 (tr 1.0395) | F1macroGap:+0.0121 (tr 0.7727) | Penalty:0.0000 | Selection(loss):1.0504
#
#   ▶ [58/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.1979 | Acc=0.7498 | F1w=0.7536 | F1m=0.7433 | AUROC=0.9347 | PRAUC=0.8533
#     F2 → Loss=1.2011 | Acc=0.7632 | F1w=0.7694 | F1m=0.7536 | AUROC=0.9321 | PRAUC=0.8507
#     F3 → Loss=1.2075 | Acc=0.7421 | F1w=0.7502 | F1m=0.7069 | AUROC=0.9349 | PRAUC=0.8551
#     F4 → Loss=1.2034 | Acc=0.7450 | F1w=0.7484 | F1m=0.7348 | AUROC=0.9314 | PRAUC=0.8508
#     F5 → Loss=1.2138 | Acc=0.7395 | F1w=0.7473 | F1m=0.7236 | AUROC=0.9255 | PRAUC=0.8371
#   ✅  Loss:1.2047±0.0055 | Acc:0.7479±0.0084 | F1w:0.7538±0.0081 | F1macro:0.7325±0.0161 | AUROC:0.9317±0.0034 | PRAUC:0.8494±0.0064 | MCC:0.6649
#       ↳ LossGap:+0.0078 (tr 1.1970) | F1macroGap:+0.0118 (tr 0.7443) | Penalty:0.0000 | Selection(loss):1.2047
#
#   ▶ [59/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.0512 | Acc=0.7767 | F1w=0.7808 | F1m=0.7617 | AUROC=0.9406 | PRAUC=0.8641
#     F2 → Loss=1.0573 | Acc=0.7776 | F1w=0.7820 | F1m=0.7675 | AUROC=0.9364 | PRAUC=0.8589
#     F3 → Loss=1.0548 | Acc=0.7728 | F1w=0.7763 | F1m=0.7465 | AUROC=0.9418 | PRAUC=0.8656
#     F4 → Loss=1.0611 | Acc=0.7637 | F1w=0.7677 | F1m=0.7588 | AUROC=0.9356 | PRAUC=0.8567
#     F5 → Loss=1.0732 | Acc=0.7444 | F1w=0.7501 | F1m=0.7299 | AUROC=0.9300 | PRAUC=0.8463
#   ✅  Loss:1.0595±0.0076 | Acc:0.7670±0.0124 | F1w:0.7714±0.0118 | F1macro:0.7529±0.0134 | AUROC:0.9369±0.0042 | PRAUC:0.8583±0.0068 | MCC:0.6869
#       ↳ LossGap:+0.0108 (tr 1.0487) | F1macroGap:+0.0107 (tr 0.7636) | Penalty:0.0000 | Selection(loss):1.0595
#
#   ▶ [60/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.2060 | Acc=0.7507 | F1w=0.7546 | F1m=0.7427 | AUROC=0.9328 | PRAUC=0.8498
#     F2 → Loss=1.2090 | Acc=0.7536 | F1w=0.7599 | F1m=0.7426 | AUROC=0.9306 | PRAUC=0.8463
#     F3 → Loss=1.2152 | Acc=0.7257 | F1w=0.7342 | F1m=0.6912 | AUROC=0.9328 | PRAUC=0.8496
#     F4 → Loss=1.2110 | Acc=0.7421 | F1w=0.7453 | F1m=0.7279 | AUROC=0.9298 | PRAUC=0.8468
#     F5 → Loss=1.2202 | Acc=0.7323 | F1w=0.7393 | F1m=0.7186 | AUROC=0.9227 | PRAUC=0.8326
#   ✅  Loss:1.2123±0.0050 | Acc:0.7409±0.0106 | F1w:0.7467±0.0095 | F1macro:0.7246±0.0190 | AUROC:0.9297±0.0037 | PRAUC:0.8450±0.0064 | MCC:0.6564
#       ↳ LossGap:+0.0077 (tr 1.2046) | F1macroGap:+0.0147 (tr 0.7393) | Penalty:0.0000 | Selection(loss):1.2123
#
#   ▶ [61/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.1
#     F1 → Loss=1.0445 | Acc=0.7771 | F1w=0.7810 | F1m=0.7633 | AUROC=0.9421 | PRAUC=0.8668
#     F2 → Loss=1.0493 | Acc=0.7752 | F1w=0.7792 | F1m=0.7712 | AUROC=0.9378 | PRAUC=0.8609
#     F3 → Loss=1.0479 | Acc=0.7810 | F1w=0.7843 | F1m=0.7593 | AUROC=0.9432 | PRAUC=0.8687
#     F4 → Loss=1.0542 | Acc=0.7671 | F1w=0.7709 | F1m=0.7671 | AUROC=0.9370 | PRAUC=0.8595
#     F5 → Loss=1.0582 | Acc=0.7607 | F1w=0.7664 | F1m=0.7419 | AUROC=0.9335 | PRAUC=0.8526
#   ✅  Loss:1.0508±0.0048 | Acc:0.7722±0.0073 | F1w:0.7763±0.0066 | F1macro:0.7605±0.0102 | AUROC:0.9387±0.0035 | PRAUC:0.8617±0.0057 | MCC:0.6934
#       ↳ LossGap:+0.0107 (tr 1.0402) | F1macroGap:+0.0115 (tr 0.7720) | Penalty:0.0000 | Selection(loss):1.0508
#
#   ▶ [62/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=1 | rate_drop=0.2
#     F1 → Loss=1.1981 | Acc=0.7498 | F1w=0.7535 | F1m=0.7435 | AUROC=0.9347 | PRAUC=0.8533
#     F2 → Loss=1.2018 | Acc=0.7627 | F1w=0.7689 | F1m=0.7543 | AUROC=0.9320 | PRAUC=0.8508
#     F3 → Loss=1.2078 | Acc=0.7411 | F1w=0.7492 | F1m=0.7063 | AUROC=0.9349 | PRAUC=0.8552
#     F4 → Loss=1.2045 | Acc=0.7416 | F1w=0.7454 | F1m=0.7331 | AUROC=0.9313 | PRAUC=0.8505
#     F5 → Loss=1.2141 | Acc=0.7400 | F1w=0.7478 | F1m=0.7237 | AUROC=0.9256 | PRAUC=0.8375
#   ✅  Loss:1.2052±0.0055 | Acc:0.7470±0.0086 | F1w:0.7530±0.0084 | F1macro:0.7322±0.0165 | AUROC:0.9317±0.0034 | PRAUC:0.8494±0.0062 | MCC:0.6637
#       ↳ LossGap:+0.0076 (tr 1.1977) | F1macroGap:+0.0116 (tr 0.7437) | Penalty:0.0000 | Selection(loss):1.2052
#
#   ▶ [63/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.1
#     F1 → Loss=1.0516 | Acc=0.7762 | F1w=0.7803 | F1m=0.7614 | AUROC=0.9407 | PRAUC=0.8640
#     F2 → Loss=1.0583 | Acc=0.7767 | F1w=0.7810 | F1m=0.7680 | AUROC=0.9361 | PRAUC=0.8577
#     F3 → Loss=1.0549 | Acc=0.7738 | F1w=0.7772 | F1m=0.7473 | AUROC=0.9417 | PRAUC=0.8658
#     F4 → Loss=1.0622 | Acc=0.7637 | F1w=0.7677 | F1m=0.7576 | AUROC=0.9354 | PRAUC=0.8562
#     F5 → Loss=1.0736 | Acc=0.7472 | F1w=0.7534 | F1m=0.7328 | AUROC=0.9297 | PRAUC=0.8460
#   ✅  Loss:1.0601±0.0076 | Acc:0.7675±0.0112 | F1w:0.7719±0.0104 | F1macro:0.7534±0.0123 | AUROC:0.9367±0.0043 | PRAUC:0.8580±0.0070 | MCC:0.6879
#       ↳ LossGap:+0.0106 (tr 1.0495) | F1macroGap:+0.0102 (tr 0.7636) | Penalty:0.0000 | Selection(loss):1.0601
#
#   ▶ [64/64] n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=5 | reg_lambda=5 | rate_drop=0.2
#     F1 → Loss=1.2062 | Acc=0.7493 | F1w=0.7530 | F1m=0.7417 | AUROC=0.9330 | PRAUC=0.8497
#     F2 → Loss=1.2096 | Acc=0.7522 | F1w=0.7583 | F1m=0.7428 | AUROC=0.9305 | PRAUC=0.8458
#     F3 → Loss=1.2155 | Acc=0.7320 | F1w=0.7403 | F1m=0.6983 | AUROC=0.9325 | PRAUC=0.8497
#     F4 → Loss=1.2120 | Acc=0.7411 | F1w=0.7443 | F1m=0.7271 | AUROC=0.9295 | PRAUC=0.8463
#     F5 → Loss=1.2204 | Acc=0.7323 | F1w=0.7392 | F1m=0.7189 | AUROC=0.9227 | PRAUC=0.8325
#   ✅  Loss:1.2127±0.0049 | Acc:0.7414±0.0084 | F1w:0.7470±0.0074 | F1macro:0.7258±0.0164 | AUROC:0.9296±0.0037 | PRAUC:0.8448±0.0064 | MCC:0.6569
#       ↳ LossGap:+0.0075 (tr 1.2052) | F1macroGap:+0.0132 (tr 0.7390) | Penalty:0.0000 | Selection(loss):1.2127
#
# 🏆 Best config : n_estimators=150 | learning_rate=0.1 | max_depth=4 | min_child_weight=1 | reg_lambda=1 | rate_drop=0.1  (min penalized log-loss)
#    Log-loss    : 1.0504±0.0047 (Acc=0.7718±0.0086 | F1w=0.7759±0.0079 | F1macro=0.7606±0.0110 | AUROC=0.9387±0.0036 | PRAUC=0.8616±0.0057)
#    Selection   : 1.0504 (LossGap=+0.0109 | F1macroGap=+0.0121)

# %%
import pandas as pd
df = pd.DataFrame(results)
filename = CSV_DIR / "xgb_dart_hpo.csv"
df.to_csv(filename, index=False)
log(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\csv\classical\xgb_dart_hpo.csv

# %%
# 📈 Best-param fit diagnostic (overfit / underfit / generalized)
fit_info = plot_fit_diagnostic(
    build_estimator, best_result['params'],
    name="xgb_dart", title="XGBoost Dart", normalize_proba=NORMALIZE_PROBA,
    fit_kwargs_fn=fit_kwargs_fn,
)
# Out:
# 📈 Fit diagnostic [XGBoost Dart] → Underfit (train acc=0.7816 | val acc=0.7718 | gap=+0.0098)
# 🖼️  Figure: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\figures\classical\xgb_dart_fit.png

# %%
best_result['model'] = "XGBoost Dart"
save_best("xgb_dart", "XGBoost Dart", best_result, extra={'variant': 'xgboost', **fit_info})
log(f"✅ [XGBoost Dart] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# 💾 Best saved: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\best\xgb_dart.json
# ✅ [XGBoost Dart] recorded | Exec. time: 34.9s
