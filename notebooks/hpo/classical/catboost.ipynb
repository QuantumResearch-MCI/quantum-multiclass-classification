# %% [markdown]
# # CatBoost — Hyperparameter Optimization

# %%
# !python -m pip install numpy pandas \
#     qiskit-aer qiskit-algorithms qiskit-machine-learning qiskit-ibm-runtime \
#     pylatexenc ucimlrepo \
#     xgboost catboost seaborn libsvm-official \
#     jinja2 scikit-optimize tensorflow imbalanced-learn

# %%
import sys
import os

cwd = os.path.abspath(os.getcwd())
project_root = cwd.split("quantum-multiclass-classification")[0] + "quantum-multiclass-classification"
print(f"Project root: {project_root}")

sys.path.append(os.path.abspath(project_root))

from utils.prepare_data import prepare_data
# Out:
# Project root: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

import sys
import importlib

def reload_package(package_name):
    modules_to_reload = [name for name in sys.modules if name.startswith(package_name)]
    for name in sorted(modules_to_reload, reverse=True):
        importlib.reload(sys.modules[name])

reload_package("model")
reload_package("utils")

# %%
dataset_path = os.path.join(project_root, "dataset", "Dataset_TehHijau.csv")
feature_cols = [
        "MQ3", "TGS822", "TGS2602", "MQ5", "MQ138", "TGS2620",
        "TGS813", "TGS2600", "TGS2611", "TGS2603", "Humidity", "Celsius",
    ]
target_cols = "Kategori"

import pandas as pd
data = pd.read_csv(dataset_path)
data.head(10)
# Out:
#     MQ3  TGS822  TGS2602    MQ5  MQ138  TGS2620  TGS813  TGS2600  TGS2611  \
# 0  90.0    43.0     46.0  133.0   97.0     46.0   552.0    289.0    546.0
# 1  90.0    42.0     47.0  133.0   96.0     47.0   551.0    290.0    547.0
# 2  89.0    42.0     47.0  133.0   97.0     45.0   553.0    291.0    547.0
# 3  89.0    41.0     47.0  133.0   96.0     45.0   552.0    290.0    546.0
# 4  90.0    42.0     48.0  132.0   95.0     46.0   552.0    289.0    546.0
# 5  90.0    42.0     46.0  132.0   96.0     45.0   552.0    289.0    545.0
# 6  89.0    43.0     46.0  133.0   96.0     45.0   552.0    291.0    546.0
# 7  90.0    42.0     46.0  132.0   96.0     46.0   551.0    290.0    547.0
# 8  90.0    41.0     47.0  132.0   97.0     46.0   550.0    290.0    548.0
# 9  90.0    41.0     48.0  132.0   95.0     46.0   551.0    289.0    547.0
#
#    TGS2603  Humidity  Celsius Chop_ID Sampling_ID  Aroma  Taste  Color  \
# 0    371.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 1    371.0      46.5     38.9   TR612     TR612_1    2.9     36    3.2
# 2    369.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 3    370.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 4    371.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 5    370.0      46.5     38.8   TR612     TR612_1    2.9     36    3.2
# 6    369.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 7    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 8    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 9    371.0      46.3     38.7   TR612     TR612_1    2.9     36    3.2
#
#    Appearance  Dreg Kategori Standar Kualitas  MQ3_mean  MQ3_min  MQ3_max  \
# 0         2.8   3.2        D             Baik      89.7     89.0       90
# 1         2.8   3.2        D             Baik      89.7     89.0       90
# 2         2.8   3.2        D             Baik      89.7     89.0       90
# 3         2.8   3.2        D             Baik      89.7     89.0       90
# 4         2.8   3.2        D             Baik      89.7     89.0       90
# 5         2.8   3.2        D             Baik      89.7     89.0       90
# 6         2.8   3.2        D             Baik      89.7     89.0       90
# 7         2.8   3.2        D             Baik      89.7     89.0       90
# 8         2.8   3.2        D             Baik      89.7     89.0       90
# 9         2.8   3.2        D             Baik      89.7     89.0       90
#
#     MQ3_std  MQ3_skew  MQ3_kurtosis  MQ3_auc  TGS822_mean  TGS822_min  \
# 0  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 1  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 2  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 3  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 4  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 5  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 6  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 7  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 8  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 9  0.483046 -0.872872     -1.238095    807.0         41.9          41
#
#    TGS822_max  TGS822_std  TGS822_skew  TGS822_kurtosis  TGS822_auc  \
# 0          43    0.737865     0.139942        -0.960433       377.0
# 1          43    0.737865     0.139942        -0.960433       377.0
# 2          43    0.737865     0.139942        -0.960433       377.0
# 3          43    0.737865     0.139942        -0.960433       377.0
# 4          43    0.737865     0.139942        -0.960433       377.0
# 5          43    0.737865     0.139942        -0.960433       377.0
# 6          43    0.737865     0.139942        -0.960433       377.0
# 7          43    0.737865     0.139942        -0.960433       377.0
# 8          43    0.737865     0.139942        -0.960433       377.0
# 9          43    0.737865     0.139942        -0.960433       377.0
#
#    TGS2602_mean  TGS2602_min  TGS2602_max  TGS2602_std  TGS2602_skew  \
# 0          46.8           46           48     0.788811      0.343622
# 1          46.8           46           48     0.788811      0.343622
# 2          46.8           46           48     0.788811      0.343622
# 3          46.8           46           48     0.788811      0.343622
# 4          46.8           46           48     0.788811      0.343622
# 5          46.8           46           48     0.788811      0.343622
# 6          46.8           46           48     0.788811      0.343622
# 7          46.8           46           48     0.788811      0.343622
# 8          46.8           46           48     0.788811      0.343622
# 9          46.8           46           48     0.788811      0.343622
#
#    TGS2602_kurtosis  TGS2602_auc  MQ5_mean  MQ5_min  MQ5_max   MQ5_std  \
# 0         -1.153061        421.0     132.5      132    133.0  0.527046
# 1         -1.153061        421.0     132.5      132    133.0  0.527046
# 2         -1.153061        421.0     132.5      132    133.0  0.527046
# 3         -1.153061        421.0     132.5      132    133.0  0.527046
# 4         -1.153061        421.0     132.5      132    133.0  0.527046
# 5         -1.153061        421.0     132.5      132    133.0  0.527046
# 6         -1.153061        421.0     132.5      132    133.0  0.527046
# 7         -1.153061        421.0     132.5      132    133.0  0.527046
# 8         -1.153061        421.0     132.5      132    133.0  0.527046
# 9         -1.153061        421.0     132.5      132    133.0  0.527046
#
#    MQ5_skew  MQ5_kurtosis  MQ5_auc  MQ138_mean  MQ138_min  MQ138_max  \
# 0       0.0          -2.0   1192.5        96.1         95         97
# 1       0.0          -2.0   1192.5        96.1         95         97
# 2       0.0          -2.0   1192.5        96.1         95         97
# 3       0.0          -2.0   1192.5        96.1         95         97
# 4       0.0          -2.0   1192.5        96.1         95         97
# 5       0.0          -2.0   1192.5        96.1         95         97
# 6       0.0          -2.0   1192.5        96.1         95         97
# 7       0.0          -2.0   1192.5        96.1         95         97
# 8       0.0          -2.0   1192.5        96.1         95         97
# 9       0.0          -2.0   1192.5        96.1         95         97
#
#    MQ138_std  MQ138_skew  MQ138_kurtosis  MQ138_auc  TGS2620_mean  \
# 0   0.737865   -0.139942       -0.960433      865.0          45.7
# 1   0.737865   -0.139942       -0.960433      865.0          45.7
# 2   0.737865   -0.139942       -0.960433      865.0          45.7
# 3   0.737865   -0.139942       -0.960433      865.0          45.7
# 4   0.737865   -0.139942       -0.960433      865.0          45.7
# 5   0.737865   -0.139942       -0.960433      865.0          45.7
# 6   0.737865   -0.139942       -0.960433      865.0          45.7
# 7   0.737865   -0.139942       -0.960433      865.0          45.7
# 8   0.737865   -0.139942       -0.960433      865.0          45.7
# 9   0.737865   -0.139942       -0.960433      865.0          45.7
#
#    TGS2620_min  TGS2620_max  TGS2620_std  TGS2620_skew  TGS2620_kurtosis  \
# 0           45           47     0.674949      0.365675         -0.705532
# 1           45           47     0.674949      0.365675         -0.705532
# 2           45           47     0.674949      0.365675         -0.705532
# 3           45           47     0.674949      0.365675         -0.705532
# 4           45           47     0.674949      0.365675         -0.705532
# 5           45           47     0.674949      0.365675         -0.705532
# 6           45           47     0.674949      0.365675         -0.705532
# 7           45           47     0.674949      0.365675         -0.705532
# 8           45           47     0.674949      0.365675         -0.705532
# 9           45           47     0.674949      0.365675         -0.705532
#
#    TGS2620_auc  TGS813_mean  TGS813_min  TGS813_max  TGS813_std  TGS813_skew  \
# 0        411.0        551.6         550         553    0.843274    -0.328125
# 1        411.0        551.6         550         553    0.843274    -0.328125
# 2        411.0        551.6         550         553    0.843274    -0.328125
# 3        411.0        551.6         550         553    0.843274    -0.328125
# 4        411.0        551.6         550         553    0.843274    -0.328125
# 5        411.0        551.6         550         553    0.843274    -0.328125
# 6        411.0        551.6         550         553    0.843274    -0.328125
# 7        411.0        551.6         550         553    0.843274    -0.328125
# 8        411.0        551.6         550         553    0.843274    -0.328125
# 9        411.0        551.6         550         553    0.843274    -0.328125
#
#    TGS813_kurtosis  TGS813_auc  TGS2600_mean  TGS2600_min  TGS2600_max  \
# 0        -0.335937      4964.5         289.8        289.0          291
# 1        -0.335937      4964.5         289.8        289.0          291
# 2        -0.335937      4964.5         289.8        289.0          291
# 3        -0.335937      4964.5         289.8        289.0          291
# 4        -0.335937      4964.5         289.8        289.0          291
# 5        -0.335937      4964.5         289.8        289.0          291
# 6        -0.335937      4964.5         289.8        289.0          291
# 7        -0.335937      4964.5         289.8        289.0          291
# 8        -0.335937      4964.5         289.8        289.0          291
# 9        -0.335937      4964.5         289.8        289.0          291
#
#    TGS2600_std  TGS2600_skew  TGS2600_kurtosis  TGS2600_auc  TGS2611_mean  \
# 0     0.788811      0.343622         -1.153061       2609.0         546.5
# 1     0.788811      0.343622         -1.153061       2609.0         546.5
# 2     0.788811      0.343622         -1.153061       2609.0         546.5
# 3     0.788811      0.343622         -1.153061       2609.0         546.5
# 4     0.788811      0.343622         -1.153061       2609.0         546.5
# 5     0.788811      0.343622         -1.153061       2609.0         546.5
# 6     0.788811      0.343622         -1.153061       2609.0         546.5
# 7     0.788811      0.343622         -1.153061       2609.0         546.5
# 8     0.788811      0.343622         -1.153061       2609.0         546.5
# 9     0.788811      0.343622         -1.153061       2609.0         546.5
#
#    TGS2611_min  TGS2611_max  TGS2611_std  TGS2611_skew  TGS2611_kurtosis  \
# 0          545          548     0.849837           0.0         -0.485207
# 1          545          548     0.849837           0.0         -0.485207
# 2          545          548     0.849837           0.0         -0.485207
# 3          545          548     0.849837           0.0         -0.485207
# 4          545          548     0.849837           0.0         -0.485207
# 5          545          548     0.849837           0.0         -0.485207
# 6          545          548     0.849837           0.0         -0.485207
# 7          545          548     0.849837           0.0         -0.485207
# 8          545          548     0.849837           0.0         -0.485207
# 9          545          548     0.849837           0.0         -0.485207
#
#    TGS2611_auc  TGS2603_mean  TGS2603_min  TGS2603_max  TGS2603_std  \
# 0       4918.5         370.2          369          371     0.788811
# 1       4918.5         370.2          369          371     0.788811
# 2       4918.5         370.2          369          371     0.788811
# 3       4918.5         370.2          369          371     0.788811
# 4       4918.5         370.2          369          371     0.788811
# 5       4918.5         370.2          369          371     0.788811
# 6       4918.5         370.2          369          371     0.788811
# 7       4918.5         370.2          369          371     0.788811
# 8       4918.5         370.2          369          371     0.788811
# 9       4918.5         370.2          369          371     0.788811
#
#    TGS2603_skew  TGS2603_kurtosis  TGS2603_auc  Humidity_mean  Humidity_min  \
# 0     -0.343622         -1.153061       3331.0          46.43          46.3
# 1     -0.343622         -1.153061       3331.0          46.43          46.3
# 2     -0.343622         -1.153061       3331.0          46.43          46.3
# 3     -0.343622         -1.153061       3331.0          46.43          46.3
# 4     -0.343622         -1.153061       3331.0          46.43          46.3
# 5     -0.343622         -1.153061       3331.0          46.43          46.3
# 6     -0.343622         -1.153061       3331.0          46.43          46.3
# 7     -0.343622         -1.153061       3331.0          46.43          46.3
# 8     -0.343622         -1.153061       3331.0          46.43          46.3
# 9     -0.343622         -1.153061       3331.0          46.43          46.3
#
#    Humidity_max  Humidity_std  Humidity_skew  Humidity_kurtosis  Humidity_auc  \
# 0          46.5      0.067495      -0.365675          -0.705532        417.95
# 1          46.5      0.067495      -0.365675          -0.705532        417.95
# 2          46.5      0.067495      -0.365675          -0.705532        417.95
# 3          46.5      0.067495      -0.365675          -0.705532        417.95
# 4          46.5      0.067495      -0.365675          -0.705532        417.95
# 5          46.5      0.067495      -0.365675          -0.705532        417.95
# 6          46.5      0.067495      -0.365675          -0.705532        417.95
# 7          46.5      0.067495      -0.365675          -0.705532        417.95
# 8          46.5      0.067495      -0.365675          -0.705532        417.95
# 9          46.5      0.067495      -0.365675          -0.705532        417.95
#
#    Celsius_mean  Celsius_min  Celsius_max  Celsius_std  Celsius_skew  \
# 0         38.81         38.7         38.9      0.08756      -0.18843
# 1         38.81         38.7         38.9      0.08756      -0.18843
# 2         38.81         38.7         38.9      0.08756      -0.18843
# 3         38.81         38.7         38.9      0.08756      -0.18843
# 4         38.81         38.7         38.9      0.08756      -0.18843
# 5         38.81         38.7         38.9      0.08756      -0.18843
# 6         38.81         38.7         38.9      0.08756      -0.18843
# 7         38.81         38.7         38.9      0.08756      -0.18843
# 8         38.81         38.7         38.9      0.08756      -0.18843
# 9         38.81         38.7         38.9      0.08756      -0.18843
#
#    Celsius_kurtosis  Celsius_auc  Aroma_mean  Aroma_min  Aroma_max  \
# 0          -1.52615        349.3         2.9        2.9        2.9
# 1          -1.52615        349.3         2.9        2.9        2.9
# 2          -1.52615        349.3         2.9        2.9        2.9
# 3          -1.52615        349.3         2.9        2.9        2.9
# 4          -1.52615        349.3         2.9        2.9        2.9
# 5          -1.52615        349.3         2.9        2.9        2.9
# 6          -1.52615        349.3         2.9        2.9        2.9
# 7          -1.52615        349.3         2.9        2.9        2.9
# 8          -1.52615        349.3         2.9        2.9        2.9
# 9          -1.52615        349.3         2.9        2.9        2.9
#
#       Aroma_std  Aroma_auc  Taste_mean  Taste_min  Taste_max  Taste_std  \
# 0  4.681111e-16       26.1          36         36         36          0
# 1  4.681111e-16       26.1          36         36         36          0
# 2  4.681111e-16       26.1          36         36         36          0
# 3  4.681111e-16       26.1          36         36         36          0
# 4  4.681111e-16       26.1          36         36         36          0
# 5  4.681111e-16       26.1          36         36         36          0
# 6  4.681111e-16       26.1          36         36         36          0
# 7  4.681111e-16       26.1          36         36         36          0
# 8  4.681111e-16       26.1          36         36         36          0
# 9  4.681111e-16       26.1          36         36         36          0
#
#    Taste_auc  Color_mean  Color_min  Color_max     Color_std  Color_auc  \
# 0        324         3.2        3.2        3.2  4.681111e-16       28.8
# 1        324         3.2        3.2        3.2  4.681111e-16       28.8
# 2        324         3.2        3.2        3.2  4.681111e-16       28.8
# 3        324         3.2        3.2        3.2  4.681111e-16       28.8
# 4        324         3.2        3.2        3.2  4.681111e-16       28.8
# 5        324         3.2        3.2        3.2  4.681111e-16       28.8
# 6        324         3.2        3.2        3.2  4.681111e-16       28.8
# 7        324         3.2        3.2        3.2  4.681111e-16       28.8
# 8        324         3.2        3.2        3.2  4.681111e-16       28.8
# 9        324         3.2        3.2        3.2  4.681111e-16       28.8
#
#    Appearance_mean  Appearance_min  Appearance_max  Appearance_std  \
# 0              2.8             2.8             2.8    4.681111e-16
# 1              2.8             2.8             2.8    4.681111e-16
# 2              2.8             2.8             2.8    4.681111e-16
# 3              2.8             2.8             2.8    4.681111e-16
# 4              2.8             2.8             2.8    4.681111e-16
# 5              2.8             2.8             2.8    4.681111e-16
# 6              2.8             2.8             2.8    4.681111e-16
# 7              2.8             2.8             2.8    4.681111e-16
# 8              2.8             2.8             2.8    4.681111e-16
# 9              2.8             2.8             2.8    4.681111e-16
#
#    Appearance_auc  Dreg_mean  Dreg_min  Dreg_max      Dreg_std  Dreg_auc
# 0            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 1            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 2            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 3            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 4            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 5            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 6            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 7            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 8            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 9            25.2        3.2       3.2       3.2  4.681111e-16      28.8

# %%
X = data[feature_cols]
y = data[target_cols]
print(X.shape, y.shape)

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# Groups for StratifiedKFold — prevents leakage across folds.
# Many rows share the same Sampling_ID; they must stay within the same fold.
# (Sampling_ID, not Chop_ID: class B has only 2 Chop_ID -> can't make 5 folds.)
groups = data["Sampling_ID"].values
print("n groups:", len(set(groups)))
# Out:
# (10409, 12) (10409,)
# n groups: 274

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt

def plot_pca_variance(X, n_components, threshold=0.95):
    pca = PCA(n_components=n_components)
    pca.fit(X)
    cumvar = np.cumsum(pca.explained_variance_ratio_)
    n_optimal = np.argmax(cumvar >= threshold) + 1

    plt.figure(figsize=(8, 5))
    plt.plot(range(1, n_components + 1), cumvar, marker='o', color='blue')
    plt.axhline(y=threshold, color='gray', linestyle='--', linewidth=1)
    plt.xlabel('Number of Principal Components')
    plt.ylabel('Cumulative Explained Variance')
    plt.xticks(range(1, n_components + 1))
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    print(f'Optimal number of components to retain {threshold*100:.0f}% variance: {n_optimal}')
    return n_optimal

n_optimal = plot_pca_variance(X, n_components=X.shape[1], threshold=0.92)
# Out:
# Optimal number of components to retain 92% variance: 3

# %%
import time, json, pickle
import numpy as np
from pathlib import Path
from datetime import datetime

CATEGORY = "classical"
# Bump when the HPO logic changes in a way that invalidates old checkpoints.
# v2: dropped class_weight/sample_weight balancing + overfit-aware selection.
# v3: added SMOTEENN resampling inside the CV pipeline (train-fold only).
# v4: scoring switched to penalized validation log-loss (minimize), not composite.
# v5: overfit penalty now uses TWO signals — loss_gap + macro-F1 gap.
CKPT_VERSION = 5
HPO_RESULTS = Path(project_root) / "notebooks" / "hpo" / "results"
CSV_DIR  = HPO_RESULTS / "csv" / CATEGORY
LOG_DIR  = HPO_RESULTS / "logs" / CATEGORY
CKPT_DIR = HPO_RESULTS / "checkpoints" / CATEGORY
BEST_DIR = HPO_RESULTS / "best"
FIG_DIR  = HPO_RESULTS / "figures" / CATEGORY
for _d in (CSV_DIR, LOG_DIR, CKPT_DIR, BEST_DIR, FIG_DIR):
    _d.mkdir(parents=True, exist_ok=True)

_current_log_path = None

def setup_logger(name):
    """Call at the start of each section; name is the section slug."""
    global _current_log_path
    _current_log_path = LOG_DIR / f"{name}.log"
    _current_log_path.write_text("")          # fresh log every run
    log(f"📝 Log: {_current_log_path}")
    log(f"🕒 Started: {datetime.now().isoformat(timespec='seconds')}")

def log(msg=""):
    print(msg)
    if _current_log_path is not None:
        with open(_current_log_path, "a", encoding="utf-8") as f:
            f.write(str(msg) + "\n")

def _fresh_ckpt():
    # best_score = +inf because selection minimizes penalized log-loss.
    return {"version": CKPT_VERSION, "done_configs": {}, "results": [],
            "best_result": None, "best_score": np.inf}

def load_checkpoint(name):
    """Resume a section; returns an empty skeleton if no (compatible) checkpoint."""
    ckpt_path = CKPT_DIR / f"{name}.pkl"
    if ckpt_path.exists():
        with open(ckpt_path, "rb") as f:
            data = pickle.load(f)
        if data.get("version") != CKPT_VERSION:
            log(f"♻️  Ignoring stale checkpoint (v{data.get('version')} != v{CKPT_VERSION}); starting fresh: {ckpt_path}")
            return _fresh_ckpt(), ckpt_path
        log(f"♻️  Resumed checkpoint: {ckpt_path} ({len(data['done_configs'])} configs done)")
        return data, ckpt_path
    return _fresh_ckpt(), ckpt_path

def save_checkpoint(ckpt_path, data):
    """Atomic save (write .tmp then replace)."""
    data.setdefault("version", CKPT_VERSION)
    tmp = ckpt_path.with_suffix(".pkl.tmp")
    with open(tmp, "wb") as f:
        pickle.dump(data, f)
    tmp.replace(ckpt_path)

def save_best(name, model_label, best_result, extra=None):
    """Persist the section's best result so results.ipynb can aggregate it."""
    payload = {
        "name": name,
        "model": model_label,
        "category": CATEGORY,
        "tag": best_result.get("tag"),
        "loss": best_result.get("loss"),
        "selection_score": best_result.get("selection_score"),
        "train_loss_cv": best_result.get("train_loss_cv"),
        "train_f1macro_cv": best_result.get("train_f1macro_cv"),
        "loss_gap": best_result.get("loss_gap"),
        "f1_gap": best_result.get("f1_gap"),
        "acc": best_result.get("acc"),
        "prec": best_result.get("prec"),
        "rec": best_result.get("rec"),
        "f1": best_result.get("f1"),
        "f1_macro": best_result.get("f1_macro"),
        "roc": best_result.get("roc"),
        "pra": best_result.get("pra"),
        "execution_time": best_result.get("execution_time"),
        "params": best_result.get("params", {}),
    }
    if extra:
        payload.update(extra)
    with open(BEST_DIR / f"{name}.json", "w", encoding="utf-8") as f:
        json.dump(payload, f, ensure_ascii=False, indent=2, default=str)
    log(f"💾 Best saved: {BEST_DIR / (name + '.json')}")

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, log_loss

def plot_fit_diagnostic(build_estimator, params, name, title,
                        normalize_proba=False, fit_kwargs_fn=None,
                        overfit_gap=0.05, low_thresh=0.80):
    """Refit best params per fold, compare TRAIN vs VAL to flag over/underfit."""
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    _fkw = fit_kwargs_fn or (lambda y_tr: {})

    def _scores(model, Xs, ys):
        yp = model.predict(Xs)
        pr = model.predict_proba(Xs)
        if normalize_proba:
            pr = pr / pr.sum(axis=1, keepdims=True)
        a = accuracy_score(ys, yp)
        ll = log_loss(ys, pr, labels=np.unique(y))
        return a, ll

    tr_acc, va_acc, tr_loss, va_loss = [], [], [], []
    for tr, va in skf.split(X, y, groups):
        m = build_estimator(params)
        m.fit(X.iloc[tr], y[tr], **_fkw(y[tr]))
        a1, c1 = _scores(m, X.iloc[tr], y[tr])
        a2, c2 = _scores(m, X.iloc[va], y[va])
        tr_acc.append(a1); va_acc.append(a2); tr_loss.append(c1); va_loss.append(c2)

    tr_acc_m, va_acc_m = float(np.mean(tr_acc)), float(np.mean(va_acc))
    gap = tr_acc_m - va_acc_m
    # Overfit (train >> val) is checked first so a big gap is never masked as
    # "Underfit" just because both means sit below low_thresh.
    if gap > overfit_gap:
        verdict = "Overfit"
    elif va_acc_m < low_thresh:
        verdict = "Underfit"
    else:
        verdict = "Generalized"

    folds = np.arange(1, 6)
    w = 0.35
    fig, ax = plt.subplots(1, 2, figsize=(12, 4.5))
    ax[0].bar(folds - w/2, tr_acc, w, label='Train', color='#4C72B0')
    ax[0].bar(folds + w/2, va_acc, w, label='Validation', color='#DD8452')
    ax[0].axhline(tr_acc_m, color='#4C72B0', ls='--', lw=1)
    ax[0].axhline(va_acc_m, color='#DD8452', ls='--', lw=1)
    ax[0].set_title('Accuracy'); ax[0].set_xlabel('Fold'); ax[0].set_ylim(0, 1.05)
    ax[0].set_xticks(folds); ax[0].legend(); ax[0].grid(axis='y', alpha=0.3)

    ax[1].bar(folds - w/2, tr_loss, w, label='Train', color='#4C72B0')
    ax[1].bar(folds + w/2, va_loss, w, label='Validation', color='#DD8452')
    ax[1].set_title('Log-loss (lower = better)')
    ax[1].set_xlabel('Fold')
    ax[1].set_xticks(folds); ax[1].legend(); ax[1].grid(axis='y', alpha=0.3)

    fig.suptitle(f"{title} — best-param fit: {verdict}  "
                 f"(train acc={tr_acc_m:.3f}, val acc={va_acc_m:.3f}, gap={gap:+.3f})",
                 fontsize=12)
    fig.tight_layout()
    fig_path = FIG_DIR / f"{name}_fit.png"
    fig.savefig(fig_path, dpi=120, bbox_inches='tight')
    plt.show()

    log(f"📈 Fit diagnostic [{title}] → {verdict} "
        f"(train acc={tr_acc_m:.4f} | val acc={va_acc_m:.4f} | gap={gap:+.4f})")
    log(f"🖼️  Figure: {fig_path}")
    return {"fit_verdict": verdict, "train_acc": tr_acc_m,
            "val_acc": va_acc_m, "fit_gap": float(gap)}

# %% [markdown]
# ## CatBoost

# %%
# Search Space + estimator builder
import numpy as np

NORMALIZE_PROBA = True

search_space = {
  'iterations': [80, 150],
  'depth': [3, 4],
  'learning_rate': [0.05, 0.1],
  'l2_leaf_reg': [3, 7],
  'bagging_temperature': [0.5, 1],
  'random_strength': [1, 5],
}

from imblearn.pipeline import Pipeline
from imblearn.combine import SMOTEENN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from catboost import CatBoostClassifier

def build_estimator(params):
    return Pipeline([
        ('scaler', StandardScaler()),
        ('pca', PCA(n_components=n_optimal)),
        ('smoteenn', SMOTEENN(random_state=42)),  # train-fold only (no leak)
        ('cat', CatBoostClassifier(loss_function='MultiClassOneVsAll',
                                   eval_metric='Accuracy', verbose=0,
                                   bootstrap_type='Bayesian',
                                   random_seed=42, **params)),
    ])

fit_kwargs_fn = lambda y_tr: {}

# %%
setup_logger("catboost")
from sklearn.model_selection import StratifiedKFold
from itertools import product
import time
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score,
    average_precision_score, matthews_corrcoef,
    precision_score, recall_score, log_loss,
)

state = 42
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

classes = np.unique(y)

# Primary scoring = mean validation LOG-LOSS (lower is better). Overfit is checked
# with TWO signals, each penalized only beyond its own tolerance:
#   loss_gap = val_loss - train_loss        -> probability calibration
#   f1_gap   = train_macroF1 - val_macroF1  -> per-class balance (catches minority overfit)
#   penalty  = W_LOSS*max(0, loss_gap - TOL_LOSS) + W_F1*max(0, f1_gap - TOL_F1)
#   selection_score = val_loss + penalty    -> best config = the MINIMUM
# Train metrics are measured on the ORIGINAL (non-resampled) train fold.
TOL_LOSS = 0.05   # "free" train-val log-loss gap (no penalty below this)
TOL_F1   = 0.05   # "free" train-val macro-F1 gap
W_LOSS   = 1.0    # weight for the log-loss overfit signal
W_F1     = 1.0    # weight for the macro-F1 overfit signal

param_keys = list(search_space.keys())
param_vals = list(search_space.values())
search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = int(np.prod([len(v) for v in param_vals]))
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: mean validation log-loss (lower better); overfit penalty on loss_gap + macroF1_gap")
log(f"   Overfit guard: +{W_LOSS}×max(0, loss_gap - {TOL_LOSS}) +{W_F1}×max(0, f1_gap - {TOL_F1})")

ckpt, ckpt_path = load_checkpoint("catboost")
done_configs = ckpt["done_configs"]
results      = ckpt["results"]
best_result  = ckpt["best_result"]
best_score   = ckpt["best_score"]

for i, comb in enumerate(product(*param_vals)):
    params = dict(zip(param_keys, comb))
    tag = " | ".join(f"{k}={v}" for k, v in params.items())

    if tag in done_configs:
        log(f"\n  ⏭️  [{i+1}/{total_configs}] {tag}  (skipped, already done)")
        continue

    log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
    _iter_t0 = time.perf_counter()

    accs, f1s, f1ms, rocs, pras, precs, recs, lls = [], [], [], [], [], [], [], []
    tr_lls, tr_f1ms = [], []
    y_val_all, y_pred_all = [], []
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, y, groups), 1):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y[train_idx], y[val_idx]

        model = build_estimator(params)
        model.fit(X_train, y_train, **fit_kwargs_fn(y_train))

        y_pred = model.predict(X_val)
        y_prob = model.predict_proba(X_val)
        if NORMALIZE_PROBA:
            y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)

        # Train log-loss + macro-F1 (original train fold) for the overfit checks
        tr_prob = model.predict_proba(X_train)
        if NORMALIZE_PROBA:
            tr_prob = tr_prob / tr_prob.sum(axis=1, keepdims=True)
        tr_lls.append(log_loss(y_train, tr_prob, labels=classes))
        # use model.predict (not argmax of proba) so train f1 matches how val f1 is computed
        tr_f1ms.append(f1_score(y_train, model.predict(X_train), average='macro'))

        y_val_all.extend(y_val)
        y_pred_all.extend(y_pred)

        acc  = accuracy_score(y_val, y_pred)
        f1   = f1_score(y_val, y_pred, average='weighted')
        f1m  = f1_score(y_val, y_pred, average='macro')
        roc  = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
        pra  = average_precision_score(y_val, y_prob, average='weighted')
        prec = precision_score(y_val, y_pred, average='weighted')
        rec  = recall_score(y_val, y_pred, average='weighted')
        ll   = log_loss(y_val, y_prob, labels=classes)

        accs.append(acc); f1s.append(f1); f1ms.append(f1m); rocs.append(roc)
        pras.append(pra); precs.append(prec); recs.append(rec); lls.append(ll)

        log(f"    F{fold} → Loss={ll:.4f} | Acc={acc:.4f} | F1w={f1:.4f} | F1m={f1m:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

        results.append({
            "tag": tag, **params, "fold": fold,
            "accuracy": acc, "precision": prec, "recall": rec,
            "F1": f1, "f1_macro": f1m, "auroc": roc, "prauc": pra,
            "loss": ll, "train_loss": tr_lls[-1],
        })

    acc_mean,  acc_std  = np.mean(accs),  np.std(accs)
    prec_mean, prec_std = np.mean(precs), np.std(precs)
    rec_mean,  rec_std  = np.mean(recs),  np.std(recs)
    f1_mean,   f1_std   = np.mean(f1s),   np.std(f1s)
    f1m_mean,  f1m_std  = np.mean(f1ms),  np.std(f1ms)
    roc_mean,  roc_std  = np.mean(rocs),  np.std(rocs)
    pra_mean,  pra_std  = np.mean(pras),  np.std(pras)
    loss_mean, loss_std = np.mean(lls),   np.std(lls)
    mcc = matthews_corrcoef(y_val_all, y_pred_all)

    # Overfit-aware selection: MINIMIZE val log-loss, penalize TWO overfit signals:
    #   loss_gap = val_loss - train_loss ; f1_gap = train_macroF1 - val_macroF1
    tr_loss_mean = float(np.mean(tr_lls))
    tr_f1m_mean  = float(np.mean(tr_f1ms))
    loss_gap = loss_mean - tr_loss_mean
    f1_gap   = tr_f1m_mean - f1m_mean
    penalty  = W_LOSS * max(0.0, loss_gap - TOL_LOSS) + W_F1 * max(0.0, f1_gap - TOL_F1)
    selection_score = loss_mean + penalty
    overfit_flag = " ⚠️ OVERFIT" if (loss_gap > TOL_LOSS or f1_gap > TOL_F1) else ""

    log(
        f"  ✅  Loss:{loss_mean:.4f}±{loss_std:.4f} | "
        f"Acc:{acc_mean:.4f}±{acc_std:.4f} | "
        f"F1w:{f1_mean:.4f}±{f1_std:.4f} | "
        f"F1macro:{f1m_mean:.4f}±{f1m_std:.4f} | "
        f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
        f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
        f"MCC:{mcc:.4f}"
    )
    log(
        f"      ↳ LossGap:{loss_gap:+.4f} (tr {tr_loss_mean:.4f}) | "
        f"F1macroGap:{f1_gap:+.4f} (tr {tr_f1m_mean:.4f}) | "
        f"Penalty:{penalty:.4f} | Selection(loss):{selection_score:.4f}{overfit_flag}"
    )

    iter_time = time.perf_counter() - _iter_t0
    if best_score is None or selection_score < best_score:
        best_score = selection_score
        best_result = {
            'tag': tag,
            'loss': f"{loss_mean:.4f}±{loss_std:.4f}",
            'selection_score': selection_score,
            'train_loss_cv': f"{tr_loss_mean:.4f}",
            'train_f1macro_cv': f"{tr_f1m_mean:.4f}",
            'loss_gap': f"{loss_gap:+.4f}",
            'f1_gap': f"{f1_gap:+.4f}",
            'acc':  f"{acc_mean:.4f}±{acc_std:.4f}",
            'f1':   f"{f1_mean:.4f}±{f1_std:.4f}",
            'f1_macro': f"{f1m_mean:.4f}±{f1m_std:.4f}",
            'roc':  f"{roc_mean:.4f}±{roc_std:.4f}",
            'pra':  f"{pra_mean:.4f}±{pra_std:.4f}",
            'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
            'rec':  f"{rec_mean:.4f}±{rec_std:.4f}",
            'params': params, 'execution_time': iter_time,
        }

    done_configs[tag] = {"loss": loss_mean, "selection_score": selection_score,
                         "loss_gap": loss_gap, "f1_gap": f1_gap, "params": params}
    save_checkpoint(ckpt_path, {
        "version": CKPT_VERSION,
        "done_configs": done_configs, "results": results,
        "best_result": best_result, "best_score": best_score,
    })

log(f"\n🏆 Best config : {best_result['tag']}  (min penalized log-loss)")
log(
    f"   Log-loss    : {best_result['loss']} "
    f"(Acc={best_result['acc']} | F1w={best_result['f1']} | F1macro={best_result['f1_macro']} | "
    f"AUROC={best_result['roc']} | PRAUC={best_result['pra']})"
)
log(
    f"   Selection   : {best_result['selection_score']:.4f} "
    f"(LossGap={best_result['loss_gap']} | F1macroGap={best_result['f1_gap']})"
)
# Out:
# 📝 Log: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\logs\classical\catboost.log
# 🕒 Started: 2026-06-08T11:26:42
# 🔬 Search space: 2 iterations × 2 depth × 2 learning_rate × 2 l2_leaf_reg × 2 bagging_temperature × 2 random_strength =  64 configs × 5 folds = 320 fits
#    Scoring criterion: mean validation log-loss (lower better); overfit penalty on loss_gap + macroF1_gap
#    Overfit guard: +1.0×max(0, loss_gap - 0.05) +1.0×max(0, f1_gap - 0.05)
#
#   ▶ [1/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.9444 | Acc=0.7109 | F1w=0.7142 | F1m=0.6964 | AUROC=0.9110 | PRAUC=0.8206
#     F2 → Loss=0.9466 | Acc=0.7219 | F1w=0.7276 | F1m=0.6996 | AUROC=0.9176 | PRAUC=0.8257
#     F3 → Loss=0.9391 | Acc=0.7229 | F1w=0.7283 | F1m=0.7008 | AUROC=0.9201 | PRAUC=0.8270
#     F4 → Loss=0.9381 | Acc=0.7137 | F1w=0.7178 | F1m=0.7142 | AUROC=0.9185 | PRAUC=0.8240
#     F5 → Loss=0.9541 | Acc=0.6915 | F1w=0.6932 | F1m=0.6948 | AUROC=0.9109 | PRAUC=0.8173
#   ✅  Loss:0.9444±0.0058 | Acc:0.7122±0.0113 | F1w:0.7162±0.0128 | F1macro:0.7012±0.0069 | AUROC:0.9156±0.0039 | PRAUC:0.8229±0.0035 | MCC:0.6216
#       ↳ LossGap:+0.0056 (tr 0.9388) | F1macroGap:+0.0042 (tr 0.7054) | Penalty:0.0000 | Selection(loss):0.9444
#
#   ▶ [2/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=1.0077 | Acc=0.6691 | F1w=0.6688 | F1m=0.6466 | AUROC=0.8987 | PRAUC=0.7917
#     F2 → Loss=1.0032 | Acc=0.6979 | F1w=0.7008 | F1m=0.6812 | AUROC=0.9054 | PRAUC=0.8023
#     F3 → Loss=1.0009 | Acc=0.6792 | F1w=0.6803 | F1m=0.6511 | AUROC=0.9101 | PRAUC=0.8035
#     F4 → Loss=0.9931 | Acc=0.6926 | F1w=0.6961 | F1m=0.6906 | AUROC=0.9131 | PRAUC=0.8107
#     F5 → Loss=1.0103 | Acc=0.6617 | F1w=0.6654 | F1m=0.6471 | AUROC=0.9034 | PRAUC=0.8014
#   ✅  Loss:1.0030±0.0059 | Acc:0.6801±0.0137 | F1w:0.6823±0.0142 | F1macro:0.6633±0.0188 | AUROC:0.9061±0.0051 | PRAUC:0.8019±0.0061 | MCC:0.5797
#       ↳ LossGap:+0.0042 (tr 0.9988) | F1macroGap:+0.0039 (tr 0.6672) | Penalty:0.0000 | Selection(loss):1.0030
#
#   ▶ [3/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.9472 | Acc=0.7056 | F1w=0.7083 | F1m=0.6878 | AUROC=0.9091 | PRAUC=0.8188
#     F2 → Loss=0.9427 | Acc=0.7277 | F1w=0.7321 | F1m=0.7100 | AUROC=0.9194 | PRAUC=0.8311
#     F3 → Loss=0.9445 | Acc=0.7209 | F1w=0.7259 | F1m=0.6954 | AUROC=0.9141 | PRAUC=0.8180
#     F4 → Loss=0.9366 | Acc=0.7147 | F1w=0.7183 | F1m=0.7014 | AUROC=0.9200 | PRAUC=0.8302
#     F5 → Loss=0.9594 | Acc=0.6896 | F1w=0.6927 | F1m=0.6878 | AUROC=0.9090 | PRAUC=0.8158
#   ✅  Loss:0.9461±0.0075 | Acc:0.7117±0.0132 | F1w:0.7155±0.0139 | F1macro:0.6965±0.0084 | AUROC:0.9143±0.0048 | PRAUC:0.8228±0.0065 | MCC:0.6184
#       ↳ LossGap:+0.0047 (tr 0.9414) | F1macroGap:+0.0043 (tr 0.7007) | Penalty:0.0000 | Selection(loss):0.9461
#
#   ▶ [4/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.9989 | Acc=0.6801 | F1w=0.6815 | F1m=0.6617 | AUROC=0.9008 | PRAUC=0.7990
#     F2 → Loss=0.9989 | Acc=0.7051 | F1w=0.7098 | F1m=0.6923 | AUROC=0.9087 | PRAUC=0.8072
#     F3 → Loss=0.9951 | Acc=0.6921 | F1w=0.6921 | F1m=0.6724 | AUROC=0.9121 | PRAUC=0.8095
#     F4 → Loss=0.9896 | Acc=0.6936 | F1w=0.6966 | F1m=0.6868 | AUROC=0.9108 | PRAUC=0.8051
#     F5 → Loss=1.0081 | Acc=0.6742 | F1w=0.6764 | F1m=0.6642 | AUROC=0.9016 | PRAUC=0.7967
#   ✅  Loss:0.9981±0.0060 | Acc:0.6890±0.0108 | F1w:0.6913±0.0118 | F1macro:0.6755±0.0121 | AUROC:0.9068±0.0047 | PRAUC:0.8035±0.0049 | MCC:0.5913
#       ↳ LossGap:+0.0041 (tr 0.9940) | F1macroGap:+0.0029 (tr 0.6784) | Penalty:0.0000 | Selection(loss):0.9981
#
#   ▶ [5/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.9562 | Acc=0.6984 | F1w=0.7026 | F1m=0.6824 | AUROC=0.9088 | PRAUC=0.8165
#     F2 → Loss=0.9608 | Acc=0.7137 | F1w=0.7202 | F1m=0.6908 | AUROC=0.9144 | PRAUC=0.8205
#     F3 → Loss=0.9553 | Acc=0.7065 | F1w=0.7113 | F1m=0.6854 | AUROC=0.9109 | PRAUC=0.8127
#     F4 → Loss=0.9483 | Acc=0.7109 | F1w=0.7140 | F1m=0.7083 | AUROC=0.9162 | PRAUC=0.8246
#     F5 → Loss=0.9693 | Acc=0.6852 | F1w=0.6890 | F1m=0.6864 | AUROC=0.9068 | PRAUC=0.8103
#   ✅  Loss:0.9580±0.0070 | Acc:0.7029±0.0103 | F1w:0.7074±0.0108 | F1macro:0.6907±0.0092 | AUROC:0.9114±0.0035 | PRAUC:0.8169±0.0051 | MCC:0.6098
#       ↳ LossGap:+0.0050 (tr 0.9530) | F1macroGap:+0.0046 (tr 0.6953) | Penalty:0.0000 | Selection(loss):0.9580
#
#   ▶ [6/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=1.0151 | Acc=0.6739 | F1w=0.6737 | F1m=0.6552 | AUROC=0.8984 | PRAUC=0.7924
#     F2 → Loss=1.0128 | Acc=0.6936 | F1w=0.6964 | F1m=0.6809 | AUROC=0.9051 | PRAUC=0.8007
#     F3 → Loss=1.0056 | Acc=0.6748 | F1w=0.6754 | F1m=0.6530 | AUROC=0.9105 | PRAUC=0.8039
#     F4 → Loss=1.0044 | Acc=0.6748 | F1w=0.6769 | F1m=0.6603 | AUROC=0.9101 | PRAUC=0.8079
#     F5 → Loss=1.0179 | Acc=0.6569 | F1w=0.6605 | F1m=0.6380 | AUROC=0.9030 | PRAUC=0.8008
#   ✅  Loss:1.0111±0.0053 | Acc:0.6748±0.0116 | F1w:0.6766±0.0115 | F1macro:0.6575±0.0139 | AUROC:0.9054±0.0046 | PRAUC:0.8011±0.0051 | MCC:0.5733
#       ↳ LossGap:+0.0037 (tr 1.0074) | F1macroGap:+0.0022 (tr 0.6597) | Penalty:0.0000 | Selection(loss):1.0111
#
#   ▶ [7/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.9529 | Acc=0.7113 | F1w=0.7132 | F1m=0.6994 | AUROC=0.9118 | PRAUC=0.8240
#     F2 → Loss=0.9555 | Acc=0.7248 | F1w=0.7305 | F1m=0.6965 | AUROC=0.9173 | PRAUC=0.8281
#     F3 → Loss=0.9525 | Acc=0.7027 | F1w=0.7053 | F1m=0.6821 | AUROC=0.9154 | PRAUC=0.8215
#     F4 → Loss=0.9463 | Acc=0.7118 | F1w=0.7171 | F1m=0.6986 | AUROC=0.9202 | PRAUC=0.8314
#     F5 → Loss=0.9672 | Acc=0.6857 | F1w=0.6880 | F1m=0.6765 | AUROC=0.9069 | PRAUC=0.8104
#   ✅  Loss:0.9549±0.0069 | Acc:0.7073±0.0129 | F1w:0.7108±0.0140 | F1macro:0.6906±0.0095 | AUROC:0.9143±0.0046 | PRAUC:0.8231±0.0072 | MCC:0.6134
#       ↳ LossGap:+0.0047 (tr 0.9502) | F1macroGap:+0.0091 (tr 0.6997) | Penalty:0.0000 | Selection(loss):0.9549
#
#   ▶ [8/64] iterations=80 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=1.0128 | Acc=0.6609 | F1w=0.6626 | F1m=0.6324 | AUROC=0.8963 | PRAUC=0.7918
#     F2 → Loss=1.0048 | Acc=0.6974 | F1w=0.7010 | F1m=0.6851 | AUROC=0.9082 | PRAUC=0.8045
#     F3 → Loss=1.0045 | Acc=0.6873 | F1w=0.6869 | F1m=0.6664 | AUROC=0.9107 | PRAUC=0.8070
#     F4 → Loss=0.9995 | Acc=0.6734 | F1w=0.6767 | F1m=0.6636 | AUROC=0.9091 | PRAUC=0.8027
#     F5 → Loss=1.0188 | Acc=0.6665 | F1w=0.6687 | F1m=0.6498 | AUROC=0.8993 | PRAUC=0.7923
#   ✅  Loss:1.0081±0.0068 | Acc:0.6771±0.0135 | F1w:0.6792±0.0136 | F1macro:0.6595±0.0176 | AUROC:0.9047±0.0058 | PRAUC:0.7996±0.0064 | MCC:0.5770
#       ↳ LossGap:+0.0043 (tr 1.0038) | F1macroGap:+0.0055 (tr 0.6650) | Penalty:0.0000 | Selection(loss):1.0081
#
#   ▶ [9/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.7175 | Acc=0.7738 | F1w=0.7771 | F1m=0.7597 | AUROC=0.9411 | PRAUC=0.8700
#     F2 → Loss=0.7231 | Acc=0.7863 | F1w=0.7894 | F1m=0.7640 | AUROC=0.9435 | PRAUC=0.8768
#     F3 → Loss=0.6962 | Acc=0.8012 | F1w=0.8057 | F1m=0.7867 | AUROC=0.9551 | PRAUC=0.8940
#     F4 → Loss=0.6983 | Acc=0.7887 | F1w=0.7916 | F1m=0.7802 | AUROC=0.9494 | PRAUC=0.8871
#     F5 → Loss=0.7218 | Acc=0.7934 | F1w=0.7966 | F1m=0.7922 | AUROC=0.9431 | PRAUC=0.8778
#   ✅  Loss:0.7114±0.0117 | Acc:0.7886±0.0090 | F1w:0.7921±0.0093 | F1macro:0.7766±0.0127 | AUROC:0.9464±0.0051 | PRAUC:0.8811±0.0084 | MCC:0.7149
#       ↳ LossGap:+0.0087 (tr 0.7027) | F1macroGap:+0.0046 (tr 0.7811) | Penalty:0.0000 | Selection(loss):0.7114
#
#   ▶ [10/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.7677 | Acc=0.7526 | F1w=0.7566 | F1m=0.7258 | AUROC=0.9345 | PRAUC=0.8550
#     F2 → Loss=0.7690 | Acc=0.7613 | F1w=0.7644 | F1m=0.7533 | AUROC=0.9375 | PRAUC=0.8627
#     F3 → Loss=0.7577 | Acc=0.7738 | F1w=0.7765 | F1m=0.7643 | AUROC=0.9410 | PRAUC=0.8639
#     F4 → Loss=0.7673 | Acc=0.7546 | F1w=0.7593 | F1m=0.7400 | AUROC=0.9353 | PRAUC=0.8543
#     F5 → Loss=0.7779 | Acc=0.7540 | F1w=0.7580 | F1m=0.7369 | AUROC=0.9335 | PRAUC=0.8520
#   ✅  Loss:0.7679±0.0064 | Acc:0.7592±0.0079 | F1w:0.7630±0.0072 | F1macro:0.7441±0.0134 | AUROC:0.9364±0.0027 | PRAUC:0.8576±0.0048 | MCC:0.6796
#       ↳ LossGap:+0.0049 (tr 0.7630) | F1macroGap:+0.0074 (tr 0.7515) | Penalty:0.0000 | Selection(loss):0.7679
#
#   ▶ [11/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.7196 | Acc=0.7743 | F1w=0.7786 | F1m=0.7528 | AUROC=0.9431 | PRAUC=0.8726
#     F2 → Loss=0.7128 | Acc=0.7973 | F1w=0.8006 | F1m=0.7822 | AUROC=0.9478 | PRAUC=0.8836
#     F3 → Loss=0.6966 | Acc=0.7863 | F1w=0.7918 | F1m=0.7668 | AUROC=0.9536 | PRAUC=0.8932
#     F4 → Loss=0.6858 | Acc=0.7973 | F1w=0.8014 | F1m=0.7868 | AUROC=0.9535 | PRAUC=0.8935
#     F5 → Loss=0.7277 | Acc=0.7938 | F1w=0.7965 | F1m=0.7893 | AUROC=0.9416 | PRAUC=0.8741
#   ✅  Loss:0.7085±0.0153 | Acc:0.7898±0.0088 | F1w:0.7938±0.0083 | F1macro:0.7756±0.0138 | AUROC:0.9479±0.0050 | PRAUC:0.8834±0.0090 | MCC:0.7166
#       ↳ LossGap:+0.0083 (tr 0.7002) | F1macroGap:+0.0045 (tr 0.7801) | Penalty:0.0000 | Selection(loss):0.7085
#
#   ▶ [12/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.7728 | Acc=0.7464 | F1w=0.7503 | F1m=0.7281 | AUROC=0.9348 | PRAUC=0.8560
#     F2 → Loss=0.7627 | Acc=0.7598 | F1w=0.7641 | F1m=0.7457 | AUROC=0.9375 | PRAUC=0.8590
#     F3 → Loss=0.7579 | Acc=0.7815 | F1w=0.7847 | F1m=0.7641 | AUROC=0.9412 | PRAUC=0.8654
#     F4 → Loss=0.7481 | Acc=0.7776 | F1w=0.7814 | F1m=0.7626 | AUROC=0.9404 | PRAUC=0.8641
#     F5 → Loss=0.7836 | Acc=0.7492 | F1w=0.7543 | F1m=0.7286 | AUROC=0.9312 | PRAUC=0.8465
#   ✅  Loss:0.7650±0.0122 | Acc:0.7629±0.0144 | F1w:0.7669±0.0139 | F1macro:0.7458±0.0157 | AUROC:0.9370±0.0037 | PRAUC:0.8582±0.0068 | MCC:0.6833
#       ↳ LossGap:+0.0040 (tr 0.7610) | F1macroGap:+0.0039 (tr 0.7497) | Penalty:0.0000 | Selection(loss):0.7650
#
#   ▶ [13/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.7318 | Acc=0.7743 | F1w=0.7781 | F1m=0.7547 | AUROC=0.9422 | PRAUC=0.8732
#     F2 → Loss=0.7269 | Acc=0.7911 | F1w=0.7950 | F1m=0.7740 | AUROC=0.9458 | PRAUC=0.8799
#     F3 → Loss=0.7246 | Acc=0.7781 | F1w=0.7841 | F1m=0.7577 | AUROC=0.9494 | PRAUC=0.8808
#     F4 → Loss=0.7013 | Acc=0.7992 | F1w=0.8027 | F1m=0.7866 | AUROC=0.9521 | PRAUC=0.8902
#     F5 → Loss=0.7416 | Acc=0.7862 | F1w=0.7900 | F1m=0.7702 | AUROC=0.9410 | PRAUC=0.8727
#   ✅  Loss:0.7252±0.0133 | Acc:0.7858±0.0090 | F1w:0.7900±0.0085 | F1macro:0.7687±0.0116 | AUROC:0.9461±0.0042 | PRAUC:0.8794±0.0064 | MCC:0.7110
#       ↳ LossGap:+0.0066 (tr 0.7186) | F1macroGap:+0.0027 (tr 0.7714) | Penalty:0.0000 | Selection(loss):0.7252
#
#   ▶ [14/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.7819 | Acc=0.7464 | F1w=0.7510 | F1m=0.7200 | AUROC=0.9317 | PRAUC=0.8497
#     F2 → Loss=0.7735 | Acc=0.7666 | F1w=0.7701 | F1m=0.7501 | AUROC=0.9356 | PRAUC=0.8581
#     F3 → Loss=0.7693 | Acc=0.7738 | F1w=0.7768 | F1m=0.7616 | AUROC=0.9399 | PRAUC=0.8623
#     F4 → Loss=0.7719 | Acc=0.7555 | F1w=0.7595 | F1m=0.7389 | AUROC=0.9367 | PRAUC=0.8563
#     F5 → Loss=0.7861 | Acc=0.7472 | F1w=0.7507 | F1m=0.7363 | AUROC=0.9326 | PRAUC=0.8507
#   ✅  Loss:0.7765±0.0064 | Acc:0.7579±0.0108 | F1w:0.7616±0.0104 | F1macro:0.7414±0.0139 | AUROC:0.9353±0.0029 | PRAUC:0.8554±0.0047 | MCC:0.6778
#       ↳ LossGap:+0.0052 (tr 0.7713) | F1macroGap:+0.0106 (tr 0.7520) | Penalty:0.0000 | Selection(loss):0.7765
#
#   ▶ [15/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.7308 | Acc=0.7671 | F1w=0.7700 | F1m=0.7525 | AUROC=0.9412 | PRAUC=0.8729
#     F2 → Loss=0.7290 | Acc=0.7901 | F1w=0.7931 | F1m=0.7760 | AUROC=0.9449 | PRAUC=0.8799
#     F3 → Loss=0.7147 | Acc=0.7853 | F1w=0.7900 | F1m=0.7671 | AUROC=0.9514 | PRAUC=0.8873
#     F4 → Loss=0.7014 | Acc=0.7983 | F1w=0.8022 | F1m=0.7853 | AUROC=0.9499 | PRAUC=0.8872
#     F5 → Loss=0.7365 | Acc=0.7857 | F1w=0.7893 | F1m=0.7805 | AUROC=0.9402 | PRAUC=0.8712
#   ✅  Loss:0.7225±0.0128 | Acc:0.7853±0.0102 | F1w:0.7889±0.0105 | F1macro:0.7723±0.0116 | AUROC:0.9455±0.0045 | PRAUC:0.8797±0.0068 | MCC:0.7106
#       ↳ LossGap:+0.0088 (tr 0.7136) | F1macroGap:+0.0043 (tr 0.7766) | Penalty:0.0000 | Selection(loss):0.7225
#
#   ▶ [16/64] iterations=80 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.7894 | Acc=0.7378 | F1w=0.7420 | F1m=0.7193 | AUROC=0.9284 | PRAUC=0.8467
#     F2 → Loss=0.7767 | Acc=0.7531 | F1w=0.7572 | F1m=0.7402 | AUROC=0.9359 | PRAUC=0.8585
#     F3 → Loss=0.7750 | Acc=0.7671 | F1w=0.7693 | F1m=0.7504 | AUROC=0.9388 | PRAUC=0.8622
#     F4 → Loss=0.7604 | Acc=0.7685 | F1w=0.7725 | F1m=0.7569 | AUROC=0.9394 | PRAUC=0.8621
#     F5 → Loss=0.7879 | Acc=0.7564 | F1w=0.7599 | F1m=0.7470 | AUROC=0.9315 | PRAUC=0.8501
#   ✅  Loss:0.7779±0.0105 | Acc:0.7566±0.0111 | F1w:0.7602±0.0107 | F1macro:0.7428±0.0129 | AUROC:0.9348±0.0042 | PRAUC:0.8559±0.0064 | MCC:0.6756
#       ↳ LossGap:+0.0052 (tr 0.7727) | F1macroGap:+0.0047 (tr 0.7475) | Penalty:0.0000 | Selection(loss):0.7779
#
#   ▶ [17/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.8157 | Acc=0.7594 | F1w=0.7631 | F1m=0.7522 | AUROC=0.9360 | PRAUC=0.8679
#     F2 → Loss=0.8104 | Acc=0.7805 | F1w=0.7836 | F1m=0.7657 | AUROC=0.9419 | PRAUC=0.8772
#     F3 → Loss=0.8041 | Acc=0.7666 | F1w=0.7719 | F1m=0.7554 | AUROC=0.9439 | PRAUC=0.8734
#     F4 → Loss=0.7939 | Acc=0.7762 | F1w=0.7806 | F1m=0.7699 | AUROC=0.9451 | PRAUC=0.8793
#     F5 → Loss=0.8217 | Acc=0.7636 | F1w=0.7685 | F1m=0.7622 | AUROC=0.9396 | PRAUC=0.8715
#   ✅  Loss:0.8092±0.0096 | Acc:0.7692±0.0079 | F1w:0.7735±0.0076 | F1macro:0.7611±0.0065 | AUROC:0.9413±0.0032 | PRAUC:0.8738±0.0041 | MCC:0.6916
#       ↳ LossGap:+0.0062 (tr 0.8029) | F1macroGap:+0.0026 (tr 0.7637) | Penalty:0.0000 | Selection(loss):0.8092
#
#   ▶ [18/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.8818 | Acc=0.7248 | F1w=0.7298 | F1m=0.7099 | AUROC=0.9254 | PRAUC=0.8487
#     F2 → Loss=0.8690 | Acc=0.7541 | F1w=0.7587 | F1m=0.7433 | AUROC=0.9337 | PRAUC=0.8586
#     F3 → Loss=0.8640 | Acc=0.7358 | F1w=0.7392 | F1m=0.7387 | AUROC=0.9340 | PRAUC=0.8542
#     F4 → Loss=0.8679 | Acc=0.7358 | F1w=0.7408 | F1m=0.7347 | AUROC=0.9289 | PRAUC=0.8479
#     F5 → Loss=0.8868 | Acc=0.7227 | F1w=0.7269 | F1m=0.7224 | AUROC=0.9275 | PRAUC=0.8443
#   ✅  Loss:0.8739±0.0088 | Acc:0.7347±0.0111 | F1w:0.7391±0.0112 | F1macro:0.7298±0.0121 | AUROC:0.9299±0.0034 | PRAUC:0.8507±0.0051 | MCC:0.6507
#       ↳ LossGap:+0.0051 (tr 0.8688) | F1macroGap:+0.0052 (tr 0.7350) | Penalty:0.0000 | Selection(loss):0.8739
#
#   ▶ [19/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.8153 | Acc=0.7555 | F1w=0.7594 | F1m=0.7405 | AUROC=0.9357 | PRAUC=0.8668
#     F2 → Loss=0.8105 | Acc=0.7791 | F1w=0.7828 | F1m=0.7652 | AUROC=0.9444 | PRAUC=0.8808
#     F3 → Loss=0.8059 | Acc=0.7695 | F1w=0.7733 | F1m=0.7622 | AUROC=0.9452 | PRAUC=0.8754
#     F4 → Loss=0.7927 | Acc=0.7791 | F1w=0.7828 | F1m=0.7619 | AUROC=0.9471 | PRAUC=0.8823
#     F5 → Loss=0.8225 | Acc=0.7684 | F1w=0.7727 | F1m=0.7598 | AUROC=0.9386 | PRAUC=0.8665
#   ✅  Loss:0.8094±0.0100 | Acc:0.7703±0.0087 | F1w:0.7742±0.0086 | F1macro:0.7579±0.0089 | AUROC:0.9422±0.0043 | PRAUC:0.8743±0.0067 | MCC:0.6922
#       ↳ LossGap:+0.0069 (tr 0.8025) | F1macroGap:+0.0050 (tr 0.7629) | Penalty:0.0000 | Selection(loss):0.8094
#
#   ▶ [20/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.8694 | Acc=0.7320 | F1w=0.7377 | F1m=0.7201 | AUROC=0.9298 | PRAUC=0.8561
#     F2 → Loss=0.8705 | Acc=0.7469 | F1w=0.7512 | F1m=0.7456 | AUROC=0.9320 | PRAUC=0.8581
#     F3 → Loss=0.8590 | Acc=0.7478 | F1w=0.7513 | F1m=0.7460 | AUROC=0.9369 | PRAUC=0.8583
#     F4 → Loss=0.8686 | Acc=0.7358 | F1w=0.7407 | F1m=0.7272 | AUROC=0.9318 | PRAUC=0.8513
#     F5 → Loss=0.8824 | Acc=0.7347 | F1w=0.7392 | F1m=0.7305 | AUROC=0.9267 | PRAUC=0.8421
#   ✅  Loss:0.8700±0.0074 | Acc:0.7395±0.0066 | F1w:0.7440±0.0060 | F1macro:0.7339±0.0103 | AUROC:0.9315±0.0033 | PRAUC:0.8532±0.0061 | MCC:0.6565
#       ↳ LossGap:+0.0042 (tr 0.8658) | F1macroGap:+0.0025 (tr 0.7364) | Penalty:0.0000 | Selection(loss):0.8700
#
#   ▶ [21/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.8333 | Acc=0.7661 | F1w=0.7694 | F1m=0.7544 | AUROC=0.9347 | PRAUC=0.8654
#     F2 → Loss=0.8203 | Acc=0.7872 | F1w=0.7904 | F1m=0.7756 | AUROC=0.9429 | PRAUC=0.8786
#     F3 → Loss=0.8205 | Acc=0.7714 | F1w=0.7765 | F1m=0.7640 | AUROC=0.9432 | PRAUC=0.8738
#     F4 → Loss=0.8147 | Acc=0.7714 | F1w=0.7758 | F1m=0.7613 | AUROC=0.9461 | PRAUC=0.8822
#     F5 → Loss=0.8367 | Acc=0.7535 | F1w=0.7593 | F1m=0.7399 | AUROC=0.9371 | PRAUC=0.8657
#   ✅  Loss:0.8251±0.0084 | Acc:0.7699±0.0108 | F1w:0.7743±0.0101 | F1macro:0.7590±0.0118 | AUROC:0.9408±0.0042 | PRAUC:0.8731±0.0067 | MCC:0.6922
#       ↳ LossGap:+0.0058 (tr 0.8193) | F1macroGap:+0.0045 (tr 0.7635) | Penalty:0.0000 | Selection(loss):0.8251
#
#   ▶ [22/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.8885 | Acc=0.7382 | F1w=0.7425 | F1m=0.7241 | AUROC=0.9267 | PRAUC=0.8497
#     F2 → Loss=0.8872 | Acc=0.7445 | F1w=0.7491 | F1m=0.7328 | AUROC=0.9303 | PRAUC=0.8530
#     F3 → Loss=0.8759 | Acc=0.7354 | F1w=0.7393 | F1m=0.7372 | AUROC=0.9331 | PRAUC=0.8512
#     F4 → Loss=0.8917 | Acc=0.7157 | F1w=0.7211 | F1m=0.7091 | AUROC=0.9241 | PRAUC=0.8394
#     F5 → Loss=0.8962 | Acc=0.7170 | F1w=0.7216 | F1m=0.7137 | AUROC=0.9253 | PRAUC=0.8401
#   ✅  Loss:0.8879±0.0067 | Acc:0.7301±0.0117 | F1w:0.7347±0.0114 | F1macro:0.7234±0.0107 | AUROC:0.9279±0.0033 | PRAUC:0.8467±0.0058 | MCC:0.6444
#       ↳ LossGap:+0.0048 (tr 0.8831) | F1macroGap:+0.0049 (tr 0.7283) | Penalty:0.0000 | Selection(loss):0.8879
#
#   ▶ [23/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.8344 | Acc=0.7502 | F1w=0.7536 | F1m=0.7402 | AUROC=0.9326 | PRAUC=0.8605
#     F2 → Loss=0.8279 | Acc=0.7848 | F1w=0.7881 | F1m=0.7754 | AUROC=0.9429 | PRAUC=0.8793
#     F3 → Loss=0.8202 | Acc=0.7699 | F1w=0.7751 | F1m=0.7611 | AUROC=0.9440 | PRAUC=0.8737
#     F4 → Loss=0.8134 | Acc=0.7752 | F1w=0.7795 | F1m=0.7684 | AUROC=0.9434 | PRAUC=0.8790
#     F5 → Loss=0.8430 | Acc=0.7568 | F1w=0.7607 | F1m=0.7521 | AUROC=0.9352 | PRAUC=0.8658
#   ✅  Loss:0.8278±0.0104 | Acc:0.7674±0.0125 | F1w:0.7714±0.0126 | F1macro:0.7594±0.0124 | AUROC:0.9396±0.0048 | PRAUC:0.8717±0.0074 | MCC:0.6904
#       ↳ LossGap:+0.0059 (tr 0.8219) | F1macroGap:+0.0024 (tr 0.7619) | Penalty:0.0000 | Selection(loss):0.8278
#
#   ▶ [24/64] iterations=80 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.8888 | Acc=0.7185 | F1w=0.7238 | F1m=0.7093 | AUROC=0.9245 | PRAUC=0.8480
#     F2 → Loss=0.8847 | Acc=0.7459 | F1w=0.7502 | F1m=0.7440 | AUROC=0.9314 | PRAUC=0.8573
#     F3 → Loss=0.8789 | Acc=0.7291 | F1w=0.7331 | F1m=0.7356 | AUROC=0.9317 | PRAUC=0.8485
#     F4 → Loss=0.8921 | Acc=0.7233 | F1w=0.7292 | F1m=0.7178 | AUROC=0.9265 | PRAUC=0.8415
#     F5 → Loss=0.8959 | Acc=0.7314 | F1w=0.7356 | F1m=0.7276 | AUROC=0.9252 | PRAUC=0.8379
#   ✅  Loss:0.8881±0.0059 | Acc:0.7297±0.0093 | F1w:0.7344±0.0088 | F1macro:0.7269±0.0123 | AUROC:0.9279±0.0031 | PRAUC:0.8467±0.0067 | MCC:0.6441
#       ↳ LossGap:+0.0055 (tr 0.8826) | F1macroGap:+0.0014 (tr 0.7282) | Penalty:0.0000 | Selection(loss):0.8881
#
#   ▶ [25/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.5980 | Acc=0.8016 | F1w=0.8047 | F1m=0.7935 | AUROC=0.9573 | PRAUC=0.9005
#     F2 → Loss=0.5849 | Acc=0.8329 | F1w=0.8353 | F1m=0.8340 | AUROC=0.9628 | PRAUC=0.9137
#     F3 → Loss=0.5667 | Acc=0.8314 | F1w=0.8352 | F1m=0.8243 | AUROC=0.9654 | PRAUC=0.9162
#     F4 → Loss=0.5651 | Acc=0.8305 | F1w=0.8329 | F1m=0.8291 | AUROC=0.9639 | PRAUC=0.9192
#     F5 → Loss=0.6128 | Acc=0.8150 | F1w=0.8175 | F1m=0.8166 | AUROC=0.9541 | PRAUC=0.8992
#   ✅  Loss:0.5855±0.0183 | Acc:0.8223±0.0122 | F1w:0.8251±0.0122 | F1macro:0.8195±0.0142 | AUROC:0.9607±0.0043 | PRAUC:0.9098±0.0083 | MCC:0.7566
#       ↳ LossGap:+0.0087 (tr 0.5768) | F1macroGap:+0.0096 (tr 0.8291) | Penalty:0.0000 | Selection(loss):0.5855
#
#   ▶ [26/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.6551 | Acc=0.7882 | F1w=0.7916 | F1m=0.7807 | AUROC=0.9493 | PRAUC=0.8886
#     F2 → Loss=0.6354 | Acc=0.8040 | F1w=0.8067 | F1m=0.8008 | AUROC=0.9549 | PRAUC=0.9023
#     F3 → Loss=0.6285 | Acc=0.8045 | F1w=0.8078 | F1m=0.8002 | AUROC=0.9586 | PRAUC=0.9052
#     F4 → Loss=0.6347 | Acc=0.7968 | F1w=0.8010 | F1m=0.7927 | AUROC=0.9553 | PRAUC=0.8982
#     F5 → Loss=0.6614 | Acc=0.7958 | F1w=0.7983 | F1m=0.8016 | AUROC=0.9486 | PRAUC=0.8883
#   ✅  Loss:0.6430±0.0128 | Acc:0.7979±0.0060 | F1w:0.8011±0.0059 | F1macro:0.7952±0.0079 | AUROC:0.9534±0.0038 | PRAUC:0.8965±0.0070 | MCC:0.7272
#       ↳ LossGap:+0.0073 (tr 0.6357) | F1macroGap:+0.0018 (tr 0.7970) | Penalty:0.0000 | Selection(loss):0.6430
#
#   ▶ [27/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.5942 | Acc=0.8050 | F1w=0.8082 | F1m=0.7982 | AUROC=0.9590 | PRAUC=0.9038
#     F2 → Loss=0.5947 | Acc=0.8189 | F1w=0.8216 | F1m=0.8224 | AUROC=0.9599 | PRAUC=0.9097
#     F3 → Loss=0.5702 | Acc=0.8252 | F1w=0.8289 | F1m=0.8236 | AUROC=0.9656 | PRAUC=0.9163
#     F4 → Loss=0.5694 | Acc=0.8290 | F1w=0.8313 | F1m=0.8354 | AUROC=0.9639 | PRAUC=0.9153
#     F5 → Loss=0.6133 | Acc=0.8179 | F1w=0.8201 | F1m=0.8224 | AUROC=0.9539 | PRAUC=0.8993
#   ✅  Loss:0.5884±0.0166 | Acc:0.8192±0.0082 | F1w:0.8220±0.0081 | F1macro:0.8204±0.0121 | AUROC:0.9605±0.0041 | PRAUC:0.9089±0.0066 | MCC:0.7524
#       ↳ LossGap:+0.0082 (tr 0.5801) | F1macroGap:+0.0060 (tr 0.8264) | Penalty:0.0000 | Selection(loss):0.5884
#
#   ▶ [28/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.6422 | Acc=0.7939 | F1w=0.7970 | F1m=0.7821 | AUROC=0.9504 | PRAUC=0.8919
#     F2 → Loss=0.6311 | Acc=0.8060 | F1w=0.8088 | F1m=0.8011 | AUROC=0.9551 | PRAUC=0.9022
#     F3 → Loss=0.6239 | Acc=0.7997 | F1w=0.8035 | F1m=0.7910 | AUROC=0.9584 | PRAUC=0.9055
#     F4 → Loss=0.6399 | Acc=0.7978 | F1w=0.8012 | F1m=0.7989 | AUROC=0.9546 | PRAUC=0.8982
#     F5 → Loss=0.6533 | Acc=0.8025 | F1w=0.8048 | F1m=0.8097 | AUROC=0.9508 | PRAUC=0.8918
#   ✅  Loss:0.6380±0.0100 | Acc:0.8000±0.0041 | F1w:0.8030±0.0039 | F1macro:0.7966±0.0094 | AUROC:0.9539±0.0029 | PRAUC:0.8979±0.0055 | MCC:0.7292
#       ↳ LossGap:+0.0062 (tr 0.6318) | F1macroGap:+0.0006 (tr 0.7971) | Penalty:0.0000 | Selection(loss):0.6380
#
#   ▶ [29/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.6114 | Acc=0.8031 | F1w=0.8058 | F1m=0.7937 | AUROC=0.9574 | PRAUC=0.9015
#     F2 → Loss=0.6049 | Acc=0.8242 | F1w=0.8264 | F1m=0.8222 | AUROC=0.9596 | PRAUC=0.9089
#     F3 → Loss=0.5925 | Acc=0.8285 | F1w=0.8331 | F1m=0.8221 | AUROC=0.9634 | PRAUC=0.9136
#     F4 → Loss=0.5891 | Acc=0.8170 | F1w=0.8198 | F1m=0.8155 | AUROC=0.9618 | PRAUC=0.9105
#     F5 → Loss=0.6323 | Acc=0.8164 | F1w=0.8190 | F1m=0.8089 | AUROC=0.9518 | PRAUC=0.8946
#   ✅  Loss:0.6060±0.0154 | Acc:0.8178±0.0087 | F1w:0.8208±0.0091 | F1macro:0.8125±0.0106 | AUROC:0.9588±0.0040 | PRAUC:0.9058±0.0069 | MCC:0.7512
#       ↳ LossGap:+0.0086 (tr 0.5975) | F1macroGap:+0.0084 (tr 0.8209) | Penalty:0.0000 | Selection(loss):0.6060
#
#   ▶ [30/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.6664 | Acc=0.7776 | F1w=0.7817 | F1m=0.7660 | AUROC=0.9488 | PRAUC=0.8910
#     F2 → Loss=0.6583 | Acc=0.7992 | F1w=0.8024 | F1m=0.7937 | AUROC=0.9519 | PRAUC=0.8975
#     F3 → Loss=0.6417 | Acc=0.8088 | F1w=0.8120 | F1m=0.8012 | AUROC=0.9575 | PRAUC=0.9033
#     F4 → Loss=0.6570 | Acc=0.7959 | F1w=0.7999 | F1m=0.7904 | AUROC=0.9521 | PRAUC=0.8936
#     F5 → Loss=0.6786 | Acc=0.7929 | F1w=0.7955 | F1m=0.7965 | AUROC=0.9468 | PRAUC=0.8843
#   ✅  Loss:0.6604±0.0121 | Acc:0.7949±0.0102 | F1w:0.7983±0.0099 | F1macro:0.7896±0.0123 | AUROC:0.9514±0.0036 | PRAUC:0.8940±0.0063 | MCC:0.7236
#       ↳ LossGap:+0.0061 (tr 0.6543) | F1macroGap:+0.0024 (tr 0.7919) | Penalty:0.0000 | Selection(loss):0.6604
#
#   ▶ [31/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.6029 | Acc=0.8026 | F1w=0.8065 | F1m=0.7866 | AUROC=0.9595 | PRAUC=0.9054
#     F2 → Loss=0.6075 | Acc=0.8285 | F1w=0.8302 | F1m=0.8274 | AUROC=0.9593 | PRAUC=0.9088
#     F3 → Loss=0.5921 | Acc=0.8199 | F1w=0.8229 | F1m=0.8226 | AUROC=0.9633 | PRAUC=0.9136
#     F4 → Loss=0.5993 | Acc=0.8232 | F1w=0.8262 | F1m=0.8190 | AUROC=0.9607 | PRAUC=0.9080
#     F5 → Loss=0.6257 | Acc=0.8111 | F1w=0.8141 | F1m=0.8060 | AUROC=0.9539 | PRAUC=0.8978
#   ✅  Loss:0.6055±0.0113 | Acc:0.8171±0.0092 | F1w:0.8200±0.0086 | F1macro:0.8123±0.0147 | AUROC:0.9593±0.0030 | PRAUC:0.9067±0.0052 | MCC:0.7498
#       ↳ LossGap:+0.0086 (tr 0.5969) | F1macroGap:+0.0024 (tr 0.8147) | Penalty:0.0000 | Selection(loss):0.6055
#
#   ▶ [32/64] iterations=80 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.6636 | Acc=0.7843 | F1w=0.7874 | F1m=0.7747 | AUROC=0.9483 | PRAUC=0.8879
#     F2 → Loss=0.6509 | Acc=0.7959 | F1w=0.7989 | F1m=0.7943 | AUROC=0.9533 | PRAUC=0.8983
#     F3 → Loss=0.6396 | Acc=0.8036 | F1w=0.8074 | F1m=0.7961 | AUROC=0.9577 | PRAUC=0.9039
#     F4 → Loss=0.6458 | Acc=0.8045 | F1w=0.8081 | F1m=0.8035 | AUROC=0.9550 | PRAUC=0.8982
#     F5 → Loss=0.6799 | Acc=0.7929 | F1w=0.7954 | F1m=0.7934 | AUROC=0.9457 | PRAUC=0.8821
#   ✅  Loss:0.6560±0.0143 | Acc:0.7962±0.0074 | F1w:0.7995±0.0077 | F1macro:0.7924±0.0095 | AUROC:0.9520±0.0044 | PRAUC:0.8941±0.0079 | MCC:0.7250
#       ↳ LossGap:+0.0069 (tr 0.6491) | F1macroGap:+0.0033 (tr 0.7956) | Penalty:0.0000 | Selection(loss):0.6560
#
#   ▶ [33/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.7390 | Acc=0.7752 | F1w=0.7798 | F1m=0.7566 | AUROC=0.9416 | PRAUC=0.8731
#     F2 → Loss=0.7368 | Acc=0.7848 | F1w=0.7884 | F1m=0.7654 | AUROC=0.9461 | PRAUC=0.8797
#     F3 → Loss=0.7208 | Acc=0.7915 | F1w=0.7973 | F1m=0.7750 | AUROC=0.9515 | PRAUC=0.8870
#     F4 → Loss=0.7222 | Acc=0.7819 | F1w=0.7866 | F1m=0.7642 | AUROC=0.9494 | PRAUC=0.8867
#     F5 → Loss=0.7515 | Acc=0.7871 | F1w=0.7904 | F1m=0.7817 | AUROC=0.9404 | PRAUC=0.8718
#   ✅  Loss:0.7340±0.0114 | Acc:0.7841±0.0055 | F1w:0.7885±0.0057 | F1macro:0.7686±0.0088 | AUROC:0.9458±0.0043 | PRAUC:0.8797±0.0065 | MCC:0.7102
#       ↳ LossGap:+0.0073 (tr 0.7268) | F1macroGap:+0.0036 (tr 0.7722) | Penalty:0.0000 | Selection(loss):0.7340
#
#   ▶ [34/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.7978 | Acc=0.7450 | F1w=0.7476 | F1m=0.7280 | AUROC=0.9275 | PRAUC=0.8482
#     F2 → Loss=0.7894 | Acc=0.7574 | F1w=0.7610 | F1m=0.7427 | AUROC=0.9337 | PRAUC=0.8569
#     F3 → Loss=0.7788 | Acc=0.7618 | F1w=0.7655 | F1m=0.7521 | AUROC=0.9388 | PRAUC=0.8632
#     F4 → Loss=0.7808 | Acc=0.7541 | F1w=0.7576 | F1m=0.7493 | AUROC=0.9362 | PRAUC=0.8614
#     F5 → Loss=0.8020 | Acc=0.7328 | F1w=0.7368 | F1m=0.7208 | AUROC=0.9281 | PRAUC=0.8482
#   ✅  Loss:0.7897±0.0091 | Acc:0.7502±0.0103 | F1w:0.7537±0.0103 | F1macro:0.7386±0.0122 | AUROC:0.9329±0.0045 | PRAUC:0.8556±0.0064 | MCC:0.6663
#       ↳ LossGap:+0.0060 (tr 0.7838) | F1macroGap:+0.0080 (tr 0.7466) | Penalty:0.0000 | Selection(loss):0.7897
#
#   ▶ [35/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.7469 | Acc=0.7699 | F1w=0.7744 | F1m=0.7474 | AUROC=0.9388 | PRAUC=0.8681
#     F2 → Loss=0.7344 | Acc=0.7863 | F1w=0.7891 | F1m=0.7732 | AUROC=0.9460 | PRAUC=0.8817
#     F3 → Loss=0.7216 | Acc=0.7824 | F1w=0.7878 | F1m=0.7674 | AUROC=0.9510 | PRAUC=0.8861
#     F4 → Loss=0.7263 | Acc=0.7824 | F1w=0.7871 | F1m=0.7678 | AUROC=0.9485 | PRAUC=0.8819
#     F5 → Loss=0.7487 | Acc=0.7828 | F1w=0.7863 | F1m=0.7746 | AUROC=0.9416 | PRAUC=0.8730
#   ✅  Loss:0.7356±0.0108 | Acc:0.7808±0.0056 | F1w:0.7849±0.0053 | F1macro:0.7661±0.0098 | AUROC:0.9452±0.0044 | PRAUC:0.8782±0.0066 | MCC:0.7061
#       ↳ LossGap:+0.0081 (tr 0.7275) | F1macroGap:+0.0046 (tr 0.7707) | Penalty:0.0000 | Selection(loss):0.7356
#
#   ▶ [36/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.7948 | Acc=0.7382 | F1w=0.7412 | F1m=0.7257 | AUROC=0.9268 | PRAUC=0.8479
#     F2 → Loss=0.7792 | Acc=0.7709 | F1w=0.7742 | F1m=0.7543 | AUROC=0.9361 | PRAUC=0.8618
#     F3 → Loss=0.7763 | Acc=0.7632 | F1w=0.7664 | F1m=0.7546 | AUROC=0.9395 | PRAUC=0.8640
#     F4 → Loss=0.7780 | Acc=0.7565 | F1w=0.7610 | F1m=0.7438 | AUROC=0.9385 | PRAUC=0.8630
#     F5 → Loss=0.8005 | Acc=0.7482 | F1w=0.7510 | F1m=0.7331 | AUROC=0.9302 | PRAUC=0.8512
#   ✅  Loss:0.7858±0.0100 | Acc:0.7554±0.0114 | F1w:0.7588±0.0116 | F1macro:0.7423±0.0115 | AUROC:0.9342±0.0049 | PRAUC:0.8576±0.0067 | MCC:0.6733
#       ↳ LossGap:+0.0057 (tr 0.7801) | F1macroGap:+0.0058 (tr 0.7481) | Penalty:0.0000 | Selection(loss):0.7858
#
#   ▶ [37/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.7576 | Acc=0.7709 | F1w=0.7761 | F1m=0.7473 | AUROC=0.9376 | PRAUC=0.8657
#     F2 → Loss=0.7462 | Acc=0.7896 | F1w=0.7930 | F1m=0.7690 | AUROC=0.9442 | PRAUC=0.8769
#     F3 → Loss=0.7367 | Acc=0.7800 | F1w=0.7856 | F1m=0.7662 | AUROC=0.9486 | PRAUC=0.8816
#     F4 → Loss=0.7382 | Acc=0.7733 | F1w=0.7776 | F1m=0.7624 | AUROC=0.9464 | PRAUC=0.8819
#     F5 → Loss=0.7628 | Acc=0.7809 | F1w=0.7847 | F1m=0.7652 | AUROC=0.9392 | PRAUC=0.8695
#   ✅  Loss:0.7483±0.0104 | Acc:0.7789±0.0066 | F1w:0.7834±0.0061 | F1macro:0.7620±0.0077 | AUROC:0.9432±0.0042 | PRAUC:0.8751±0.0065 | MCC:0.7034
#       ↳ LossGap:+0.0086 (tr 0.7396) | F1macroGap:+0.0038 (tr 0.7658) | Penalty:0.0000 | Selection(loss):0.7483
#
#   ▶ [38/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.8069 | Acc=0.7402 | F1w=0.7429 | F1m=0.7222 | AUROC=0.9268 | PRAUC=0.8477
#     F2 → Loss=0.7974 | Acc=0.7618 | F1w=0.7649 | F1m=0.7516 | AUROC=0.9344 | PRAUC=0.8579
#     F3 → Loss=0.7917 | Acc=0.7661 | F1w=0.7689 | F1m=0.7598 | AUROC=0.9374 | PRAUC=0.8594
#     F4 → Loss=0.7941 | Acc=0.7459 | F1w=0.7498 | F1m=0.7418 | AUROC=0.9332 | PRAUC=0.8564
#     F5 → Loss=0.8151 | Acc=0.7357 | F1w=0.7402 | F1m=0.7153 | AUROC=0.9275 | PRAUC=0.8464
#   ✅  Loss:0.8011±0.0087 | Acc:0.7499±0.0120 | F1w:0.7534±0.0116 | F1macro:0.7381±0.0170 | AUROC:0.9319±0.0041 | PRAUC:0.8536±0.0054 | MCC:0.6662
#       ↳ LossGap:+0.0052 (tr 0.7958) | F1macroGap:+0.0047 (tr 0.7429) | Penalty:0.0000 | Selection(loss):0.8011
#
#   ▶ [39/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.7576 | Acc=0.7671 | F1w=0.7712 | F1m=0.7497 | AUROC=0.9390 | PRAUC=0.8681
#     F2 → Loss=0.7496 | Acc=0.7805 | F1w=0.7842 | F1m=0.7622 | AUROC=0.9448 | PRAUC=0.8790
#     F3 → Loss=0.7362 | Acc=0.7762 | F1w=0.7827 | F1m=0.7535 | AUROC=0.9483 | PRAUC=0.8828
#     F4 → Loss=0.7364 | Acc=0.7786 | F1w=0.7834 | F1m=0.7640 | AUROC=0.9468 | PRAUC=0.8810
#     F5 → Loss=0.7660 | Acc=0.7814 | F1w=0.7846 | F1m=0.7735 | AUROC=0.9399 | PRAUC=0.8707
#   ✅  Loss:0.7492±0.0117 | Acc:0.7767±0.0052 | F1w:0.7812±0.0051 | F1macro:0.7606±0.0084 | AUROC:0.9437±0.0037 | PRAUC:0.8763±0.0058 | MCC:0.7013
#       ↳ LossGap:+0.0068 (tr 0.7424) | F1macroGap:+0.0059 (tr 0.7664) | Penalty:0.0000 | Selection(loss):0.7492
#
#   ▶ [40/64] iterations=150 | depth=3 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.8057 | Acc=0.7334 | F1w=0.7366 | F1m=0.7190 | AUROC=0.9257 | PRAUC=0.8476
#     F2 → Loss=0.7911 | Acc=0.7584 | F1w=0.7619 | F1m=0.7467 | AUROC=0.9343 | PRAUC=0.8585
#     F3 → Loss=0.7843 | Acc=0.7646 | F1w=0.7684 | F1m=0.7536 | AUROC=0.9396 | PRAUC=0.8648
#     F4 → Loss=0.7923 | Acc=0.7464 | F1w=0.7513 | F1m=0.7355 | AUROC=0.9345 | PRAUC=0.8570
#     F5 → Loss=0.8079 | Acc=0.7405 | F1w=0.7436 | F1m=0.7327 | AUROC=0.9293 | PRAUC=0.8487
#   ✅  Loss:0.7963±0.0091 | Acc:0.7487±0.0114 | F1w:0.7524±0.0116 | F1macro:0.7375±0.0119 | AUROC:0.9327±0.0048 | PRAUC:0.8553±0.0064 | MCC:0.6645
#       ↳ LossGap:+0.0057 (tr 0.7905) | F1macroGap:+0.0066 (tr 0.7441) | Penalty:0.0000 | Selection(loss):0.7963
#
#   ▶ [41/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.5481 | Acc=0.8112 | F1w=0.8145 | F1m=0.8017 | AUROC=0.9601 | PRAUC=0.9073
#     F2 → Loss=0.5457 | Acc=0.8295 | F1w=0.8313 | F1m=0.8299 | AUROC=0.9609 | PRAUC=0.9109
#     F3 → Loss=0.5263 | Acc=0.8314 | F1w=0.8350 | F1m=0.8339 | AUROC=0.9661 | PRAUC=0.9191
#     F4 → Loss=0.5301 | Acc=0.8261 | F1w=0.8287 | F1m=0.8351 | AUROC=0.9639 | PRAUC=0.9164
#     F5 → Loss=0.5695 | Acc=0.8203 | F1w=0.8230 | F1m=0.8268 | AUROC=0.9558 | PRAUC=0.9022
#   ✅  Loss:0.5439±0.0153 | Acc:0.8237±0.0073 | F1w:0.8265±0.0072 | F1macro:0.8255±0.0123 | AUROC:0.9614±0.0035 | PRAUC:0.9112±0.0061 | MCC:0.7587
#       ↳ LossGap:+0.0135 (tr 0.5305) | F1macroGap:+0.0122 (tr 0.8377) | Penalty:0.0000 | Selection(loss):0.5439
#
#   ▶ [42/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.5724 | Acc=0.8074 | F1w=0.8103 | F1m=0.7983 | AUROC=0.9571 | PRAUC=0.8992
#     F2 → Loss=0.5675 | Acc=0.8208 | F1w=0.8228 | F1m=0.8209 | AUROC=0.9597 | PRAUC=0.9090
#     F3 → Loss=0.5510 | Acc=0.8285 | F1w=0.8313 | F1m=0.8264 | AUROC=0.9641 | PRAUC=0.9147
#     F4 → Loss=0.5557 | Acc=0.8266 | F1w=0.8288 | F1m=0.8325 | AUROC=0.9614 | PRAUC=0.9113
#     F5 → Loss=0.5940 | Acc=0.8140 | F1w=0.8170 | F1m=0.8167 | AUROC=0.9529 | PRAUC=0.8964
#   ✅  Loss:0.5681±0.0151 | Acc:0.8195±0.0079 | F1w:0.8220±0.0077 | F1macro:0.8190±0.0116 | AUROC:0.9590±0.0038 | PRAUC:0.9061±0.0071 | MCC:0.7536
#       ↳ LossGap:+0.0095 (tr 0.5586) | F1macroGap:+0.0079 (tr 0.8268) | Penalty:0.0000 | Selection(loss):0.5681
#
#   ▶ [43/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.5410 | Acc=0.8098 | F1w=0.8131 | F1m=0.7977 | AUROC=0.9619 | PRAUC=0.9096
#     F2 → Loss=0.5427 | Acc=0.8305 | F1w=0.8322 | F1m=0.8377 | AUROC=0.9621 | PRAUC=0.9130
#     F3 → Loss=0.5248 | Acc=0.8305 | F1w=0.8339 | F1m=0.8347 | AUROC=0.9661 | PRAUC=0.9205
#     F4 → Loss=0.5309 | Acc=0.8276 | F1w=0.8300 | F1m=0.8432 | AUROC=0.9641 | PRAUC=0.9163
#     F5 → Loss=0.5735 | Acc=0.8222 | F1w=0.8250 | F1m=0.8256 | AUROC=0.9547 | PRAUC=0.9018
#   ✅  Loss:0.5426±0.0168 | Acc:0.8241±0.0078 | F1w:0.8268±0.0075 | F1macro:0.8278±0.0161 | AUROC:0.9618±0.0038 | PRAUC:0.9122±0.0064 | MCC:0.7592
#       ↳ LossGap:+0.0119 (tr 0.5307) | F1macroGap:+0.0101 (tr 0.8379) | Penalty:0.0000 | Selection(loss):0.5426
#
#   ▶ [44/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.5787 | Acc=0.8098 | F1w=0.8124 | F1m=0.8037 | AUROC=0.9558 | PRAUC=0.8959
#     F2 → Loss=0.5632 | Acc=0.8261 | F1w=0.8281 | F1m=0.8277 | AUROC=0.9595 | PRAUC=0.9078
#     F3 → Loss=0.5524 | Acc=0.8280 | F1w=0.8311 | F1m=0.8254 | AUROC=0.9640 | PRAUC=0.9141
#     F4 → Loss=0.5484 | Acc=0.8295 | F1w=0.8319 | F1m=0.8430 | AUROC=0.9626 | PRAUC=0.9147
#     F5 → Loss=0.5951 | Acc=0.8097 | F1w=0.8123 | F1m=0.8140 | AUROC=0.9528 | PRAUC=0.8956
#   ✅  Loss:0.5675±0.0173 | Acc:0.8206±0.0089 | F1w:0.8231±0.0089 | F1macro:0.8228±0.0132 | AUROC:0.9589±0.0042 | PRAUC:0.9056±0.0084 | MCC:0.7548
#       ↳ LossGap:+0.0094 (tr 0.5581) | F1macroGap:+0.0032 (tr 0.8260) | Penalty:0.0000 | Selection(loss):0.5675
#
#   ▶ [45/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.5609 | Acc=0.8079 | F1w=0.8117 | F1m=0.7964 | AUROC=0.9597 | PRAUC=0.9065
#     F2 → Loss=0.5565 | Acc=0.8256 | F1w=0.8278 | F1m=0.8284 | AUROC=0.9607 | PRAUC=0.9109
#     F3 → Loss=0.5403 | Acc=0.8280 | F1w=0.8319 | F1m=0.8274 | AUROC=0.9657 | PRAUC=0.9175
#     F4 → Loss=0.5422 | Acc=0.8314 | F1w=0.8339 | F1m=0.8353 | AUROC=0.9642 | PRAUC=0.9177
#     F5 → Loss=0.5820 | Acc=0.8203 | F1w=0.8231 | F1m=0.8288 | AUROC=0.9550 | PRAUC=0.9013
#   ✅  Loss:0.5563±0.0151 | Acc:0.8227±0.0082 | F1w:0.8257±0.0079 | F1macro:0.8232±0.0137 | AUROC:0.9611±0.0037 | PRAUC:0.9108±0.0063 | MCC:0.7575
#       ↳ LossGap:+0.0108 (tr 0.5455) | F1macroGap:+0.0111 (tr 0.8343) | Penalty:0.0000 | Selection(loss):0.5563
#
#   ▶ [46/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.5842 | Acc=0.8074 | F1w=0.8101 | F1m=0.7948 | AUROC=0.9559 | PRAUC=0.8963
#     F2 → Loss=0.5784 | Acc=0.8213 | F1w=0.8236 | F1m=0.8275 | AUROC=0.9581 | PRAUC=0.9055
#     F3 → Loss=0.5632 | Acc=0.8252 | F1w=0.8282 | F1m=0.8254 | AUROC=0.9638 | PRAUC=0.9137
#     F4 → Loss=0.5733 | Acc=0.8151 | F1w=0.8178 | F1m=0.8171 | AUROC=0.9597 | PRAUC=0.9070
#     F5 → Loss=0.6061 | Acc=0.8097 | F1w=0.8122 | F1m=0.8167 | AUROC=0.9520 | PRAUC=0.8962
#   ✅  Loss:0.5811±0.0143 | Acc:0.8157±0.0067 | F1w:0.8184±0.0068 | F1macro:0.8163±0.0116 | AUROC:0.9579±0.0039 | PRAUC:0.9038±0.0067 | MCC:0.7489
#       ↳ LossGap:+0.0086 (tr 0.5725) | F1macroGap:+0.0070 (tr 0.8233) | Penalty:0.0000 | Selection(loss):0.5811
#
#   ▶ [47/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.5639 | Acc=0.8108 | F1w=0.8140 | F1m=0.8011 | AUROC=0.9594 | PRAUC=0.9060
#     F2 → Loss=0.5549 | Acc=0.8242 | F1w=0.8266 | F1m=0.8300 | AUROC=0.9609 | PRAUC=0.9110
#     F3 → Loss=0.5403 | Acc=0.8271 | F1w=0.8310 | F1m=0.8299 | AUROC=0.9653 | PRAUC=0.9172
#     F4 → Loss=0.5444 | Acc=0.8280 | F1w=0.8306 | F1m=0.8380 | AUROC=0.9629 | PRAUC=0.9150
#     F5 → Loss=0.5845 | Acc=0.8236 | F1w=0.8262 | F1m=0.8304 | AUROC=0.9542 | PRAUC=0.9002
#   ✅  Loss:0.5576±0.0158 | Acc:0.8227±0.0062 | F1w:0.8257±0.0062 | F1macro:0.8259±0.0128 | AUROC:0.9605±0.0038 | PRAUC:0.9099±0.0062 | MCC:0.7576
#       ↳ LossGap:+0.0110 (tr 0.5466) | F1macroGap:+0.0093 (tr 0.8352) | Penalty:0.0000 | Selection(loss):0.5576
#
#   ▶ [48/64] iterations=150 | depth=3 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.5895 | Acc=0.8031 | F1w=0.8065 | F1m=0.7964 | AUROC=0.9554 | PRAUC=0.8965
#     F2 → Loss=0.5767 | Acc=0.8266 | F1w=0.8289 | F1m=0.8304 | AUROC=0.9583 | PRAUC=0.9062
#     F3 → Loss=0.5623 | Acc=0.8261 | F1w=0.8294 | F1m=0.8254 | AUROC=0.9645 | PRAUC=0.9144
#     F4 → Loss=0.5709 | Acc=0.8218 | F1w=0.8243 | F1m=0.8284 | AUROC=0.9605 | PRAUC=0.9079
#     F5 → Loss=0.6119 | Acc=0.8083 | F1w=0.8109 | F1m=0.8111 | AUROC=0.9504 | PRAUC=0.8918
#   ✅  Loss:0.5823±0.0173 | Acc:0.8172±0.0097 | F1w:0.8200±0.0095 | F1macro:0.8183±0.0129 | AUROC:0.9578±0.0047 | PRAUC:0.9034±0.0081 | MCC:0.7512
#       ↳ LossGap:+0.0091 (tr 0.5732) | F1macroGap:+0.0049 (tr 0.8233) | Penalty:0.0000 | Selection(loss):0.5823
#
#   ▶ [49/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.6142 | Acc=0.8002 | F1w=0.8035 | F1m=0.7885 | AUROC=0.9582 | PRAUC=0.9036
#     F2 → Loss=0.6079 | Acc=0.8218 | F1w=0.8239 | F1m=0.8166 | AUROC=0.9604 | PRAUC=0.9106
#     F3 → Loss=0.5881 | Acc=0.8184 | F1w=0.8223 | F1m=0.8144 | AUROC=0.9656 | PRAUC=0.9177
#     F4 → Loss=0.5962 | Acc=0.8223 | F1w=0.8251 | F1m=0.8177 | AUROC=0.9625 | PRAUC=0.9119
#     F5 → Loss=0.6316 | Acc=0.8160 | F1w=0.8189 | F1m=0.8150 | AUROC=0.9544 | PRAUC=0.8995
#   ✅  Loss:0.6076±0.0150 | Acc:0.8157±0.0081 | F1w:0.8187±0.0079 | F1macro:0.8105±0.0110 | AUROC:0.9602±0.0038 | PRAUC:0.9087±0.0064 | MCC:0.7480
#       ↳ LossGap:+0.0078 (tr 0.5998) | F1macroGap:+0.0080 (tr 0.8185) | Penalty:0.0000 | Selection(loss):0.6076
#
#   ▶ [50/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.6736 | Acc=0.7776 | F1w=0.7808 | F1m=0.7661 | AUROC=0.9476 | PRAUC=0.8875
#     F2 → Loss=0.6587 | Acc=0.7949 | F1w=0.7981 | F1m=0.7873 | AUROC=0.9525 | PRAUC=0.8971
#     F3 → Loss=0.6411 | Acc=0.8021 | F1w=0.8051 | F1m=0.7995 | AUROC=0.9585 | PRAUC=0.9042
#     F4 → Loss=0.6470 | Acc=0.7959 | F1w=0.7994 | F1m=0.7955 | AUROC=0.9547 | PRAUC=0.8998
#     F5 → Loss=0.6792 | Acc=0.7919 | F1w=0.7948 | F1m=0.7915 | AUROC=0.9461 | PRAUC=0.8841
#   ✅  Loss:0.6599±0.0147 | Acc:0.7925±0.0081 | F1w:0.7957±0.0081 | F1macro:0.7880±0.0117 | AUROC:0.9519±0.0046 | PRAUC:0.8945±0.0076 | MCC:0.7219
#       ↳ LossGap:+0.0069 (tr 0.6530) | F1macroGap:+0.0052 (tr 0.7932) | Penalty:0.0000 | Selection(loss):0.6599
#
#   ▶ [51/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.6125 | Acc=0.8040 | F1w=0.8074 | F1m=0.7881 | AUROC=0.9583 | PRAUC=0.9043
#     F2 → Loss=0.6040 | Acc=0.8261 | F1w=0.8284 | F1m=0.8161 | AUROC=0.9613 | PRAUC=0.9124
#     F3 → Loss=0.5927 | Acc=0.8204 | F1w=0.8246 | F1m=0.8191 | AUROC=0.9648 | PRAUC=0.9178
#     F4 → Loss=0.5892 | Acc=0.8256 | F1w=0.8281 | F1m=0.8268 | AUROC=0.9644 | PRAUC=0.9167
#     F5 → Loss=0.6293 | Acc=0.8169 | F1w=0.8196 | F1m=0.8128 | AUROC=0.9549 | PRAUC=0.8993
#   ✅  Loss:0.6055±0.0145 | Acc:0.8186±0.0081 | F1w:0.8216±0.0078 | F1macro:0.8126±0.0131 | AUROC:0.9607±0.0037 | PRAUC:0.9101±0.0072 | MCC:0.7521
#       ↳ LossGap:+0.0080 (tr 0.5976) | F1macroGap:+0.0074 (tr 0.8200) | Penalty:0.0000 | Selection(loss):0.6055
#
#   ▶ [52/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.6649 | Acc=0.7805 | F1w=0.7839 | F1m=0.7668 | AUROC=0.9497 | PRAUC=0.8898
#     F2 → Loss=0.6585 | Acc=0.8002 | F1w=0.8032 | F1m=0.7931 | AUROC=0.9516 | PRAUC=0.8961
#     F3 → Loss=0.6388 | Acc=0.8050 | F1w=0.8078 | F1m=0.8002 | AUROC=0.9584 | PRAUC=0.9043
#     F4 → Loss=0.6429 | Acc=0.8021 | F1w=0.8055 | F1m=0.8015 | AUROC=0.9554 | PRAUC=0.9020
#     F5 → Loss=0.6772 | Acc=0.7919 | F1w=0.7948 | F1m=0.7936 | AUROC=0.9457 | PRAUC=0.8831
#   ✅  Loss:0.6565±0.0142 | Acc:0.7959±0.0089 | F1w:0.7990±0.0087 | F1macro:0.7910±0.0126 | AUROC:0.9522±0.0044 | PRAUC:0.8951±0.0078 | MCC:0.7262
#       ↳ LossGap:+0.0061 (tr 0.6503) | F1macroGap:+0.0059 (tr 0.7970) | Penalty:0.0000 | Selection(loss):0.6565
#
#   ▶ [53/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.6304 | Acc=0.7983 | F1w=0.8017 | F1m=0.7810 | AUROC=0.9565 | PRAUC=0.9010
#     F2 → Loss=0.6242 | Acc=0.8252 | F1w=0.8274 | F1m=0.8162 | AUROC=0.9591 | PRAUC=0.9080
#     F3 → Loss=0.6070 | Acc=0.8132 | F1w=0.8169 | F1m=0.8082 | AUROC=0.9639 | PRAUC=0.9143
#     F4 → Loss=0.6159 | Acc=0.8146 | F1w=0.8178 | F1m=0.8110 | AUROC=0.9625 | PRAUC=0.9125
#     F5 → Loss=0.6412 | Acc=0.8140 | F1w=0.8170 | F1m=0.8090 | AUROC=0.9540 | PRAUC=0.8977
#   ✅  Loss:0.6238±0.0118 | Acc:0.8130±0.0086 | F1w:0.8161±0.0082 | F1macro:0.8051±0.0124 | AUROC:0.9592±0.0037 | PRAUC:0.9067±0.0064 | MCC:0.7445
#       ↳ LossGap:+0.0078 (tr 0.6160) | F1macroGap:+0.0079 (tr 0.8130) | Penalty:0.0000 | Selection(loss):0.6238
#
#   ▶ [54/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.6836 | Acc=0.7738 | F1w=0.7773 | F1m=0.7601 | AUROC=0.9471 | PRAUC=0.8879
#     F2 → Loss=0.6768 | Acc=0.7896 | F1w=0.7926 | F1m=0.7826 | AUROC=0.9507 | PRAUC=0.8942
#     F3 → Loss=0.6557 | Acc=0.7949 | F1w=0.7981 | F1m=0.7913 | AUROC=0.9566 | PRAUC=0.8995
#     F4 → Loss=0.6661 | Acc=0.7968 | F1w=0.8003 | F1m=0.7974 | AUROC=0.9519 | PRAUC=0.8950
#     F5 → Loss=0.6926 | Acc=0.7881 | F1w=0.7911 | F1m=0.7879 | AUROC=0.9448 | PRAUC=0.8813
#   ✅  Loss:0.6750±0.0130 | Acc:0.7886±0.0081 | F1w:0.7919±0.0081 | F1macro:0.7839±0.0128 | AUROC:0.9502±0.0041 | PRAUC:0.8916±0.0063 | MCC:0.7161
#       ↳ LossGap:+0.0067 (tr 0.6683) | F1macroGap:+0.0079 (tr 0.7917) | Penalty:0.0000 | Selection(loss):0.6750
#
#   ▶ [55/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.6321 | Acc=0.8021 | F1w=0.8053 | F1m=0.7852 | AUROC=0.9566 | PRAUC=0.9001
#     F2 → Loss=0.6230 | Acc=0.8199 | F1w=0.8222 | F1m=0.8120 | AUROC=0.9597 | PRAUC=0.9099
#     F3 → Loss=0.6140 | Acc=0.8079 | F1w=0.8125 | F1m=0.8009 | AUROC=0.9627 | PRAUC=0.9131
#     F4 → Loss=0.6145 | Acc=0.8160 | F1w=0.8192 | F1m=0.8087 | AUROC=0.9618 | PRAUC=0.9115
#     F5 → Loss=0.6463 | Acc=0.8121 | F1w=0.8150 | F1m=0.8123 | AUROC=0.9531 | PRAUC=0.8972
#   ✅  Loss:0.6260±0.0121 | Acc:0.8116±0.0062 | F1w:0.8148±0.0058 | F1macro:0.8038±0.0101 | AUROC:0.9588±0.0035 | PRAUC:0.9064±0.0064 | MCC:0.7436
#       ↳ LossGap:+0.0085 (tr 0.6175) | F1macroGap:+0.0084 (tr 0.8123) | Penalty:0.0000 | Selection(loss):0.6260
#
#   ▶ [56/64] iterations=150 | depth=4 | learning_rate=0.05 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.6868 | Acc=0.7743 | F1w=0.7770 | F1m=0.7635 | AUROC=0.9455 | PRAUC=0.8827
#     F2 → Loss=0.6701 | Acc=0.7911 | F1w=0.7939 | F1m=0.7852 | AUROC=0.9507 | PRAUC=0.8954
#     F3 → Loss=0.6563 | Acc=0.7935 | F1w=0.7964 | F1m=0.7883 | AUROC=0.9559 | PRAUC=0.8989
#     F4 → Loss=0.6659 | Acc=0.7939 | F1w=0.7975 | F1m=0.7925 | AUROC=0.9522 | PRAUC=0.8943
#     F5 → Loss=0.6908 | Acc=0.7895 | F1w=0.7927 | F1m=0.7949 | AUROC=0.9443 | PRAUC=0.8806
#   ✅  Loss:0.6740±0.0129 | Acc:0.7885±0.0073 | F1w:0.7915±0.0074 | F1macro:0.7849±0.0112 | AUROC:0.9497±0.0043 | PRAUC:0.8904±0.0073 | MCC:0.7165
#       ↳ LossGap:+0.0083 (tr 0.6657) | F1macroGap:+0.0069 (tr 0.7918) | Penalty:0.0000 | Selection(loss):0.6740
#
#   ▶ [57/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.4532 | Acc=0.8434 | F1w=0.8457 | F1m=0.8466 | AUROC=0.9693 | PRAUC=0.9263
#     F2 → Loss=0.4497 | Acc=0.8511 | F1w=0.8531 | F1m=0.8582 | AUROC=0.9704 | PRAUC=0.9305
#     F3 → Loss=0.4279 | Acc=0.8468 | F1w=0.8495 | F1m=0.8512 | AUROC=0.9740 | PRAUC=0.9344
#     F4 → Loss=0.4321 | Acc=0.8444 | F1w=0.8466 | F1m=0.8585 | AUROC=0.9727 | PRAUC=0.9361
#     F5 → Loss=0.4848 | Acc=0.8419 | F1w=0.8438 | F1m=0.8540 | AUROC=0.9633 | PRAUC=0.9178
#   ✅  Loss:0.4496±0.0201 | Acc:0.8455±0.0032 | F1w:0.8478±0.0033 | F1macro:0.8537±0.0045 | AUROC:0.9699±0.0037 | PRAUC:0.9290±0.0066 | MCC:0.7873
#       ↳ LossGap:+0.0134 (tr 0.4361) | F1macroGap:+0.0065 (tr 0.8602) | Penalty:0.0000 | Selection(loss):0.4496
#
#   ▶ [58/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.4798 | Acc=0.8381 | F1w=0.8401 | F1m=0.8402 | AUROC=0.9654 | PRAUC=0.9176
#     F2 → Loss=0.4717 | Acc=0.8473 | F1w=0.8492 | F1m=0.8575 | AUROC=0.9679 | PRAUC=0.9250
#     F3 → Loss=0.4489 | Acc=0.8506 | F1w=0.8532 | F1m=0.8572 | AUROC=0.9731 | PRAUC=0.9339
#     F4 → Loss=0.4610 | Acc=0.8420 | F1w=0.8444 | F1m=0.8605 | AUROC=0.9697 | PRAUC=0.9287
#     F5 → Loss=0.5028 | Acc=0.8357 | F1w=0.8379 | F1m=0.8461 | AUROC=0.9619 | PRAUC=0.9137
#   ✅  Loss:0.4728±0.0182 | Acc:0.8427±0.0056 | F1w:0.8450±0.0056 | F1macro:0.8523±0.0078 | AUROC:0.9676±0.0038 | PRAUC:0.9238±0.0073 | MCC:0.7842
#       ↳ LossGap:+0.0100 (tr 0.4628) | F1macroGap:+0.0061 (tr 0.8585) | Penalty:0.0000 | Selection(loss):0.4728
#
#   ▶ [59/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.4525 | Acc=0.8458 | F1w=0.8479 | F1m=0.8498 | AUROC=0.9695 | PRAUC=0.9280
#     F2 → Loss=0.4511 | Acc=0.8497 | F1w=0.8516 | F1m=0.8596 | AUROC=0.9699 | PRAUC=0.9284
#     F3 → Loss=0.4306 | Acc=0.8516 | F1w=0.8542 | F1m=0.8539 | AUROC=0.9742 | PRAUC=0.9351
#     F4 → Loss=0.4354 | Acc=0.8453 | F1w=0.8476 | F1m=0.8584 | AUROC=0.9727 | PRAUC=0.9357
#     F5 → Loss=0.4795 | Acc=0.8448 | F1w=0.8472 | F1m=0.8497 | AUROC=0.9641 | PRAUC=0.9192
#   ✅  Loss:0.4498±0.0171 | Acc:0.8474±0.0027 | F1w:0.8497±0.0028 | F1macro:0.8543±0.0042 | AUROC:0.9701±0.0035 | PRAUC:0.9293±0.0060 | MCC:0.7899
#       ↳ LossGap:+0.0132 (tr 0.4366) | F1macroGap:+0.0067 (tr 0.8610) | Penalty:0.0000 | Selection(loss):0.4498
#
#   ▶ [60/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.4753 | Acc=0.8343 | F1w=0.8366 | F1m=0.8320 | AUROC=0.9664 | PRAUC=0.9217
#     F2 → Loss=0.4702 | Acc=0.8468 | F1w=0.8486 | F1m=0.8576 | AUROC=0.9685 | PRAUC=0.9267
#     F3 → Loss=0.4535 | Acc=0.8511 | F1w=0.8535 | F1m=0.8587 | AUROC=0.9720 | PRAUC=0.9326
#     F4 → Loss=0.4646 | Acc=0.8429 | F1w=0.8453 | F1m=0.8573 | AUROC=0.9691 | PRAUC=0.9279
#     F5 → Loss=0.5009 | Acc=0.8376 | F1w=0.8396 | F1m=0.8478 | AUROC=0.9627 | PRAUC=0.9169
#   ✅  Loss:0.4729±0.0157 | Acc:0.8425±0.0061 | F1w:0.8447±0.0061 | F1macro:0.8507±0.0101 | AUROC:0.9677±0.0031 | PRAUC:0.9252±0.0054 | MCC:0.7835
#       ↳ LossGap:+0.0116 (tr 0.4613) | F1macroGap:+0.0068 (tr 0.8575) | Penalty:0.0000 | Selection(loss):0.4729
#
#   ▶ [61/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=1
#     F1 → Loss=0.4690 | Acc=0.8401 | F1w=0.8420 | F1m=0.8452 | AUROC=0.9681 | PRAUC=0.9239
#     F2 → Loss=0.4636 | Acc=0.8458 | F1w=0.8479 | F1m=0.8579 | AUROC=0.9691 | PRAUC=0.9279
#     F3 → Loss=0.4491 | Acc=0.8482 | F1w=0.8510 | F1m=0.8500 | AUROC=0.9723 | PRAUC=0.9319
#     F4 → Loss=0.4517 | Acc=0.8396 | F1w=0.8420 | F1m=0.8511 | AUROC=0.9709 | PRAUC=0.9304
#     F5 → Loss=0.4986 | Acc=0.8390 | F1w=0.8415 | F1m=0.8457 | AUROC=0.9624 | PRAUC=0.9154
#   ✅  Loss:0.4664±0.0177 | Acc:0.8425±0.0038 | F1w:0.8449±0.0039 | F1macro:0.8500±0.0046 | AUROC:0.9686±0.0034 | PRAUC:0.9259±0.0059 | MCC:0.7832
#       ↳ LossGap:+0.0127 (tr 0.4537) | F1macroGap:+0.0068 (tr 0.8568) | Penalty:0.0000 | Selection(loss):0.4664
#
#   ▶ [62/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=0.5 | random_strength=5
#     F1 → Loss=0.4939 | Acc=0.8314 | F1w=0.8340 | F1m=0.8280 | AUROC=0.9652 | PRAUC=0.9189
#     F2 → Loss=0.4919 | Acc=0.8415 | F1w=0.8436 | F1m=0.8543 | AUROC=0.9660 | PRAUC=0.9218
#     F3 → Loss=0.4633 | Acc=0.8501 | F1w=0.8525 | F1m=0.8549 | AUROC=0.9726 | PRAUC=0.9323
#     F4 → Loss=0.4790 | Acc=0.8396 | F1w=0.8421 | F1m=0.8538 | AUROC=0.9687 | PRAUC=0.9259
#     F5 → Loss=0.5237 | Acc=0.8318 | F1w=0.8343 | F1m=0.8422 | AUROC=0.9595 | PRAUC=0.9091
#   ✅  Loss:0.4904±0.0199 | Acc:0.8389±0.0069 | F1w:0.8413±0.0068 | F1macro:0.8466±0.0104 | AUROC:0.9664±0.0043 | PRAUC:0.9216±0.0077 | MCC:0.7795
#       ↳ LossGap:+0.0100 (tr 0.4804) | F1macroGap:+0.0072 (tr 0.8538) | Penalty:0.0000 | Selection(loss):0.4904
#
#   ▶ [63/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=1
#     F1 → Loss=0.4635 | Acc=0.8415 | F1w=0.8439 | F1m=0.8424 | AUROC=0.9693 | PRAUC=0.9265
#     F2 → Loss=0.4699 | Acc=0.8521 | F1w=0.8543 | F1m=0.8624 | AUROC=0.9676 | PRAUC=0.9251
#     F3 → Loss=0.4464 | Acc=0.8506 | F1w=0.8536 | F1m=0.8556 | AUROC=0.9731 | PRAUC=0.9344
#     F4 → Loss=0.4578 | Acc=0.8444 | F1w=0.8465 | F1m=0.8586 | AUROC=0.9709 | PRAUC=0.9320
#     F5 → Loss=0.4954 | Acc=0.8409 | F1w=0.8430 | F1m=0.8467 | AUROC=0.9627 | PRAUC=0.9152
#   ✅  Loss:0.4666±0.0163 | Acc:0.8459±0.0046 | F1w:0.8483±0.0048 | F1macro:0.8531±0.0075 | AUROC:0.9687±0.0035 | PRAUC:0.9266±0.0067 | MCC:0.7881
#       ↳ LossGap:+0.0121 (tr 0.4545) | F1macroGap:+0.0044 (tr 0.8575) | Penalty:0.0000 | Selection(loss):0.4666
#
#   ▶ [64/64] iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=7 | bagging_temperature=1 | random_strength=5
#     F1 → Loss=0.4957 | Acc=0.8314 | F1w=0.8337 | F1m=0.8301 | AUROC=0.9645 | PRAUC=0.9180
#     F2 → Loss=0.4889 | Acc=0.8425 | F1w=0.8445 | F1m=0.8540 | AUROC=0.9666 | PRAUC=0.9234
#     F3 → Loss=0.4644 | Acc=0.8473 | F1w=0.8500 | F1m=0.8512 | AUROC=0.9717 | PRAUC=0.9315
#     F4 → Loss=0.4758 | Acc=0.8405 | F1w=0.8431 | F1m=0.8578 | AUROC=0.9692 | PRAUC=0.9285
#     F5 → Loss=0.5161 | Acc=0.8333 | F1w=0.8355 | F1m=0.8432 | AUROC=0.9611 | PRAUC=0.9137
#   ✅  Loss:0.4882±0.0176 | Acc:0.8390±0.0059 | F1w:0.8413±0.0060 | F1macro:0.8473±0.0098 | AUROC:0.9666±0.0037 | PRAUC:0.9230±0.0066 | MCC:0.7794
#       ↳ LossGap:+0.0106 (tr 0.4775) | F1macroGap:+0.0059 (tr 0.8532) | Penalty:0.0000 | Selection(loss):0.4882
#
# 🏆 Best config : iterations=150 | depth=4 | learning_rate=0.1 | l2_leaf_reg=3 | bagging_temperature=0.5 | random_strength=1  (min penalized log-loss)
#    Log-loss    : 0.4496±0.0201 (Acc=0.8455±0.0032 | F1w=0.8478±0.0033 | F1macro=0.8537±0.0045 | AUROC=0.9699±0.0037 | PRAUC=0.9290±0.0066)
#    Selection   : 0.4496 (LossGap=+0.0134 | F1macroGap=+0.0065)

# %%
import pandas as pd
df = pd.DataFrame(results)
filename = CSV_DIR / "catboost_hpo.csv"
df.to_csv(filename, index=False)
log(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\csv\classical\catboost_hpo.csv

# %%
# 📈 Best-param fit diagnostic (overfit / underfit / generalized)
fit_info = plot_fit_diagnostic(
    build_estimator, best_result['params'],
    name="catboost", title="CatBoost", normalize_proba=NORMALIZE_PROBA,
    fit_kwargs_fn=fit_kwargs_fn,
)
# Out:
# 📈 Fit diagnostic [CatBoost] → Generalized (train acc=0.8518 | val acc=0.8455 | gap=+0.0063)
# 🖼️  Figure: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\figures\classical\catboost_fit.png

# %%
best_result['model'] = "CatBoost"
save_best("catboost", "CatBoost", best_result, extra={'variant': 'catboost', **fit_info})
log(f"✅ [CatBoost] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# 💾 Best saved: c:\`Bioinformatics\quantum-gesang\quantum-multiclass-classification\notebooks\hpo\results\best\catboost.json
# ✅ [CatBoost] recorded | Exec. time: 11.4s
