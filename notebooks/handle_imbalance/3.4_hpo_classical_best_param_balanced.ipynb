# %%
# !python -m pip install numpy pandas \
    qiskit-aer qiskit-algorithms qiskit-machine-learning qiskit-ibm-runtime \
    pylatexenc ucimlrepo \
    xgboost catboost seaborn libsvm-official \
    jinja2 \
    scikit-optimize
# Out:
# Requirement already satisfied: numpy in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (2.4.4)
# Requirement already satisfied: pandas in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.0.2)
# Requirement already satisfied: qiskit-aer in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.17.2)
# Requirement already satisfied: qiskit-algorithms in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.4.0)
# Requirement already satisfied: qiskit-machine-learning in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.9.0)
# Requirement already satisfied: qiskit-ibm-runtime in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.46.1)
# Requirement already satisfied: pylatexenc in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (2.10)
# Requirement already satisfied: ucimlrepo in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.0.7)
# Requirement already satisfied: xgboost in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.2.0)
# Requirement already satisfied: catboost in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (1.2.10)
# Requirement already satisfied: seaborn in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.13.2)
# Requirement already satisfied: libsvm-official in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.37.0)
# Requirement already satisfied: jinja2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (3.1.6)
# Requirement already satisfied: scikit-optimize in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (0.10.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: qiskit>=1.1.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-aer) (2.3.1)
# Requirement already satisfied: scipy>=1.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-aer) (1.17.1)
# Requirement already satisfied: psutil>=5 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: scikit-learn>=1.2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-machine-learning) (1.8.0)
# Requirement already satisfied: setuptools>=40.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-machine-learning) (82.0.1)
# Requirement already satisfied: dill>=0.3.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-machine-learning) (0.4.1)
# Requirement already satisfied: requests>=2.32.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (2.33.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: urllib3>=2.4.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: ibm-platform-services>=0.55.3 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (0.75.0)
# Requirement already satisfied: ibm-quantum-schemas>=0.5.20260320 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (0.6.20260414)
# Requirement already satisfied: pydantic>=2.7.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (2.13.0)
# Requirement already satisfied: packaging in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (26.1)
# Requirement already satisfied: pybase64>=1.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (1.4.3)
# Requirement already satisfied: samplomatic>=0.13.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit-ibm-runtime) (0.18.0)
# Requirement already satisfied: certifi>=2020.12.5 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from ucimlrepo) (2026.2.25)
# Requirement already satisfied: graphviz in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (3.10.8)
# Requirement already satisfied: plotly in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (6.7.0)
# Requirement already satisfied: six in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from jinja2) (3.0.3)
# Requirement already satisfied: joblib>=0.11 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from scikit-optimize) (1.5.3)
# Requirement already satisfied: pyaml>=16.9 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from scikit-optimize) (26.2.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (2.12.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (2.46.0)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: PyYAML in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pyaml>=16.9->scikit-optimize) (6.0.3)
# Requirement already satisfied: cryptography>=1.3 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.7)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Requirement already satisfied: sspilib>=0.3.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.5.0)
# Requirement already satisfied: orjson>=3.9.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from samplomatic>=0.13.0->qiskit-ibm-runtime) (3.11.8)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\`bioinformatics\quantum-gesang\codes\.quantum\lib\site-packages (from plotly->catboost) (2.19.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import os

cwd = os.path.abspath(os.getcwd())
project_root = cwd.split("codes")[0] + "codes"

sys.path.append(os.path.abspath(project_root))

from utils.prepare_data import prepare_data

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import warnings
from qiskit.transpiler import generate_preset_pass_manager
warnings.filterwarnings('ignore')

# %%
import sys
import importlib

def reload_package(package_name):
    modules_to_reload = [
        name for name in sys.modules
        if name.startswith(package_name)
    ]

    for name in sorted(modules_to_reload, reverse=True):
        importlib.reload(sys.modules[name])

# Usage
reload_package("model")
reload_package("utils")

# %%
dataset_path = os.path.join(project_root, "dataset", "Dataset_TehHijau.csv")
feature_cols = [
        "MQ3", 
        "TGS822", 
        "TGS2602", 
        "MQ5", 
        "MQ138", 
        "TGS2620", 
        "TGS813", 
        "TGS2600", 
        "TGS2611", 
        "TGS2603",
        "Humidity",
        "Celsius",
    ]
target_cols = "Kategori"

quantum_kernel_types = [
    # 'full', 
    'linear', 
    # 'circular', 
    # 'pauli_x', 
    # 'pauli_y', 
    # 'pauli_z'
]
kernel_types = [
    'linear', 
    # 'poly', 
    # 'rbf', 
    # 'sigmoid'
]

# %%
import pandas as pd
data = pd.read_csv(dataset_path)
data.head(10)
# Out:
#     MQ3  TGS822  TGS2602    MQ5  MQ138  TGS2620  TGS813  TGS2600  TGS2611  \
# 0  90.0    43.0     46.0  133.0   97.0     46.0   552.0    289.0    546.0
# 1  90.0    42.0     47.0  133.0   96.0     47.0   551.0    290.0    547.0
# 2  89.0    42.0     47.0  133.0   97.0     45.0   553.0    291.0    547.0
# 3  89.0    41.0     47.0  133.0   96.0     45.0   552.0    290.0    546.0
# 4  90.0    42.0     48.0  132.0   95.0     46.0   552.0    289.0    546.0
# 5  90.0    42.0     46.0  132.0   96.0     45.0   552.0    289.0    545.0
# 6  89.0    43.0     46.0  133.0   96.0     45.0   552.0    291.0    546.0
# 7  90.0    42.0     46.0  132.0   96.0     46.0   551.0    290.0    547.0
# 8  90.0    41.0     47.0  132.0   97.0     46.0   550.0    290.0    548.0
# 9  90.0    41.0     48.0  132.0   95.0     46.0   551.0    289.0    547.0
#
#    TGS2603  Humidity  Celsius Chop_ID Sampling_ID  Aroma  Taste  Color  \
# 0    371.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 1    371.0      46.5     38.9   TR612     TR612_1    2.9     36    3.2
# 2    369.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 3    370.0      46.4     38.9   TR612     TR612_1    2.9     36    3.2
# 4    371.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 5    370.0      46.5     38.8   TR612     TR612_1    2.9     36    3.2
# 6    369.0      46.4     38.8   TR612     TR612_1    2.9     36    3.2
# 7    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 8    370.0      46.5     38.7   TR612     TR612_1    2.9     36    3.2
# 9    371.0      46.3     38.7   TR612     TR612_1    2.9     36    3.2
#
#    Appearance  Dreg Kategori Standar Kualitas  MQ3_mean  MQ3_min  MQ3_max  \
# 0         2.8   3.2        D             Baik      89.7     89.0       90
# 1         2.8   3.2        D             Baik      89.7     89.0       90
# 2         2.8   3.2        D             Baik      89.7     89.0       90
# 3         2.8   3.2        D             Baik      89.7     89.0       90
# 4         2.8   3.2        D             Baik      89.7     89.0       90
# 5         2.8   3.2        D             Baik      89.7     89.0       90
# 6         2.8   3.2        D             Baik      89.7     89.0       90
# 7         2.8   3.2        D             Baik      89.7     89.0       90
# 8         2.8   3.2        D             Baik      89.7     89.0       90
# 9         2.8   3.2        D             Baik      89.7     89.0       90
#
#     MQ3_std  MQ3_skew  MQ3_kurtosis  MQ3_auc  TGS822_mean  TGS822_min  \
# 0  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 1  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 2  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 3  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 4  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 5  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 6  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 7  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 8  0.483046 -0.872872     -1.238095    807.0         41.9          41
# 9  0.483046 -0.872872     -1.238095    807.0         41.9          41
#
#    TGS822_max  TGS822_std  TGS822_skew  TGS822_kurtosis  TGS822_auc  \
# 0          43    0.737865     0.139942        -0.960433       377.0
# 1          43    0.737865     0.139942        -0.960433       377.0
# 2          43    0.737865     0.139942        -0.960433       377.0
# 3          43    0.737865     0.139942        -0.960433       377.0
# 4          43    0.737865     0.139942        -0.960433       377.0
# 5          43    0.737865     0.139942        -0.960433       377.0
# 6          43    0.737865     0.139942        -0.960433       377.0
# 7          43    0.737865     0.139942        -0.960433       377.0
# 8          43    0.737865     0.139942        -0.960433       377.0
# 9          43    0.737865     0.139942        -0.960433       377.0
#
#    TGS2602_mean  TGS2602_min  TGS2602_max  TGS2602_std  TGS2602_skew  \
# 0          46.8           46           48     0.788811      0.343622
# 1          46.8           46           48     0.788811      0.343622
# 2          46.8           46           48     0.788811      0.343622
# 3          46.8           46           48     0.788811      0.343622
# 4          46.8           46           48     0.788811      0.343622
# 5          46.8           46           48     0.788811      0.343622
# 6          46.8           46           48     0.788811      0.343622
# 7          46.8           46           48     0.788811      0.343622
# 8          46.8           46           48     0.788811      0.343622
# 9          46.8           46           48     0.788811      0.343622
#
#    TGS2602_kurtosis  TGS2602_auc  MQ5_mean  MQ5_min  MQ5_max   MQ5_std  \
# 0         -1.153061        421.0     132.5      132    133.0  0.527046
# 1         -1.153061        421.0     132.5      132    133.0  0.527046
# 2         -1.153061        421.0     132.5      132    133.0  0.527046
# 3         -1.153061        421.0     132.5      132    133.0  0.527046
# 4         -1.153061        421.0     132.5      132    133.0  0.527046
# 5         -1.153061        421.0     132.5      132    133.0  0.527046
# 6         -1.153061        421.0     132.5      132    133.0  0.527046
# 7         -1.153061        421.0     132.5      132    133.0  0.527046
# 8         -1.153061        421.0     132.5      132    133.0  0.527046
# 9         -1.153061        421.0     132.5      132    133.0  0.527046
#
#    MQ5_skew  MQ5_kurtosis  MQ5_auc  MQ138_mean  MQ138_min  MQ138_max  \
# 0       0.0          -2.0   1192.5        96.1         95         97
# 1       0.0          -2.0   1192.5        96.1         95         97
# 2       0.0          -2.0   1192.5        96.1         95         97
# 3       0.0          -2.0   1192.5        96.1         95         97
# 4       0.0          -2.0   1192.5        96.1         95         97
# 5       0.0          -2.0   1192.5        96.1         95         97
# 6       0.0          -2.0   1192.5        96.1         95         97
# 7       0.0          -2.0   1192.5        96.1         95         97
# 8       0.0          -2.0   1192.5        96.1         95         97
# 9       0.0          -2.0   1192.5        96.1         95         97
#
#    MQ138_std  MQ138_skew  MQ138_kurtosis  MQ138_auc  TGS2620_mean  \
# 0   0.737865   -0.139942       -0.960433      865.0          45.7
# 1   0.737865   -0.139942       -0.960433      865.0          45.7
# 2   0.737865   -0.139942       -0.960433      865.0          45.7
# 3   0.737865   -0.139942       -0.960433      865.0          45.7
# 4   0.737865   -0.139942       -0.960433      865.0          45.7
# 5   0.737865   -0.139942       -0.960433      865.0          45.7
# 6   0.737865   -0.139942       -0.960433      865.0          45.7
# 7   0.737865   -0.139942       -0.960433      865.0          45.7
# 8   0.737865   -0.139942       -0.960433      865.0          45.7
# 9   0.737865   -0.139942       -0.960433      865.0          45.7
#
#    TGS2620_min  TGS2620_max  TGS2620_std  TGS2620_skew  TGS2620_kurtosis  \
# 0           45           47     0.674949      0.365675         -0.705532
# 1           45           47     0.674949      0.365675         -0.705532
# 2           45           47     0.674949      0.365675         -0.705532
# 3           45           47     0.674949      0.365675         -0.705532
# 4           45           47     0.674949      0.365675         -0.705532
# 5           45           47     0.674949      0.365675         -0.705532
# 6           45           47     0.674949      0.365675         -0.705532
# 7           45           47     0.674949      0.365675         -0.705532
# 8           45           47     0.674949      0.365675         -0.705532
# 9           45           47     0.674949      0.365675         -0.705532
#
#    TGS2620_auc  TGS813_mean  TGS813_min  TGS813_max  TGS813_std  TGS813_skew  \
# 0        411.0        551.6         550         553    0.843274    -0.328125
# 1        411.0        551.6         550         553    0.843274    -0.328125
# 2        411.0        551.6         550         553    0.843274    -0.328125
# 3        411.0        551.6         550         553    0.843274    -0.328125
# 4        411.0        551.6         550         553    0.843274    -0.328125
# 5        411.0        551.6         550         553    0.843274    -0.328125
# 6        411.0        551.6         550         553    0.843274    -0.328125
# 7        411.0        551.6         550         553    0.843274    -0.328125
# 8        411.0        551.6         550         553    0.843274    -0.328125
# 9        411.0        551.6         550         553    0.843274    -0.328125
#
#    TGS813_kurtosis  TGS813_auc  TGS2600_mean  TGS2600_min  TGS2600_max  \
# 0        -0.335937      4964.5         289.8        289.0          291
# 1        -0.335937      4964.5         289.8        289.0          291
# 2        -0.335937      4964.5         289.8        289.0          291
# 3        -0.335937      4964.5         289.8        289.0          291
# 4        -0.335937      4964.5         289.8        289.0          291
# 5        -0.335937      4964.5         289.8        289.0          291
# 6        -0.335937      4964.5         289.8        289.0          291
# 7        -0.335937      4964.5         289.8        289.0          291
# 8        -0.335937      4964.5         289.8        289.0          291
# 9        -0.335937      4964.5         289.8        289.0          291
#
#    TGS2600_std  TGS2600_skew  TGS2600_kurtosis  TGS2600_auc  TGS2611_mean  \
# 0     0.788811      0.343622         -1.153061       2609.0         546.5
# 1     0.788811      0.343622         -1.153061       2609.0         546.5
# 2     0.788811      0.343622         -1.153061       2609.0         546.5
# 3     0.788811      0.343622         -1.153061       2609.0         546.5
# 4     0.788811      0.343622         -1.153061       2609.0         546.5
# 5     0.788811      0.343622         -1.153061       2609.0         546.5
# 6     0.788811      0.343622         -1.153061       2609.0         546.5
# 7     0.788811      0.343622         -1.153061       2609.0         546.5
# 8     0.788811      0.343622         -1.153061       2609.0         546.5
# 9     0.788811      0.343622         -1.153061       2609.0         546.5
#
#    TGS2611_min  TGS2611_max  TGS2611_std  TGS2611_skew  TGS2611_kurtosis  \
# 0          545          548     0.849837           0.0         -0.485207
# 1          545          548     0.849837           0.0         -0.485207
# 2          545          548     0.849837           0.0         -0.485207
# 3          545          548     0.849837           0.0         -0.485207
# 4          545          548     0.849837           0.0         -0.485207
# 5          545          548     0.849837           0.0         -0.485207
# 6          545          548     0.849837           0.0         -0.485207
# 7          545          548     0.849837           0.0         -0.485207
# 8          545          548     0.849837           0.0         -0.485207
# 9          545          548     0.849837           0.0         -0.485207
#
#    TGS2611_auc  TGS2603_mean  TGS2603_min  TGS2603_max  TGS2603_std  \
# 0       4918.5         370.2          369          371     0.788811
# 1       4918.5         370.2          369          371     0.788811
# 2       4918.5         370.2          369          371     0.788811
# 3       4918.5         370.2          369          371     0.788811
# 4       4918.5         370.2          369          371     0.788811
# 5       4918.5         370.2          369          371     0.788811
# 6       4918.5         370.2          369          371     0.788811
# 7       4918.5         370.2          369          371     0.788811
# 8       4918.5         370.2          369          371     0.788811
# 9       4918.5         370.2          369          371     0.788811
#
#    TGS2603_skew  TGS2603_kurtosis  TGS2603_auc  Humidity_mean  Humidity_min  \
# 0     -0.343622         -1.153061       3331.0          46.43          46.3
# 1     -0.343622         -1.153061       3331.0          46.43          46.3
# 2     -0.343622         -1.153061       3331.0          46.43          46.3
# 3     -0.343622         -1.153061       3331.0          46.43          46.3
# 4     -0.343622         -1.153061       3331.0          46.43          46.3
# 5     -0.343622         -1.153061       3331.0          46.43          46.3
# 6     -0.343622         -1.153061       3331.0          46.43          46.3
# 7     -0.343622         -1.153061       3331.0          46.43          46.3
# 8     -0.343622         -1.153061       3331.0          46.43          46.3
# 9     -0.343622         -1.153061       3331.0          46.43          46.3
#
#    Humidity_max  Humidity_std  Humidity_skew  Humidity_kurtosis  Humidity_auc  \
# 0          46.5      0.067495      -0.365675          -0.705532        417.95
# 1          46.5      0.067495      -0.365675          -0.705532        417.95
# 2          46.5      0.067495      -0.365675          -0.705532        417.95
# 3          46.5      0.067495      -0.365675          -0.705532        417.95
# 4          46.5      0.067495      -0.365675          -0.705532        417.95
# 5          46.5      0.067495      -0.365675          -0.705532        417.95
# 6          46.5      0.067495      -0.365675          -0.705532        417.95
# 7          46.5      0.067495      -0.365675          -0.705532        417.95
# 8          46.5      0.067495      -0.365675          -0.705532        417.95
# 9          46.5      0.067495      -0.365675          -0.705532        417.95
#
#    Celsius_mean  Celsius_min  Celsius_max  Celsius_std  Celsius_skew  \
# 0         38.81         38.7         38.9      0.08756      -0.18843
# 1         38.81         38.7         38.9      0.08756      -0.18843
# 2         38.81         38.7         38.9      0.08756      -0.18843
# 3         38.81         38.7         38.9      0.08756      -0.18843
# 4         38.81         38.7         38.9      0.08756      -0.18843
# 5         38.81         38.7         38.9      0.08756      -0.18843
# 6         38.81         38.7         38.9      0.08756      -0.18843
# 7         38.81         38.7         38.9      0.08756      -0.18843
# 8         38.81         38.7         38.9      0.08756      -0.18843
# 9         38.81         38.7         38.9      0.08756      -0.18843
#
#    Celsius_kurtosis  Celsius_auc  Aroma_mean  Aroma_min  Aroma_max  \
# 0          -1.52615        349.3         2.9        2.9        2.9
# 1          -1.52615        349.3         2.9        2.9        2.9
# 2          -1.52615        349.3         2.9        2.9        2.9
# 3          -1.52615        349.3         2.9        2.9        2.9
# 4          -1.52615        349.3         2.9        2.9        2.9
# 5          -1.52615        349.3         2.9        2.9        2.9
# 6          -1.52615        349.3         2.9        2.9        2.9
# 7          -1.52615        349.3         2.9        2.9        2.9
# 8          -1.52615        349.3         2.9        2.9        2.9
# 9          -1.52615        349.3         2.9        2.9        2.9
#
#       Aroma_std  Aroma_auc  Taste_mean  Taste_min  Taste_max  Taste_std  \
# 0  4.681111e-16       26.1          36         36         36          0
# 1  4.681111e-16       26.1          36         36         36          0
# 2  4.681111e-16       26.1          36         36         36          0
# 3  4.681111e-16       26.1          36         36         36          0
# 4  4.681111e-16       26.1          36         36         36          0
# 5  4.681111e-16       26.1          36         36         36          0
# 6  4.681111e-16       26.1          36         36         36          0
# 7  4.681111e-16       26.1          36         36         36          0
# 8  4.681111e-16       26.1          36         36         36          0
# 9  4.681111e-16       26.1          36         36         36          0
#
#    Taste_auc  Color_mean  Color_min  Color_max     Color_std  Color_auc  \
# 0        324         3.2        3.2        3.2  4.681111e-16       28.8
# 1        324         3.2        3.2        3.2  4.681111e-16       28.8
# 2        324         3.2        3.2        3.2  4.681111e-16       28.8
# 3        324         3.2        3.2        3.2  4.681111e-16       28.8
# 4        324         3.2        3.2        3.2  4.681111e-16       28.8
# 5        324         3.2        3.2        3.2  4.681111e-16       28.8
# 6        324         3.2        3.2        3.2  4.681111e-16       28.8
# 7        324         3.2        3.2        3.2  4.681111e-16       28.8
# 8        324         3.2        3.2        3.2  4.681111e-16       28.8
# 9        324         3.2        3.2        3.2  4.681111e-16       28.8
#
#    Appearance_mean  Appearance_min  Appearance_max  Appearance_std  \
# 0              2.8             2.8             2.8    4.681111e-16
# 1              2.8             2.8             2.8    4.681111e-16
# 2              2.8             2.8             2.8    4.681111e-16
# 3              2.8             2.8             2.8    4.681111e-16
# 4              2.8             2.8             2.8    4.681111e-16
# 5              2.8             2.8             2.8    4.681111e-16
# 6              2.8             2.8             2.8    4.681111e-16
# 7              2.8             2.8             2.8    4.681111e-16
# 8              2.8             2.8             2.8    4.681111e-16
# 9              2.8             2.8             2.8    4.681111e-16
#
#    Appearance_auc  Dreg_mean  Dreg_min  Dreg_max      Dreg_std  Dreg_auc
# 0            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 1            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 2            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 3            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 4            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 5            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 6            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 7            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 8            25.2        3.2       3.2       3.2  4.681111e-16      28.8
# 9            25.2        3.2       3.2       3.2  4.681111e-16      28.8

# %%
data.describe()
# Out:
#                 MQ3        TGS822       TGS2602           MQ5         MQ138  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      89.414833     47.600730     47.936209     98.291575     89.182246
# std        3.669168      4.678116      4.616558     15.849443      4.209028
# min       80.000000     37.000000     36.000000     64.000000     78.000000
# 25%       87.000000     45.000000     45.000000     88.000000     86.000000
# 50%       89.000000     47.000000     47.000000     96.000000     89.000000
# 75%       91.000000     50.000000     50.000000    109.000000     92.000000
# max      101.000000     64.000000     64.000000    188.000000    103.000000
#
#             TGS2620        TGS813       TGS2600       TGS2611       TGS2603  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      51.548756    533.670093    213.738592    531.124604    330.500336
# std        4.967588      7.007443     24.613671      5.552207     12.907070
# min       39.000000    514.000000    186.000000    518.000000    303.000000
# 25%       49.000000    529.000000    198.000000    527.000000    322.000000
# 50%       51.000000    532.000000    206.000000    530.000000    329.000000
# 75%       54.000000    536.000000    215.000000    533.000000    335.000000
# max       80.000000    554.000000    304.000000    548.000000    371.000000
#
#            Humidity       Celsius         Aroma         Taste         Color  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      48.387732     39.656701      2.935143     34.888942      3.035383
# std        3.126527      1.312791      0.257778      1.732650      0.255256
# min       39.200000     36.000000      2.400000     31.000000      2.400000
# 25%       46.300000     38.900000      2.800000     33.000000      2.800000
# 50%       48.500000     39.600000      2.900000     35.000000      3.000000
# 75%       50.400000     40.600000      3.100000     36.000000      3.200000
# max       60.200000     43.600000      3.800000     38.000000      3.700000
#
#          Appearance          Dreg      MQ3_mean       MQ3_min       MQ3_max  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean       3.135306      3.071880     89.401187     88.072610     90.838121
# std        0.270518      0.307778      4.282145      7.651619     21.264395
# min        2.800000      2.400000     72.380000      0.000000     82.000000
# 25%        2.900000      2.800000     87.100000     86.000000     88.000000
# 50%        3.100000      3.000000     89.200000     88.000000     90.000000
# 75%        3.300000      3.200000     91.100000     90.000000     92.000000
# max        3.800000      3.900000    160.200000    100.000000    803.000000
#
#             MQ3_std      MQ3_skew  MQ3_kurtosis       MQ3_auc   TGS822_mean  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean       0.983066      0.031130     -0.497871    797.282995     51.381383
# std        7.032746      0.840692      1.501362     52.931071    134.638191
# min        0.316228     -2.666667     -2.000000    511.500000     35.100000
# 25%        0.516398     -0.365675     -1.333333    781.500000     44.900000
# 50%        0.567646      0.000000     -0.705532    800.000000     46.900000
# 75%        0.674949      0.408248      0.154260    819.000000     50.300000
# max      225.857280      2.666667      5.111111   1513.000000   4902.100000
#
#          TGS822_min    TGS822_max    TGS822_std   TGS822_skew  \
# count  10409.000000  10409.000000  10409.000000  10409.000000
# mean      46.428283     86.377366     12.767992      0.047886
# std        5.136031   1345.593517    425.520299      0.552556
# min        0.000000     39.000000      0.316228     -2.666667
# 25%       44.000000     46.000000      0.674949     -0.223607
# 50%       46.000000     48.000000      0.788811      0.000000
# 75%       49.000000     51.000000      0.918937      0.365675
# max       61.000000  48600.000000  15353.877024      2.666667
#
#        TGS822_kurtosis    TGS822_auc  TGS2602_mean   TGS2602_min  \
# count     10409.000000  10409.000000  10409.000000  10409.000000
# mean         -0.767730    461.091603     48.923492     46.665674
# std           0.759330   1346.620866     27.219648      5.088537
# min          -2.000000    244.500000     35.900000      0.000000
# 25%          -1.213319    397.500000     45.600000     44.000000
# 50%          -0.897959    421.500000     47.200000     46.000000
# 75%          -0.444444    451.000000     50.300000     49.000000
# max           5.111111  48975.000000    959.200000     61.000000
#
#         TGS2602_max   TGS2602_std  TGS2602_skew  TGS2602_kurtosis  \
# count  10409.000000  10409.000000  10409.000000      10409.000000
# mean      56.401095      3.417439      0.042129         -0.742829
# std      180.916345     64.156847      0.547445          0.739631
# min       38.000000      0.316228     -2.661423         -2.000000
# 25%       47.000000      0.707107     -0.271545         -1.153061
# 50%       48.000000      0.823273      0.000000         -0.837370
# 75%       52.000000      0.948683      0.343622         -0.444444
# max     4995.000000   1925.490114      2.666667          5.111111
#
#         TGS2602_auc      MQ5_mean       MQ5_min       MQ5_max       MQ5_std  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean     435.501633     98.319587     97.190220     99.975002      0.977440
# std      272.739018     15.985696     16.412742     29.400385      8.140189
# min      245.000000     64.900000      0.000000     66.000000      0.316228
# 25%      405.000000     87.800000     87.000000     89.000000      0.487950
# 50%      423.000000     96.400000     96.000000     97.000000      0.567646
# 75%      451.500000    108.900000    108.000000    110.000000      0.699206
# max     9541.500000    182.000000    176.000000    939.200000    268.049170
#
#            MQ5_skew  MQ5_kurtosis       MQ5_auc    MQ138_mean     MQ138_min  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean       0.153864     -0.336209    872.003728     89.167083     87.839082
# std        0.873800      1.542203    150.300578      4.220817      5.963905
# min       -2.666667     -2.000000    459.500000     74.100000      0.000000
# 25%       -0.209922     -1.238095    778.500000     86.428571     85.000000
# 50%        0.000000     -0.628099    854.500000     88.600000     87.000000
# 75%        0.625514      0.250000    974.000000     92.100000     91.000000
# max        2.666667      5.111111   1671.700000    114.222222    100.000000
#
#           MQ138_max     MQ138_std    MQ138_skew  MQ138_kurtosis     MQ138_auc  \
# count  10409.000000  10409.000000  10409.000000    10409.000000  10409.000000
# mean      90.566625      0.975194      0.054069       -0.778237    790.103132
# std        7.759153      2.798350      0.558517        0.739505     58.771488
# min       80.000000      0.316228     -2.666667       -2.000000    509.500000
# 25%       88.000000      0.699206     -0.271545       -1.238095    767.500000
# 50%       90.000000      0.823273      0.000000       -0.897959    794.000000
# 75%       93.000000      0.966092      0.382818       -0.485207    826.000000
# max      327.000000     79.796268      2.474323        5.111111    940.000000
#
#        TGS2620_mean   TGS2620_min   TGS2620_max   TGS2620_std  TGS2620_skew  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean      52.047207     50.200692     56.931309      2.411880      0.011063
# std       17.146579      6.110356    131.709310     46.550137      0.618758
# min       37.750000      0.000000     41.000000      0.316228     -2.666667
# 25%       48.800000     48.000000     50.000000      0.632456     -0.343622
# 50%       51.100000     50.000000     52.000000      0.707107      0.000000
# 75%       54.500000     53.000000     55.000000      0.823273      0.343622
# max      681.500000     68.000000   5096.000000   1783.727478      2.666667
#
#        TGS2620_kurtosis   TGS2620_auc   TGS813_mean    TGS813_min  \
# count      10409.000000  10409.000000  10409.000000  10409.000000
# mean          -0.779548    460.377366    533.585382    530.475646
# std            0.944303    139.116630      7.076472     22.158615
# min           -2.000000    244.500000    487.200000      0.000000
# 25%           -1.329389    435.000000    528.900000    526.000000
# 50%           -0.960433    457.500000    532.100000    529.000000
# 75%           -0.444444    488.500000    536.000000    534.000000
# max            5.111111   5401.500000    552.666667    552.000000
#
#          TGS813_max    TGS813_std   TGS813_skew  TGS813_kurtosis  \
# count  10409.000000  10409.000000  10409.000000     10409.000000
# mean     535.648189      1.716062     -0.230519        -0.613955
# std        6.352277      6.679696      0.605296         0.951359
# min      525.000000      0.316228     -2.666667        -2.000000
# 25%      531.000000      0.971825     -0.580993        -1.203214
# 50%      534.000000      1.418136     -0.211547        -0.775022
# 75%      538.000000      1.870829      0.110588        -0.276929
# max      554.000000    171.255624      2.666667         5.111111
#
#          TGS813_auc  TGS2600_mean   TGS2600_min   TGS2600_max   TGS2600_std  \
# count  10409.000000  10409.000000  10409.000000  10409.000000  10409.000000
# mean    4754.938419    215.542657    212.039427    231.564223      6.549817
# std      193.833399     77.472793     27.167422    653.653277    217.414970
# min     3176.500000    182.490000      0.000000    189.000000      0.316228
# 25%     4754.000000    198.500000    198.000000    199.000000      0.527046
# 50%     4783.500000    205.400000    204.000000    206.000000      0.674949
# 75%     4817.500000    215.400000    214.000000    216.000000      0.788811
# max     4974.000000   3048.444444    302.000000  25410.000000   8385.583374
#
#        TGS2600_skew  TGS2600_kurtosis   TGS2600_auc  TGS2611_mean  \
# count  10409.000000      10409.000000  10409.000000  10409.000000
# mean      -0.059306         -0.657508   1919.990364    531.039823
# std        0.666301          1.127310    693.665474      5.820037
# min       -2.666667         -2.000000   1157.500000    482.500000
# 25%       -0.365675         -1.238095   1772.000000    527.400000
# 50%        0.000000         -0.705532   1840.500000    530.000000
# 75%        0.328125         -0.444444   1934.500000    533.000000
# max        2.666667          5.111111  27183.500000    547.300000
#
#         TGS2611_min   TGS2611_max   TGS2611_std  TGS2611_skew  \
# count  10409.000000  10409.000000  10409.000000  10409.000000
# mean     529.310693    532.089442      1.000540     -0.031123
# std       21.482818      5.537689      6.616937      0.568960
# min        0.000000    521.000000      0.316228     -2.666667
# 25%      526.000000    528.000000      0.632456     -0.343622
# 50%      529.000000    531.000000      0.737865      0.000000
# 75%      532.000000    534.000000      0.843274      0.343622
# max      546.000000    548.000000    169.640666      2.666667
#
#        TGS2611_kurtosis   TGS2611_auc  TGS2603_mean   TGS2603_min  \
# count      10409.000000  10409.000000  10409.000000  10409.000000
# mean          -0.890127   4742.842444    330.447166    328.831396
# std            0.811196    167.298428     12.855213     18.210511
# min           -2.000000   3167.500000    303.700000      0.000000
# 25%           -1.452909   4739.000000    321.900000    321.000000
# 50%           -0.960433   4769.000000    328.700000    328.000000
# 75%           -0.500000   4795.500000    335.600000    334.000000
# max            5.111111   4926.000000    370.200000    369.000000
#
#         TGS2603_max   TGS2603_std  TGS2603_skew  TGS2603_kurtosis  \
# count  10409.000000  10409.000000  10409.000000      10409.000000
# mean     331.640503      0.980595      0.022313         -0.777011
# std       12.875590      4.372807      0.541380          0.741411
# min      304.000000      0.316228     -2.666667         -2.000000
# 25%      323.000000      0.699206     -0.343622         -1.153061
# 50%      330.000000      0.816497      0.000000         -0.895833
# 75%      337.000000      0.918937      0.343622         -0.485207
# max      371.000000    113.142977      2.666667          5.111111
#
#         TGS2603_auc  Humidity_mean  Humidity_min  Humidity_max  Humidity_std  \
# count  10409.000000   1.040900e+04  10409.000000  1.040900e+04  1.040900e+04
# mean    2953.280046   4.077809e+03     48.175252  4.034278e+04  1.274229e+04
# std      142.283603   1.369807e+05      3.645837  1.369807e+06  4.331711e+05
# min     1955.500000   3.932000e+01      0.000000  3.950000e+01  3.162278e-02
# 25%     2885.500000   4.635000e+01     46.200000  4.650000e+01  5.163978e-02
# 50%     2951.000000   4.850000e+01     48.300000  4.870000e+01  6.992059e-02
# 75%     3008.500000   5.037000e+01     50.200000  5.050000e+01  1.135292e-01
# max     3331.000000   4.660302e+06     60.100000  4.660260e+07  1.473702e+07
#
#        Humidity_skew  Humidity_kurtosis  Humidity_auc  Celsius_mean  \
# count   1.040900e+04       10409.000000  1.040900e+04  10409.000000
# mean   -2.069636e-02          -0.448380  4.072700e+04     39.656171
# std     9.620238e-01           1.755567  1.369807e+06      1.311917
# min    -2.666667e+00          -2.000000  2.858000e+02     36.075000
# 25%    -4.082483e-01          -1.425074  4.148000e+02     38.910000
# 50%    -3.835271e-14          -1.004730  4.338000e+02     39.580000
# 75%     3.934379e-01          -0.222222  4.524000e+02     40.610000
# max     2.666667e+00           5.111111  4.660298e+07     43.520000
#
#         Celsius_min   Celsius_max   Celsius_std  Celsius_skew  \
# count  10409.000000  10409.000000  10409.000000  1.040900e+04
# mean      39.596032     39.718417      0.050683 -3.135385e-03
# std        1.313344      1.307077      0.014026  1.324687e+00
# min       36.000000     36.100000      0.031623 -2.666667e+00
# 25%       38.900000     39.000000      0.042164 -8.728716e-01
# 50%       39.500000     39.600000      0.048305  2.131541e-13
# 75%       40.600000     40.700000      0.052705  8.728716e-01
# max       43.500000     43.600000      0.105409  2.666667e+00
#
#        Celsius_kurtosis   Celsius_auc    Aroma_mean     Aroma_min  \
# count      10409.000000  10409.000000  10409.000000  10409.000000
# mean           0.023642    355.665448      2.935143      2.935143
# std            2.446926     14.858732      0.257778      0.257778
# min           -2.000000    246.950000      2.400000      2.400000
# 25%           -1.833333    349.450000      2.800000      2.800000
# 50%           -1.166667    355.950000      2.900000      2.900000
# 75%            0.250000    364.750000      3.100000      3.100000
# max            5.111111    391.650000      3.800000      3.800000
#
#           Aroma_max     Aroma_std     Aroma_auc    Taste_mean     Taste_min  \
# count  10409.000000  1.040900e+04  10409.000000  10409.000000  10409.000000
# mean       2.935143  3.738503e-16     26.416284     34.888942     34.888942
# std        0.257778  1.877307e-16      2.319999      1.732650      1.732650
# min        2.400000  0.000000e+00     21.600000     31.000000     31.000000
# 25%        2.800000  4.681111e-16     25.200000     33.000000     33.000000
# 50%        2.900000  4.681111e-16     26.100000     35.000000     35.000000
# 75%        3.100000  4.681111e-16     27.900000     36.000000     36.000000
# max        3.800000  4.681111e-16     34.200000     38.000000     38.000000
#
#           Taste_max  Taste_std     Taste_auc    Color_mean     Color_min  \
# count  10409.000000    10409.0  10409.000000  10409.000000  10409.000000
# mean      34.888942        0.0    314.000480      3.035383      3.035383
# std        1.732650        0.0     15.593852      0.255256      0.255256
# min       31.000000        0.0    279.000000      2.400000      2.400000
# 25%       33.000000        0.0    297.000000      2.800000      2.800000
# 50%       35.000000        0.0    315.000000      3.000000      3.000000
# 75%       36.000000        0.0    324.000000      3.200000      3.200000
# max       38.000000        0.0    342.000000      3.700000      3.700000
#
#           Color_max     Color_std     Color_auc  Appearance_mean  \
# count  10409.000000  1.040900e+04  10409.000000     10409.000000
# mean       3.035383  3.169160e-16     27.318446         3.135306
# std        0.255256  2.189081e-16      2.297302         0.270518
# min        2.400000  0.000000e+00     21.600000         2.800000
# 25%        2.800000  0.000000e+00     25.200000         2.900000
# 50%        3.000000  4.681111e-16     27.000000         3.100000
# 75%        3.200000  4.681111e-16     28.800000         3.300000
# max        3.700000  4.681111e-16     33.300000         3.800000
#
#        Appearance_min  Appearance_max  Appearance_std  Appearance_auc  \
# count    10409.000000    10409.000000    1.040900e+04    10409.000000
# mean         3.135306        3.135306    2.763515e-16       28.217754
# std          0.270518        0.270518    2.302133e-16        2.434658
# min          2.800000        2.800000    0.000000e+00       25.200000
# 25%          2.900000        2.900000    0.000000e+00       26.100000
# 50%          3.100000        3.100000    4.681111e-16       27.900000
# 75%          3.300000        3.300000    4.681111e-16       29.700000
# max          3.800000        3.800000    4.681111e-16       34.200000
#
#           Dreg_mean      Dreg_min      Dreg_max      Dreg_std      Dreg_auc
# count  10409.000000  10409.000000  10409.000000  1.040900e+04  10409.000000
# mean       3.071880      3.071880      3.071880  3.367936e-16     27.646921
# std        0.307778      0.307778      0.307778  2.103121e-16      2.769999
# min        2.400000      2.400000      2.400000  0.000000e+00     21.600000
# 25%        2.800000      2.800000      2.800000  0.000000e+00     25.200000
# 50%        3.000000      3.000000      3.000000  4.681111e-16     27.000000
# 75%        3.200000      3.200000      3.200000  4.681111e-16     28.800000
# max        3.900000      3.900000      3.900000  4.681111e-16     35.100000

# %%
import matplotlib.pyplot as plt
data['Kategori'].hist()
plt.xlabel('Kategori')
plt.ylabel('Count')
plt.title('Histogram for the Kategori')
# Out:
# Text(0.5, 1.0, 'Histogram for the Kategori')

# %%
X = data[feature_cols]
y = data[target_cols]

print(X.shape, y.shape)
# Out:
# (10409, 12) (10409,)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %%
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
def plot_pca_variance(X, n_components, threshold=0.95):
  pca = PCA(n_components=n_components)
  pca.fit(X)

  cumvar = np.cumsum(pca.explained_variance_ratio_)
  n_optimal = np.argmax(cumvar >= threshold) + 1

  plt.figure(figsize=(8, 5))
  plt.plot(range(1, n_components + 1), cumvar, marker='o', color='blue')
  plt.axhline(y=threshold, color='gray', linestyle='--', linewidth=1)
  plt.xlabel('Number of Principal Components')
  plt.ylabel('Cumulative Explained Variance')
  plt.xticks(range(1, n_components + 1))
  plt.grid(True)
  plt.tight_layout()
  plt.show()

  print(f'Optimal number of components to retain {threshold*100:.0f}% variance: {n_optimal}')

  return n_optimal

# %%
n_optimal = plot_pca_variance(X, n_components=X.shape[1], threshold=0.95)
# Out:
# Optimal number of components to retain 95% variance: 4

# %%
import time
from pathlib import Path
from datetime import datetime

all_best = []  # collects best_result from every model
_iter_t0 = None

# Logger setup
log_dir = Path("./results/logs/ml/best_param")
log_dir.mkdir(parents=True, exist_ok=True)

_current_log_path = None

def setup_logger(name):
  """Panggil di awal tiap section. name contoh: 'svc_linear', 'xgb_gbtree'."""
  global _current_log_path
  _current_log_path = log_dir / f"classical_{name}_hpo.log"
  # truncate file kalau sudah ada, biar tiap run fresh
  _current_log_path.write_text("")
  log(f"📝 Log: {_current_log_path}")
  log(f"🕒 Started: {datetime.now().isoformat(timespec='seconds')}")

def log(msg=""):
  """Print ke console dan append ke file log section aktif."""
  print(msg)
  if _current_log_path is not None:
    with open(_current_log_path, "a", encoding="utf-8") as f:
      f.write(str(msg) + "\n")

# %% [markdown]
# # 1. SVC

# %% [markdown]
# ## 1.1 Linear

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [10],
  'tol': [0.1]
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("svc_linear")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils.hpo import get_search_space
from skopt import BayesSearchCV
from sklearn.decomposition import PCA
from model.models import svc_model
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()
  

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', SVC(class_weight='balanced',
        kernel='linear',
        probability=True,
        random_state=42, 
        decision_function_shape='ovr',
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_svc_linear_hpo.log
# 🕒 Started: 2026-06-06T20:49:03
# 🔬 Search space: 1 C × 1 tol =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] C=10 | tol=0.1
#     F1 → Acc=0.3934 | Prec=0.5784 | Rec=0.3934 | F1=0.4058 | AUROC=0.6947 | PRAUC=0.4846
#     F2 → Acc=0.4025 | Prec=0.5790 | Rec=0.4025 | F1=0.4163 | AUROC=0.7087 | PRAUC=0.4999
#     F3 → Acc=0.3838 | Prec=0.5537 | Rec=0.3838 | F1=0.3918 | AUROC=0.6798 | PRAUC=0.4719
#     F4 → Acc=0.4049 | Prec=0.5599 | Rec=0.4049 | F1=0.4117 | AUROC=0.6925 | PRAUC=0.4837
#     F5 → Acc=0.3767 | Prec=0.5466 | Rec=0.3767 | F1=0.3835 | AUROC=0.6853 | PRAUC=0.4723
#   ✅  Acc:0.3923±0.0108 | Precision:0.5635±0.0131  |Recall:0.3923±0.0108 |F1:0.4018±0.0123 | AUROC:0.6922±0.0098 | PRAUC:0.4825±0.0103 | MCC:0.2574 | Composite:0.5223
#
# 🏆 Best config : C=10 | tol=0.1
#    Composite   : 0.5223 (AUROC=0.6922±0.0098 | PRAUC=0.4825±0.0103 | Acc=0.3923±0.0108 |Prec=0.5635±0.0131 |Rec=0.3923±0.0108) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "svc_linear_hpo.csv"
df.to_csv(filename, index=False)

log(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/svc_linear_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "SVC Linear"
all_best.append(dict(best_result))
log(f"✅ [SVC Linear] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [SVC Linear] recorded | Exec. time: 200.6s

# %% [markdown]
# ## 1.2 Poly

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [1],
  'tol': [0.1],
  'degree': [5],
  'gamma': [0.5],
  'coef0': [3],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("svc_poly")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils.hpo import get_search_space
from skopt import BayesSearchCV
from sklearn.decomposition import PCA
from model.models import svc_model
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()
  
  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', SVC(class_weight='balanced',kernel='poly', probability=True, random_state=42, **params))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

     
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_svc_poly_hpo.log
# 🕒 Started: 2026-06-06T20:52:25
# 🔬 Search space: 1 C × 1 tol × 1 degree × 1 gamma × 1 coef0 =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] C=1 | tol=0.1 | degree=5 | gamma=0.5 | coef0=3
#     F1 → Acc=0.9693 | Prec=0.9708 | Rec=0.9693 | F1=0.9696 | AUROC=0.9987 | PRAUC=0.9958
#     F2 → Acc=0.9726 | Prec=0.9732 | Rec=0.9726 | F1=0.9727 | AUROC=0.9982 | PRAUC=0.9951
#     F3 → Acc=0.9664 | Prec=0.9680 | Rec=0.9664 | F1=0.9667 | AUROC=0.9976 | PRAUC=0.9938
#     F4 → Acc=0.9721 | Prec=0.9733 | Rec=0.9721 | F1=0.9724 | AUROC=0.9988 | PRAUC=0.9962
#     F5 → Acc=0.9635 | Prec=0.9651 | Rec=0.9635 | F1=0.9637 | AUROC=0.9981 | PRAUC=0.9935
#   ✅  Acc:0.9688±0.0035 | Precision:0.9701±0.0032  |Recall:0.9688±0.0035 |F1:0.9691±0.0034 | AUROC:0.9983±0.0004 | PRAUC:0.9949±0.0011 | MCC:0.9555 | Composite:0.9873
#
# 🏆 Best config : C=1 | tol=0.1 | degree=5 | gamma=0.5 | coef0=3
#    Composite   : 0.9873 (AUROC=0.9983±0.0004 | PRAUC=0.9949±0.0011 | Acc=0.9688±0.0035 |Prec=0.9701±0.0032 |Rec=0.9688±0.0035) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "svc_poly_hpo.csv"
df.to_csv(filename, index=False)

print(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/svc_poly_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "SVC Poly"
all_best.append(dict(best_result))
log(f"✅ [SVC Poly] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [SVC Poly] recorded | Exec. time: 65.9s

# %% [markdown]
# ## 1.3 RBF

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [10],
  'tol': [0.1],
  'gamma': [0.5],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("svc_rbf")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils.hpo import get_search_space
from skopt import BayesSearchCV
from sklearn.decomposition import PCA
from model.models import svc_model
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()
  
  
  log(f"\n  ▶ {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', SVC(class_weight='balanced', decision_function_shape='ovr', kernel='rbf', probability=True, random_state=42, **params))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

     
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_svc_rbf_hpo.log
# 🕒 Started: 2026-06-06T20:53:31
# 🔬 Search space: 1 C × 1 tol × 1 gamma =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] C=10 | tol=0.1 | gamma=0.5
#
#   ▶ C=10 | tol=0.1 | gamma=0.5
#     F1 → Acc=0.9726 | Prec=0.9740 | Rec=0.9726 | F1=0.9729 | AUROC=0.9991 | PRAUC=0.9968
#     F2 → Acc=0.9745 | Prec=0.9753 | Rec=0.9745 | F1=0.9747 | AUROC=0.9975 | PRAUC=0.9895
#     F3 → Acc=0.9721 | Prec=0.9736 | Rec=0.9721 | F1=0.9725 | AUROC=0.9976 | PRAUC=0.9928
#     F4 → Acc=0.9765 | Prec=0.9773 | Rec=0.9765 | F1=0.9767 | AUROC=0.9990 | PRAUC=0.9965
#     F5 → Acc=0.9649 | Prec=0.9666 | Rec=0.9649 | F1=0.9653 | AUROC=0.9981 | PRAUC=0.9935
#   ✅  Acc:0.9721±0.0039 | Precision:0.9733±0.0036  |Recall:0.9721±0.0039 |F1:0.9724±0.0038 | AUROC:0.9983±0.0007 | PRAUC:0.9938±0.0027 | MCC:0.9603 | Composite:0.9881
#
# 🏆 Best config : C=10 | tol=0.1 | gamma=0.5
#    Composite   : 0.9881 (AUROC=0.9983±0.0007 | PRAUC=0.9938±0.0027 | Acc=0.9721±0.0039 |Prec=0.9733±0.0036 |Rec=0.9721±0.0039) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "svc_rbf_hpo.csv"
df.to_csv(filename, index=False)

print(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/svc_rbf_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "SVC RBF"
all_best.append(dict(best_result))
log(f"✅ [SVC RBF] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [SVC RBF] recorded | Exec. time: 11.3s

# %% [markdown]
# ## 1.4 Sigmoid

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'C': [1],
  'tol': [0.1],
  'gamma': [0.01],
  'coef0': [0],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("svc_sigmoid")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from utils.hpo import get_search_space
from skopt import BayesSearchCV
from sklearn.decomposition import PCA
from model.models import svc_model
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()
  
  
  log(f"\n  ▶ {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('svc', SVC(decision_function_shape='ovr', class_weight='balanced',kernel='sigmoid', probability=True, random_state=42, **params))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

     
    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_svc_sigmoid_hpo.log
# 🕒 Started: 2026-06-06T20:53:42
# 🔬 Search space: 1 C × 1 tol × 1 gamma × 1 coef0 =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] C=1 | tol=0.1 | gamma=0.01 | coef0=0
#
#   ▶ C=1 | tol=0.1 | gamma=0.01 | coef0=0
#     F1 → Acc=0.3497 | Prec=0.5191 | Rec=0.3497 | F1=0.3541 | AUROC=0.6785 | PRAUC=0.4542
#     F2 → Acc=0.3598 | Prec=0.5453 | Rec=0.3598 | F1=0.3712 | AUROC=0.6922 | PRAUC=0.4695
#     F3 → Acc=0.3463 | Prec=0.5239 | Rec=0.3463 | F1=0.3522 | AUROC=0.6632 | PRAUC=0.4432
#     F4 → Acc=0.3871 | Prec=0.5411 | Rec=0.3871 | F1=0.3851 | AUROC=0.6791 | PRAUC=0.4595
#     F5 → Acc=0.3489 | Prec=0.5132 | Rec=0.3489 | F1=0.3498 | AUROC=0.6699 | PRAUC=0.4439
#   ✅  Acc:0.3583±0.0151 | Precision:0.5285±0.0125  |Recall:0.3583±0.0151 |F1:0.3625±0.0136 | AUROC:0.6766±0.0098 | PRAUC:0.4541±0.0099 | MCC:0.2135 | Composite:0.4963
#
# 🏆 Best config : C=1 | tol=0.1 | gamma=0.01 | coef0=0
#    Composite   : 0.4963 (AUROC=0.6766±0.0098 | PRAUC=0.4541±0.0099 | Acc=0.3583±0.0151 |Prec=0.5285±0.0125 |Rec=0.3583±0.0151) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "svc_rbf_hpo.csv"
df.to_csv(filename, index=False)

print(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/svc_rbf_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "SVC Sigmoid"
all_best.append(dict(best_result))
log(f"✅ [SVC Sigmoid] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [SVC Sigmoid] recorded | Exec. time: 96.7s

# %% [markdown]
# # 2. XGBoost

# %% [markdown]
# ## 2.1 GBTree

# %%
# Search Space Configuration
import numpy as np

# search_space = {
#   'n_estimators': [1000],
#   'learning_rate': [0.01],
#   'max_depth': [10],
#   'subsample': [0.5],
#   'colsample_bytree': [1],
# }

search_space = {
  'n_estimators': [100],
  'learning_rate': [0.1],
  'max_depth': [10],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("xgb_gbtree")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_sample_weight  # ← imbalance handling
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()
  
  
  log(f"\n  ▶ {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('xgb', XGBClassifier(
        booster='gbtree', objective='multi:softprob', random_state=42, device='cuda', **params
      ))
    ])

    # Per-fold balanced sample_weight (XGBoost tidak punya class_weight)
    sw_train = compute_sample_weight('balanced', y_train)
    model.fit(X_train, y_train, xgb__sample_weight=sw_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_xgb_gbtree_hpo.log
# 🕒 Started: 2026-06-06T20:55:19
# 🔬 Search space: 1 n_estimators × 1 learning_rate × 1 max_depth =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] n_estimators=100 | learning_rate=0.1 | max_depth=10
#
#   ▶ n_estimators=100 | learning_rate=0.1 | max_depth=10
#     F1 → Acc=0.9673 | Prec=0.9677 | Rec=0.9673 | F1=0.9674 | AUROC=0.9989 | PRAUC=0.9965
#     F2 → Acc=0.9750 | Prec=0.9753 | Rec=0.9750 | F1=0.9751 | AUROC=0.9990 | PRAUC=0.9973
#     F3 → Acc=0.9673 | Prec=0.9676 | Rec=0.9673 | F1=0.9674 | AUROC=0.9981 | PRAUC=0.9935
#     F4 → Acc=0.9779 | Prec=0.9782 | Rec=0.9779 | F1=0.9780 | AUROC=0.9993 | PRAUC=0.9978
#     F5 → Acc=0.9644 | Prec=0.9648 | Rec=0.9644 | F1=0.9645 | AUROC=0.9978 | PRAUC=0.9926
#   ✅  Acc:0.9704±0.0051 | Precision:0.9707±0.0051  |Recall:0.9704±0.0051 |F1:0.9705±0.0051 | AUROC:0.9986±0.0006 | PRAUC:0.9955±0.0021 | MCC:0.9575 | Composite:0.9882
#
# 🏆 Best config : n_estimators=100 | learning_rate=0.1 | max_depth=10
#    Composite   : 0.9882 (AUROC=0.9986±0.0006 | PRAUC=0.9955±0.0021 | Acc=0.9704±0.0051 |Prec=0.9707±0.0051 |Rec=0.9704±0.0051) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "xgb_gbtree_hpo.csv"
df.to_csv(filename, index=False)

print(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/xgb_gbtree_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "XGBoost GBTree"
all_best.append(dict(best_result))
log(f"✅ [XGBoost GBTree] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [XGBoost GBTree] recorded | Exec. time: 13.2s

# %% [markdown]
# ## 2.2 Dart

# %%
# Search Space Configuration
import numpy as np

# search_space = {
#   'n_estimators': [1000],
#   'learning_rate': [0.01],
#   'max_depth': [10],
#   'subsample': [0.5],
#   'colsample_bytree': [1],

#   'rate_drop': [0],
# }

search_space = {
  'n_estimators': [100],
  'learning_rate': [0.1],
  'max_depth': [10],
  'rate_drop': [0.1],
  'skip_drop': [0.5],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("xgb_dart")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_sample_weight  # ← imbalance handling
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()
  
  
  log(f"\n  ▶ {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('xgb', XGBClassifier(
        booster='dart', objective='multi:softprob', random_state=42, device='cuda', **params
      ))
    ])

    # Per-fold balanced sample_weight (XGBoost tidak punya class_weight)
    sw_train = compute_sample_weight('balanced', y_train)
    model.fit(X_train, y_train, xgb__sample_weight=sw_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_xgb_dart_hpo.log
# 🕒 Started: 2026-06-06T20:55:32
# 🔬 Search space: 1 n_estimators × 1 learning_rate × 1 max_depth × 1 rate_drop × 1 skip_drop =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | skip_drop=0.5
#
#   ▶ n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | skip_drop=0.5
#     F1 → Acc=0.9640 | Prec=0.9644 | Rec=0.9640 | F1=0.9641 | AUROC=0.9987 | PRAUC=0.9959
#     F2 → Acc=0.9702 | Prec=0.9708 | Rec=0.9702 | F1=0.9703 | AUROC=0.9989 | PRAUC=0.9969
#     F3 → Acc=0.9621 | Prec=0.9629 | Rec=0.9621 | F1=0.9623 | AUROC=0.9976 | PRAUC=0.9921
#     F4 → Acc=0.9779 | Prec=0.9783 | Rec=0.9779 | F1=0.9780 | AUROC=0.9992 | PRAUC=0.9975
#     F5 → Acc=0.9620 | Prec=0.9625 | Rec=0.9620 | F1=0.9621 | AUROC=0.9971 | PRAUC=0.9906
#   ✅  Acc:0.9672±0.0061 | Precision:0.9678±0.0060  |Recall:0.9672±0.0061 |F1:0.9674±0.0061 | AUROC:0.9983±0.0008 | PRAUC:0.9946±0.0028 | MCC:0.9531 | Composite:0.9867
#
# 🏆 Best config : n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | skip_drop=0.5
#    Composite   : 0.9867 (AUROC=0.9983±0.0008 | PRAUC=0.9946±0.0028 | Acc=0.9672±0.0061 |Prec=0.9678±0.0060 |Rec=0.9672±0.0061) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "xgb_dart_hpo.csv"
df.to_csv(filename, index=False)

print(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/xgb_dart_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "XGBoost Dart"
all_best.append(dict(best_result))
log(f"✅ [XGBoost Dart] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [XGBoost Dart] recorded | Exec. time: 25.5s

# %% [markdown]
# # 3. CatBoost

# %%
# Search Space Configuration
import numpy as np

search_space = {
  'iterations': [500],
  'depth': [10],
  'learning_rate': [0.1],
  'l2_leaf_reg': [1],
}

param_keys = search_space.keys()
param_vals = search_space.values()

# %%
setup_logger("catboost")
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
from itertools import product
from sklearn.metrics import (
  accuracy_score, f1_score, roc_auc_score,
  average_precision_score, matthews_corrcoef,
  precision_score, recall_score
)
from catboost import CatBoostClassifier

state = 42
n_splits = 5
n_iter = 10

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=state)

search_space_sizes = {k: len(v) for k, v in search_space.items()}
total_configs = np.prod([len(v) for v in param_vals])
total_fits = total_configs * skf.get_n_splits()
space_str = " × ".join([f"{search_space_sizes[k]} {k}" for k in search_space_sizes])

log(f"🔬 Search space: {space_str} =  {total_configs} configs × {skf.get_n_splits()} folds = {total_fits} fits")
log("   Scoring criterion: (AUROC + PRAUC + Accuracy) / 3")

best_score = -np.inf
best_result = None
results = []
for i, comb in enumerate(product(*param_vals)):
  params = dict(zip(param_keys, comb))
  tag = " | ".join(f"{k}={v}" for k, v in params.items())
  log(f"\n  ▶ [{i+1}/{total_configs}] {tag}")
  _iter_t0 = time.perf_counter()

  accs, f1s, rocs, pras, precs, recs= [], [], [], [], [], []
  y_val_all, y_pred_all = [], []
  for fold, (train_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    model = Pipeline([
      ('scaler', StandardScaler()),
      ('pca', PCA(n_components=n_optimal)),
      ('cat', CatBoostClassifier(
        loss_function="MultiClassOneVsAll",
        eval_metric="Accuracy",
        verbose=0,
        random_seed=42, 
        task_type="GPU",
        devices='0',
        auto_class_weights='Balanced',  # ← imbalance handling
        **params
      ))
    ])

    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    y_prob = model.predict_proba(X_val)
    y_prob = y_prob / y_prob.sum(axis=1, keepdims=True)  # Normalize probabilities

    y_val_all.extend(y_val)
    y_pred_all.extend(y_pred)

    acc = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred, average='weighted')
    roc = roc_auc_score(y_val, y_prob, average='weighted', multi_class='ovr')
    pra = average_precision_score(y_val, y_prob, average='weighted')
    prec = precision_score(y_val, y_pred, average='weighted')
    rec = recall_score(y_val, y_pred, average='weighted')

    accs.append(acc)
    f1s.append(f1)
    rocs.append(roc)
    pras.append(pra)
    precs.append(prec)
    recs.append(rec)

    log(f"    F{fold} → Acc={acc:.4f} | Prec={prec:.4f} | Rec={rec:.4f} | F1={f1:.4f} | AUROC={roc:.4f} | PRAUC={pra:.4f}")

    results.append({
      "tag": tag,
      **params,
      "fold": fold,
      "accuracy": acc,
      "precision": prec,
      "recall": rec,
      "F1": f1,
      "auroc": roc,
      "prauc": pra,
    })

  # Aggregate
  acc_mean, acc_std = np.mean(accs), np.std(accs)
  prec_mean, prec_std = np.mean(precs), np.std(precs)
  rec_mean, rec_std = np.mean(recs), np.std(recs)
  f1_mean, f1_std = np.mean(f1s), np.std(f1s)
  roc_mean, roc_std = np.mean(rocs), np.std(rocs)
  pra_mean, pra_std = np.mean(pras), np.std(pras)
  mcc = matthews_corrcoef(y_val_all, y_pred_all)

  composite = (roc_mean + pra_mean + acc_mean) / 3

  log(
    f"  ✅  Acc:{acc_mean:.4f}±{acc_std:.4f} | "
    f"Precision:{prec_mean:.4f}±{prec_std:.4f}  |"
    f"Recall:{rec_mean:.4f}±{rec_std:.4f} |"
    f"F1:{f1_mean:.4f}±{f1_std:.4f} | "
    f"AUROC:{roc_mean:.4f}±{roc_std:.4f} | "
    f"PRAUC:{pra_mean:.4f}±{pra_std:.4f} | "
    f"MCC:{mcc:.4f} | "
    f"Composite:{composite:.4f}"
  )

  iter_time = time.perf_counter() - _iter_t0
  if composite > best_score:
    best_score = composite
    best_result = {
        'tag': tag,
        'composite': composite,
        'roc': f"{roc_mean:.4f}±{roc_std:.4f}",
        'pra': f"{pra_mean:.4f}±{pra_std:.4f}",
        'acc': f"{acc_mean:.4f}±{acc_std:.4f}",
        'f1': f"{f1_mean:.4f}±{f1_std:.4f}",
        'prec': f"{prec_mean:.4f}±{prec_std:.4f}",
        'rec': f"{rec_mean:.4f}±{rec_std:.4f}",
        'params': params,
        'y_true': list(y_val_all),
        'y_pred': list(y_pred_all),
        'execution_time': iter_time,
    }

log(f"\n🏆 Best config : {best_result['tag']}")
log(
    f"   Composite   : {best_result['composite']:.4f} "
    f"(AUROC={best_result['roc']} | "
    f"PRAUC={best_result['pra']} | "
    f"Acc={best_result['acc']} |"
    f"Prec={best_result['prec']} |"
    f"Rec={best_result['rec']}) |"
)
# Out:
# 📝 Log: results\logs\ml\best_param\classical_catboost_hpo.log
# 🕒 Started: 2026-06-06T20:55:58
# 🔬 Search space: 1 iterations × 1 depth × 1 learning_rate × 1 l2_leaf_reg =  1 configs × 5 folds = 5 fits
#    Scoring criterion: (AUROC + PRAUC + Accuracy) / 3
#
#   ▶ [1/1] iterations=500 | depth=10 | learning_rate=0.1 | l2_leaf_reg=1
#     F1 → Acc=0.9784 | Prec=0.9789 | Rec=0.9784 | F1=0.9785 | AUROC=0.9993 | PRAUC=0.9978
#     F2 → Acc=0.9789 | Prec=0.9792 | Rec=0.9789 | F1=0.9789 | AUROC=0.9993 | PRAUC=0.9980
#     F3 → Acc=0.9726 | Prec=0.9730 | Rec=0.9726 | F1=0.9728 | AUROC=0.9989 | PRAUC=0.9965
#     F4 → Acc=0.9813 | Prec=0.9815 | Rec=0.9813 | F1=0.9813 | AUROC=0.9996 | PRAUC=0.9985
#     F5 → Acc=0.9664 | Prec=0.9668 | Rec=0.9664 | F1=0.9665 | AUROC=0.9985 | PRAUC=0.9951
#   ✅  Acc:0.9755±0.0054 | Precision:0.9759±0.0053  |Recall:0.9755±0.0054 |F1:0.9756±0.0054 | AUROC:0.9991±0.0004 | PRAUC:0.9972±0.0013 | MCC:0.9649 | Composite:0.9906
#
# 🏆 Best config : iterations=500 | depth=10 | learning_rate=0.1 | l2_leaf_reg=1
#    Composite   : 0.9906 (AUROC=0.9991±0.0004 | PRAUC=0.9972±0.0013 | Acc=0.9755±0.0054 |Prec=0.9759±0.0053 |Rec=0.9755±0.0054) |

# %%
import pandas as pd
import os

dirpath = "./results/best_param/"
os.makedirs(dirpath, exist_ok=True)

df = pd.DataFrame(results)
filename = dirpath + "catboost_hpo.csv"
df.to_csv(filename, index=False)

print(f"✅ Saved: {filename}")
# Out:
# ✅ Saved: ./results/best_param/catboost_hpo.csv

# %%
# ── Collect best result ──
best_result['model'] = "CatBoost"
all_best.append(dict(best_result))
log(f"✅ [CatBoost] recorded | Exec. time: {best_result['execution_time']:.1f}s")
# Out:
# ✅ [CatBoost] recorded | Exec. time: 73.9s

# %% [markdown]
# ---
# ## 📊 Tabel Evaluasi Akhir

# %%
# ════════════════════════════════════════════════════════════
# 📊 TABEL EVALUASI AKHIR – Classical Models
# ════════════════════════════════════════════════════════════
import pandas as pd

def build_eval_table(all_best):
    rows = []
    for r in all_best:
        params_str = ' | '.join(f'{k}={v}' for k, v in r.get('params', {}).items())
        rows.append({
            'Model'          : r['model'],
            'Accuracy'       : r['acc'],
            'Precision'      : r['prec'],
            'Recall'         : r['rec'],
            'F1-Score'       : r['f1'],
            'ROC-AUC'        : r['roc'],
            'PR-AUC'         : r['pra'],
            'Exec. Time (s)' : round(r['execution_time'], 2) if 'execution_time' in r else 'N/A',
            'Best Params'    : params_str,
        })
    df = pd.DataFrame(rows)
    df = df.sort_values('ROC-AUC', ascending=False).reset_index(drop=True)
    df.index += 1
    return df

pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', '{:.4f}'.format)

eval_df = build_eval_table(all_best)
display(eval_df)
# Out:
#             Model       Accuracy      Precision         Recall       F1-Score  \
# 1        CatBoost  0.9755±0.0054  0.9759±0.0053  0.9755±0.0054  0.9756±0.0054
# 2  XGBoost GBTree  0.9704±0.0051  0.9707±0.0051  0.9704±0.0051  0.9705±0.0051
# 3    XGBoost Dart  0.9672±0.0061  0.9678±0.0060  0.9672±0.0061  0.9674±0.0061
# 4         SVC RBF  0.9721±0.0039  0.9733±0.0036  0.9721±0.0039  0.9724±0.0038
# 5        SVC Poly  0.9688±0.0035  0.9701±0.0032  0.9688±0.0035  0.9691±0.0034
# 6      SVC Linear  0.3923±0.0108  0.5635±0.0131  0.3923±0.0108  0.4018±0.0123
# 7     SVC Sigmoid  0.3583±0.0151  0.5285±0.0125  0.3583±0.0151  0.3625±0.0136
#
#          ROC-AUC         PR-AUC  Exec. Time (s)  \
# 1  0.9991±0.0004  0.9972±0.0013         73.9100
# 2  0.9986±0.0006  0.9955±0.0021         13.2000
# 3  0.9983±0.0008  0.9946±0.0028         25.5300
# 4  0.9983±0.0007  0.9938±0.0027         11.3100
# 5  0.9983±0.0004  0.9949±0.0011         65.9000
# 6  0.6922±0.0098  0.4825±0.0103        200.5500
# 7  0.6766±0.0098  0.4541±0.0099         96.6500
#
#                                                                            Best Params
# 1                        iterations=500 | depth=10 | learning_rate=0.1 | l2_leaf_reg=1
# 2                                  n_estimators=100 | learning_rate=0.1 | max_depth=10
# 3  n_estimators=100 | learning_rate=0.1 | max_depth=10 | rate_drop=0.1 | skip_drop=0.5
# 4                                                           C=10 | tol=0.1 | gamma=0.5
# 5                                       C=1 | tol=0.1 | degree=5 | gamma=0.5 | coef0=3
# 6                                                                       C=10 | tol=0.1
# 7                                                 C=1 | tol=0.1 | gamma=0.01 | coef0=0

# %%
# ════════════════════════════════════════════════════════════
# 🔢 CONFUSION MATRIX – semua model classical (out-of-fold)
# ════════════════════════════════════════════════════════════
# Memakai prediksi out-of-fold (y_true/y_pred) yang dikumpulkan tiap model
# saat cross-validation → confusion matrix mencerminkan generalisasi, bukan
# performa di data training. Berguna untuk melihat kelas minoritas (mis. B).
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay, classification_report
)

class_names = list(label_encoder.classes_)
labels = np.arange(len(class_names))

models_cm = [r for r in all_best if "y_true" in r and "y_pred" in r]
if not models_cm:
    print("⚠️  Belum ada y_true/y_pred di all_best. Jalankan ulang sel-sel training dulu.")
else:
    n = len(models_cm)
    ncols = 3
    nrows = int(np.ceil(n / ncols))

    fig, axes = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4.2 * nrows))
    axes = np.atleast_1d(axes).ravel()

    for ax, r in zip(axes, models_cm):
        cm = confusion_matrix(r["y_true"], r["y_pred"], labels=labels)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
        disp.plot(ax=ax, cmap="Blues", colorbar=False, values_format="d")
        ax.set_title(r["model"])
        ax.tick_params(axis="x", rotation=45)

    for ax in axes[len(models_cm):]:
        ax.axis("off")

    fig.suptitle("Confusion Matrix (Out-of-Fold) – Classical Models", fontsize=14)
    fig.tight_layout()

    os.makedirs("./results", exist_ok=True)
    out_path = "./results/confusion_matrix_classical_hpo.png"
    fig.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()
    print(f"✅ Saved: {out_path}")

    # ── Classification report per model (lihat performa per kelas) ──
    for r in models_cm:
        print("" + "=" * 60)
        print(r["model"])
        print("=" * 60)
        print(classification_report(
            r["y_true"], r["y_pred"],
            labels=labels, target_names=class_names, zero_division=0,
        ))
# Out:
# ✅ Saved: ./results/confusion_matrix_classical_hpo.png
# ============================================================
# SVC Linear
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.21      0.62      0.31       927
#            B       0.18      0.75      0.29       229
#            C       0.36      0.59      0.45      2287
#            D       0.58      0.26      0.36      2317
#            E       0.75      0.30      0.42      4649
#
#     accuracy                           0.39     10409
#    macro avg       0.41      0.50      0.37     10409
# weighted avg       0.56      0.39      0.40     10409
#
# ============================================================
# SVC Poly
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.89      0.97      0.93       927
#            B       0.98      1.00      0.99       229
#            C       0.95      0.98      0.96      2287
#            D       0.98      0.96      0.97      2317
#            E       0.99      0.97      0.98      4649
#
#     accuracy                           0.97     10409
#    macro avg       0.96      0.98      0.97     10409
# weighted avg       0.97      0.97      0.97     10409
#
# ============================================================
# SVC RBF
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.89      0.98      0.93       927
#            B       1.00      1.00      1.00       229
#            C       0.95      0.98      0.96      2287
#            D       0.98      0.97      0.97      2317
#            E       1.00      0.97      0.98      4649
#
#     accuracy                           0.97     10409
#    macro avg       0.96      0.98      0.97     10409
# weighted avg       0.97      0.97      0.97     10409
#
# ============================================================
# SVC Sigmoid
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.18      0.44      0.25       927
#            B       0.11      0.65      0.19       229
#            C       0.36      0.65      0.46      2287
#            D       0.56      0.17      0.27      2317
#            E       0.69      0.27      0.39      4649
#
#     accuracy                           0.36     10409
#    macro avg       0.38      0.44      0.31     10409
# weighted avg       0.53      0.36      0.36     10409
#
# ============================================================
# XGBoost GBTree
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.92      0.95      0.94       927
#            B       0.99      0.99      0.99       229
#            C       0.96      0.97      0.96      2287
#            D       0.97      0.97      0.97      2317
#            E       0.99      0.97      0.98      4649
#
#     accuracy                           0.97     10409
#    macro avg       0.97      0.97      0.97     10409
# weighted avg       0.97      0.97      0.97     10409
#
# ============================================================
# XGBoost Dart
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.92      0.95      0.93       927
#            B       0.99      0.99      0.99       229
#            C       0.95      0.97      0.96      2287
#            D       0.97      0.97      0.97      2317
#            E       0.99      0.97      0.98      4649
#
#     accuracy                           0.97     10409
#    macro avg       0.96      0.97      0.97     10409
# weighted avg       0.97      0.97      0.97     10409
#
# ============================================================
# CatBoost
# ============================================================
#               precision    recall  f1-score   support
#
#            A       0.93      0.96      0.94       927
#            B       0.99      1.00      1.00       229
#            C       0.96      0.98      0.97      2287
#            D       0.98      0.97      0.98      2317
#            E       0.99      0.98      0.98      4649
#
#     accuracy                           0.98     10409
#    macro avg       0.97      0.98      0.97     10409
# weighted avg       0.98      0.98      0.98     10409

# %% [markdown]
# ---
# ## 🧾 Classification Report per Kelas (semua model)
#
# Precision / Recall / F1-score / Support **per kelas** untuk tiap model, dari prediksi *out-of-fold* (`y_true`/`y_pred`). Fokuskan ke recall kelas minoritas (mis. **B**) untuk menilai efek `class_weight='balanced'`. Baris `accuracy`/`macro avg`/`weighted avg` adalah ringkasan global.

# %%
# ════════════════════════════════════════════════════════════
# 🧾 CLASSIFICATION REPORT (tabel) – per kelas, tiap model
# ════════════════════════════════════════════════════════════
# classification_report(output_dict=True) -> DataFrame agar rapi & bisa disimpan.
import os
import pandas as pd
from sklearn.metrics import classification_report, f1_score

os.makedirs('./results', exist_ok=True)
models_cr = [r for r in all_best if 'y_true' in r and 'y_pred' in r]

per_class_f1 = {}   # untuk tabel perbandingan antar-model
for r in models_cr:
    rep = classification_report(
        r['y_true'], r['y_pred'], labels=labels,
        target_names=class_names, zero_division=0, output_dict=True)
    cr_df = pd.DataFrame(rep).T
    cr_df['support'] = cr_df['support'].astype(int)
    print('=' * 60)
    print(r['model'])
    print('=' * 60)
    display(cr_df.style.format({'precision': '{:.4f}', 'recall': '{:.4f}',
                                'f1-score': '{:.4f}', 'support': '{:.0f}'}))
    fname = f"./results/classification_report_{r['model'].replace(' ', '_').lower()}.csv"
    cr_df.to_csv(fname)
    per_class_f1[r['model']] = [f1_score(r['y_true'], r['y_pred'], labels=[c],
                                         average='macro', zero_division=0)
                                for c in labels]

# ── Perbandingan F1 per kelas antar model (baris = kelas, kolom = model) ──
f1_compare = pd.DataFrame(per_class_f1, index=class_names)
f1_compare.index.name = 'Kelas'
f1_compare.to_csv('./results/per_class_f1_compare.csv')
print()
print('F1-score per kelas — perbandingan antar model:')
display(f1_compare.style.format('{:.4f}')
        .background_gradient(cmap='RdYlGn', axis=None))
print('✅ Saved: ./results/classification_report_<model>.csv & per_class_f1_compare.csv')
# Out:
# ============================================================
# SVC Linear
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_2573d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2573d_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_2573d_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_2573d_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_2573d_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2573d_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_2573d_row0_col0" class="data row0 col0" >0.2066</td>
#       <td id="T_2573d_row0_col1" class="data row0 col1" >0.6235</td>
#       <td id="T_2573d_row0_col2" class="data row0 col2" >0.3104</td>
#       <td id="T_2573d_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_2573d_row1_col0" class="data row1 col0" >0.1779</td>
#       <td id="T_2573d_row1_col1" class="data row1 col1" >0.7511</td>
#       <td id="T_2573d_row1_col2" class="data row1 col2" >0.2876</td>
#       <td id="T_2573d_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_2573d_row2_col0" class="data row2 col0" >0.3591</td>
#       <td id="T_2573d_row2_col1" class="data row2 col1" >0.5885</td>
#       <td id="T_2573d_row2_col2" class="data row2 col2" >0.4461</td>
#       <td id="T_2573d_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_2573d_row3_col0" class="data row3 col0" >0.5808</td>
#       <td id="T_2573d_row3_col1" class="data row3 col1" >0.2637</td>
#       <td id="T_2573d_row3_col2" class="data row3 col2" >0.3627</td>
#       <td id="T_2573d_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_2573d_row4_col0" class="data row4 col0" >0.7458</td>
#       <td id="T_2573d_row4_col1" class="data row4 col1" >0.2960</td>
#       <td id="T_2573d_row4_col2" class="data row4 col2" >0.4238</td>
#       <td id="T_2573d_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_2573d_row5_col0" class="data row5 col0" >0.3923</td>
#       <td id="T_2573d_row5_col1" class="data row5 col1" >0.3923</td>
#       <td id="T_2573d_row5_col2" class="data row5 col2" >0.3923</td>
#       <td id="T_2573d_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_2573d_row6_col0" class="data row6 col0" >0.4140</td>
#       <td id="T_2573d_row6_col1" class="data row6 col1" >0.5046</td>
#       <td id="T_2573d_row6_col2" class="data row6 col2" >0.3661</td>
#       <td id="T_2573d_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_2573d_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_2573d_row7_col0" class="data row7 col0" >0.5636</td>
#       <td id="T_2573d_row7_col1" class="data row7 col1" >0.3923</td>
#       <td id="T_2573d_row7_col2" class="data row7 col2" >0.4020</td>
#       <td id="T_2573d_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
# SVC Poly
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_c948e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c948e_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c948e_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c948e_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c948e_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c948e_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_c948e_row0_col0" class="data row0 col0" >0.8892</td>
#       <td id="T_c948e_row0_col1" class="data row0 col1" >0.9698</td>
#       <td id="T_c948e_row0_col2" class="data row0 col2" >0.9278</td>
#       <td id="T_c948e_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_c948e_row1_col0" class="data row1 col0" >0.9828</td>
#       <td id="T_c948e_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_c948e_row1_col2" class="data row1 col2" >0.9913</td>
#       <td id="T_c948e_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_c948e_row2_col0" class="data row2 col0" >0.9451</td>
#       <td id="T_c948e_row2_col1" class="data row2 col1" >0.9777</td>
#       <td id="T_c948e_row2_col2" class="data row2 col2" >0.9611</td>
#       <td id="T_c948e_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_c948e_row3_col0" class="data row3 col0" >0.9777</td>
#       <td id="T_c948e_row3_col1" class="data row3 col1" >0.9637</td>
#       <td id="T_c948e_row3_col2" class="data row3 col2" >0.9707</td>
#       <td id="T_c948e_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_c948e_row4_col0" class="data row4 col0" >0.9938</td>
#       <td id="T_c948e_row4_col1" class="data row4 col1" >0.9652</td>
#       <td id="T_c948e_row4_col2" class="data row4 col2" >0.9793</td>
#       <td id="T_c948e_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_c948e_row5_col0" class="data row5 col0" >0.9688</td>
#       <td id="T_c948e_row5_col1" class="data row5 col1" >0.9688</td>
#       <td id="T_c948e_row5_col2" class="data row5 col2" >0.9688</td>
#       <td id="T_c948e_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_c948e_row6_col0" class="data row6 col0" >0.9577</td>
#       <td id="T_c948e_row6_col1" class="data row6 col1" >0.9753</td>
#       <td id="T_c948e_row6_col2" class="data row6 col2" >0.9660</td>
#       <td id="T_c948e_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_c948e_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_c948e_row7_col0" class="data row7 col0" >0.9699</td>
#       <td id="T_c948e_row7_col1" class="data row7 col1" >0.9688</td>
#       <td id="T_c948e_row7_col2" class="data row7 col2" >0.9690</td>
#       <td id="T_c948e_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
# SVC RBF
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_64983">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64983_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_64983_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_64983_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_64983_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64983_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_64983_row0_col0" class="data row0 col0" >0.8889</td>
#       <td id="T_64983_row0_col1" class="data row0 col1" >0.9752</td>
#       <td id="T_64983_row0_col2" class="data row0 col2" >0.9300</td>
#       <td id="T_64983_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_64983_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_64983_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_64983_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_64983_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_64983_row2_col0" class="data row2 col0" >0.9510</td>
#       <td id="T_64983_row2_col1" class="data row2 col1" >0.9760</td>
#       <td id="T_64983_row2_col2" class="data row2 col2" >0.9633</td>
#       <td id="T_64983_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_64983_row3_col0" class="data row3 col0" >0.9787</td>
#       <td id="T_64983_row3_col1" class="data row3 col1" >0.9702</td>
#       <td id="T_64983_row3_col2" class="data row3 col2" >0.9744</td>
#       <td id="T_64983_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_64983_row4_col0" class="data row4 col0" >0.9971</td>
#       <td id="T_64983_row4_col1" class="data row4 col1" >0.9692</td>
#       <td id="T_64983_row4_col2" class="data row4 col2" >0.9830</td>
#       <td id="T_64983_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_64983_row5_col0" class="data row5 col0" >0.9721</td>
#       <td id="T_64983_row5_col1" class="data row5 col1" >0.9721</td>
#       <td id="T_64983_row5_col2" class="data row5 col2" >0.9721</td>
#       <td id="T_64983_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_64983_row6_col0" class="data row6 col0" >0.9631</td>
#       <td id="T_64983_row6_col1" class="data row6 col1" >0.9781</td>
#       <td id="T_64983_row6_col2" class="data row6 col2" >0.9702</td>
#       <td id="T_64983_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_64983_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_64983_row7_col0" class="data row7 col0" >0.9733</td>
#       <td id="T_64983_row7_col1" class="data row7 col1" >0.9721</td>
#       <td id="T_64983_row7_col2" class="data row7 col2" >0.9724</td>
#       <td id="T_64983_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
# SVC Sigmoid
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_0a8a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a8a6_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_0a8a6_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_0a8a6_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_0a8a6_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a8a6_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_0a8a6_row0_col0" class="data row0 col0" >0.1764</td>
#       <td id="T_0a8a6_row0_col1" class="data row0 col1" >0.4412</td>
#       <td id="T_0a8a6_row0_col2" class="data row0 col2" >0.2520</td>
#       <td id="T_0a8a6_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_0a8a6_row1_col0" class="data row1 col0" >0.1098</td>
#       <td id="T_0a8a6_row1_col1" class="data row1 col1" >0.6507</td>
#       <td id="T_0a8a6_row1_col2" class="data row1 col2" >0.1879</td>
#       <td id="T_0a8a6_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_0a8a6_row2_col0" class="data row2 col0" >0.3587</td>
#       <td id="T_0a8a6_row2_col1" class="data row2 col1" >0.6515</td>
#       <td id="T_0a8a6_row2_col2" class="data row2 col2" >0.4627</td>
#       <td id="T_0a8a6_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_0a8a6_row3_col0" class="data row3 col0" >0.5619</td>
#       <td id="T_0a8a6_row3_col1" class="data row3 col1" >0.1744</td>
#       <td id="T_0a8a6_row3_col2" class="data row3 col2" >0.2661</td>
#       <td id="T_0a8a6_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_0a8a6_row4_col0" class="data row4 col0" >0.6871</td>
#       <td id="T_0a8a6_row4_col1" class="data row4 col1" >0.2749</td>
#       <td id="T_0a8a6_row4_col2" class="data row4 col2" >0.3927</td>
#       <td id="T_0a8a6_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_0a8a6_row5_col0" class="data row5 col0" >0.3583</td>
#       <td id="T_0a8a6_row5_col1" class="data row5 col1" >0.3583</td>
#       <td id="T_0a8a6_row5_col2" class="data row5 col2" >0.3583</td>
#       <td id="T_0a8a6_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_0a8a6_row6_col0" class="data row6 col0" >0.3788</td>
#       <td id="T_0a8a6_row6_col1" class="data row6 col1" >0.4385</td>
#       <td id="T_0a8a6_row6_col2" class="data row6 col2" >0.3123</td>
#       <td id="T_0a8a6_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_0a8a6_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_0a8a6_row7_col0" class="data row7 col0" >0.5289</td>
#       <td id="T_0a8a6_row7_col1" class="data row7 col1" >0.3583</td>
#       <td id="T_0a8a6_row7_col2" class="data row7 col2" >0.3629</td>
#       <td id="T_0a8a6_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
# XGBoost GBTree
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_a05fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a05fa_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a05fa_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a05fa_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a05fa_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a05fa_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_a05fa_row0_col0" class="data row0 col0" >0.9218</td>
#       <td id="T_a05fa_row0_col1" class="data row0 col1" >0.9536</td>
#       <td id="T_a05fa_row0_col2" class="data row0 col2" >0.9374</td>
#       <td id="T_a05fa_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_a05fa_row1_col0" class="data row1 col0" >0.9912</td>
#       <td id="T_a05fa_row1_col1" class="data row1 col1" >0.9869</td>
#       <td id="T_a05fa_row1_col2" class="data row1 col2" >0.9891</td>
#       <td id="T_a05fa_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_a05fa_row2_col0" class="data row2 col0" >0.9552</td>
#       <td id="T_a05fa_row2_col1" class="data row2 col1" >0.9703</td>
#       <td id="T_a05fa_row2_col2" class="data row2 col2" >0.9627</td>
#       <td id="T_a05fa_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_a05fa_row3_col0" class="data row3 col0" >0.9697</td>
#       <td id="T_a05fa_row3_col1" class="data row3 col1" >0.9681</td>
#       <td id="T_a05fa_row3_col2" class="data row3 col2" >0.9689</td>
#       <td id="T_a05fa_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_a05fa_row4_col0" class="data row4 col0" >0.9876</td>
#       <td id="T_a05fa_row4_col1" class="data row4 col1" >0.9742</td>
#       <td id="T_a05fa_row4_col2" class="data row4 col2" >0.9808</td>
#       <td id="T_a05fa_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_a05fa_row5_col0" class="data row5 col0" >0.9704</td>
#       <td id="T_a05fa_row5_col1" class="data row5 col1" >0.9704</td>
#       <td id="T_a05fa_row5_col2" class="data row5 col2" >0.9704</td>
#       <td id="T_a05fa_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_a05fa_row6_col0" class="data row6 col0" >0.9651</td>
#       <td id="T_a05fa_row6_col1" class="data row6 col1" >0.9706</td>
#       <td id="T_a05fa_row6_col2" class="data row6 col2" >0.9678</td>
#       <td id="T_a05fa_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_a05fa_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_a05fa_row7_col0" class="data row7 col0" >0.9707</td>
#       <td id="T_a05fa_row7_col1" class="data row7 col1" >0.9704</td>
#       <td id="T_a05fa_row7_col2" class="data row7 col2" >0.9705</td>
#       <td id="T_a05fa_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
# XGBoost Dart
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_96c86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96c86_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_96c86_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_96c86_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_96c86_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96c86_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_96c86_row0_col0" class="data row0 col0" >0.9168</td>
#       <td id="T_96c86_row0_col1" class="data row0 col1" >0.9504</td>
#       <td id="T_96c86_row0_col2" class="data row0 col2" >0.9333</td>
#       <td id="T_96c86_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_96c86_row1_col0" class="data row1 col0" >0.9913</td>
#       <td id="T_96c86_row1_col1" class="data row1 col1" >0.9913</td>
#       <td id="T_96c86_row1_col2" class="data row1 col2" >0.9913</td>
#       <td id="T_96c86_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_96c86_row2_col0" class="data row2 col0" >0.9452</td>
#       <td id="T_96c86_row2_col1" class="data row2 col1" >0.9720</td>
#       <td id="T_96c86_row2_col2" class="data row2 col2" >0.9584</td>
#       <td id="T_96c86_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_96c86_row3_col0" class="data row3 col0" >0.9664</td>
#       <td id="T_96c86_row3_col1" class="data row3 col1" >0.9672</td>
#       <td id="T_96c86_row3_col2" class="data row3 col2" >0.9668</td>
#       <td id="T_96c86_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_96c86_row4_col0" class="data row4 col0" >0.9886</td>
#       <td id="T_96c86_row4_col1" class="data row4 col1" >0.9671</td>
#       <td id="T_96c86_row4_col2" class="data row4 col2" >0.9777</td>
#       <td id="T_96c86_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_96c86_row5_col0" class="data row5 col0" >0.9672</td>
#       <td id="T_96c86_row5_col1" class="data row5 col1" >0.9672</td>
#       <td id="T_96c86_row5_col2" class="data row5 col2" >0.9672</td>
#       <td id="T_96c86_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_96c86_row6_col0" class="data row6 col0" >0.9616</td>
#       <td id="T_96c86_row6_col1" class="data row6 col1" >0.9696</td>
#       <td id="T_96c86_row6_col2" class="data row6 col2" >0.9655</td>
#       <td id="T_96c86_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_96c86_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_96c86_row7_col0" class="data row7 col0" >0.9677</td>
#       <td id="T_96c86_row7_col1" class="data row7 col1" >0.9672</td>
#       <td id="T_96c86_row7_col2" class="data row7 col2" >0.9674</td>
#       <td id="T_96c86_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# ============================================================
# CatBoost
# ============================================================
# <style type="text/css">
# </style>
# <table id="T_2645a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2645a_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_2645a_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_2645a_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_2645a_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2645a_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_2645a_row0_col0" class="data row0 col0" >0.9255</td>
#       <td id="T_2645a_row0_col1" class="data row0 col1" >0.9644</td>
#       <td id="T_2645a_row0_col2" class="data row0 col2" >0.9445</td>
#       <td id="T_2645a_row0_col3" class="data row0 col3" >927</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_2645a_row1_col0" class="data row1 col0" >0.9913</td>
#       <td id="T_2645a_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_2645a_row1_col2" class="data row1 col2" >0.9957</td>
#       <td id="T_2645a_row1_col3" class="data row1 col3" >229</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_2645a_row2_col0" class="data row2 col0" >0.9600</td>
#       <td id="T_2645a_row2_col1" class="data row2 col1" >0.9764</td>
#       <td id="T_2645a_row2_col2" class="data row2 col2" >0.9681</td>
#       <td id="T_2645a_row2_col3" class="data row2 col3" >2287</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_2645a_row3_col0" class="data row3 col0" >0.9775</td>
#       <td id="T_2645a_row3_col1" class="data row3 col1" >0.9745</td>
#       <td id="T_2645a_row3_col2" class="data row3 col2" >0.9760</td>
#       <td id="T_2645a_row3_col3" class="data row3 col3" >2317</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_2645a_row4_col0" class="data row4 col0" >0.9921</td>
#       <td id="T_2645a_row4_col1" class="data row4 col1" >0.9766</td>
#       <td id="T_2645a_row4_col2" class="data row4 col2" >0.9843</td>
#       <td id="T_2645a_row4_col3" class="data row4 col3" >4649</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row5" class="row_heading level0 row5" >accuracy</th>
#       <td id="T_2645a_row5_col0" class="data row5 col0" >0.9755</td>
#       <td id="T_2645a_row5_col1" class="data row5 col1" >0.9755</td>
#       <td id="T_2645a_row5_col2" class="data row5 col2" >0.9755</td>
#       <td id="T_2645a_row5_col3" class="data row5 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row6" class="row_heading level0 row6" >macro avg</th>
#       <td id="T_2645a_row6_col0" class="data row6 col0" >0.9693</td>
#       <td id="T_2645a_row6_col1" class="data row6 col1" >0.9784</td>
#       <td id="T_2645a_row6_col2" class="data row6 col2" >0.9737</td>
#       <td id="T_2645a_row6_col3" class="data row6 col3" >10409</td>
#     </tr>
#     <tr>
#       <th id="T_2645a_level0_row7" class="row_heading level0 row7" >weighted avg</th>
#       <td id="T_2645a_row7_col0" class="data row7 col0" >0.9759</td>
#       <td id="T_2645a_row7_col1" class="data row7 col1" >0.9755</td>
#       <td id="T_2645a_row7_col2" class="data row7 col2" >0.9756</td>
#       <td id="T_2645a_row7_col3" class="data row7 col3" >10409</td>
#     </tr>
#   </tbody>
# </table>
# F1-score per kelas — perbandingan antar model:
# <style type="text/css">
# #T_6ac94_row0_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_6ac94_row0_col1, #T_6ac94_row0_col2 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_6ac94_row0_col3 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_6ac94_row0_col4 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_6ac94_row0_col5 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_6ac94_row0_col6 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_6ac94_row1_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_6ac94_row1_col1, #T_6ac94_row1_col5 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_6ac94_row1_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6ac94_row1_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6ac94_row1_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_6ac94_row1_col6 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_6ac94_row2_col0 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_6ac94_row2_col1 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_6ac94_row2_col2, #T_6ac94_row2_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_6ac94_row2_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_6ac94_row2_col5 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_6ac94_row2_col6, #T_6ac94_row3_col5 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_6ac94_row3_col0 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_6ac94_row3_col1, #T_6ac94_row3_col4 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_6ac94_row3_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_6ac94_row3_col3 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_6ac94_row3_col6, #T_6ac94_row4_col5 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_6ac94_row4_col0 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_6ac94_row4_col1, #T_6ac94_row4_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_6ac94_row4_col2 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_6ac94_row4_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_6ac94_row4_col6 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ac94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ac94_level0_col0" class="col_heading level0 col0" >SVC Linear</th>
#       <th id="T_6ac94_level0_col1" class="col_heading level0 col1" >SVC Poly</th>
#       <th id="T_6ac94_level0_col2" class="col_heading level0 col2" >SVC RBF</th>
#       <th id="T_6ac94_level0_col3" class="col_heading level0 col3" >SVC Sigmoid</th>
#       <th id="T_6ac94_level0_col4" class="col_heading level0 col4" >XGBoost GBTree</th>
#       <th id="T_6ac94_level0_col5" class="col_heading level0 col5" >XGBoost Dart</th>
#       <th id="T_6ac94_level0_col6" class="col_heading level0 col6" >CatBoost</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Kelas</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ac94_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_6ac94_row0_col0" class="data row0 col0" >0.3104</td>
#       <td id="T_6ac94_row0_col1" class="data row0 col1" >0.9278</td>
#       <td id="T_6ac94_row0_col2" class="data row0 col2" >0.9300</td>
#       <td id="T_6ac94_row0_col3" class="data row0 col3" >0.2520</td>
#       <td id="T_6ac94_row0_col4" class="data row0 col4" >0.9374</td>
#       <td id="T_6ac94_row0_col5" class="data row0 col5" >0.9333</td>
#       <td id="T_6ac94_row0_col6" class="data row0 col6" >0.9445</td>
#     </tr>
#     <tr>
#       <th id="T_6ac94_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_6ac94_row1_col0" class="data row1 col0" >0.2876</td>
#       <td id="T_6ac94_row1_col1" class="data row1 col1" >0.9913</td>
#       <td id="T_6ac94_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_6ac94_row1_col3" class="data row1 col3" >0.1879</td>
#       <td id="T_6ac94_row1_col4" class="data row1 col4" >0.9891</td>
#       <td id="T_6ac94_row1_col5" class="data row1 col5" >0.9913</td>
#       <td id="T_6ac94_row1_col6" class="data row1 col6" >0.9957</td>
#     </tr>
#     <tr>
#       <th id="T_6ac94_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_6ac94_row2_col0" class="data row2 col0" >0.4461</td>
#       <td id="T_6ac94_row2_col1" class="data row2 col1" >0.9611</td>
#       <td id="T_6ac94_row2_col2" class="data row2 col2" >0.9633</td>
#       <td id="T_6ac94_row2_col3" class="data row2 col3" >0.4627</td>
#       <td id="T_6ac94_row2_col4" class="data row2 col4" >0.9627</td>
#       <td id="T_6ac94_row2_col5" class="data row2 col5" >0.9584</td>
#       <td id="T_6ac94_row2_col6" class="data row2 col6" >0.9681</td>
#     </tr>
#     <tr>
#       <th id="T_6ac94_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_6ac94_row3_col0" class="data row3 col0" >0.3627</td>
#       <td id="T_6ac94_row3_col1" class="data row3 col1" >0.9707</td>
#       <td id="T_6ac94_row3_col2" class="data row3 col2" >0.9744</td>
#       <td id="T_6ac94_row3_col3" class="data row3 col3" >0.2661</td>
#       <td id="T_6ac94_row3_col4" class="data row3 col4" >0.9689</td>
#       <td id="T_6ac94_row3_col5" class="data row3 col5" >0.9668</td>
#       <td id="T_6ac94_row3_col6" class="data row3 col6" >0.9760</td>
#     </tr>
#     <tr>
#       <th id="T_6ac94_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_6ac94_row4_col0" class="data row4 col0" >0.4238</td>
#       <td id="T_6ac94_row4_col1" class="data row4 col1" >0.9793</td>
#       <td id="T_6ac94_row4_col2" class="data row4 col2" >0.9830</td>
#       <td id="T_6ac94_row4_col3" class="data row4 col3" >0.3927</td>
#       <td id="T_6ac94_row4_col4" class="data row4 col4" >0.9808</td>
#       <td id="T_6ac94_row4_col5" class="data row4 col5" >0.9777</td>
#       <td id="T_6ac94_row4_col6" class="data row4 col6" >0.9843</td>
#     </tr>
#   </tbody>
# </table>
# ✅ Saved: ./results/classification_report_<model>.csv & per_class_f1_compare.csv

# %% [markdown]
# CatBoost terakhir dengan waktu eksekusi 168.8900 merupakan `loss_function="Multiclass"`, sedangkan dua sisanya adalah `loss_function="MulticlassOneVsAll"`

# %%
import os
os.makedirs('./results', exist_ok=True)
eval_df.to_csv('./results/eval_classical_final_hpo.csv', index=True)
print('✅ Saved: ./results/eval_classical_final_hpo.csv')
# Out:
# ✅ Saved: ./results/eval_classical_final_hpo.csv

# %% [markdown]
# ---
# ## 📈 Kurva per Model — Macro-F1 & Loss Function
#
# Untuk **tiap model** (semua pakai `class_weight='balanced'`) ditampilkan learning curve train vs validasi dengan dua metrik: **Macro-F1** (↑ makin baik, tahan terhadap imbalance) dan **Log Loss** (loss function / cross-entropy, ↓ makin baik).

# %%
# ════════════════════════════════════════════════════════════
# 📈 Learning Curve — semua model classical (balanced)
#     Dua metrik per model: Macro-F1 (↑ makin baik) & Log Loss (↓ makin baik)
# ════════════════════════════════════════════════════════════
# Untuk tiap model best, hitung kurva train vs val pada beberapa ukuran
# training set, dengan DUA scoring:
#   - Macro-F1 : rata-rata F1 antar kelas (tidak bias ke kelas mayoritas →
#                cocok untuk data imbalance).
#   - Log Loss : loss function (cross-entropy) untuk cek overfit/underfit.
#
# CATATAN PERFORMA:
#   - Default pakai seluruh data (LC_N = len(X)). Turunkan LC_N untuk lebih cepat.
#   - SVC dengan training >5000 sampel akan sangat lambat (O(N²)).

import numpy as np
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.model_selection import learning_curve, StratifiedShuffleSplit, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.utils.class_weight import compute_sample_weight
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# ── Konfigurasi ───────────────────────────────────────────────────────────────
LC_N           = len(X)                                  # subsample (stratified)
LC_TRAIN_SIZES = np.linspace(0.2, 1.0, 5)                # 5 titik kurva
LC_CV          = 5                                       # CV folds (StratifiedKFold shuffle=True, sama dengan training)
LC_STATE       = 42
LC_BASELINE    = float(np.log(len(np.unique(y))))        # log loss tebakan-acak (ambang verdict loss)


# ── Wrapper XGBoost agar otomatis compute sample_weight per .fit() ────────────
class XGBBalancedWrapper(ClassifierMixin, BaseEstimator):
    """XGBClassifier yang otomatis pakai class_weight='balanced' analog SVC."""
    def __init__(self, **xgb_params):
        self.xgb_params = xgb_params

    def get_params(self, deep=True):
        return dict(self.xgb_params)

    def set_params(self, **params):
        self.xgb_params.update(params)
        return self

    def fit(self, X, y, sample_weight=None):
        self.model_ = XGBClassifier(device='cuda', **self.xgb_params)
        sw = compute_sample_weight("balanced", y) if sample_weight is None else sample_weight
        self.model_.fit(X, y, sample_weight=sw)
        self.classes_ = self.model_.classes_
        return self

    def predict(self, X):
        return self.model_.predict(X)

    def predict_proba(self, X):
        return self.model_.predict_proba(X)


# ── Factory: rekonstruksi pipeline dari (model_name, best_params) ────────────
#    Semua classifier memakai bobot kelas 'balanced' (class_weight /
#    sample_weight / auto_class_weights) — konsisten dengan training di atas.
def make_classical(model_name, params):
    base = [
        ("scaler", StandardScaler()),
        ("pca",    PCA(n_components=n_optimal)),
    ]
    if   model_name == "SVC Linear":
        clf = SVC(kernel="linear",  probability=True, random_state=42,
                  decision_function_shape="ovr", class_weight='balanced', **params)
    elif model_name == "SVC Poly":
        clf = SVC(kernel="poly",    probability=True, random_state=42,
                  decision_function_shape="ovr", class_weight='balanced', **params)
    elif model_name == "SVC RBF":
        clf = SVC(kernel="rbf",     probability=True, random_state=42,
                  decision_function_shape="ovr", class_weight='balanced', **params)
    elif model_name == "SVC Sigmoid":
        clf = SVC(kernel="sigmoid", probability=True, random_state=42,
                  decision_function_shape="ovr", class_weight='balanced', **params)
    elif model_name == "XGBoost GBTree":
        clf = XGBBalancedWrapper(booster="gbtree", objective="multi:softprob",
                                 random_state=42, **params)
    elif model_name == "XGBoost Dart":
        clf = XGBBalancedWrapper(booster="dart",  objective="multi:softprob",
                                 random_state=42, **params)
    elif model_name == "CatBoost":
        clf = CatBoostClassifier(
            loss_function="MultiClassOneVsAll",
            eval_metric="Accuracy",
            verbose=0,
            random_seed=42,
            auto_class_weights="Balanced",
            task_type="GPU",
            **params,
        )
    else:
        raise ValueError(f"Unknown model_name: {model_name}")
    base.append(("clf", clf))
    return Pipeline(base)


# ── Stratified subsample untuk speed ──────────────────────────────────────────
if LC_N < len(X):
    sss = StratifiedShuffleSplit(n_splits=1, train_size=LC_N, random_state=LC_STATE)
    sub_idx, _ = next(sss.split(X, y))
    X_lc, y_lc = X.iloc[sub_idx], y[sub_idx]
else:
    X_lc, y_lc = X, y
print(f"📊 Learning curve on N={len(X_lc)} samples | CV={LC_CV} | sizes={LC_TRAIN_SIZES}")

# ── Hitung learning curve per model untuk DUA metrik (macro-F1 & log loss) ────
_lc_common = dict(
    train_sizes=LC_TRAIN_SIZES,
    cv=StratifiedKFold(n_splits=LC_CV, shuffle=True, random_state=LC_STATE),
    n_jobs=1, shuffle=True, random_state=LC_STATE, error_score='raise',
)
lc_results = []
for entry in all_best:
    name   = entry["model"]
    params = entry.get("params", {})
    print(f"\n  ▶ {name}  ({params}) ...", end=" ", flush=True)
    try:
        pipe = make_classical(name, params)
        # Macro-F1 (makin besar makin baik)
        ts, f1_tr, f1_va = learning_curve(
            pipe, X_lc, y_lc, scoring="f1_macro", **_lc_common)
        # Log loss / cross-entropy (neg_log_loss → dibalik ke positif; makin kecil makin baik)
        _,  ll_tr, ll_va = learning_curve(
            pipe, X_lc, y_lc, scoring="neg_log_loss", **_lc_common)
        ll_tr, ll_va = -ll_tr, -ll_va
        lc_results.append({
            "model":       name,
            "params":      params,
            "train_sizes": ts,
            "f1_train_mean": f1_tr.mean(axis=1), "f1_train_std": f1_tr.std(axis=1),
            "f1_val_mean":   f1_va.mean(axis=1), "f1_val_std":   f1_va.std(axis=1),
            "loss_train_mean": ll_tr.mean(axis=1), "loss_train_std": ll_tr.std(axis=1),
            "loss_val_mean":   ll_va.mean(axis=1), "loss_val_std":   ll_va.std(axis=1),
        })
        print("done")
    except Exception as e:
        print(f"FAILED — {type(e).__name__}: {e}")


# ── Helper plot grid satu metrik ──────────────────────────────────────────────
def _plot_lc_grid(metric, ylabel, lower_is_better, verdict_fn, fname, suptitle):
    n_models = len(lc_results)
    ncols    = 3
    nrows    = (n_models + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols,
                             figsize=(5.5 * ncols, 4 * nrows),
                             constrained_layout=True)
    axes = np.array(axes).flatten()
    for ax, r in zip(axes, lc_results):
        ts   = r["train_sizes"]
        trm, trs = r[f"{metric}_train_mean"], r[f"{metric}_train_std"]
        vam, vas = r[f"{metric}_val_mean"],   r[f"{metric}_val_std"]
        ax.plot(ts, trm, "o-", color="steelblue",  linewidth=2, label="Train")
        ax.fill_between(ts, trm - trs, trm + trs, alpha=0.2, color="steelblue")
        ax.plot(ts, vam, "s-", color="darkorange", linewidth=2, label="Val")
        ax.fill_between(ts, vam - vas, vam + vas, alpha=0.2, color="darkorange")
        gap, verdict = verdict_fn(trm, vam)
        ax.set_title(f"{r['model']}\ngap={gap:+.3f}  |  {verdict}",
                     fontsize=11, fontweight="bold")
        ax.set_xlabel("Training set size")
        ax.set_ylabel(ylabel)
        if lower_is_better:
            ax.set_ylim(bottom=0)
        else:
            ax.set_ylim(0, 1.05)
        ax.grid(True, alpha=0.4)
        ax.legend(fontsize=8)
    for ax in axes[n_models:]:
        ax.set_visible(False)
    fig.suptitle(suptitle, fontsize=13, fontweight="bold")
    import os
    os.makedirs("./results", exist_ok=True)
    fig.savefig(fname, dpi=120, bbox_inches="tight")
    print(f"📊 Plot disimpan → {fname}")
    plt.show()


# ── Verdict per metrik (gap train↔val di ukuran training terbesar) ───────────
def _verdict_f1(trm, vam):
    gap = trm[-1] - vam[-1]                # train_f1 − val_f1 (>0 → overfit)
    if   gap > 0.15:                          v = "⚠️ OVERFIT"
    elif vam[-1] < 0.50:                      v = "⚠️ UNDERFIT"
    elif gap < 0.05 and vam[-1] > 0.70:       v = "✅ Well-fit"
    else:                                     v = "🟡 Mild gap"
    return gap, v

def _verdict_loss(trm, vam):
    gap = vam[-1] - trm[-1]                # val_loss − train_loss (>0 → overfit)
    if   gap > 0.15 * LC_BASELINE:                                  v = "⚠️ OVERFIT"
    elif vam[-1] > 0.80 * LC_BASELINE:                             v = "⚠️ UNDERFIT"
    elif gap < 0.05 * LC_BASELINE and vam[-1] < 0.40 * LC_BASELINE: v = "✅ Well-fit"
    else:                                                          v = "🟡 Mild gap"
    return gap, v
# Out:
# 📊 Learning curve on N=10409 samples | CV=5 | sizes=[0.2 0.4 0.6 0.8 1. ]
#
#   ▶ SVC Linear  ({'C': 10, 'tol': 0.1}) ... done
#
#   ▶ SVC Poly  ({'C': 1, 'tol': 0.1, 'degree': 5, 'gamma': 0.5, 'coef0': 3}) ... done
#
#   ▶ SVC RBF  ({'C': 10, 'tol': 0.1, 'gamma': 0.5}) ... done
#
#   ▶ SVC Sigmoid  ({'C': 1, 'tol': 0.1, 'gamma': 0.01, 'coef0': 0}) ... done
#
#   ▶ XGBoost GBTree  ({'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 10}) ... done
#
#   ▶ XGBoost Dart  ({'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 10, 'rate_drop': 0.1, 'skip_drop': 0.5}) ... done
#
#   ▶ CatBoost  ({'iterations': 500, 'depth': 10, 'learning_rate': 0.1, 'l2_leaf_reg': 1}) ... done

# %%
# ── Grid 1: Macro-F1 ────────────────
_plot_lc_grid(
    "f1", "Macro-F1", lower_is_better=False, verdict_fn=_verdict_f1,
    fname="./results/learning_curve_classical_balanced_hpo_macrof1.png",
    suptitle=(f"Learning Curve (Macro-F1) — Classical Models (class_weight='balanced')  |  "
              f"N={len(X_lc)} | CV={LC_CV}"),
)

# ── Grid 2: Log Loss (loss function) ──────────
_plot_lc_grid(
    "loss", "log loss", lower_is_better=True, verdict_fn=_verdict_loss,
    fname="./results/learning_curve_classical_balanced_hpo_logloss.png",
    suptitle=(f"Learning Curve (Log Loss) — Classical Models (class_weight='balanced')  |  "
              f"N={len(X_lc)} | CV={LC_CV}"),
)

# ── Ringkasan tekstual (training size terbesar) ──────
# F1Gap  = Train−Val (>0 → overfit); LossGap = Val−Train (>0 → overfit).
print("\n──── Ringkasan akhir (training size terbesar) ────")
print(f"{'Model':<20s} {'TrainF1':>9s} {'ValF1':>9s} {'F1Gap':>8s} "
      f"{'TrainLoss':>10s} {'ValLoss':>10s} {'LossGap':>8s}")
for r in sorted(lc_results, key=lambda x: -x["f1_val_mean"][-1]):
    f1_gap   = r["f1_train_mean"][-1] - r["f1_val_mean"][-1]
    loss_gap = r["loss_val_mean"][-1] - r["loss_train_mean"][-1]
    print(f"{r['model']:<20s} "
          f"{r['f1_train_mean'][-1]:>9.4f} {r['f1_val_mean'][-1]:>9.4f} {f1_gap:>+8.4f} "
          f"{r['loss_train_mean'][-1]:>10.4f} {r['loss_val_mean'][-1]:>10.4f} {loss_gap:>+8.4f}")
# Out:
# 📊 Plot disimpan → ./results/learning_curve_classical_balanced_hpo_macrof1.png
# 📊 Plot disimpan → ./results/learning_curve_classical_balanced_hpo_logloss.png
# ──── Ringkasan akhir (training size terbesar) ────
# Model                  TrainF1     ValF1    F1Gap  TrainLoss    ValLoss  LossGap
# CatBoost                0.9980    0.9741  +0.0239     0.0194     0.0697  +0.0504
# SVC RBF                 0.9721    0.9700  +0.0020     0.0688     0.0786  +0.0098
# XGBoost GBTree          0.9978    0.9673  +0.0305     0.0177     0.0826  +0.0649
# SVC Poly                0.9782    0.9670  +0.0112     0.0887     0.1068  +0.0180
# XGBoost Dart            0.9930    0.9645  +0.0285     0.0380     0.0972  +0.0592
# SVC Linear              0.3660    0.3658  +0.0002     1.1361     1.1374  +0.0013
# SVC Sigmoid             0.3128    0.3110  +0.0018     1.1614     1.1628  +0.0015
