# %% [markdown]
# # Handle Class Imbalance — Hybrid Sampling (SMOTEENN vs SMOTETomek) vs Adjusted Model
#
# **Hybrid sampling** = oversampling (SMOTE) lalu pembersihan mayoritas. Dua varian dibandingkan: **SMOTEENN** (SMOTE + Edited Nearest Neighbours) dan **SMOTETomek** (SMOTE + Tomek Links). Keduanya diadu dengan baseline **adjusted** (class_weight balanced) pada 7 model identik. Resampling hanya pada **fold training** (anti-bocor).
#
# Dataset `Dataset_TehHijau.csv` **ber-grup**: 274 `Sampling_ID`. CV memakai `StratifiedKFold(groups=Sampling_ID)`; metrik andalan **balanced accuracy** & **macro-F1**.
#
# > ⚠️ **Runtime:** hybrid meng-oversample ke level mayoritas (~23k baris/fold) lalu cleaning -> SVC `probability=True` sangat lambat, dan tiap model dijalankan untuk **tiap** teknik. Komentari model/teknik yang tak perlu di `MODELS`/`RESAMPLERS`.

# %%
# !python -m pip install -q numpy pandas scikit-learn imbalanced-learn \
    xgboost catboost matplotlib seaborn
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys, os
import warnings
warnings.filterwarnings('ignore')

cwd = os.path.abspath(os.getcwd())
project_root = cwd.split('codes')[0] + 'codes'
sys.path.append(os.path.abspath(project_root))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
import importlib

def reload_package(package_name):
    for name in sorted([n for n in sys.modules if n.startswith(package_name)], reverse=True):
        importlib.reload(sys.modules[name])

reload_package('utils')

# %% [markdown]
# ## 1. Konfigurasi

# %%
from imblearn.combine import SMOTEENN, SMOTETomek
from imblearn.over_sampling import SMOTE
from utils.imbalance_eval import (
    evaluate_cv, resample_for_viz, make_resample_pipeline, BEST_PARAMS, MODEL_ORDER)

dataset_path = os.path.join(project_root, 'dataset', 'Dataset_TehHijau.csv')

feature_cols = [
    'MQ3', 'TGS822', 'TGS2602', 'MQ5', 'MQ138', 'TGS2620',
    'TGS813', 'TGS2600', 'TGS2611', 'TGS2603', 'Humidity', 'Celsius',
]
target_col = 'Kategori'
group_col  = 'Sampling_ID'

# Teknik resampling yang dibandingkan (urutan dipakai di tabel/plot).
# Komentari yang tak perlu untuk menghemat waktu.
RESAMPLERS = {
    'SMOTEENN':   SMOTEENN(random_state=42),
    'SMOTETomek': SMOTETomek(random_state=42),
    'SMOTE':     SMOTE(random_state=42, k_neighbors=5),
}
STRATEGY = 'hybrid'

XGB_DEVICE   = 'cuda'   # ganti 'cpu' kalau tak ada GPU
CAT_TASK_TYPE = 'GPU'   # ganti 'CPU' kalau tak ada GPU

MODELS = list(MODEL_ORDER)
print('Models:', MODELS)
print('Teknik:', list(RESAMPLERS.keys()))

OUT_DIR = os.path.join(cwd, 'results', STRATEGY)
os.makedirs(OUT_DIR, exist_ok=True)
print('Output:', OUT_DIR)
# Out:
# Models: ['SVC Linear', 'SVC Sigmoid', 'SVC Poly', 'SVC RBF', 'XGBoost GBTree', 'XGBoost Dart', 'CatBoost']
# Teknik: ['SMOTEENN', 'SMOTETomek', 'SMOTE']
# Output: c:\`Bioinformatics\quantum-gesang\codes\notebooks\handle_imbalance\results\hybrid

# %% [markdown]
# ## 2. Muat Data & Distribusi Kelas

# %%
data = pd.read_csv(dataset_path)
print('shape:', data.shape, '| n Sampling_ID:', data[group_col].nunique())
data[target_col].value_counts().sort_index()
# Out:
# shape: (10409, 130) | n Sampling_ID: 274
# Kategori
# A     927
# B     229
# C    2287
# D    2317
# E    4649
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

X = data[feature_cols]
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(data[target_col])
groups = data[group_col].values
labels = np.unique(y)
class_names = list(label_encoder.classes_)
print('X:', X.shape, '| classes:', class_names)
# Out:
# X: (10409, 12) | classes: ['A', 'B', 'C', 'D', 'E']

# %% [markdown]
# ## 3. PCA — jumlah komponen optimal (95% varians)

# %%
from sklearn.decomposition import PCA

_pca = PCA(n_components=X.shape[1]).fit(X)
cumvar = np.cumsum(_pca.explained_variance_ratio_)
n_optimal = int(np.argmax(cumvar >= 0.95) + 1)
print('n_optimal =', n_optimal)
# Out:
# n_optimal = 4

# %% [markdown]
# ## 4. Komposisi Dataset — Sebelum vs Sesudah (tiap teknik)
#
# Jumlah baris per kelas pada 1 fold training, untuk tiap teknik. Histogram tidak terpengaruh PCA; scatter PC1–PC2 menampilkan sebaran fitur.

# %%
from collections import Counter

comp = pd.DataFrame(index=class_names)
before_xy = None
scatters = []
for tech, R in RESAMPLERS.items():
    v = resample_for_viz(X, y, groups, R, n_optimal, fold_index=0)
    if before_xy is None:
        before_xy = (v['X_before'], v['y_before'])
        comp['Sebelum'] = [Counter(v['y_before']).get(i, 0) for i in labels]
    comp[tech] = [Counter(v['y_after']).get(i, 0) for i in labels]
    scatters.append((tech, v['X_after'], v['y_after']))
print('Komposisi kelas (1 fold training):'); print(comp)
comp.to_csv(os.path.join(OUT_DIR, f'{STRATEGY}_composition.csv'))

ax = comp.plot(kind='bar', figsize=(10, 5))
ax.set_title(f'Komposisi kelas — Sebelum vs {STRATEGY}')
ax.set_xlabel('Kategori'); ax.set_ylabel('Jumlah baris'); ax.tick_params(axis='x', rotation=0)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, f'{STRATEGY}_composition_bar.png'), dpi=130, bbox_inches='tight')
plt.show()

cmap = plt.cm.tab10
panels = [('Sebelum', before_xy[0], before_xy[1])] + [(t, Xa, ya) for (t, Xa, ya) in scatters]
ncols = len(panels)
fig, axes = plt.subplots(1, ncols, figsize=(6 * ncols, 5))
axes = np.atleast_1d(axes)
for ax, (ttl, Xp, yp) in zip(axes, panels):
    for i, cn in enumerate(class_names):
        m = yp == labels[i]
        ax.scatter(Xp[m, 0], Xp[m, 1], s=8, alpha=0.4, color=cmap(i), label=f'{cn} (n={int(m.sum())})')
    ax.set_title(f'PCA PC1-PC2 — {ttl}'); ax.set_xlabel('PC1'); ax.set_ylabel('PC2')
    ax.legend(fontsize=7, markerscale=2)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, f'{STRATEGY}_composition_scatter.png'), dpi=130, bbox_inches='tight')
plt.show()
# Out:
# Komposisi kelas (1 fold training):
#    Sebelum  SMOTEENN  SMOTETomek  SMOTE
# A      742      3678        3716   3719
# B      183      3719        3719   3719
# C     1830      3612        3713   3719
# D     1853      3631        3716   3719
# E     3719      3615        3713   3719

# %% [markdown]
# ## 5. Evaluasi: Adjusted vs tiap teknik hybrid
#
# Tiap model dijalankan untuk **adjusted** (balanced, tanpa resampling) lalu **tiap teknik** (resampling di fold training, classifier tanpa bobot).

# %%
import time
from pathlib import Path
from datetime import datetime

log_path = Path(OUT_DIR) / f'{STRATEGY}_run.log'
log_path.write_text('', encoding='utf-8')

def log(msg=''):
    print(msg)
    with open(log_path, 'a', encoding='utf-8') as f:
        f.write(str(msg) + '\n')

log(f'Started: {datetime.now().isoformat(timespec="seconds")} | strategy={STRATEGY}')

common = dict(n_optimal=n_optimal, labels=labels,
              xgb_device=XGB_DEVICE, cat_task_type=CAT_TASK_TYPE, log=log)
STRATEGIES = ['adjusted'] + list(RESAMPLERS.keys())

all_results = []
for name in MODELS:
    params = BEST_PARAMS[name]
    for strat in STRATEGIES:
        log(f'\n=== {name} | {strat} ===')
        try:
            if strat == 'adjusted':
                r = evaluate_cv(X, y, groups, name, params, mode='adjusted', **common)
            else:
                r = evaluate_cv(X, y, groups, name, params, mode='resample',
                                resampler=RESAMPLERS[strat], **common)
            r['strategy'] = strat
            all_results.append(r)
        except Exception as e:
            log(f'  FAILED [{name} | {strat}] -> {type(e).__name__}: {e}')
log(f'\nDone. {len(all_results)} (model x strategi).')
# Out:
# Started: 2026-06-07T07:32:00 | strategy=hybrid
#
# === SVC Linear | adjusted ===
#     F1 -> Acc=0.3895 | BalAcc=0.4873 | MacroF1=0.3593 | AUROC=0.6943 | PRAUC=0.4838
#     F2 -> Acc=0.3963 | BalAcc=0.5010 | MacroF1=0.3644 | AUROC=0.7083 | PRAUC=0.4997
#     F3 -> Acc=0.3799 | BalAcc=0.4855 | MacroF1=0.3519 | AUROC=0.6795 | PRAUC=0.4723
#     F4 -> Acc=0.4015 | BalAcc=0.5135 | MacroF1=0.3741 | AUROC=0.6925 | PRAUC=0.4840
#     F5 -> Acc=0.3763 | BalAcc=0.5018 | MacroF1=0.3527 | AUROC=0.6848 | PRAUC=0.4729
#   OK [SVC Linear | adjusted] BalAcc=0.4978 MacroF1=0.3605 AUROC=0.6919 MCC=0.2529 (75.2s)
#
# === SVC Linear | SMOTEENN ===
#     F1 -> Acc=0.3939 | BalAcc=0.5072 | MacroF1=0.3660 | AUROC=0.7024 | PRAUC=0.4879
#     F2 -> Acc=0.4030 | BalAcc=0.5247 | MacroF1=0.3740 | AUROC=0.7170 | PRAUC=0.5044
#     F3 -> Acc=0.3866 | BalAcc=0.5065 | MacroF1=0.3600 | AUROC=0.6923 | PRAUC=0.4828
#     F4 -> Acc=0.4135 | BalAcc=0.5423 | MacroF1=0.3897 | AUROC=0.7012 | PRAUC=0.4947
#     F5 -> Acc=0.3806 | BalAcc=0.5188 | MacroF1=0.3583 | AUROC=0.6966 | PRAUC=0.4854
#   OK [SVC Linear | resample] BalAcc=0.5199 MacroF1=0.3696 AUROC=0.7019 MCC=0.2688 (232.0s)
#
# === SVC Linear | SMOTETomek ===
#     F1 -> Acc=0.3929 | BalAcc=0.4942 | MacroF1=0.3641 | AUROC=0.7024 | PRAUC=0.4886
#     F2 -> Acc=0.4011 | BalAcc=0.5184 | MacroF1=0.3712 | AUROC=0.7168 | PRAUC=0.5049
#     F3 -> Acc=0.3881 | BalAcc=0.5033 | MacroF1=0.3605 | AUROC=0.6918 | PRAUC=0.4824
#     F4 -> Acc=0.4063 | BalAcc=0.5230 | MacroF1=0.3800 | AUROC=0.7008 | PRAUC=0.4946
#     F5 -> Acc=0.3830 | BalAcc=0.5104 | MacroF1=0.3597 | AUROC=0.6963 | PRAUC=0.4861
#   OK [SVC Linear | resample] BalAcc=0.5099 MacroF1=0.3671 AUROC=0.7016 MCC=0.2620 (258.3s)
#
# === SVC Linear | SMOTE ===
#     F1 -> Acc=0.3924 | BalAcc=0.4929 | MacroF1=0.3633 | AUROC=0.7024 | PRAUC=0.4886
#     F2 -> Acc=0.4015 | BalAcc=0.5169 | MacroF1=0.3714 | AUROC=0.7168 | PRAUC=0.5050
#     F3 -> Acc=0.3871 | BalAcc=0.5024 | MacroF1=0.3598 | AUROC=0.6917 | PRAUC=0.4825
#     F4 -> Acc=0.4054 | BalAcc=0.5193 | MacroF1=0.3781 | AUROC=0.7007 | PRAUC=0.4946
#     F5 -> Acc=0.3825 | BalAcc=0.5076 | MacroF1=0.3586 | AUROC=0.6963 | PRAUC=0.4861
#   OK [SVC Linear | resample] BalAcc=0.5078 MacroF1=0.3662 AUROC=0.7016 MCC=0.2607 (256.7s)
#
# === SVC Sigmoid | adjusted ===
#     F1 -> Acc=0.1744 | BalAcc=0.2546 | MacroF1=0.1703 | AUROC=0.6297 | PRAUC=0.3937
#     F2 -> Acc=0.1744 | BalAcc=0.2680 | MacroF1=0.1738 | AUROC=0.6309 | PRAUC=0.3935
#     F3 -> Acc=0.1652 | BalAcc=0.2353 | MacroF1=0.1631 | AUROC=0.6286 | PRAUC=0.3924
#     F4 -> Acc=0.1705 | BalAcc=0.2524 | MacroF1=0.1677 | AUROC=0.6367 | PRAUC=0.3973
#     F5 -> Acc=0.1701 | BalAcc=0.2309 | MacroF1=0.1675 | AUROC=0.6390 | PRAUC=0.3898
#   OK [SVC Sigmoid | adjusted] BalAcc=0.2482 MacroF1=0.1685 AUROC=0.6330 MCC=0.0440 (112.3s)
#
# === SVC Sigmoid | SMOTEENN ===
#     F1 -> Acc=0.1796 | BalAcc=0.2408 | MacroF1=0.1713 | AUROC=0.6315 | PRAUC=0.3802
#     F2 -> Acc=0.1873 | BalAcc=0.2590 | MacroF1=0.1807 | AUROC=0.6478 | PRAUC=0.3880
#     F3 -> Acc=0.1686 | BalAcc=0.2195 | MacroF1=0.1649 | AUROC=0.6213 | PRAUC=0.3724
#     F4 -> Acc=0.1787 | BalAcc=0.2438 | MacroF1=0.1678 | AUROC=0.6364 | PRAUC=0.3912
#     F5 -> Acc=0.1658 | BalAcc=0.2118 | MacroF1=0.1574 | AUROC=0.6209 | PRAUC=0.3781
#   OK [SVC Sigmoid | resample] BalAcc=0.2350 MacroF1=0.1684 AUROC=0.6316 MCC=0.0353 (388.5s)
#
# === SVC Sigmoid | SMOTETomek ===
#     F1 -> Acc=0.1801 | BalAcc=0.2397 | MacroF1=0.1719 | AUROC=0.6273 | PRAUC=0.3755
#     F2 -> Acc=0.1883 | BalAcc=0.2592 | MacroF1=0.1820 | AUROC=0.6462 | PRAUC=0.3862
#     F3 -> Acc=0.1695 | BalAcc=0.2193 | MacroF1=0.1657 | AUROC=0.6158 | PRAUC=0.3721
#     F4 -> Acc=0.1854 | BalAcc=0.2492 | MacroF1=0.1739 | AUROC=0.6343 | PRAUC=0.3858
#     F5 -> Acc=0.1672 | BalAcc=0.2144 | MacroF1=0.1590 | AUROC=0.6167 | PRAUC=0.3784
#   OK [SVC Sigmoid | resample] BalAcc=0.2364 MacroF1=0.1705 AUROC=0.6281 MCC=0.0363 (398.9s)
#
# === SVC Sigmoid | SMOTE ===
#     F1 -> Acc=0.1806 | BalAcc=0.2408 | MacroF1=0.1724 | AUROC=0.6268 | PRAUC=0.3752
#     F2 -> Acc=0.1878 | BalAcc=0.2581 | MacroF1=0.1814 | AUROC=0.6471 | PRAUC=0.3864
#     F3 -> Acc=0.1700 | BalAcc=0.2198 | MacroF1=0.1663 | AUROC=0.6155 | PRAUC=0.3722
#     F4 -> Acc=0.1859 | BalAcc=0.2494 | MacroF1=0.1742 | AUROC=0.6364 | PRAUC=0.3891
#     F5 -> Acc=0.1663 | BalAcc=0.2100 | MacroF1=0.1580 | AUROC=0.6172 | PRAUC=0.3787
#   OK [SVC Sigmoid | resample] BalAcc=0.2356 MacroF1=0.1705 AUROC=0.6286 MCC=0.0360 (418.8s)
#
# === SVC Poly | adjusted ===
#     F1 -> Acc=0.4328 | BalAcc=0.5170 | MacroF1=0.3943 | AUROC=0.7757 | PRAUC=0.6064
#     F2 -> Acc=0.4419 | BalAcc=0.5306 | MacroF1=0.4218 | AUROC=0.7881 | PRAUC=0.6246
#     F3 -> Acc=0.4227 | BalAcc=0.5021 | MacroF1=0.4009 | AUROC=0.7804 | PRAUC=0.6110
#     F4 -> Acc=0.4270 | BalAcc=0.5132 | MacroF1=0.3969 | AUROC=0.7683 | PRAUC=0.5933
#     F5 -> Acc=0.4219 | BalAcc=0.5255 | MacroF1=0.4008 | AUROC=0.7810 | PRAUC=0.6065
#   OK [SVC Poly | adjusted] BalAcc=0.5177 MacroF1=0.4029 AUROC=0.7787 MCC=0.3230 (86.3s)
#
# === SVC Poly | SMOTEENN ===
#     F1 -> Acc=0.4616 | BalAcc=0.5284 | MacroF1=0.4225 | AUROC=0.7741 | PRAUC=0.6215
#     F2 -> Acc=0.4573 | BalAcc=0.5319 | MacroF1=0.4272 | AUROC=0.7871 | PRAUC=0.6435
#     F3 -> Acc=0.4486 | BalAcc=0.5188 | MacroF1=0.4236 | AUROC=0.7801 | PRAUC=0.6323
#     F4 -> Acc=0.4500 | BalAcc=0.5244 | MacroF1=0.4258 | AUROC=0.7687 | PRAUC=0.6122
#     F5 -> Acc=0.4426 | BalAcc=0.5309 | MacroF1=0.4170 | AUROC=0.7793 | PRAUC=0.6207
#   OK [SVC Poly | resample] BalAcc=0.5269 MacroF1=0.4232 AUROC=0.7779 MCC=0.3179 (249.0s)
#
# === SVC Poly | SMOTETomek ===
#     F1 -> Acc=0.4669 | BalAcc=0.5307 | MacroF1=0.4265 | AUROC=0.7736 | PRAUC=0.6187
#     F2 -> Acc=0.4817 | BalAcc=0.5444 | MacroF1=0.4536 | AUROC=0.7869 | PRAUC=0.6409
#     F3 -> Acc=0.4669 | BalAcc=0.5277 | MacroF1=0.4424 | AUROC=0.7790 | PRAUC=0.6288
#     F4 -> Acc=0.4587 | BalAcc=0.5276 | MacroF1=0.4341 | AUROC=0.7674 | PRAUC=0.6081
#     F5 -> Acc=0.4623 | BalAcc=0.5406 | MacroF1=0.4371 | AUROC=0.7789 | PRAUC=0.6183
#   OK [SVC Poly | resample] BalAcc=0.5342 MacroF1=0.4387 AUROC=0.7772 MCC=0.3323 (253.9s)
#
# === SVC Poly | SMOTE ===
#     F1 -> Acc=0.4669 | BalAcc=0.5307 | MacroF1=0.4265 | AUROC=0.7735 | PRAUC=0.6183
#     F2 -> Acc=0.4817 | BalAcc=0.5444 | MacroF1=0.4538 | AUROC=0.7866 | PRAUC=0.6403
#     F3 -> Acc=0.4669 | BalAcc=0.5277 | MacroF1=0.4424 | AUROC=0.7790 | PRAUC=0.6286
#     F4 -> Acc=0.4592 | BalAcc=0.5278 | MacroF1=0.4344 | AUROC=0.7672 | PRAUC=0.6074
#     F5 -> Acc=0.4647 | BalAcc=0.5417 | MacroF1=0.4397 | AUROC=0.7785 | PRAUC=0.6177
#   OK [SVC Poly | resample] BalAcc=0.5344 MacroF1=0.4394 AUROC=0.7770 MCC=0.3328 (271.2s)
#
# === SVC RBF | adjusted ===
#     F1 -> Acc=0.6888 | BalAcc=0.7738 | MacroF1=0.7109 | AUROC=0.9188 | PRAUC=0.8327
#     F2 -> Acc=0.7209 | BalAcc=0.8114 | MacroF1=0.7456 | AUROC=0.9289 | PRAUC=0.8543
#     F3 -> Acc=0.7118 | BalAcc=0.7945 | MacroF1=0.7342 | AUROC=0.9253 | PRAUC=0.8478
#     F4 -> Acc=0.7041 | BalAcc=0.7942 | MacroF1=0.7272 | AUROC=0.9225 | PRAUC=0.8420
#     F5 -> Acc=0.6944 | BalAcc=0.7836 | MacroF1=0.7258 | AUROC=0.9107 | PRAUC=0.8131
#   OK [SVC RBF | adjusted] BalAcc=0.7915 MacroF1=0.7287 AUROC=0.9212 MCC=0.6270 (103.9s)
#
# === SVC RBF | SMOTEENN ===
#     F1 -> Acc=0.7099 | BalAcc=0.8013 | MacroF1=0.7240 | AUROC=0.9370 | PRAUC=0.8675
#     F2 -> Acc=0.7411 | BalAcc=0.8293 | MacroF1=0.7585 | AUROC=0.9414 | PRAUC=0.8780
#     F3 -> Acc=0.7373 | BalAcc=0.8209 | MacroF1=0.7624 | AUROC=0.9408 | PRAUC=0.8745
#     F4 -> Acc=0.7325 | BalAcc=0.8246 | MacroF1=0.7561 | AUROC=0.9384 | PRAUC=0.8711
#     F5 -> Acc=0.7198 | BalAcc=0.8069 | MacroF1=0.7440 | AUROC=0.9258 | PRAUC=0.8423
#   OK [SVC RBF | resample] BalAcc=0.8166 MacroF1=0.7490 AUROC=0.9367 MCC=0.6578 (257.7s)
#
# === SVC RBF | SMOTETomek ===
#     F1 -> Acc=0.7085 | BalAcc=0.7969 | MacroF1=0.7220 | AUROC=0.9372 | PRAUC=0.8683
#     F2 -> Acc=0.7421 | BalAcc=0.8304 | MacroF1=0.7577 | AUROC=0.9429 | PRAUC=0.8817
#     F3 -> Acc=0.7373 | BalAcc=0.8198 | MacroF1=0.7629 | AUROC=0.9426 | PRAUC=0.8782
#     F4 -> Acc=0.7305 | BalAcc=0.8231 | MacroF1=0.7539 | AUROC=0.9405 | PRAUC=0.8759
#     F5 -> Acc=0.7194 | BalAcc=0.8059 | MacroF1=0.7436 | AUROC=0.9274 | PRAUC=0.8460
#   OK [SVC RBF | resample] BalAcc=0.8152 MacroF1=0.7480 AUROC=0.9381 MCC=0.6566 (275.4s)
#
# === SVC RBF | SMOTE ===
#     F1 -> Acc=0.7085 | BalAcc=0.7969 | MacroF1=0.7220 | AUROC=0.9372 | PRAUC=0.8684
#     F2 -> Acc=0.7421 | BalAcc=0.8304 | MacroF1=0.7577 | AUROC=0.9429 | PRAUC=0.8817
#     F3 -> Acc=0.7373 | BalAcc=0.8198 | MacroF1=0.7629 | AUROC=0.9426 | PRAUC=0.8782
#     F4 -> Acc=0.7305 | BalAcc=0.8231 | MacroF1=0.7541 | AUROC=0.9406 | PRAUC=0.8765
#     F5 -> Acc=0.7208 | BalAcc=0.8067 | MacroF1=0.7432 | AUROC=0.9277 | PRAUC=0.8471
#   OK [SVC RBF | resample] BalAcc=0.8154 MacroF1=0.7480 AUROC=0.9382 MCC=0.6569 (269.4s)
#
# === XGBoost GBTree | adjusted ===
#     F1 -> Acc=0.6345 | BalAcc=0.7286 | MacroF1=0.5840 | AUROC=0.8875 | PRAUC=0.7494
#     F2 -> Acc=0.6369 | BalAcc=0.7271 | MacroF1=0.5847 | AUROC=0.8934 | PRAUC=0.7586
#     F3 -> Acc=0.6287 | BalAcc=0.7214 | MacroF1=0.5751 | AUROC=0.8883 | PRAUC=0.7463
#     F4 -> Acc=0.6393 | BalAcc=0.7277 | MacroF1=0.6270 | AUROC=0.8919 | PRAUC=0.7538
#     F5 -> Acc=0.6012 | BalAcc=0.6964 | MacroF1=0.5859 | AUROC=0.8851 | PRAUC=0.7431
#   OK [XGBoost GBTree | adjusted] BalAcc=0.7202 MacroF1=0.5913 AUROC=0.8892 MCC=0.5125 (4.0s)
#
# === XGBoost GBTree | SMOTEENN ===
#     F1 -> Acc=0.6398 | BalAcc=0.7316 | MacroF1=0.5896 | AUROC=0.8960 | PRAUC=0.7648
#     F2 -> Acc=0.6393 | BalAcc=0.7376 | MacroF1=0.5890 | AUROC=0.9021 | PRAUC=0.7716
#     F3 -> Acc=0.6532 | BalAcc=0.7449 | MacroF1=0.5935 | AUROC=0.8959 | PRAUC=0.7615
#     F4 -> Acc=0.6907 | BalAcc=0.7622 | MacroF1=0.6745 | AUROC=0.9002 | PRAUC=0.7749
#     F5 -> Acc=0.6362 | BalAcc=0.7171 | MacroF1=0.6234 | AUROC=0.8942 | PRAUC=0.7641
#   OK [XGBoost GBTree | resample] BalAcc=0.7387 MacroF1=0.6140 AUROC=0.8977 MCC=0.5419 (4.4s)
#
# === XGBoost GBTree | SMOTETomek ===
#     F1 -> Acc=0.6273 | BalAcc=0.7047 | MacroF1=0.5748 | AUROC=0.8963 | PRAUC=0.7671
#     F2 -> Acc=0.6402 | BalAcc=0.7228 | MacroF1=0.5867 | AUROC=0.9015 | PRAUC=0.7701
#     F3 -> Acc=0.6595 | BalAcc=0.7381 | MacroF1=0.5971 | AUROC=0.8967 | PRAUC=0.7644
#     F4 -> Acc=0.6897 | BalAcc=0.7602 | MacroF1=0.6707 | AUROC=0.9009 | PRAUC=0.7751
#     F5 -> Acc=0.6425 | BalAcc=0.7166 | MacroF1=0.6270 | AUROC=0.8940 | PRAUC=0.7634
#   OK [XGBoost GBTree | resample] BalAcc=0.7285 MacroF1=0.6113 AUROC=0.8979 MCC=0.5393 (4.4s)
#
# === XGBoost GBTree | SMOTE ===
#     F1 -> Acc=0.6292 | BalAcc=0.7047 | MacroF1=0.5773 | AUROC=0.8962 | PRAUC=0.7662
#     F2 -> Acc=0.6436 | BalAcc=0.7438 | MacroF1=0.5930 | AUROC=0.9014 | PRAUC=0.7735
#     F3 -> Acc=0.6652 | BalAcc=0.7408 | MacroF1=0.6014 | AUROC=0.8968 | PRAUC=0.7653
#     F4 -> Acc=0.6883 | BalAcc=0.7604 | MacroF1=0.6666 | AUROC=0.8995 | PRAUC=0.7739
#     F5 -> Acc=0.6612 | BalAcc=0.7250 | MacroF1=0.6359 | AUROC=0.8951 | PRAUC=0.7644
#   OK [XGBoost GBTree | resample] BalAcc=0.7350 MacroF1=0.6148 AUROC=0.8978 MCC=0.5465 (4.7s)
#
# === XGBoost Dart | adjusted ===
#     F1 -> Acc=0.5845 | BalAcc=0.6792 | MacroF1=0.5388 | AUROC=0.8551 | PRAUC=0.6863
#     F2 -> Acc=0.5615 | BalAcc=0.6811 | MacroF1=0.5142 | AUROC=0.8686 | PRAUC=0.7066
#     F3 -> Acc=0.5048 | BalAcc=0.6609 | MacroF1=0.4756 | AUROC=0.8640 | PRAUC=0.6950
#     F4 -> Acc=0.5793 | BalAcc=0.6933 | MacroF1=0.5438 | AUROC=0.8650 | PRAUC=0.6993
#     F5 -> Acc=0.5286 | BalAcc=0.6713 | MacroF1=0.4918 | AUROC=0.8574 | PRAUC=0.6909
#   OK [XGBoost Dart | adjusted] BalAcc=0.6771 MacroF1=0.5128 AUROC=0.8620 MCC=0.4402 (15.0s)
#
# === XGBoost Dart | SMOTEENN ===
#     F1 -> Acc=0.5581 | BalAcc=0.6793 | MacroF1=0.5195 | AUROC=0.8643 | PRAUC=0.7067
#     F2 -> Acc=0.5572 | BalAcc=0.6726 | MacroF1=0.5095 | AUROC=0.8769 | PRAUC=0.7233
#     F3 -> Acc=0.5192 | BalAcc=0.6618 | MacroF1=0.4810 | AUROC=0.8712 | PRAUC=0.7057
#     F4 -> Acc=0.5783 | BalAcc=0.6979 | MacroF1=0.5420 | AUROC=0.8755 | PRAUC=0.7193
#     F5 -> Acc=0.5440 | BalAcc=0.6746 | MacroF1=0.5044 | AUROC=0.8681 | PRAUC=0.7078
#   OK [XGBoost Dart | resample] BalAcc=0.6773 MacroF1=0.5112 AUROC=0.8712 MCC=0.4352 (14.9s)
#
# === XGBoost Dart | SMOTETomek ===
#     F1 -> Acc=0.5903 | BalAcc=0.6894 | MacroF1=0.5455 | AUROC=0.8691 | PRAUC=0.7142
#     F2 -> Acc=0.5956 | BalAcc=0.6912 | MacroF1=0.5443 | AUROC=0.8805 | PRAUC=0.7301
#     F3 -> Acc=0.5259 | BalAcc=0.6689 | MacroF1=0.4874 | AUROC=0.8740 | PRAUC=0.7141
#     F4 -> Acc=0.5620 | BalAcc=0.6934 | MacroF1=0.5286 | AUROC=0.8762 | PRAUC=0.7207
#     F5 -> Acc=0.5469 | BalAcc=0.6775 | MacroF1=0.5078 | AUROC=0.8714 | PRAUC=0.7124
#   OK [XGBoost Dart | resample] BalAcc=0.6841 MacroF1=0.5227 AUROC=0.8742 MCC=0.4485 (14.9s)
#
# === XGBoost Dart | SMOTE ===
#     F1 -> Acc=0.5879 | BalAcc=0.6865 | MacroF1=0.5431 | AUROC=0.8691 | PRAUC=0.7155
#     F2 -> Acc=0.6023 | BalAcc=0.6957 | MacroF1=0.5503 | AUROC=0.8815 | PRAUC=0.7312
#     F3 -> Acc=0.5759 | BalAcc=0.6986 | MacroF1=0.5339 | AUROC=0.8739 | PRAUC=0.7129
#     F4 -> Acc=0.5841 | BalAcc=0.7101 | MacroF1=0.5479 | AUROC=0.8751 | PRAUC=0.7185
#     F5 -> Acc=0.5416 | BalAcc=0.6775 | MacroF1=0.5048 | AUROC=0.8720 | PRAUC=0.7125
#   OK [XGBoost Dart | resample] BalAcc=0.6937 MacroF1=0.5360 AUROC=0.8743 MCC=0.4654 (16.2s)
#
# === CatBoost | adjusted ===
#     F1 -> Acc=0.6441 | BalAcc=0.7404 | MacroF1=0.6078 | AUROC=0.8840 | PRAUC=0.7751
#     F2 -> Acc=0.6619 | BalAcc=0.7632 | MacroF1=0.6323 | AUROC=0.8919 | PRAUC=0.7808
#     F3 -> Acc=0.6508 | BalAcc=0.7542 | MacroF1=0.6301 | AUROC=0.8802 | PRAUC=0.7606
#     F4 -> Acc=0.6681 | BalAcc=0.7794 | MacroF1=0.6594 | AUROC=0.8923 | PRAUC=0.7836
#     F5 -> Acc=0.6295 | BalAcc=0.7482 | MacroF1=0.6168 | AUROC=0.8789 | PRAUC=0.7591
#   OK [CatBoost | adjusted] BalAcc=0.7571 MacroF1=0.6293 AUROC=0.8855 MCC=0.5486 (4.5s)
#
# === CatBoost | SMOTEENN ===
#     F1 -> Acc=0.6297 | BalAcc=0.7290 | MacroF1=0.5973 | AUROC=0.8809 | PRAUC=0.7691
#     F2 -> Acc=0.6575 | BalAcc=0.7481 | MacroF1=0.6246 | AUROC=0.8915 | PRAUC=0.7759
#     F3 -> Acc=0.6378 | BalAcc=0.7184 | MacroF1=0.6175 | AUROC=0.8834 | PRAUC=0.7651
#     F4 -> Acc=0.6508 | BalAcc=0.7627 | MacroF1=0.6382 | AUROC=0.8899 | PRAUC=0.7845
#     F5 -> Acc=0.6127 | BalAcc=0.7368 | MacroF1=0.6030 | AUROC=0.8791 | PRAUC=0.7618
#   OK [CatBoost | resample] BalAcc=0.7390 MacroF1=0.6161 AUROC=0.8849 MCC=0.5299 (5.1s)
#
# === CatBoost | SMOTETomek ===
#     F1 -> Acc=0.6393 | BalAcc=0.7357 | MacroF1=0.6228 | AUROC=0.8769 | PRAUC=0.7622
#     F2 -> Acc=0.6628 | BalAcc=0.7498 | MacroF1=0.6293 | AUROC=0.8925 | PRAUC=0.7803
#     F3 -> Acc=0.6407 | BalAcc=0.7221 | MacroF1=0.6134 | AUROC=0.8837 | PRAUC=0.7659
#     F4 -> Acc=0.6623 | BalAcc=0.7720 | MacroF1=0.6553 | AUROC=0.8922 | PRAUC=0.7860
#     F5 -> Acc=0.6343 | BalAcc=0.7493 | MacroF1=0.6242 | AUROC=0.8821 | PRAUC=0.7641
#   OK [CatBoost | resample] BalAcc=0.7458 MacroF1=0.6290 AUROC=0.8855 MCC=0.5413 (4.6s)
#
# === CatBoost | SMOTE ===
#     F1 -> Acc=0.6455 | BalAcc=0.7428 | MacroF1=0.6188 | AUROC=0.8811 | PRAUC=0.7714
#     F2 -> Acc=0.6580 | BalAcc=0.7533 | MacroF1=0.6351 | AUROC=0.8910 | PRAUC=0.7765
#     F3 -> Acc=0.6345 | BalAcc=0.7159 | MacroF1=0.6173 | AUROC=0.8803 | PRAUC=0.7557
#     F4 -> Acc=0.6508 | BalAcc=0.7599 | MacroF1=0.6383 | AUROC=0.8875 | PRAUC=0.7824
#     F5 -> Acc=0.6285 | BalAcc=0.7450 | MacroF1=0.6214 | AUROC=0.8780 | PRAUC=0.7555
#   OK [CatBoost | resample] BalAcc=0.7434 MacroF1=0.6262 AUROC=0.8836 MCC=0.5364 (4.3s)
#
# Done. 28 (model x strategi).

# %% [markdown]
# ## 6. Tabel Perbandingan

# %%
metric_cols = ['balanced_accuracy', 'macro_f1', 'accuracy', 'weighted_f1',
               'precision', 'recall', 'roc_auc', 'pr_auc', 'mcc', 'execution_time']
rows = [{'Model': r['model'], 'Strategy': r['strategy'],
         **{m: r[m] for m in metric_cols}} for r in all_results]
res_df = pd.DataFrame(rows)
res_df.to_csv(os.path.join(OUT_DIR, f'{STRATEGY}_metrics_long.csv'), index=False)
res_df.style.format({m: '{:.4f}' for m in metric_cols})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9d99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9d99_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a9d99_level0_col1" class="col_heading level0 col1" >Strategy</th>
#       <th id="T_a9d99_level0_col2" class="col_heading level0 col2" >balanced_accuracy</th>
#       <th id="T_a9d99_level0_col3" class="col_heading level0 col3" >macro_f1</th>
#       <th id="T_a9d99_level0_col4" class="col_heading level0 col4" >accuracy</th>
#       <th id="T_a9d99_level0_col5" class="col_heading level0 col5" >weighted_f1</th>
#       <th id="T_a9d99_level0_col6" class="col_heading level0 col6" >precision</th>
#       <th id="T_a9d99_level0_col7" class="col_heading level0 col7" >recall</th>
#       <th id="T_a9d99_level0_col8" class="col_heading level0 col8" >roc_auc</th>
#       <th id="T_a9d99_level0_col9" class="col_heading level0 col9" >pr_auc</th>
#       <th id="T_a9d99_level0_col10" class="col_heading level0 col10" >mcc</th>
#       <th id="T_a9d99_level0_col11" class="col_heading level0 col11" >execution_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9d99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9d99_row0_col0" class="data row0 col0" >SVC Linear</td>
#       <td id="T_a9d99_row0_col1" class="data row0 col1" >adjusted</td>
#       <td id="T_a9d99_row0_col2" class="data row0 col2" >0.4978</td>
#       <td id="T_a9d99_row0_col3" class="data row0 col3" >0.3605</td>
#       <td id="T_a9d99_row0_col4" class="data row0 col4" >0.3887</td>
#       <td id="T_a9d99_row0_col5" class="data row0 col5" >0.3987</td>
#       <td id="T_a9d99_row0_col6" class="data row0 col6" >0.5599</td>
#       <td id="T_a9d99_row0_col7" class="data row0 col7" >0.3887</td>
#       <td id="T_a9d99_row0_col8" class="data row0 col8" >0.6919</td>
#       <td id="T_a9d99_row0_col9" class="data row0 col9" >0.4826</td>
#       <td id="T_a9d99_row0_col10" class="data row0 col10" >0.2529</td>
#       <td id="T_a9d99_row0_col11" class="data row0 col11" >75.2389</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9d99_row1_col0" class="data row1 col0" >SVC Linear</td>
#       <td id="T_a9d99_row1_col1" class="data row1 col1" >SMOTEENN</td>
#       <td id="T_a9d99_row1_col2" class="data row1 col2" >0.5199</td>
#       <td id="T_a9d99_row1_col3" class="data row1 col3" >0.3696</td>
#       <td id="T_a9d99_row1_col4" class="data row1 col4" >0.3955</td>
#       <td id="T_a9d99_row1_col5" class="data row1 col5" >0.4036</td>
#       <td id="T_a9d99_row1_col6" class="data row1 col6" >0.5698</td>
#       <td id="T_a9d99_row1_col7" class="data row1 col7" >0.3955</td>
#       <td id="T_a9d99_row1_col8" class="data row1 col8" >0.7019</td>
#       <td id="T_a9d99_row1_col9" class="data row1 col9" >0.4910</td>
#       <td id="T_a9d99_row1_col10" class="data row1 col10" >0.2688</td>
#       <td id="T_a9d99_row1_col11" class="data row1 col11" >231.9958</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9d99_row2_col0" class="data row2 col0" >SVC Linear</td>
#       <td id="T_a9d99_row2_col1" class="data row2 col1" >SMOTETomek</td>
#       <td id="T_a9d99_row2_col2" class="data row2 col2" >0.5099</td>
#       <td id="T_a9d99_row2_col3" class="data row2 col3" >0.3671</td>
#       <td id="T_a9d99_row2_col4" class="data row2 col4" >0.3943</td>
#       <td id="T_a9d99_row2_col5" class="data row2 col5" >0.4032</td>
#       <td id="T_a9d99_row2_col6" class="data row2 col6" >0.5638</td>
#       <td id="T_a9d99_row2_col7" class="data row2 col7" >0.3943</td>
#       <td id="T_a9d99_row2_col8" class="data row2 col8" >0.7016</td>
#       <td id="T_a9d99_row2_col9" class="data row2 col9" >0.4913</td>
#       <td id="T_a9d99_row2_col10" class="data row2 col10" >0.2620</td>
#       <td id="T_a9d99_row2_col11" class="data row2 col11" >258.3319</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9d99_row3_col0" class="data row3 col0" >SVC Linear</td>
#       <td id="T_a9d99_row3_col1" class="data row3 col1" >SMOTE</td>
#       <td id="T_a9d99_row3_col2" class="data row3 col2" >0.5078</td>
#       <td id="T_a9d99_row3_col3" class="data row3 col3" >0.3662</td>
#       <td id="T_a9d99_row3_col4" class="data row3 col4" >0.3938</td>
#       <td id="T_a9d99_row3_col5" class="data row3 col5" >0.4031</td>
#       <td id="T_a9d99_row3_col6" class="data row3 col6" >0.5631</td>
#       <td id="T_a9d99_row3_col7" class="data row3 col7" >0.3938</td>
#       <td id="T_a9d99_row3_col8" class="data row3 col8" >0.7016</td>
#       <td id="T_a9d99_row3_col9" class="data row3 col9" >0.4914</td>
#       <td id="T_a9d99_row3_col10" class="data row3 col10" >0.2607</td>
#       <td id="T_a9d99_row3_col11" class="data row3 col11" >256.7139</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9d99_row4_col0" class="data row4 col0" >SVC Sigmoid</td>
#       <td id="T_a9d99_row4_col1" class="data row4 col1" >adjusted</td>
#       <td id="T_a9d99_row4_col2" class="data row4 col2" >0.2482</td>
#       <td id="T_a9d99_row4_col3" class="data row4 col3" >0.1685</td>
#       <td id="T_a9d99_row4_col4" class="data row4 col4" >0.1709</td>
#       <td id="T_a9d99_row4_col5" class="data row4 col5" >0.1932</td>
#       <td id="T_a9d99_row4_col6" class="data row4 col6" >0.3501</td>
#       <td id="T_a9d99_row4_col7" class="data row4 col7" >0.1709</td>
#       <td id="T_a9d99_row4_col8" class="data row4 col8" >0.6330</td>
#       <td id="T_a9d99_row4_col9" class="data row4 col9" >0.3933</td>
#       <td id="T_a9d99_row4_col10" class="data row4 col10" >0.0440</td>
#       <td id="T_a9d99_row4_col11" class="data row4 col11" >112.3215</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9d99_row5_col0" class="data row5 col0" >SVC Sigmoid</td>
#       <td id="T_a9d99_row5_col1" class="data row5 col1" >SMOTEENN</td>
#       <td id="T_a9d99_row5_col2" class="data row5 col2" >0.2350</td>
#       <td id="T_a9d99_row5_col3" class="data row5 col3" >0.1684</td>
#       <td id="T_a9d99_row5_col4" class="data row5 col4" >0.1760</td>
#       <td id="T_a9d99_row5_col5" class="data row5 col5" >0.2045</td>
#       <td id="T_a9d99_row5_col6" class="data row5 col6" >0.3392</td>
#       <td id="T_a9d99_row5_col7" class="data row5 col7" >0.1760</td>
#       <td id="T_a9d99_row5_col8" class="data row5 col8" >0.6316</td>
#       <td id="T_a9d99_row5_col9" class="data row5 col9" >0.3820</td>
#       <td id="T_a9d99_row5_col10" class="data row5 col10" >0.0353</td>
#       <td id="T_a9d99_row5_col11" class="data row5 col11" >388.5319</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9d99_row6_col0" class="data row6 col0" >SVC Sigmoid</td>
#       <td id="T_a9d99_row6_col1" class="data row6 col1" >SMOTETomek</td>
#       <td id="T_a9d99_row6_col2" class="data row6 col2" >0.2364</td>
#       <td id="T_a9d99_row6_col3" class="data row6 col3" >0.1705</td>
#       <td id="T_a9d99_row6_col4" class="data row6 col4" >0.1781</td>
#       <td id="T_a9d99_row6_col5" class="data row6 col5" >0.2069</td>
#       <td id="T_a9d99_row6_col6" class="data row6 col6" >0.3390</td>
#       <td id="T_a9d99_row6_col7" class="data row6 col7" >0.1781</td>
#       <td id="T_a9d99_row6_col8" class="data row6 col8" >0.6281</td>
#       <td id="T_a9d99_row6_col9" class="data row6 col9" >0.3796</td>
#       <td id="T_a9d99_row6_col10" class="data row6 col10" >0.0363</td>
#       <td id="T_a9d99_row6_col11" class="data row6 col11" >398.8645</td>
#     </tr>
#     <tr>
#       <th id="T_a9d99_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9d99_row7_col0" class="data row7 col0" >SVC Sigmoid</td>
#       <td id="T_a9d99_row7_col1" class="data row7 col1" >SMOTE</td>
#       <td id="T_a9d99_row7_col2" class="data row7 col2" >0.2356</td>
#       <td id="T_a9d99_

# %%
# Strategi terbaik per model (balanced_accuracy)
best = (res_df.sort_values('balanced_accuracy', ascending=False)
        .groupby('Model', sort=False).first()[['Strategy', 'balanced_accuracy', 'macro_f1', 'roc_auc', 'mcc']])
best = best.reindex([m for m in MODELS if m in best.index])
best.to_csv(os.path.join(OUT_DIR, f'{STRATEGY}_best_per_model.csv'))
log('Strategi terbaik per model (balanced_accuracy):')
for m, row in best.iterrows():
    log(f"  {m:<16s} -> {row['Strategy']:<12s} BalAcc={row['balanced_accuracy']:.4f} MacroF1={row['macro_f1']:.4f}")
best
# Out:
# Strategi terbaik per model (balanced_accuracy):
#   SVC Linear       -> SMOTEENN     BalAcc=0.5199 MacroF1=0.3696
#   SVC Sigmoid      -> adjusted     BalAcc=0.2482 MacroF1=0.1685
#   SVC Poly         -> SMOTE        BalAcc=0.5344 MacroF1=0.4394
#   SVC RBF          -> SMOTEENN     BalAcc=0.8166 MacroF1=0.7490
#   XGBoost GBTree   -> SMOTEENN     BalAcc=0.7387 MacroF1=0.6140
#   XGBoost Dart     -> SMOTE        BalAcc=0.6937 MacroF1=0.5360
#   CatBoost         -> adjusted     BalAcc=0.7571 MacroF1=0.6293
#                 Strategy  balanced_accuracy  macro_f1  roc_auc    mcc
# Model
# SVC Linear      SMOTEENN             0.5199    0.3696   0.7019 0.2688
# SVC Sigmoid     adjusted             0.2482    0.1685   0.6330 0.0440
# SVC Poly           SMOTE             0.5344    0.4394   0.7770 0.3328
# SVC RBF         SMOTEENN             0.8166    0.7490   0.9367 0.6578
# XGBoost GBTree  SMOTEENN             0.7387    0.6140   0.8977 0.5419
# XGBoost Dart       SMOTE             0.6937    0.5360   0.8743 0.4654
# CatBoost        adjusted             0.7571    0.6293   0.8855 0.5486

# %% [markdown]
# ## 7. Visual: Balanced Accuracy & Macro-F1 per strategi

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
for ax, metric, title in zip(axes, ['balanced_accuracy', 'macro_f1'],
                             ['Balanced Accuracy', 'Macro-F1']):
    sub = res_df.pivot(index='Model', columns='Strategy', values=metric)
    sub = sub.reindex(index=[m for m in MODELS if m in sub.index],
                      columns=[s for s in STRATEGIES if s in sub.columns])
    sub.plot(kind='bar', ax=ax)
    ax.set_title(f'{title} — adjusted vs {STRATEGY}'); ax.set_ylabel(title)
    ax.set_ylim(0, 1.0); ax.tick_params(axis='x', rotation=45)
    ax.grid(axis='y', alpha=0.3); ax.legend(fontsize=8)
plt.tight_layout()
fig.savefig(os.path.join(OUT_DIR, f'{STRATEGY}_bar_compare.png'), dpi=130, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Confusion Matrix Out-of-Fold
#
# Kolom = strategi (adjusted + tiap teknik); baris = model.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

by_model = {}
for r in all_results:
    by_model.setdefault(r['model'], {})[r['strategy']] = r
ordered = [m for m in MODELS if m in by_model]

ncols = len(STRATEGIES); nrows = len(ordered)
fig, axes = plt.subplots(nrows, ncols, figsize=(4.2 * ncols, 4 * nrows))
axes = np.atleast_2d(axes)
for i, name in enumerate(ordered):
    for j, strat in enumerate(STRATEGIES):
        ax = axes[i, j]; r = by_model[name].get(strat)
        if r is None:
            ax.axis('off'); continue
        cm = confusion_matrix(r['y_true'], r['y_pred'], labels=labels)
        ConfusionMatrixDisplay(cm, display_labels=class_names).plot(
            ax=ax, cmap='Blues', colorbar=False, values_format='d')
        ax.set_title(f"{name} | {strat}\nBalAcc={r['balanced_accuracy']:.3f}", fontsize=9)
        ax.tick_params(axis='x', rotation=45)
fig.suptitle(f'Confusion Matrix OOF — {STRATEGY}', fontsize=14)
fig.tight_layout()
fig.savefig(os.path.join(OUT_DIR, f'{STRATEGY}_confusion_matrices.png'), dpi=120, bbox_inches='tight')
plt.show()

# %%
for name in ordered:
    for strat in STRATEGIES:
        r = by_model[name].get(strat)
        if r is None: continue
        log('=' * 64); log(f'{name} | {strat}')
        log(classification_report(r['y_true'], r['y_pred'], labels=labels,
                                  target_names=class_names, zero_division=0))
# Out:
# ================================================================
# SVC Linear | adjusted
#               precision    recall  f1-score   support
#
#            A       0.20      0.61      0.31       927
#            B       0.17      0.74      0.27       229
#            C       0.36      0.59      0.45      2287
#            D       0.58      0.26      0.36      2317
#            E       0.74      0.29      0.42      4649
#
#     accuracy                           0.39     10409
#    macro avg       0.41      0.50      0.36     10409
# weighted avg       0.56      0.39      0.40     10409
#
# ================================================================
# SVC Linear | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.22      0.74      0.34       927
#            B       0.17      0.74      0.28       229
#            C       0.38      0.57      0.46      2287
#            D       0.58      0.26      0.36      2317
#            E       0.75      0.29      0.42      4649
#
#     accuracy                           0.40     10409
#    macro avg       0.42      0.52      0.37     10409
# weighted avg       0.57      0.40      0.40     10409
#
# ================================================================
# SVC Linear | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.21      0.67      0.33       927
#            B       0.17      0.74      0.28       229
#            C       0.37      0.58      0.45      2287
#            D       0.58      0.26      0.36      2317
#            E       0.74      0.30      0.42      4649
#
#     accuracy                           0.39     10409
#    macro avg       0.41      0.51      0.37     10409
# weighted avg       0.56      0.39      0.40     10409
#
# ================================================================
# SVC Linear | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.21      0.66      0.32       927
#            B       0.17      0.74      0.28       229
#            C       0.37      0.58      0.45      2287
#            D       0.58      0.26      0.36      2317
#            E       0.74      0.30      0.42      4649
#
#     accuracy                           0.39     10409
#    macro avg       0.41      0.51      0.37     10409
# weighted avg       0.56      0.39      0.40     10409
#
# ================================================================
# SVC Sigmoid | adjusted
#               precision    recall  f1-score   support
#
#            A       0.16      0.47      0.23       927
#            B       0.02      0.36      0.04       229
#            C       0.26      0.19      0.22      2287
#            D       0.35      0.09      0.15      2317
#            E       0.45      0.13      0.20      4649
#
#     accuracy                           0.17     10409
#    macro avg       0.25      0.25      0.17     10409
# weighted avg       0.35      0.17      0.19     10409
#
# ================================================================
# SVC Sigmoid | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.15      0.41      0.22       927
#            B       0.02      0.33      0.04       229
#            C       0.26      0.17      0.21      2287
#            D       0.29      0.09      0.14      2317
#            E       0.46      0.16      0.24      4649
#
#     accuracy                           0.18     10409
#    macro avg       0.23      0.23      0.17     10409
# weighted avg       0.34      0.18      0.20     10409
#
# ================================================================
# SVC Sigmoid | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.15      0.41      0.22       927
#            B       0.02      0.33      0.04       229
#            C       0.26      0.18      0.21      2287
#            D       0.28      0.10      0.14      2317
#            E       0.46      0.17      0.24      4649
#
#     accuracy                           0.18     10409
#    macro avg       0.23      0.24      0.17     10409
# weighted avg       0.34      0.18      0.21     10409
#
# ================================================================
# SVC Sigmoid | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.15      0.41      0.22       927
#            B       0.02      0.33      0.04       229
#            C       0.26      0.17      0.21      2287
#            D       0.28      0.10      0.14      2317
#            E       0.46      0.17      0.24      4649
#
#     accuracy                           0.18     10409
#    macro avg       0.23      0.24      0.17     10409
# weighted avg       0.34      0.18      0.21     10409
#
# ================================================================
# SVC Poly | adjusted
#               precision    recall  f1-score   support
#
#            A       0.48      0.38      0.43       927
#            B       0.25      0.81      0.38       229
#            C       0.31      0.91      0.46      2287
#            D       0.93      0.17      0.29      2317
#            E       0.86      0.31      0.45      4649
#
#     accuracy                           0.43     10409
#    macro avg       0.56      0.52      0.40     10409
# weighted avg       0.71      0.43      0.42     10409
#
# ================================================================
# SVC Poly | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.40      0.38      0.39       927
#            B       0.27      0.82      0.40       229
#            C       0.32      0.83      0.47      2287
#            D       0.70      0.23      0.35      2317
#            E       0.79      0.37      0.50      4649
#
#     accuracy                           0.45     10409
#    macro avg       0.50      0.53      0.42     10409
# weighted avg       0.62      0.45      0.45     10409
#
# ================================================================
# SVC Poly | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.51      0.38      0.44       927
#            B       0.27      0.82      0.40       229
#            C       0.33      0.84      0.47      2287
#            D       0.70      0.23      0.35      2317
#            E       0.78      0.40      0.53      4649
#
#     accuracy                           0.47     10409
#    macro avg       0.52      0.53      0.44     10409
# weighted avg       0.63      0.47      0.47     10409
#
# ================================================================
# SVC Poly | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.52      0.38      0.44       927
#            B       0.27      0.82      0.40       229
#            C       0.33      0.84      0.47      2287
#            D       0.70      0.23      0.35      2317
#            E       0.78      0.40      0.53      4649
#
#     accuracy                           0.47     10409
#    macro avg       0.52      0.53      0.44     10409
# weighted avg       0.63      0.47      0.47     10409
#
# ================================================================
# SVC RBF | adjusted
#               precision    recall  f1-score   support
#
#            A       0.49      0.80      0.61       927
#            B       0.85      1.00      0.92       229
#            C       0.56      0.98      0.71      2287
#            D       0.78      0.59      0.67      2317
#            E       0.96      0.59      0.73      4649
#
#     accuracy                           0.70     10409
#    macro avg       0.73      0.79      0.73     10409
# weighted avg       0.79      0.70      0.71     10409
#
# ================================================================
# SVC RBF | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.53      0.84      0.65       927
#            B       0.81      1.00      0.90       229
#            C       0.58      0.97      0.73      2287
#            D       0.80      0.66      0.72      2317
#            E       0.97      0.60      0.74      4649
#
#     accuracy                           0.73     10409
#    macro avg       0.74      0.82      0.75     10409
# weighted avg       0.80      0.73      0.73     10409
#
# ================================================================
# SVC RBF | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.54      0.83      0.66       927
#            B       0.80      1.00      0.89       229
#            C       0.58      0.98      0.73      2287
#            D       0.80      0.66      0.72      2317
#            E       0.97      0.60      0.74      4649
#
#     accuracy                           0.73     10409
#    macro avg       0.74      0.82      0.75     10409
# weighted avg       0.80      0.73      0.73     10409
#
# ================================================================
# SVC RBF | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.54      0.83      0.66       927
#            B       0.80      1.00      0.89       229
#            C       0.58      0.98      0.73      2287
#            D       0.80      0.66      0.72      2317
#            E       0.97      0.60      0.74      4649
#
#     accuracy                           0.73     10409
#    macro avg       0.74      0.82      0.75     10409
# weighted avg       0.80      0.73      0.73     10409
#
# ================================================================
# XGBoost GBTree | adjusted
#               precision    recall  f1-score   support
#
#            A       0.43      0.80      0.56       927
#            B       0.31      0.95      0.47       229
#            C       0.62      0.81      0.70      2287
#            D       0.62      0.46      0.53      2317
#            E       0.81      0.57      0.67      4649
#
#     accuracy                           0.63     10409
#    macro avg       0.56      0.72      0.59     10409
# weighted avg       0.68      0.63      0.63     10409
#
# ================================================================
# XGBoost GBTree | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.45      0.86      0.59       927
#            B       0.32      0.94      0.48       229
#            C       0.64      0.79      0.71      2287
#            D       0.64      0.50      0.56      2317
#            E       0.84      0.61      0.70      4649
#
#     accuracy                           0.65     10409
#    macro avg       0.58      0.74      0.61     10409
# weighted avg       0.71      0.65      0.66     10409
#
# ================================================================
# XGBoost GBTree | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.46      0.77      0.57       927
#            B       0.33      0.95      0.48       229
#            C       0.62      0.82      0.71      2287
#            D       0.65      0.49      0.56      2317
#            E       0.84      0.61      0.71      4649
#
#     accuracy                           0.65     10409
#    macro avg       0.58      0.73      0.61     10409
# weighted avg       0.70      0.65      0.66     10409
#
# ================================================================
# XGBoost GBTree | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.46      0.80      0.58       927
#            B       0.32      0.95      0.48       229
#            C       0.63      0.81      0.71      2287
#            D       0.66      0.50      0.57      2317
#            E       0.84      0.62      0.71      4649
#
#     accuracy                           0.66     10409
#    macro avg       0.58      0.73      0.61     10409
# weighted avg       0.71      0.66      0.66     10409
#
# ================================================================
# XGBoost Dart | adjusted
#               precision    recall  f1-score   support
#
#            A       0.38      0.81      0.52       927
#            B       0.21      0.94      0.34       229
#            C       0.56      0.75      0.64      2287
#            D       0.56      0.46      0.50      2317
#            E       0.84      0.43      0.57      4649
#
#     accuracy                           0.55     10409
#    macro avg       0.51      0.68      0.51     10409
# weighted avg       0.66      0.55      0.56     10409
#
# ================================================================
# XGBoost Dart | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.37      0.86      0.51       927
#            B       0.21      0.94      0.35       229
#            C       0.58      0.70      0.63      2287
#            D       0.54      0.42      0.47      2317
#            E       0.82      0.46      0.59      4649
#
#     accuracy                           0.55     10409
#    macro avg       0.50      0.68      0.51     10409
# weighted avg       0.65      0.55      0.56     10409
#
# ================================================================
# XGBoost Dart | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.40      0.80      0.53       927
#            B       0.22      0.96      0.36       229
#            C       0.58      0.78      0.66      2287
#            D       0.54      0.43      0.48      2317
#            E       0.82      0.46      0.59      4649
#
#     accuracy                           0.56     10409
#    macro avg       0.51      0.68      0.52     10409
# weighted avg       0.65      0.56      0.57     10409
#
# ================================================================
# XGBoost Dart | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.44      0.77      0.56       927
#            B       0.22      0.96      0.36       229
#            C       0.58      0.85      0.69      2287
#            D       0.54      0.43      0.48      2317
#            E       0.82      0.46      0.59      4649
#
#     accuracy                           0.58     10409
#    macro avg       0.52      0.69      0.54     10409
# weighted avg       0.66      0.58      0.58     10409
#
# ================================================================
# CatBoost | adjusted
#               precision    recall  f1-score   support
#
#            A       0.54      0.90      0.68       927
#            B       0.36      0.97      0.53       229
#            C       0.53      0.82      0.64      2287
#            D       0.74      0.53      0.62      2317
#            E       0.86      0.56      0.68      4649
#
#     accuracy                           0.65     10409
#    macro avg       0.61      0.76      0.63     10409
# weighted avg       0.72      0.65      0.65     10409
#
# ================================================================
# CatBoost | SMOTEENN
#               precision    recall  f1-score   support
#
#            A       0.53      0.90      0.67       927
#            B       0.36      0.94      0.52       229
#            C       0.51      0.81      0.63      2287
#            D       0.74      0.48      0.58      2317
#            E       0.84      0.56      0.67      4649
#
#     accuracy                           0.64     10409
#    macro avg       0.60      0.74      0.62     10409
# weighted avg       0.71      0.64      0.64     10409
#
# ================================================================
# CatBoost | SMOTETomek
#               precision    recall  f1-score   support
#
#            A       0.56      0.89      0.69       927
#            B       0.37      0.94      0.54       229
#            C       0.52      0.82      0.63      2287
#            D       0.74      0.51      0.61      2317
#            E       0.84      0.57      0.68      4649
#
#     accuracy                           0.65     10409
#    macro avg       0.61      0.75      0.63     10409
# weighted avg       0.71      0.65      0.65     10409
#
# ================================================================
# CatBoost | SMOTE
#               precision    recall  f1-score   support
#
#            A       0.58      0.87      0.70       927
#            B       0.37      0.95      0.54       229
#            C       0.51      0.83      0.63      2287
#            D       0.73      0.49      0.59      2317
#            E       0.84      0.56      0.67      4649
#
#     accuracy                           0.64     10409
#    macro avg       0.61      0.74      0.63     10409
# weighted avg       0.71      0.64      0.64     10409

# %% [markdown]
# ## 9. Learning Curve — cek Overfit / Underfit (tiap teknik)
#
# Grid: baris = model, kolom = teknik. Mode resample (classifier tanpa balanced). `probability=True` dipakai karena `scoring='neg_log_loss'` butuh `predict_proba` — tanpa ini SVC tak punya `predict_proba` sehingga skornya NaN dan kurva SVC kosong.

# %%
from sklearn.model_selection import learning_curve, StratifiedKFold

LC_TRAIN_SIZES = np.linspace(0.2, 1.0, 5)
LC_CV = 5; LC_SCORING = 'neg_log_loss'; LC_STATE = 42
groups_arr = np.asarray(groups)
techs = list(RESAMPLERS.keys())

lc = {}
for name in MODELS:
    for tech in techs:
        log(f'  > LC: {name} | {tech} ...')
        try:
            pipe = make_resample_pipeline(name, BEST_PARAMS[name], RESAMPLERS[tech],
                                          n_optimal, xgb_device=XGB_DEVICE, cat_task_type=CAT_TASK_TYPE, probability=True)
            ts, tr, va = learning_curve(
                pipe, X, y, train_sizes=LC_TRAIN_SIZES,
                cv=StratifiedKFold(LC_CV, shuffle=True, random_state=LC_STATE),
                scoring=LC_SCORING, n_jobs=1, shuffle=True, random_state=LC_STATE)
            lc[(name, tech)] = (ts, tr.mean(1), tr.std(1), va.mean(1), va.std(1))
        except Exception as e:
            log(f'    FAILED [{name}|{tech}] -> {type(e).__name__}: {e}')
log(f'LC selesai: {len(lc)} kurva.')
# Out:
#   > LC: SVC Linear | SMOTEENN ...
#   > LC: SVC Linear | SMOTETomek ...
#   > LC: SVC Linear | SMOTE ...
#   > LC: SVC Sigmoid | SMOTEENN ...
#   > LC: SVC Sigmoid | SMOTETomek ...
#   > LC: SVC Sigmoid | SMOTE ...
#   > LC: SVC Poly | SMOTEENN ...
#   > LC: SVC Poly | SMOTETomek ...
#   > LC: SVC Poly | SMOTE ...
#   > LC: SVC RBF | SMOTEENN ...
#   > LC: SVC RBF | SMOTETomek ...
#   > LC: SVC RBF | SMOTE ...
#   > LC: XGBoost GBTree | SMOTEENN ...
#   > LC: XGBoost GBTree | SMOTETomek ...
#   > LC: XGBoost GBTree | SMOTE ...
#   > LC: XGBoost Dart | SMOTEENN ...
#   > LC: XGBoost Dart | SMOTETomek ...
#   > LC: XGBoost Dart | SMOTE ...
#   > LC: CatBoost | SMOTEENN ...
#   > LC: CatBoost | SMOTETomek ...
#   > LC: CatBoost | SMOTE ...
# LC selesai: 21 kurva.

# %%
LC_BASELINE = float(np.log(len(np.unique(y))))   # log loss tebakan-acak (ambang verdict)
nrows = len(MODELS); ncols = len(techs)
fig, axes = plt.subplots(nrows, ncols, figsize=(5.2 * ncols, 3.6 * nrows), constrained_layout=True)
axes = np.atleast_2d(axes)
for i, name in enumerate(MODELS):
    for j, tech in enumerate(techs):
        ax = axes[i, j]
        if (name, tech) not in lc:
            ax.axis('off'); continue
        ts, trm, trs, vam, vas = lc[(name, tech)]
        trm, vam = -trm, -vam   # neg_log_loss → log loss (positif; makin kecil makin baik)
        ax.plot(ts, trm, 'o-', color='steelblue', lw=2, label='Train')
        ax.fill_between(ts, trm - trs, trm + trs, alpha=0.2, color='steelblue')
        ax.plot(ts, vam, 's-', color='darkorange', lw=2, label='Val')
        ax.fill_between(ts, vam - vas, vam + vas, alpha=0.2, color='darkorange')
        gap = vam[-1] - trm[-1]   # val_loss − train_loss (>0 → overfit)
        v = ('OVERFIT' if gap > 0.15 * LC_BASELINE else 'UNDERFIT' if vam[-1] > 0.80 * LC_BASELINE
             else 'Well-fit' if gap < 0.05 * LC_BASELINE and vam[-1] < 0.40 * LC_BASELINE else 'Mild gap')
        ax.set_title(f'{name} | {tech}\ngap={gap:+.3f} | {v}', fontsize=9, fontweight='bold')
        ax.set_ylim(bottom=0); ax.set_ylabel('log loss'); ax.grid(True, alpha=0.4); ax.legend(fontsize=7)
fig.suptitle(f'Learning Curve — {STRATEGY} (model tanpa balanced) | {LC_SCORING}',
             fontsize=13, fontweight='bold')
fig.savefig(os.path.join(OUT_DIR, f'{STRATEGY}_learning_curve.png'), dpi=110, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 10. Kurva Seluruh Metrik Evaluasi (Train vs Val)
#
# Learning curve untuk **semua** metrik sekaligus: **accuracy, precision, recall, f1 (macro)** dan **loss function (log loss)** terhadap ukuran data latih. Tiap (ukuran fold) di-*fit* sekali lalu kelima metrik dihitung bersama (lebih hemat daripada memanggil `learning_curve` per-metrik). Lingkup = teknik resampling (mode resample, classifier tanpa bobot), sama dengan Sel 9. Grid: baris = model, kolom = teknik.

# %%
from sklearn.metrics import (accuracy_score, precision_score, recall_score,
                             f1_score, log_loss)

# Pakai konfigurasi yg sama dgn Sel 9 (LC_TRAIN_SIZES, LC_CV, LC_STATE, techs).
CURVE_METRICS = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro', 'log_loss']

def _full_proba(pipe, Xset, labels):
    """Selaraskan kolom predict_proba ke urutan `labels` (isi 0 utk kelas yg tak
    dilatih di subset), lalu normalisasi -> aman utk log_loss & subset kecil."""
    proba = np.asarray(pipe.predict_proba(Xset), dtype=float)
    idx = {c: k for k, c in enumerate(labels)}
    full = np.zeros((proba.shape[0], len(labels)))
    for k, c in enumerate(pipe.classes_):
        full[:, idx[c]] = proba[:, k]
    s = full.sum(1, keepdims=True); s[s == 0] = 1.0
    return full / s

def _score_all(y_true, y_pred, y_proba, labels):
    return {
        'accuracy':        accuracy_score(y_true, y_pred),
        'precision_macro': precision_score(y_true, y_pred, average='macro', zero_division=0),
        'recall_macro':    recall_score(y_true, y_pred, average='macro', zero_division=0),
        'f1_macro':        f1_score(y_true, y_pred, average='macro', zero_division=0),
        'log_loss':        log_loss(y_true, y_proba, labels=labels),
    }

curves = {}   # (model, tech) -> metric -> (sizes, tr_mean, tr_std, va_mean, va_std)
skf_cv = StratifiedKFold(LC_CV, shuffle=True, random_state=LC_STATE)
nsz = len(LC_TRAIN_SIZES); min_n = len(np.unique(y))
for name in MODELS:
    for tech in techs:
        log(f'  > Kurva metrik: {name} | {tech} ...')
        tr = {m: [[] for _ in range(nsz)] for m in CURVE_METRICS}
        va = {m: [[] for _ in range(nsz)] for m in CURVE_METRICS}
        for tr_idx, va_idx in skf_cv.split(X, y):
            tr_idx = tr_idx.copy()
            np.random.RandomState(LC_STATE).shuffle(tr_idx)
            Xva, yva = X.iloc[va_idx], y[va_idx]
            for k, frac in enumerate(LC_TRAIN_SIZES):
                sub = tr_idx[:max(min_n, int(round(frac * len(tr_idx))))]
                Xsub, ysub = X.iloc[sub], y[sub]
                try:
                    pipe = make_resample_pipeline(
                        name, BEST_PARAMS[name], RESAMPLERS[tech], n_optimal,
                        xgb_device=XGB_DEVICE, cat_task_type=CAT_TASK_TYPE, probability=True)
                    pipe.fit(Xsub, ysub)
                    for Xset, yset, store in ((Xsub, ysub, tr), (Xva, yva, va)):
                        yp = np.ravel(pipe.predict(Xset))
                        sc = _score_all(yset, yp, _full_proba(pipe, Xset, labels), labels)
                        for m in CURVE_METRICS:
                            store[m][k].append(sc[m])
                except Exception as e:
                    for m in CURVE_METRICS:
                        tr[m][k].append(np.nan); va[m][k].append(np.nan)
                    log(f'    skip [{name}|{tech}|frac={frac:.2f}] -> {type(e).__name__}: {e}')
        curves[(name, tech)] = {
            m: (LC_TRAIN_SIZES,
                np.array([np.nanmean(tr[m][k]) for k in range(nsz)]),
                np.array([np.nanstd(tr[m][k])  for k in range(nsz)]),
                np.array([np.nanmean(va[m][k]) for k in range(nsz)]),
                np.array([np.nanstd(va[m][k])  for k in range(nsz)]))
            for m in CURVE_METRICS}
log(f'Kurva metrik selesai: {len(curves)} (model x teknik).')
# Out:
#   > Kurva metrik: SVC Linear | SMOTEENN ...
#   > Kurva metrik: SVC Linear | SMOTETomek ...
#   > Kurva metrik: SVC Linear | SMOTE ...
#   > Kurva metrik: SVC Sigmoid | SMOTEENN ...
#   > Kurva metrik: SVC Sigmoid | SMOTETomek ...
#   > Kurva metrik: SVC Sigmoid | SMOTE ...
#   > Kurva metrik: SVC Poly | SMOTEENN ...
#   > Kurva metrik: SVC Poly | SMOTETomek ...
#   > Kurva metrik: SVC Poly | SMOTE ...
#   > Kurva metrik: SVC RBF | SMOTEENN ...
#   > Kurva metrik: SVC RBF | SMOTETomek ...
#   > Kurva metrik: SVC RBF | SMOTE ...
#   > Kurva metrik: XGBoost GBTree | SMOTEENN ...
#   > Kurva metrik: XGBoost GBTree | SMOTETomek ...
#   > Kurva metrik: XGBoost GBTree | SMOTE ...
#   > Kurva metrik: XGBoost Dart | SMOTEENN ...
#   > Kurva metrik: XGBoost Dart | SMOTETomek ...
#   > Kurva metrik: XGBoost Dart | SMOTE ...
#   > Kurva metrik: CatBoost | SMOTEENN ...
#   > Kurva metrik: CatBoost | SMOTETomek ...
#   > Kurva metrik: CatBoost | SMOTE ...
# Kurva metrik selesai: 21 (model x teknik).

# %%
METRIC_TITLES = {'accuracy': 'Accuracy', 'precision_macro': 'Precision (macro)',
                 'recall_macro': 'Recall (macro)', 'f1_macro': 'F1 (macro)',
                 'log_loss': 'Log Loss'}
nrows, ncols = len(MODELS), len(techs)
for metric in CURVE_METRICS:
    fig, axes = plt.subplots(nrows, ncols, figsize=(5.2 * ncols, 3.6 * nrows),
                             constrained_layout=True)
    axes = np.atleast_2d(axes)
    for i, name in enumerate(MODELS):
        for j, tech in enumerate(techs):
            ax = axes[i, j]
            if (name, tech) not in curves:
                ax.axis('off'); continue
            ts, trm, trs, vam, vas = curves[(name, tech)][metric]
            ax.plot(ts, trm, 'o-', color='steelblue', lw=2, label='Train')
            ax.fill_between(ts, trm - trs, trm + trs, alpha=0.2, color='steelblue')
            ax.plot(ts, vam, 's-', color='darkorange', lw=2, label='Val')
            ax.fill_between(ts, vam - vas, vam + vas, alpha=0.2, color='darkorange')
            # selisih train vs val di fraksi data latih terbesar
            gap = trm[-1] - vam[-1]
            ax.set_title(f'{name} | {tech}\nTrain={trm[-1]:.3f} Val={vam[-1]:.3f} | selisih={gap:+.3f}',
                         fontsize=8, fontweight='bold')
            ax.set_xlabel('fraksi data latih'); ax.set_ylabel(METRIC_TITLES[metric])
            if metric == 'log_loss':
                ax.set_ylim(bottom=0)
            else:
                ax.set_ylim(0, 1.02)
            ax.grid(True, alpha=0.4); ax.legend(fontsize=7)
    fig.suptitle(f'Kurva {METRIC_TITLES[metric]} — {STRATEGY} (Train vs Val)',
                 fontsize=13, fontweight='bold')
    fig.savefig(os.path.join(OUT_DIR, f'{STRATEGY}_curve_{metric}.png'),
                dpi=110, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ### Selisih (gap) Train vs Val — tabel terpisah per metrik
#
# Satu tabel untuk tiap metrik (**Accuracy, Precision, Recall, F1**, dan Log Loss), berisi nilai `Train`, `Val`, dan `Selisih (Train-Val)` di fraksi data latih terbesar untuk tiap (model × teknik). Kolom `overfit_gap` menyeragamkan arah: **>0 = indikasi overfit** (skor = Train−Val; `log_loss` = Val−Train, karena loss makin kecil makin baik). Makin besar `overfit_gap`, makin lebar jurang train↔val.

# %%
# -- Tabel selisih (gap) Train vs Val, DIPISAH per metrik (fraksi data latih terbesar) --
gap_tables = {}
for metric in CURVE_METRICS:
    rows = []
    for (name, tech), mdict in curves.items():
        ts, trm, trs, vam, vas = mdict[metric]
        train_f, val_f = float(trm[-1]), float(vam[-1])
        train_s, val_s = float(trs[-1]), float(vas[-1])   # std antar-fold di fraksi terbesar
        selisih = train_f - val_f
        overfit_gap = (val_f - train_f) if metric == 'log_loss' else (train_f - val_f)
        rows.append({'Model': name, 'Teknik': tech,
                     'Train': train_f, 'Train_std': train_s,
                     'Val': val_f, 'Val_std': val_s,
                     'Selisih (Train-Val)': selisih, 'overfit_gap': overfit_gap})
    df = pd.DataFrame(rows)
    gap_tables[metric] = df
    df.to_csv(os.path.join(OUT_DIR, f'{STRATEGY}_gap_{metric}.csv'), index=False)
    log(f'[{METRIC_TITLES[metric]}] selisih train-val -> {STRATEGY}_gap_{metric}.csv')

# Tampilkan satu tabel per metrik: Train & Val sbg 'mean ± std' (overfit_gap diwarnai).
for metric in CURVE_METRICS:
    df = gap_tables[metric]
    disp = pd.DataFrame({'Model': df['Model'], 'Teknik': df['Teknik']})
    disp['Train'] = [f'{m:.4f} ± {s:.4f}' for m, s in zip(df['Train'], df['Train_std'])]
    disp['Val']   = [f'{m:.4f} ± {s:.4f}' for m, s in zip(df['Val'], df['Val_std'])]
    disp['Selisih (Train-Val)'] = df['Selisih (Train-Val)']
    disp['overfit_gap'] = df['overfit_gap']
    print('=' * 60)
    print(f'Metrik: {METRIC_TITLES[metric]}')
    display(disp.style.format({'Selisih (Train-Val)': '{:.4f}', 'overfit_gap': '{:.4f}'})
            .background_gradient(cmap='Reds', subset=['overfit_gap']))
# Out:
# [Accuracy] selisih train-val -> hybrid_gap_accuracy.csv
# [Precision (macro)] selisih train-val -> hybrid_gap_precision_macro.csv
# [Recall (macro)] selisih train-val -> hybrid_gap_recall_macro.csv
# [F1 (macro)] selisih train-val -> hybrid_gap_f1_macro.csv
# [Log Loss] selisih train-val -> hybrid_gap_log_loss.csv
# ============================================================
# Metrik: Accuracy
# <style type="text/css">
# #T_af640_row0_col5 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_af640_row1_col5 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_af640_row2_col5 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_af640_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_af640_row4_col5 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_af640_row5_col5 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_af640_row6_col5 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_af640_row7_col5 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_af640_row8_col5 {
#   background-color: #fdc7b2;
#   color: #000000;
# }
# #T_af640_row9_col5 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_af640_row10_col5 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_af640_row11_col5 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_af640_row12_col5 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_af640_row13_col5 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_af640_row14_col5 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_af640_row15_col5 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_af640_row16_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_af640_row17_col5 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_af640_row18_col5 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_af640_row19_col5 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_af640_row20_col5 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_af640">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af640_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_af640_level0_col1" class="col_heading level0 col1" >Teknik</th>
#       <th id="T_af640_level0_col2" class="col_heading level0 col2" >Train</th>
#       <th id="T_af640_level0_col3" class="col_heading level0 col3" >Val</th>
#       <th id="T_af640_level0_col4" class="col_heading level0 col4" >Selisih (Train-Val)</th>
#       <th id="T_af640_level0_col5" class="col_heading level0 col5" >overfit_gap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af640_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af640_row0_col0" class="data row0 col0" >SVC Linear</td>
#       <td id="T_af640_row0_col1" class="data row0 col1" >SMOTEENN</td>
#       <td id="T_af640_row0_col2" class="data row0 col2" >0.3921 ± 0.0032</td>
#       <td id="T_af640_row0_col3" class="data row0 col3" >0.3922 ± 0.0133</td>
#       <td id="T_af640_row0_col4" class="data row0 col4" >-0.0001</td>
#       <td id="T_af640_row0_col5" class="data row0 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af640_row1_col0" class="data row1 col0" >SVC Linear</td>
#       <td id="T_af640_row1_col1" class="data row1 col1" >SMOTETomek</td>
#       <td id="T_af640_row1_col2" class="data row1 col2" >0.3906 ± 0.0034</td>
#       <td id="T_af640_row1_col3" class="data row1 col3" >0.3897 ± 0.0110</td>
#       <td id="T_af640_row1_col4" class="data row1 col4" >0.0009</td>
#       <td id="T_af640_row1_col5" class="data row1 col5" >0.0009</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af640_row2_col0" class="data row2 col0" >SVC Linear</td>
#       <td id="T_af640_row2_col1" class="data row2 col1" >SMOTE</td>
#       <td id="T_af640_row2_col2" class="data row2 col2" >0.3903 ± 0.0032</td>
#       <td id="T_af640_row2_col3" class="data row2 col3" >0.3898 ± 0.0107</td>
#       <td id="T_af640_row2_col4" class="data row2 col4" >0.0006</td>
#       <td id="T_af640_row2_col5" class="data row2 col5" >0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af640_row3_col0" class="data row3 col0" >SVC Sigmoid</td>
#       <td id="T_af640_row3_col1" class="data row3 col1" >SMOTEENN</td>
#       <td id="T_af640_row3_col2" class="data row3 col2" >0.1774 ± 0.0062</td>
#       <td id="T_af640_row3_col3" class="data row3 col3" >0.1782 ± 0.0084</td>
#       <td id="T_af640_row3_col4" class="data row3 col4" >-0.0008</td>
#       <td id="T_af640_row3_col5" class="data row3 col5" >-0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_af640_row4_col0" class="data row4 col0" >SVC Sigmoid</td>
#       <td id="T_af640_row4_col1" class="data row4 col1" >SMOTETomek</td>
#       <td id="T_af640_row4_col2" class="data row4 col2" >0.1779 ± 0.0065</td>
#       <td id="T_af640_row4_col3" class="data row4 col3" >0.1781 ± 0.0084</td>
#       <td id="T_af640_row4_col4" class="data row4 col4" >-0.0002</td>
#       <td id="T_af640_row4_col5" class="data row4 col5" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_af640_row5_col0" class="data row5 col0" >SVC Sigmoid</td>
#       <td id="T_af640_row5_col1" class="data row5 col1" >SMOTE</td>
#       <td id="T_af640_row5_col2" class="data row5 col2" >0.1783 ± 0.0062</td>
#       <td id="T_af640_row5_col3" class="data row5 col3" >0.1784 ± 0.0085</td>
#       <td id="T_af640_row5_col4" class="data row5 col4" >-0.0001</td>
#       <td id="T_af640_row5_col5" class="data row5 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_af640_row6_col0" class="data row6 col0" >SVC Poly</td>
#       <td id="T_af640_row6_col1" class="data row6 col1" >SMOTEENN</td>
#       <td id="T_af640_row6_col2" class="data row6 col2" >0.4592 ± 0.0061</td>
#       <td id="T_af640_row6_col3" class="data row6 col3" >0.4591 ± 0.0070</td>
#       <td id="T_af640_row6_col4" class="data row6 col4" >0.0001</td>
#       <td id="T_af640_row6_col5" class="data row6 col5" >0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_af640_row7_col0" class="data row7 col0" >SVC Poly</td>
#       <td id="T_af640_row7_col1" class="data row7 col1" >SMOTETomek</td>
#       <td id="T_af640_row7_col2" class="data row7 col2" >0.4688 ± 0.0039</td>
#       <td id="T_af640_row7_col3" class="data row7 col3" >0.4669 ± 0.0078</td>
#       <td id="T_af640_row7_col4" class="data row7 col4" >0.0019</td>
#       <td id="T_af640_row7_col5" class="data row7 col5" >0.0019</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_af640_row8_col0" class="data row8 col0" >SVC Poly</td>
#       <td id="T_af640_row8_col1" class="data row8 col1" >SMOTE</td>
#       <td id="T_af640_row8_col2" class="data row8 col2" >0.4691 ± 0.0039</td>
#       <td id="T_af640_row8_col3" class="data row8 col3" >0.4677 ± 0.0077</td>
#       <td id="T_af640_row8_col4" class="data row8 col4" >0.0015</td>
#       <td id="T_af640_row8_col5" class="data row8 col5" >0.0015</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_af640_row9_col0" class="data row9 col0" >SVC RBF</td>
#       <td id="T_af640_row9_col1" class="data row9 col1" >SMOTEENN</td>
#       <td id="T_af640_row9_col2" class="data row9 col2" >0.7309 ± 0.0037</td>
#       <td id="T_af640_row9_col3" class="data row9 col3" >0.7300 ± 0.0139</td>
#       <td id="T_af640_row9_col4" class="data row9 col4" >0.0008</td>
#       <td id="T_af640_row9_col5" class="data row9 col5" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_af640_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_af640_row10_col0" class="data row10 col0" >SVC RBF</td>
#       <td id="T_af640_row10_col1" class="data row10 col1" >SMOTETomek</td>
#       <td id="T_af640_row10_col2" class="data row10 col2" >0.7307 ± 0.0040</td>
#       <td id="T_af640_row10_col3" class="data row10 col3" >0.7300 ± 0.0136</td>
#       <td id="T_af640_row10_col4" class="data row10 col4" >0.0006</td>
#       <td id="T_af640_row10_col5" class="data row10 col5" >0.0006</td>
#     </tr>
#     <tr>
# ============================================================
# Metrik: Precision (macro)
# <style type="text/css">
# #T_15930_row0_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_15930_row1_col5 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_15930_row2_col5 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_15930_row3_col5 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_15930_row4_col5 {
#   background-color: #fcc2aa;
#   color: #000000;
# }
# #T_15930_row5_col5, #T_15930_row10_col5 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_15930_row6_col5 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_15930_row7_col5 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_15930_row8_col5 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_15930_row9_col5 {
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_15930_row11_col5 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_15930_row12_col5 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_15930_row13_col5 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_15930_row14_col5 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_15930_row15_col5 {
#   background-color: #880811;
#   color: #f1f1f1;
# }
# #T_15930_row16_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_15930_row17_col5 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_15930_row18_col5 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_15930_row19_col5 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_15930_row20_col5 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_15930">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15930_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_15930_level0_col1" class="col_heading level0 col1" >Teknik</th>
#       <th id="T_15930_level0_col2" class="col_heading level0 col2" >Train</th>
#       <th id="T_15930_level0_col3" class="col_heading level0 col3" >Val</th>
#       <th id="T_15930_level0_col4" class="col_heading level0 col4" >Selisih (Train-Val)</th>
#       <th id="T_15930_level0_col5" class="col_heading level0 col5" >overfit_gap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15930_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15930_row0_col0" class="data row0 col0" >SVC Linear</td>
#       <td id="T_15930_row0_col1" class="data row0 col1" >SMOTEENN</td>
#       <td id="T_15930_row0_col2" class="data row0 col2" >0.4178 ± 0.0037</td>
#       <td id="T_15930_row0_col3" class="data row0 col3" >0.4187 ± 0.0085</td>
#       <td id="T_15930_row0_col4" class="data row0 col4" >-0.0008</td>
#       <td id="T_15930_row0_col5" class="data row0 col5" >-0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15930_row1_col0" class="data row1 col0" >SVC Linear</td>
#       <td id="T_15930_row1_col1" class="data row1 col1" >SMOTETomek</td>
#       <td id="T_15930_row1_col2" class="data row1 col2" >0.4125 ± 0.0038</td>
#       <td id="T_15930_row1_col3" class="data row1 col3" >0.4122 ± 0.0063</td>
#       <td id="T_15930_row1_col4" class="data row1 col4" >0.0003</td>
#       <td id="T_15930_row1_col5" class="data row1 col5" >0.0003</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15930_row2_col0" class="data row2 col0" >SVC Linear</td>
#       <td id="T_15930_row2_col1" class="data row2 col1" >SMOTE</td>
#       <td id="T_15930_row2_col2" class="data row2 col2" >0.4120 ± 0.0039</td>
#       <td id="T_15930_row2_col3" class="data row2 col3" >0.4119 ± 0.0059</td>
#       <td id="T_15930_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_15930_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15930_row3_col0" class="data row3 col0" >SVC Sigmoid</td>
#       <td id="T_15930_row3_col1" class="data row3 col1" >SMOTEENN</td>
#       <td id="T_15930_row3_col2" class="data row3 col2" >0.2388 ± 0.0032</td>
#       <td id="T_15930_row3_col3" class="data row3 col3" >0.2381 ± 0.0132</td>
#       <td id="T_15930_row3_col4" class="data row3 col4" >0.0007</td>
#       <td id="T_15930_row3_col5" class="data row3 col5" >0.0007</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_15930_row4_col0" class="data row4 col0" >SVC Sigmoid</td>
#       <td id="T_15930_row4_col1" class="data row4 col1" >SMOTETomek</td>
#       <td id="T_15930_row4_col2" class="data row4 col2" >0.2360 ± 0.0050</td>
#       <td id="T_15930_row4_col3" class="data row4 col3" >0.2347 ± 0.0126</td>
#       <td id="T_15930_row4_col4" class="data row4 col4" >0.0013</td>
#       <td id="T_15930_row4_col5" class="data row4 col5" >0.0013</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_15930_row5_col0" class="data row5 col0" >SVC Sigmoid</td>
#       <td id="T_15930_row5_col1" class="data row5 col1" >SMOTE</td>
#       <td id="T_15930_row5_col2" class="data row5 col2" >0.2361 ± 0.0051</td>
#       <td id="T_15930_row5_col3" class="data row5 col3" >0.2345 ± 0.0123</td>
#       <td id="T_15930_row5_col4" class="data row5 col4" >0.0016</td>
#       <td id="T_15930_row5_col5" class="data row5 col5" >0.0016</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_15930_row6_col0" class="data row6 col0" >SVC Poly</td>
#       <td id="T_15930_row6_col1" class="data row6 col1" >SMOTEENN</td>
#       <td id="T_15930_row6_col2" class="data row6 col2" >0.5059 ± 0.0120</td>
#       <td id="T_15930_row6_col3" class="data row6 col3" >0.5062 ± 0.0118</td>
#       <td id="T_15930_row6_col4" class="data row6 col4" >-0.0004</td>
#       <td id="T_15930_row6_col5" class="data row6 col5" >-0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_15930_row7_col0" class="data row7 col0" >SVC Poly</td>
#       <td id="T_15930_row7_col1" class="data row7 col1" >SMOTETomek</td>
#       <td id="T_15930_row7_col2" class="data row7 col2" >0.5207 ± 0.0074</td>
#       <td id="T_15930_row7_col3" class="data row7 col3" >0.5198 ± 0.0167</td>
#       <td id="T_15930_row7_col4" class="data row7 col4" >0.0009</td>
#       <td id="T_15930_row7_col5" class="data row7 col5" >0.0009</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_15930_row8_col0" class="data row8 col0" >SVC Poly</td>
#       <td id="T_15930_row8_col1" class="data row8 col1" >SMOTE</td>
#       <td id="T_15930_row8_col2" class="data row8 col2" >0.5213 ± 0.0076</td>
#       <td id="T_15930_row8_col3" class="data row8 col3" >0.5209 ± 0.0174</td>
#       <td id="T_15930_row8_col4" class="data row8 col4" >0.0004</td>
#       <td id="T_15930_row8_col5" class="data row8 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_15930_row9_col0" class="data row9 col0" >SVC RBF</td>
#       <td id="T_15930_row9_col1" class="data row9 col1" >SMOTEENN</td>
#       <td id="T_15930_row9_col2" class="data row9 col2" >0.7439 ± 0.0024</td>
#       <td id="T_15930_row9_col3" class="data row9 col3" >0.7414 ± 0.0160</td>
#       <td id="T_15930_row9_col4" class="data row9 col4" >0.0025</td>
#       <td id="T_15930_row9_col5" class="data row9 col5" >0.0025</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_15930_row10_col0" class="data row10 col0" >SVC RBF</td>
#       <td id="T_15930_row10_col1" class="data row10 col1" >SMOTETomek</td>
#       <td id="T_15930_row10_col2" class="data row10 col2" >0.7423 ± 0.0032</td>
#       <td id="T_15930_row10_col3" class="data row10 col3" >0.7407 ± 0.0157</td>
#       <td id="T_15930_row10_col4" class="data row10 col4" >0.0016</td>
#       <td id="T_15930_row10_col5" class="data row10 col5" >0.0016</td>
#     </tr>
#     <tr>
#       <th id="T_15930_level0_row11" class="row_heading lev
# ============================================================
# Metrik: Recall (macro)
# <style type="text/css">
# #T_c81a9_row0_col5 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_c81a9_row1_col5 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_c81a9_row2_col5 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# #T_c81a9_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_c81a9_row4_col5 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_c81a9_row5_col5 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_c81a9_row6_col5 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_c81a9_row7_col5 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_c81a9_row8_col5, #T_c81a9_row10_col5 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_c81a9_row9_col5 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_c81a9_row11_col5 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_c81a9_row12_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c81a9_row13_col5 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_c81a9_row14_col5 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_c81a9_row15_col5 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_c81a9_row16_col5 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_c81a9_row17_col5 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_c81a9_row18_col5 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_c81a9_row19_col5 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_c81a9_row20_col5 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c81a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c81a9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c81a9_level0_col1" class="col_heading level0 col1" >Teknik</th>
#       <th id="T_c81a9_level0_col2" class="col_heading level0 col2" >Train</th>
#       <th id="T_c81a9_level0_col3" class="col_heading level0 col3" >Val</th>
#       <th id="T_c81a9_level0_col4" class="col_heading level0 col4" >Selisih (Train-Val)</th>
#       <th id="T_c81a9_level0_col5" class="col_heading level0 col5" >overfit_gap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c81a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c81a9_row0_col0" class="data row0 col0" >SVC Linear</td>
#       <td id="T_c81a9_row0_col1" class="data row0 col1" >SMOTEENN</td>
#       <td id="T_c81a9_row0_col2" class="data row0 col2" >0.5116 ± 0.0110</td>
#       <td id="T_c81a9_row0_col3" class="data row0 col3" >0.5132 ± 0.0189</td>
#       <td id="T_c81a9_row0_col4" class="data row0 col4" >-0.0016</td>
#       <td id="T_c81a9_row0_col5" class="data row0 col5" >-0.0016</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c81a9_row1_col0" class="data row1 col0" >SVC Linear</td>
#       <td id="T_c81a9_row1_col1" class="data row1 col1" >SMOTETomek</td>
#       <td id="T_c81a9_row1_col2" class="data row1 col2" >0.4996 ± 0.0086</td>
#       <td id="T_c81a9_row1_col3" class="data row1 col3" >0.4990 ± 0.0117</td>
#       <td id="T_c81a9_row1_col4" class="data row1 col4" >0.0005</td>
#       <td id="T_c81a9_row1_col5" class="data row1 col5" >0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c81a9_row2_col0" class="data row2 col0" >SVC Linear</td>
#       <td id="T_c81a9_row2_col1" class="data row2 col1" >SMOTE</td>
#       <td id="T_c81a9_row2_col2" class="data row2 col2" >0.4986 ± 0.0093</td>
#       <td id="T_c81a9_row2_col3" class="data row2 col3" >0.4987 ± 0.0119</td>
#       <td id="T_c81a9_row2_col4" class="data row2 col4" >-0.0001</td>
#       <td id="T_c81a9_row2_col5" class="data row2 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c81a9_row3_col0" class="data row3 col0" >SVC Sigmoid</td>
#       <td id="T_c81a9_row3_col1" class="data row3 col1" >SMOTEENN</td>
#       <td id="T_c81a9_row3_col2" class="data row3 col2" >0.2373 ± 0.0100</td>
#       <td id="T_c81a9_row3_col3" class="data row3 col3" >0.2415 ± 0.0170</td>
#       <td id="T_c81a9_row3_col4" class="data row3 col4" >-0.0041</td>
#       <td id="T_c81a9_row3_col5" class="data row3 col5" >-0.0041</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c81a9_row4_col0" class="data row4 col0" >SVC Sigmoid</td>
#       <td id="T_c81a9_row4_col1" class="data row4 col1" >SMOTETomek</td>
#       <td id="T_c81a9_row4_col2" class="data row4 col2" >0.2357 ± 0.0111</td>
#       <td id="T_c81a9_row4_col3" class="data row4 col3" >0.2381 ± 0.0163</td>
#       <td id="T_c81a9_row4_col4" class="data row4 col4" >-0.0024</td>
#       <td id="T_c81a9_row4_col5" class="data row4 col5" >-0.0024</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c81a9_row5_col0" class="data row5 col0" >SVC Sigmoid</td>
#       <td id="T_c81a9_row5_col1" class="data row5 col1" >SMOTE</td>
#       <td id="T_c81a9_row5_col2" class="data row5 col2" >0.2358 ± 0.0110</td>
#       <td id="T_c81a9_row5_col3" class="data row5 col3" >0.2382 ± 0.0162</td>
#       <td id="T_c81a9_row5_col4" class="data row5 col4" >-0.0024</td>
#       <td id="T_c81a9_row5_col5" class="data row5 col5" >-0.0024</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c81a9_row6_col0" class="data row6 col0" >SVC Poly</td>
#       <td id="T_c81a9_row6_col1" class="data row6 col1" >SMOTEENN</td>
#       <td id="T_c81a9_row6_col2" class="data row6 col2" >0.5313 ± 0.0041</td>
#       <td id="T_c81a9_row6_col3" class="data row6 col3" >0.5311 ± 0.0089</td>
#       <td id="T_c81a9_row6_col4" class="data row6 col4" >0.0002</td>
#       <td id="T_c81a9_row6_col5" class="data row6 col5" >0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c81a9_row7_col0" class="data row7 col0" >SVC Poly</td>
#       <td id="T_c81a9_row7_col1" class="data row7 col1" >SMOTETomek</td>
#       <td id="T_c81a9_row7_col2" class="data row7 col2" >0.5354 ± 0.0038</td>
#       <td id="T_c81a9_row7_col3" class="data row7 col3" >0.5344 ± 0.0093</td>
#       <td id="T_c81a9_row7_col4" class="data row7 col4" >0.0010</td>
#       <td id="T_c81a9_row7_col5" class="data row7 col5" >0.0010</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c81a9_row8_col0" class="data row8 col0" >SVC Poly</td>
#       <td id="T_c81a9_row8_col1" class="data row8 col1" >SMOTE</td>
#       <td id="T_c81a9_row8_col2" class="data row8 col2" >0.5355 ± 0.0040</td>
#       <td id="T_c81a9_row8_col3" class="data row8 col3" >0.5347 ± 0.0094</td>
#       <td id="T_c81a9_row8_col4" class="data row8 col4" >0.0008</td>
#       <td id="T_c81a9_row8_col5" class="data row8 col5" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c81a9_row9_col0" class="data row9 col0" >SVC RBF</td>
#       <td id="T_c81a9_row9_col1" class="data row9 col1" >SMOTEENN</td>
#       <td id="T_c81a9_row9_col2" class="data row9 col2" >0.8188 ± 0.0035</td>
#       <td id="T_c81a9_row9_col3" class="data row9 col3" >0.8174 ± 0.0130</td>
#       <td id="T_c81a9_row9_col4" class="data row9 col4" >0.0014</td>
#       <td id="T_c81a9_row9_col5" class="data row9 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c81a9_row10_col0" class="data row10 col0" >SVC RBF</td>
#       <td id="T_c81a9_row10_col1" class="data row10 col1" >SMOTETomek</td>
#       <td id="T_c81a9_row10_col2" class="data row10 col2" >0.8177 ± 0.0036</td>
#       <td id="T_c81a9_row10_col3" class="data row10 col3" >0.8169 ± 0.0128</td>
#       <td id="T_c81a9_row10_col4" class="data row10 col4" >0.0008</td>
#       <td id="T_c81a9_row10_col5" class="data row10 col5" >0.0008</td>
#     </tr>
#     <tr>
#       <th id="T_c81a9_level0_row11" class="row_headi
# ============================================================
# Metrik: F1 (macro)
# <style type="text/css">
# #T_596da_row0_col5, #T_596da_row3_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_596da_row1_col5 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_596da_row2_col5, #T_596da_row6_col5 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_596da_row4_col5 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_596da_row5_col5 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_596da_row7_col5 {
#   background-color: #fdd1be;
#   color: #000000;
# }
# #T_596da_row8_col5 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_596da_row9_col5 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_596da_row10_col5 {
#   background-color: #fdc5ae;
#   color: #000000;
# }
# #T_596da_row11_col5 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_596da_row12_col5 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_596da_row13_col5 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_596da_row14_col5 {
#   background-color: #f5523a;
#   color: #f1f1f1;
# }
# #T_596da_row15_col5 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_596da_row16_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_596da_row17_col5 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_596da_row18_col5 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_596da_row19_col5 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_596da_row20_col5 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_596da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_596da_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_596da_level0_col1" class="col_heading level0 col1" >Teknik</th>
#       <th id="T_596da_level0_col2" class="col_heading level0 col2" >Train</th>
#       <th id="T_596da_level0_col3" class="col_heading level0 col3" >Val</th>
#       <th id="T_596da_level0_col4" class="col_heading level0 col4" >Selisih (Train-Val)</th>
#       <th id="T_596da_level0_col5" class="col_heading level0 col5" >overfit_gap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_596da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_596da_row0_col0" class="data row0 col0" >SVC Linear</td>
#       <td id="T_596da_row0_col1" class="data row0 col1" >SMOTEENN</td>
#       <td id="T_596da_row0_col2" class="data row0 col2" >0.3655 ± 0.0037</td>
#       <td id="T_596da_row0_col3" class="data row0 col3" >0.3661 ± 0.0134</td>
#       <td id="T_596da_row0_col4" class="data row0 col4" >-0.0006</td>
#       <td id="T_596da_row0_col5" class="data row0 col5" >-0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_596da_row1_col0" class="data row1 col0" >SVC Linear</td>
#       <td id="T_596da_row1_col1" class="data row1 col1" >SMOTETomek</td>
#       <td id="T_596da_row1_col2" class="data row1 col2" >0.3621 ± 0.0038</td>
#       <td id="T_596da_row1_col3" class="data row1 col3" >0.3617 ± 0.0093</td>
#       <td id="T_596da_row1_col4" class="data row1 col4" >0.0004</td>
#       <td id="T_596da_row1_col5" class="data row1 col5" >0.0004</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_596da_row2_col0" class="data row2 col0" >SVC Linear</td>
#       <td id="T_596da_row2_col1" class="data row2 col1" >SMOTE</td>
#       <td id="T_596da_row2_col2" class="data row2 col2" >0.3617 ± 0.0040</td>
#       <td id="T_596da_row2_col3" class="data row2 col3" >0.3616 ± 0.0092</td>
#       <td id="T_596da_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_596da_row2_col5" class="data row2 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_596da_row3_col0" class="data row3 col0" >SVC Sigmoid</td>
#       <td id="T_596da_row3_col1" class="data row3 col1" >SMOTEENN</td>
#       <td id="T_596da_row3_col2" class="data row3 col2" >0.1708 ± 0.0063</td>
#       <td id="T_596da_row3_col3" class="data row3 col3" >0.1714 ± 0.0072</td>
#       <td id="T_596da_row3_col4" class="data row3 col4" >-0.0006</td>
#       <td id="T_596da_row3_col5" class="data row3 col5" >-0.0006</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_596da_row4_col0" class="data row4 col0" >SVC Sigmoid</td>
#       <td id="T_596da_row4_col1" class="data row4 col1" >SMOTETomek</td>
#       <td id="T_596da_row4_col2" class="data row4 col2" >0.1711 ± 0.0067</td>
#       <td id="T_596da_row4_col3" class="data row4 col3" >0.1713 ± 0.0068</td>
#       <td id="T_596da_row4_col4" class="data row4 col4" >-0.0002</td>
#       <td id="T_596da_row4_col5" class="data row4 col5" >-0.0002</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_596da_row5_col0" class="data row5 col0" >SVC Sigmoid</td>
#       <td id="T_596da_row5_col1" class="data row5 col1" >SMOTE</td>
#       <td id="T_596da_row5_col2" class="data row5 col2" >0.1714 ± 0.0065</td>
#       <td id="T_596da_row5_col3" class="data row5 col3" >0.1715 ± 0.0068</td>
#       <td id="T_596da_row5_col4" class="data row5 col4" >-0.0001</td>
#       <td id="T_596da_row5_col5" class="data row5 col5" >-0.0001</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_596da_row6_col0" class="data row6 col0" >SVC Poly</td>
#       <td id="T_596da_row6_col1" class="data row6 col1" >SMOTEENN</td>
#       <td id="T_596da_row6_col2" class="data row6 col2" >0.4313 ± 0.0078</td>
#       <td id="T_596da_row6_col3" class="data row6 col3" >0.4313 ± 0.0090</td>
#       <td id="T_596da_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_596da_row6_col5" class="data row6 col5" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_596da_row7_col0" class="data row7 col0" >SVC Poly</td>
#       <td id="T_596da_row7_col1" class="data row7 col1" >SMOTETomek</td>
#       <td id="T_596da_row7_col2" class="data row7 col2" >0.4413 ± 0.0049</td>
#       <td id="T_596da_row7_col3" class="data row7 col3" >0.4401 ± 0.0114</td>
#       <td id="T_596da_row7_col4" class="data row7 col4" >0.0013</td>
#       <td id="T_596da_row7_col5" class="data row7 col5" >0.0013</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_596da_row8_col0" class="data row8 col0" >SVC Poly</td>
#       <td id="T_596da_row8_col1" class="data row8 col1" >SMOTE</td>
#       <td id="T_596da_row8_col2" class="data row8 col2" >0.4417 ± 0.0050</td>
#       <td id="T_596da_row8_col3" class="data row8 col3" >0.4406 ± 0.0115</td>
#       <td id="T_596da_row8_col4" class="data row8 col4" >0.0011</td>
#       <td id="T_596da_row8_col5" class="data row8 col5" >0.0011</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_596da_row9_col0" class="data row9 col0" >SVC RBF</td>
#       <td id="T_596da_row9_col1" class="data row9 col1" >SMOTEENN</td>
#       <td id="T_596da_row9_col2" class="data row9 col2" >0.7528 ± 0.0026</td>
#       <td id="T_596da_row9_col3" class="data row9 col3" >0.7504 ± 0.0159</td>
#       <td id="T_596da_row9_col4" class="data row9 col4" >0.0024</td>
#       <td id="T_596da_row9_col5" class="data row9 col5" >0.0024</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_596da_row10_col0" class="data row10 col0" >SVC RBF</td>
#       <td id="T_596da_row10_col1" class="data row10 col1" >SMOTETomek</td>
#       <td id="T_596da_row10_col2" class="data row10 col2" >0.7518 ± 0.0032</td>
#       <td id="T_596da_row10_col3" class="data row10 col3" >0.7501 ± 0.0157</td>
#       <td id="T_596da_row10_col4" class="data row10 col4" >0.0017</td>
#       <td id="T_596da_row10_col5" class="data row10 col5" >0.0017</td>
#     </tr>
#     <tr>
#       <th id="T_596da_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_596da_row1
# ============================================================
# Metrik: Log Loss
# <style type="text/css">
# #T_afcce_row0_col5 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_afcce_row1_col5 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_afcce_row2_col5 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_afcce_row3_col5 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_afcce_row4_col5 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_afcce_row5_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_afcce_row6_col5 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_afcce_row7_col5 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_afcce_row8_col5 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_afcce_row9_col5 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_afcce_row10_col5 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_afcce_row11_col5 {
#   background-color: #f44d38;
#   color: #f1f1f1;
# }
# #T_afcce_row12_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_afcce_row13_col5 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_afcce_row14_col5 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_afcce_row15_col5 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_afcce_row16_col5 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_afcce_row17_col5 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_afcce_row18_col5, #T_afcce_row19_col5 {
#   background-color: #fca588;
#   color: #000000;
# }
# #T_afcce_row20_col5 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# </style>
# <table id="T_afcce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afcce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_afcce_level0_col1" class="col_heading level0 col1" >Teknik</th>
#       <th id="T_afcce_level0_col2" class="col_heading level0 col2" >Train</th>
#       <th id="T_afcce_level0_col3" class="col_heading level0 col3" >Val</th>
#       <th id="T_afcce_level0_col4" class="col_heading level0 col4" >Selisih (Train-Val)</th>
#       <th id="T_afcce_level0_col5" class="col_heading level0 col5" >overfit_gap</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afcce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afcce_row0_col0" class="data row0 col0" >SVC Linear</td>
#       <td id="T_afcce_row0_col1" class="data row0 col1" >SMOTEENN</td>
#       <td id="T_afcce_row0_col2" class="data row0 col2" >1.2710 ± 0.0053</td>
#       <td id="T_afcce_row0_col3" class="data row0 col3" >1.2731 ± 0.0161</td>
#       <td id="T_afcce_row0_col4" class="data row0 col4" >-0.0021</td>
#       <td id="T_afcce_row0_col5" class="data row0 col5" >0.0021</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afcce_row1_col0" class="data row1 col0" >SVC Linear</td>
#       <td id="T_afcce_row1_col1" class="data row1 col1" >SMOTETomek</td>
#       <td id="T_afcce_row1_col2" class="data row1 col2" >1.2673 ± 0.0047</td>
#       <td id="T_afcce_row1_col3" class="data row1 col3" >1.2693 ± 0.0168</td>
#       <td id="T_afcce_row1_col4" class="data row1 col4" >-0.0020</td>
#       <td id="T_afcce_row1_col5" class="data row1 col5" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afcce_row2_col0" class="data row2 col0" >SVC Linear</td>
#       <td id="T_afcce_row2_col1" class="data row2 col1" >SMOTE</td>
#       <td id="T_afcce_row2_col2" class="data row2 col2" >1.2669 ± 0.0046</td>
#       <td id="T_afcce_row2_col3" class="data row2 col3" >1.2689 ± 0.0168</td>
#       <td id="T_afcce_row2_col4" class="data row2 col4" >-0.0020</td>
#       <td id="T_afcce_row2_col5" class="data row2 col5" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afcce_row3_col0" class="data row3 col0" >SVC Sigmoid</td>
#       <td id="T_afcce_row3_col1" class="data row3 col1" >SMOTEENN</td>
#       <td id="T_afcce_row3_col2" class="data row3 col2" >1.5034 ± 0.0030</td>
#       <td id="T_afcce_row3_col3" class="data row3 col3" >1.5048 ± 0.0061</td>
#       <td id="T_afcce_row3_col4" class="data row3 col4" >-0.0014</td>
#       <td id="T_afcce_row3_col5" class="data row3 col5" >0.0014</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_afcce_row4_col0" class="data row4 col0" >SVC Sigmoid</td>
#       <td id="T_afcce_row4_col1" class="data row4 col1" >SMOTETomek</td>
#       <td id="T_afcce_row4_col2" class="data row4 col2" >1.4987 ± 0.0029</td>
#       <td id="T_afcce_row4_col3" class="data row4 col3" >1.5000 ± 0.0059</td>
#       <td id="T_afcce_row4_col4" class="data row4 col4" >-0.0013</td>
#       <td id="T_afcce_row4_col5" class="data row4 col5" >0.0013</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_afcce_row5_col0" class="data row5 col0" >SVC Sigmoid</td>
#       <td id="T_afcce_row5_col1" class="data row5 col1" >SMOTE</td>
#       <td id="T_afcce_row5_col2" class="data row5 col2" >1.4982 ± 0.0032</td>
#       <td id="T_afcce_row5_col3" class="data row5 col3" >1.4995 ± 0.0062</td>
#       <td id="T_afcce_row5_col4" class="data row5 col4" >-0.0013</td>
#       <td id="T_afcce_row5_col5" class="data row5 col5" >0.0013</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_afcce_row6_col0" class="data row6 col0" >SVC Poly</td>
#       <td id="T_afcce_row6_col1" class="data row6 col1" >SMOTEENN</td>
#       <td id="T_afcce_row6_col2" class="data row6 col2" >1.1552 ± 0.0051</td>
#       <td id="T_afcce_row6_col3" class="data row6 col3" >1.1588 ± 0.0106</td>
#       <td id="T_afcce_row6_col4" class="data row6 col4" >-0.0035</td>
#       <td id="T_afcce_row6_col5" class="data row6 col5" >0.0035</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_afcce_row7_col0" class="data row7 col0" >SVC Poly</td>
#       <td id="T_afcce_row7_col1" class="data row7 col1" >SMOTETomek</td>
#       <td id="T_afcce_row7_col2" class="data row7 col2" >1.1442 ± 0.0039</td>
#       <td id="T_afcce_row7_col3" class="data row7 col3" >1.1476 ± 0.0115</td>
#       <td id="T_afcce_row7_col4" class="data row7 col4" >-0.0034</td>
#       <td id="T_afcce_row7_col5" class="data row7 col5" >0.0034</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_afcce_row8_col0" class="data row8 col0" >SVC Poly</td>
#       <td id="T_afcce_row8_col1" class="data row8 col1" >SMOTE</td>
#       <td id="T_afcce_row8_col2" class="data row8 col2" >1.1426 ± 0.0032</td>
#       <td id="T_afcce_row8_col3" class="data row8 col3" >1.1460 ± 0.0120</td>
#       <td id="T_afcce_row8_col4" class="data row8 col4" >-0.0034</td>
#       <td id="T_afcce_row8_col5" class="data row8 col5" >0.0034</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_afcce_row9_col0" class="data row9 col0" >SVC RBF</td>
#       <td id="T_afcce_row9_col1" class="data row9 col1" >SMOTEENN</td>
#       <td id="T_afcce_row9_col2" class="data row9 col2" >0.5390 ± 0.0074</td>
#       <td id="T_afcce_row9_col3" class="data row9 col3" >0.5451 ± 0.0237</td>
#       <td id="T_afcce_row9_col4" class="data row9 col4" >-0.0061</td>
#       <td id="T_afcce_row9_col5" class="data row9 col5" >0.0061</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_afcce_row10_col0" class="data row10 col0" >SVC RBF</td>
#       <td id="T_afcce_row10_col1" class="data row10 col1" >SMOTETomek</td>
#       <td id="T_afcce_row10_col2" class="data row10 col2" >0.5297 ± 0.0075</td>
#       <td id="T_afcce_row10_col3" class="data row10 col3" >0.5353 ± 0.0224</td>
#       <td id="T_afcce_row10_col4" class="data row10 col4" >-0.0056</td>
#       <td id="T_afcce_row10_col5" class="data row10 col5" >0.0056</td>
#     </tr>
#     <tr>
#       <th id="T_afcce_level0_row11" class="row_head

# %% [markdown]
# ## 11. Kesimpulan
#
# - **Tabel best-per-model (sel 6)**: strategi mana menang di tiap model.
# - Bandingkan SMOTEENN vs SMOTETomek vs SMOTE vs adjusted di bar chart & confusion matrix (recall kelas **B**).
# - Learning curve (sel 9): cek apakah hybrid bikin overfit (gap besar).
# - **Kurva seluruh metrik (sel 10)**: accuracy, precision, recall, F1 (macro), dan log loss Train vs Val terhadap ukuran data latih untuk tiap (model × teknik), plus tabel selisih (gap) per metrik (`overfit_gap` > 0 = indikasi overfit).
# - Semua dari `StratifiedKFold(Sampling_ID)` + resampling khusus fold training → bebas bocor.
#
# File hasil di `OUT_DIR` (CSV metrik, best-per-model, gap per metrik, PNG bar/CM/learning curve/kurva metrik).
