# %%
# !python -m pip install numpy pandas \
    qiskit-aer qiskit-algorithms qiskit-machine-learning qiskit-ibm-runtime \
    pylatexenc ucimlrepo \
    xgboost catboost seaborn libsvm-official
# Out:
# Requirement already satisfied: numpy in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (2.4.3)
# Requirement already satisfied: pandas in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (3.0.1)
# Requirement already satisfied: qiskit-aer in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (0.17.2)
# Requirement already satisfied: qiskit-algorithms in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (0.4.0)
# Requirement already satisfied: qiskit-machine-learning in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (0.9.0)
# Requirement already satisfied: qiskit-ibm-runtime in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (0.46.1)
# Requirement already satisfied: pylatexenc in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (2.10)
# Requirement already satisfied: ucimlrepo in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (0.0.7)
# Requirement already satisfied: xgboost in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (3.2.0)
# Requirement already satisfied: catboost in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (1.2.10)
# Requirement already satisfied: seaborn in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: libsvm-official in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (3.37.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arph\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-aer) (2.3.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-aer) (1.17.1)
# Requirement already satisfied: psutil>=5 in c:\users\arph\appdata\roaming\python\python313\site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-machine-learning) (1.8.0)
# Requirement already satisfied: setuptools>=40.1 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-machine-learning) (82.0.1)
# Requirement already satisfied: dill>=0.3.4 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-machine-learning) (0.4.1)
# Requirement already satisfied: requests>=2.32.4 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (2.33.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: urllib3>=2.4.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: ibm-platform-services>=0.55.3 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (0.74.0)
# Requirement already satisfied: ibm-quantum-schemas>=0.5.20260320 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (0.5.20260320)
# Requirement already satisfied: pydantic>=2.7.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (2.12.5)
# Requirement already satisfied: packaging in c:\users\arph\appdata\roaming\python\python313\site-packages (from qiskit-ibm-runtime) (26.0)
# Requirement already satisfied: pybase64>=1.4 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (1.4.3)
# Requirement already satisfied: samplomatic>=0.13.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from ucimlrepo) (2026.2.25)
# Requirement already satisfied: graphviz in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from catboost) (3.10.8)
# Requirement already satisfied: plotly in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from catboost) (6.6.0)
# Requirement already satisfied: six in c:\users\arph\appdata\roaming\python\python313\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (2.12.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: cryptography>=1.3 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.6)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Requirement already satisfied: sspilib>=0.3.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.5.0)
# Requirement already satisfied: orjson>=3.9.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from samplomatic>=0.13.0->qiskit-ibm-runtime) (3.11.8)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\arph\appdata\local\programs\python\python313\lib\site-packages (from plotly->catboost) (2.18.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
import os

# Add project root (210226) to Python path
sys.path.append(os.path.abspath(".."))

from utils.prepare_data import prepare_data

# %%
import warnings
from qiskit.transpiler import generate_preset_pass_manager
warnings.filterwarnings('ignore')

# %%
# from qiskit_ibm_runtime import QiskitRuntimeService
 
# QiskitRuntimeService.save_account(
#   token=token,
#   overwrite=True
# )

# %%
import sys
import importlib

def reload_package(package_name):
    modules_to_reload = [
        name for name in sys.modules
        if name.startswith(package_name)
    ]

    for name in sorted(modules_to_reload, reverse=True):
        importlib.reload(sys.modules[name])

# Usage
reload_package("model")
reload_package("utils")

# %%
dataset_path = '../dataset/Dataset_TehHijau.csv'
feature_cols = [
        "MQ3", 
        "TGS822", 
        "TGS2602", 
        "MQ5", 
        "MQ138", 
        "TGS2620", 
        "TGS813", 
        "TGS2600", 
        "TGS2611", 
        "TGS2603",
        "Humidity",
        "Celsius",
    ]
target_cols = "Kategori"

quantum_kernel_types = [
    'full', 
    'linear', 
    'circular', 
    'pauli_x', 
    'pauli_y', 
    'pauli_z'
]
kernel_types = [
    'linear', 
    'poly', 
    'rbf', 
    'sigmoid'
]

# %%
import pandas as pd
data = pd.read_csv(dataset_path)
data.head(10)
# Out:
#     MQ3  TGS822  TGS2602    MQ5  MQ138  TGS2620  TGS813  TGS2600  TGS2611  \
# 0  90.0    43.0     46.0  133.0   97.0     46.0   552.0    289.0    546.0
# 1  90.0    42.0     47.0  133.0   96.0     47.0   551.0    290.0    547.0
# 2  89.0    42.0     47.0  133.0   97.0     45.0   553.0    291.0    547.0
# 3  89.0    41.0     47.0  133.0   96.0     45.0   552.0    290.0    546.0
# 4  90.0    42.0     48.0  132.0   95.0     46.0   552.0    289.0    546.0
# 5  90.0    42.0     46.0  132.0   96.0     45.0   552.0    289.0    545.0
# 6  89.0    43.0     46.0  133.0   96.0     45.0   552.0    291.0    546.0
# 7  90.0    42.0     46.0  132.0   96.0     46.0   551.0    290.0    547.0
# 8  90.0    41.0     47.0  132.0   97.0     46.0   550.0    290.0    548.0
# 9  90.0    41.0     48.0  132.0   95.0     46.0   551.0    289.0    547.0
#
#    TGS2603  ...  Appearance_mean  Appearance_min Appearance_max  \
# 0    371.0  ...              2.8             2.8            2.8
# 1    371.0  ...              2.8             2.8            2.8
# 2    369.0  ...              2.8             2.8            2.8
# 3    370.0  ...              2.8             2.8            2.8
# 4    371.0  ...              2.8             2.8            2.8
# 5    370.0  ...              2.8             2.8            2.8
# 6    369.0  ...              2.8             2.8            2.8
# 7    370.0  ...              2.8             2.8            2.8
# 8    370.0  ...              2.8             2.8            2.8
# 9    371.0  ...              2.8             2.8            2.8
#
#   Appearance_std  Appearance_auc  Dreg_mean  Dreg_min  Dreg_max      Dreg_std  \
# 0   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 1   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 2   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 3   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 4   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 5   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 6   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 7   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 8   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
# 9   4.681111e-16            25.2        3.2       3.2       3.2  4.681111e-16
#
#   Dreg_auc
# 0     28.8
# 1     28.8
# 2     28.8
# 3     28.8
# 4     28.8
# 5     28.8
# 6     28.8
# 7     28.8
# 8     28.8
# 9     28.8
#
# [10 rows x 130 columns]

# %%
import matplotlib.pyplot as plt
data['Kategori'].hist()
plt.xlabel('Kategori')
plt.ylabel('Count')
plt.title('Histogram for the Kategori')
# Out:
# Text(0.5, 1.0, 'Histogram for the Kategori')

# %%
from utils.prepare_data import prepare_data
from model.evaluate import evaluate_svc, evaluate_xgboost, evaluate_catboost, evaluate_quantum, evaluate_libsvm

random_state = [10, 42, 100, 2021, 1234]
all_results = []

for state in random_state:
    print(f"Evaluating models with random state {state}")
    data = prepare_data(
        dataset_path=dataset_path, 
        feature_cols=feature_cols,
        target_cols=target_cols,
        random_state=state,
        manual=False,
        # manualDirPath =f"../dataset/manual/{state}",
    )

    model_outputs = {
        "SVC": evaluate_svc(data, kernel_types),
        "XGBoost": evaluate_xgboost(data, kernel_types),
        "CatBoost": evaluate_catboost(data, kernel_types),
        "Quantum": evaluate_quantum(data, quantum_kernel_types),
        "LibSVM": evaluate_libsvm(data, kernel_types)
    }

    for model_name, results in model_outputs.items():
        for r in results:
            r_copy = r.copy()
            r_copy["model"] = model_name
            r_copy["random_state"] = state
            all_results.append(r_copy)
# Out:
# Evaluating models with random state 10
# Evaluating models with random state 42
# Evaluating models with random state 100
# Evaluating models with random state 2021
# Evaluating models with random state 1234

# %%
import pandas as pd

df = pd.DataFrame(all_results)

summary = (
    df
    .groupby(["model", "kernel"])
    .agg(
        mean_accuracy=("accuracy", "mean"),
        std_accuracy=("accuracy", "std"),
        mean_f1=("f1-score", "mean"),
        std_f1=("f1-score", "std"),
        mean_val_acc=("val_accuracy", "mean"),
        std_val_acc=("val_accuracy", "std"),
        mean_total_time=("total_time", "mean")
    )
    .reset_index()
)

# %%
from utils.aggregate_result import aggregate_results
from utils.report import report
from utils.conf_matrix import plot_conf_matrix

# 1. Agregasi hasil
final_aggregated_results = aggregate_results(all_results)

# 2. Print tabel metrik
# (Pastikan fungsi report Anda di-update juga jika ingin print kolom 'model')
report(final_aggregated_results, data, is_aggregated=True)

# 3. Plot Grand Confusion Matrix
for result in final_aggregated_results:
    title = f"Aggregated CM: {result['model']} - Kernel {result['kernel']}"
    plot_conf_matrix(result['confusion_matrix_sum'], title=title)
# Out:
# N_train = 7286
# N_val   = 1561
# N_test  = 1562
#
# ======================================================================================================================================================
#
# === KOMPOSISI KELAS DATASET (Sample dari Run Terakhir) ===
#    Train  Validation  Test
# 4   3254         697   698
# 3   1622         347   348
# 2   1601         343   343
# 0    649         139   139
# 1    160          35    34
#
# ======================================================================================================================================================
#                                                                  PERFORMANCE SUMMARY
# ======================================================================================================================================================
# Model                | Val Acc    | Acc        | Prec       | Recall     | F1         | Total(s)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# SVC - Linear         | 0.529±0.008 | 0.524±0.008 | 0.459±0.010 | 0.524±0.008 | 0.429±0.010 | 3.63±0.09
# SVC - Poly           | 0.770±0.008 | 0.767±0.002 | 0.798±0.005 | 0.767±0.002 | 0.760±0.001 | 1.66±0.09
# SVC - Rbf            | 0.949±0.007 | 0.940±0.004 | 0.941±0.004 | 0.940±0.004 | 0.940±0.004 | 1.81±0.06
# SVC - Sigmoid        | 0.298±0.008 | 0.292±0.005 | 0.284±0.008 | 0.292±0.005 | 0.273±0.005 | 3.51±0.31
# XGBoost              | 0.984±0.002 | 0.986±0.003 | 0.986±0.003 | 0.986±0.003 | 0.986±0.003 | 1.82±0.22
# CatBoost             | 0.985±0.002 | 0.984±0.003 | 0.984±0.003 | 0.984±0.003 | 0.984±0.003 | 2.53±0.48
# Quantum - Full       | 0.982±0.002 | 0.981±0.003 | 0.982±0.003 | 0.981±0.003 | 0.981±0.003 | 950.34±49.48
# Quantum - Linear     | 0.966±0.006 | 0.968±0.003 | 0.969±0.002 | 0.968±0.003 | 0.968±0.003 | 960.84±16.86
# Quantum - Circular   | 0.973±0.008 | 0.977±0.004 | 0.978±0.004 | 0.977±0.004 | 0.977±0.004 | 974.35±5.48
# Quantum - Pauli_X    | 0.953±0.006 | 0.947±0.004 | 0.948±0.004 | 0.947±0.004 | 0.947±0.004 | 960.84±4.86
# Quantum - Pauli_Y    | 0.953±0.006 | 0.947±0.004 | 0.948±0.004 | 0.947±0.004 | 0.947±0.004 | 957.19±5.39
# Quantum - Pauli_Z    | 0.953±0.006 | 0.947±0.004 | 0.948±0.004 | 0.947±0.004 | 0.947±0.004 | 964.98±4.21
# LibSVM - Linear      | 0.525±0.005 | 0.521±0.005 | 0.483±0.011 | 0.521±0.005 | 0.410±0.007 | 2.98±0.09
# LibSVM - Poly        | 0.861±0.009 | 0.860±0.004 | 0.862±0.004 | 0.860±0.004 | 0.859±0.005 | 5.27±0.16
# LibSVM - Rbf         | 0.983±0.004 | 0.983±0.004 | 0.983±0.004 | 0.983±0.004 | 0.983±0.004 | 0.50±0.13
# LibSVM - Sigmoid     | 0.259±0.010 | 0.258±0.009 | 0.223±0.012 | 0.258±0.009 | 0.228±0.009 | 1.25±0.04
# ======================================================================================================================================================
